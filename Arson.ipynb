# %% [markdown]
# <a href="https://colab.research.google.com/github/dantecomedia/Video-Classifcation-using-Deep-Learning/blob/master/Arson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount("/content/gdrive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import numpy as np 
import pandas as pd
import os
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_files
import random
import shutil
# !pip install scikit-video
import numpy as np
from skvideo.io import FFmpegReader, ffprobe
from skvideo.utils import rgb2gray
from PIL import Image
from keras.preprocessing import image
from tqdm import tqdm
import matplotlib.pyplot as plt
from keras.utils import to_categorical
import matplotlib.pyplot as plt
from __future__ import absolute_import

from keras import backend as K
from keras import initializers
from keras import regularizers
from keras import constraints
from keras import layers
from keras.engine import InputSpec
from keras.utils import conv_utils
from keras.legacy.interfaces import conv3d_args_preprocessor, generate_legacy_interface
from keras.layers import Conv3D
from keras.backend.tensorflow_backend import _preprocess_padding, _preprocess_conv3d_input

import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv3D, MaxPooling3D, GlobalAveragePooling3D
from keras.layers.core import Dense
import tensorflow.keras.backend as K
from keras.callbacks import ModelCheckpoint
from keras.layers.core import Dropout
from sklearn.metrics import classification_report
# Out:
# Collecting scikit-video
#   Downloading https://files.pythonhosted.org/packages/b1/a6/c69cad508139a342810ae46e946ebb3256aa6e42f690d901bb68f50582e3/scikit_video-1.1.11-py2.py3-none-any.whl (2.3MB)
#      |████████████████████████████████| 2.3MB 4.9MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from scikit-video) (1.18.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from scikit-video) (7.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from scikit-video) (1.4.1)
# Installing collected packages: scikit-video
# Successfully installed scikit-video-1.1.11
# Using TensorFlow backend.

# %%
# !cp "/content/gdrive/My Drive/Security Dataset/Trimmed Dataset-20200612T201236Z-001.zip" "/content/"
# !unzip "/content/Trimmed Dataset-20200612T201236Z-001.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Trimmed Dataset/Burglary/Burglary011_x264_29.mp4
#   inflating: Trimmed Dataset/Arson/Arson034_x264_19.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_14.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_22.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest036_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_13.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary037_x264_22.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest017_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary014_x264_29.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_30.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary069_x264_11.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing018_x264_18.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary069_x264_2.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism044_x264_9.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism040_x264_3.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism045_x264_14.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing105_x264_14.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting036_x264_15.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism045_x264_8.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary007_x264_23.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest025_x264_13.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_5.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism035_x264_17.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing097_x264_11.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary089_x264_5.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary037_x264_30.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism040_x264_4.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism015_x264_17.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest009_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_12.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism002_x264_3.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary007_x264_18.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary015_x264_26.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_13.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing066_x264_14.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing106_x264_11.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents138_x264_11.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing018_x264_5.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest025_x264_21.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_6.mp4
#   inflating: Trimmed Dataset/Assault/Assault007_x264_31.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery066_x264_3.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing093_x264_19.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary015_x264_15.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_22.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing066_x264_15.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_21.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_2.mp4
#   inflating: Trimmed Dataset/Fighting/Fighting013_x264_29.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing094_x264_5.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary035_x264_5.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest038_x264_7.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_19.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing010_x264_30.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting029_x264_25.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary085_x264_6.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents036_x264_20.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary090_x264_8.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary021_x264_29.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest038_x264_18.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism002_x264_10.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism045_x264_12.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism047_x264_27.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_10.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing078_x264_30.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing093_x264_21.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary099_x264_5.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest013_x264_11.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_13.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents138_x264_22.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing018_x264_16.mp4
#   inflating: Trimmed Dataset/Shoplifting/Shoplifting022_x264_5.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary099_x264_4.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_29.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest036_x264_19.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing105_x264_9.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing097_x264_6.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents050_x264_10.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_18.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing008_x264_28.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism034_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary099_x264_2.mp4
#   inflating: Trimmed Dataset/Assault/Assault011_x264_18.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing009_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary014_x264_2.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing022_x264_15.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting022_x264_27.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing113_x264_25.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest009_x264_31.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism034_x264_19.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_12.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary036_x264_4.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing066_x264_17.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary036_x264_18.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism025_x264_3.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_17.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary037_x264_13.mp4
#   inflating: Trimmed Dataset/Assault/Assault004_x264_8.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary048_x264_10.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_10.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism035_x264_14.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing017_x264_21.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing066_x264_11.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_19.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing114_x264_2.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary069_x264_10.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary014_x264_0.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting019_x264_22.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing075_x264_29.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_22.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary069_x264_13.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary069_x264_31.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_27.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary099_x264_9.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary069_x264_30.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary099_x264_16.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_16.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_23.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary014_x264_10.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_12.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery053_x264_27.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing008_x264_30.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary011_x264_16.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting008_x264_12.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing017_x264_19.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_27.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism036_x264_18.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism004_x264_19.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_21.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism003_x264_19.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism034_x264_26.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism004_x264_2.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary055_x264_21.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing060_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary046_x264_12.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing078_x264_31.mp4
#   inflating: Trimmed Dataset/Explosion/Explosion026_x264_2.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_19.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_5.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_4.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_10.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_24.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing014_x264_7.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_20.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_28.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing075_x264_14.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery007_x264_9.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary036_x264_12.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting025_x264_12.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest036_x264_20.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary087_x264_14.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing108_x264_20.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest036_x264_28.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing101_x264_30.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism035_x264_6.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents036_x264_17.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary007_x264_2.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_11.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing017_x264_25.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing113_x264_28.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_9.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest040_x264_30.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing016_x264_27.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary022_x264_17.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing108_x264_31.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_4.mp4
#   inflating: Trimmed Dataset/Assault/Assault033_x264_22.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism045_x264_22.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_3.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism045_x264_11.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing015_x264_24.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism002_x264_12.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary015_x264_12.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing097_x264_8.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing078_x264_25.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_6.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_10.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents066_x264_8.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_30.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism013_x264_28.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary048_x264_14.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_7.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary037_x264_18.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_17.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary080_x264_10.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism035_x264_7.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism005_x264_27.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_11.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing008_x264_19.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_22.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_5.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_11.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest040_x264_29.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_15.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_11.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting030_x264_25.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_25.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism040_x264_28.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing097_x264_12.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents032_x264_21.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary015_x264_4.mp4
#   inflating: Trimmed Dataset/Normal/Robbery114_x264_22.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting041_x264_21.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary036_x264_5.mp4
#   inflating: Trimmed Dataset/Arson/Arson020_x264_27.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_18.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing097_x264_10.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary036_x264_23.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism045_x264_24.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing098_x264_30.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary074_x264_6.mp4
#   inflating: Trimmed Dataset/Shoplifting/Shoplifting048_x264_3.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary017_x264_25.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing018_x264_9.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing113_x264_29.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_24.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_31.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_20.mp4
#   inflating: Trimmed Dataset/Assault/Assault007_x264_11.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_17.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary048_x264_9.mp4
#   inflating: Trimmed Dataset/Assault/Assault017_x264_11.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_16.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting010_x264_22.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism001_x264_16.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism005_x264_23.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing037_x264_31.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary014_x264_31.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest009_x264_28.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism044_x264_25.mp4
#   inflating: Trimmed Dataset/Explosion/Explosion028_x264_9.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary035_x264_2.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_25.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_21.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest005_x264_20.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary015_x264_5.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_3.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing018_x264_17.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary074_x264_20.mp4
#   inflating: Trimmed Dataset/Shoplifting/Shoplifting025_x264_24.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_22.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing037_x264_24.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary021_x264_28.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest003_x264_28.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_8.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting007_x264_17.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing060_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary037_x264_14.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary011_x264_14.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse050_x264_24.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary014_x264_9.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest019_x264_14.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary089_x264_28.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism025_x264_2.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary011_x264_18.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing008_x264_18.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_7.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary048_x264_27.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary021_x264_3.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing113_x264_27.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest025_x264_26.mp4
#   inflating: Trimmed Dataset/Normal/Robbery066_x264_15.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism019_x264_17.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_24.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing108_x264_26.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing105_x264_8.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing060_x264_22.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary069_x264_27.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_11.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary090_x264_11.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest040_x264_27.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary099_x264_10.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse004_x264_3.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing105_x264_5.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing078_x264_24.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary026_x264_2.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism040_x264_9.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_9.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_26.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest040_x264_26.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest040_x264_20.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism034_x264_22.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary041_x264_19.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary015_x264_31.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_10.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism035_x264_5.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism045_x264_29.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing022_x264_22.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_4.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing113_x264_22.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_12.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing114_x264_7.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery029_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary080_x264_31.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary011_x264_1.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_19.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest025_x264_27.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary021_x264_7.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents126_x264_15.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism045_x264_20.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing066_x264_28.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse022_x264_9.mp4
#   inflating: Trimmed Dataset/Fighting/Fighting013_x264_22.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing006_x264_26.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest040_x264_25.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents032_x264_22.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing105_x264_11.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing008_x264_23.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary011_x264_6.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing105_x264_12.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing078_x264_27.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery053_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary069_x264_28.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary036_x264_31.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing037_x264_17.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_18.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_23.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest036_x264_9.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism005_x264_25.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing105_x264_7.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary074_x264_25.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest025_x264_24.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary037_x264_23.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_3.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism035_x264_9.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism035_x264_16.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary014_x264_3.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism044_x264_11.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary015_x264_30.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary074_x264_22.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary035_x264_10.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism002_x264_27.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_28.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing037_x264_8.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary085_x264_8.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing015_x264_26.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing112_x264_30.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing008_x264_31.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting042_x264_9.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting029_x264_17.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing018_x264_1.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary055_x264_31.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism044_x264_27.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing094_x264_7.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents031_x264_12.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary069_x264_6.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary015_x264_8.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary035_x264_4.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing044_x264_24.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents019_x264_31.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting030_x264_24.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_9.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing066_x264_9.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing008_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary041_x264_15.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism037_x264_12.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse027_x264_21.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing114_x264_13.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing112_x264_27.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary007_x264_13.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing112_x264_16.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse045_x264_1.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing011_x264_27.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_24.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary099_x264_25.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary085_x264_13.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse006_x264_30.mp4
#   inflating: Trimmed Dataset/Arson/Arson024_x264_20.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest040_x264_24.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery080_x264_9.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest032_x264_25.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest025_x264_29.mp4
#   inflating: Trimmed Dataset/Explosion/Explosion004_x264_5.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_14.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary007_x264_31.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents099_x264_16.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary048_x264_18.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing060_x264_21.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing018_x264_10.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing108_x264_23.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting005_x264_9.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary085_x264_17.mp4
#   inflating: Trimmed Dataset/Arson/Arson034_x264_24.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery136_x264_19.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism040_x264_10.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_9.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing078_x264_9.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism045_x264_16.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest025_x264_16.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism034_x264_28.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse027_x264_28.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary015_x264_14.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_16.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_28.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism034_x264_30.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary074_x264_24.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_31.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest024_x264_16.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism044_x264_16.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing112_x264_21.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_21.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary021_x264_9.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing114_x264_5.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing114_x264_11.mp4
#   inflating: Trimmed Dataset/Normal/Robbery007_x264_1.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary015_x264_3.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest036_x264_18.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_9.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing017_x264_18.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents019_x264_25.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary015_x264_16.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary014_x264_20.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing060_x264_27.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_15.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting007_x264_30.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary074_x264_31.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery129_x264_18.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing037_x264_12.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism036_x264_17.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents032_x264_8.mp4
#   inflating: Trimmed Dataset/Arson/Arson020_x264_31.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism047_x264_1.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary037_x264_20.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary011_x264_15.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery129_x264_22.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary089_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_18.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism036_x264_21.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary021_x264_27.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing010_x264_31.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing022_x264_19.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting011_x264_17.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism040_x264_1.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest036_x264_30.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism040_x264_5.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing081_x264_22.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary080_x264_23.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_25.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary069_x264_5.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary085_x264_10.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing078_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary036_x264_20.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism036_x264_20.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_14.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary017_x264_13.mp4
#   inflating: Trimmed Dataset/Assault/Assault009_x264_17.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary048_x264_22.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_19.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary055_x264_20.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_31.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing014_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_21.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents032_x264_24.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary024_x264_3.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest003_x264_24.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents032_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary036_x264_21.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary022_x264_24.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest036_x264_24.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_8.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing017_x264_22.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing044_x264_9.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing022_x264_18.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest042_x264_21.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_13.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_27.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_6.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_16.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing017_x264_12.mp4
#   inflating: Trimmed Dataset/Arson/Arson047_x264_18.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing112_x264_23.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing006_x264_27.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary014_x264_6.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing112_x264_14.mp4
#   inflating: Trimmed Dataset/Arson/Arson020_x264_23.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary015_x264_18.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary080_x264_7.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary022_x264_4.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary074_x264_18.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing022_x264_21.mp4
#   inflating: Trimmed Dataset/Assault/Assault028_x264_12.mp4
#   inflating: Trimmed Dataset/Arson/Arson024_x264_24.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary085_x264_5.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary022_x264_13.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing017_x264_15.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting020_x264_20.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary014_x264_22.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_27.mp4
#   inflating: Trimmed Dataset/Fighting/Fighting013_x264_17.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing078_x264_19.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents015_x264_21.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_23.mp4
#   inflating: Trimmed Dataset/Explosion/Explosion004_x264_3.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_20.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism045_x264_13.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_2.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism015_x264_19.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism030_x264_3.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism036_x264_19.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary074_x264_12.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing044_x264_21.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_28.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing114_x264_3.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest038_x264_30.mp4
#   inflating: Trimmed Dataset/Normal/Robbery111_x264_4.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_28.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_27.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest025_x264_20.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing101_x264_25.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing108_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary026_x264_12.mp4
#   inflating: Trimmed Dataset/Normal/Robbery114_x264_29.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery082_x264_17.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism045_x264_23.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing037_x264_1.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism040_x264_31.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing112_x264_31.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism035_x264_4.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism044_x264_15.mp4
#   inflating: Trimmed Dataset/Arson/Arson042_x264_26.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing018_x264_8.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary048_x264_12.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents145_x264_16.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_17.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary090_x264_9.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest040_x264_21.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing015_x264_30.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary089_x264_17.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary037_x264_21.mp4
#   inflating: Trimmed Dataset/Explosion/Explosion009_x264_12.mp4
#   inflating: Trimmed Dataset/Shoplifting/Shoplifting006_x264_27.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing018_x264_2.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_6.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest036_x264_25.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing113_x264_24.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest036_x264_22.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse043_x264_4.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse022_x264_13.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_31.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest025_x264_17.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_10.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse050_x264_21.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing017_x264_20.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents113_x264_21.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary080_x264_16.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing017_x264_17.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery029_x264_23.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest036_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary099_x264_17.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest009_x264_30.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing044_x264_7.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary048_x264_20.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary035_x264_7.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse043_x264_23.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing018_x264_6.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing078_x264_23.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism003_x264_20.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery082_x264_4.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary085_x264_12.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism040_x264_29.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism035_x264_2.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism037_x264_4.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing066_x264_8.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing078_x264_22.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary037_x264_5.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery100_x264_18.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing044_x264_28.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting007_x264_10.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary013_x264_22.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_22.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary099_x264_13.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest032_x264_13.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing075_x264_6.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_23.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing018_x264_19.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_20.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing060_x264_25.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_13.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing060_x264_20.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_3.mp4
#   inflating: Trimmed Dataset/Shoplifting/Shoplifting001_x264_9.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_4.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing101_x264_27.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary022_x264_22.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting026_x264_1.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing037_x264_2.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary021_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_6.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest040_x264_22.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing015_x264_27.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest001_x264_24.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism025_x264_8.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism035_x264_3.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting041_x264_16.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_12.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary069_x264_21.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism005_x264_22.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing112_x264_6.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary048_x264_11.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest003_x264_16.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_8.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism030_x264_4.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_24.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary019_x264_10.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism033_x264_19.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest025_x264_18.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary099_x264_29.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents141_x264_11.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing114_x264_12.mp4
#   inflating: Trimmed Dataset/Normal/Robbery114_x264_14.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary080_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary046_x264_28.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents140_x264_7.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing006_x264_28.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism004_x264_22.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing018_x264_4.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_22.mp4
#   inflating: Trimmed Dataset/Normal/Robbery007_x264_3.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary041_x264_28.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents048_x264_31.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest002_x264_23.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing097_x264_9.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism044_x264_19.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest013_x264_10.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing112_x264_12.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents018_x264_14.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary007_x264_11.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting036_x264_14.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary046_x264_18.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary099_x264_7.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_31.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary014_x264_7.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary015_x264_17.mp4
#   inflating: Trimmed Dataset/Shoplifting/Shoplifting049_x264_17.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary074_x264_17.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing112_x264_13.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_24.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary048_x264_25.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_8.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing050_x264_7.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_24.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism045_x264_7.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_2.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_11.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_19.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary015_x264_10.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse031_x264_26.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse026_x264_15.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism040_x264_2.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism005_x264_28.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing015_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary007_x264_15.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents011_x264_6.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_8.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing014_x264_18.mp4
#   inflating: Trimmed Dataset/Assault/Assault014_x264_10.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_7.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents091_x264_14.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism040_x264_0.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_8.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_19.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_25.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse013_x264_7.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing112_x264_7.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_18.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing051_x264_13.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary069_x264_23.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary011_x264_7.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery146_x264_21.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_9.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing051_x264_21.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism003_x264_15.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism036_x264_23.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_30.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing008_x264_25.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing113_x264_30.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary011_x264_10.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_14.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing050_x264_19.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary011_x264_3.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_31.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_9.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_16.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary053_x264_29.mp4
#   inflating: Trimmed Dataset/Assault/Assault014_x264_9.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_17.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents025_x264_29.mp4
#   inflating: Trimmed Dataset/Explosion/Explosion020_x264_4.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery136_x264_21.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing075_x264_9.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary037_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary021_x264_2.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing105_x264_13.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary055_x264_19.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary007_x264_12.mp4
#   inflating: Trimmed Dataset/Explosion/Explosion033_x264_27.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery100_x264_14.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing106_x264_12.mp4
#   inflating: Trimmed Dataset/Assault/Assault025_x264_13.mp4
#   inflating: Trimmed Dataset/Normal/Robbery094_x264_1.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_17.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism005_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary090_x264_18.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting031_x264_11.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_24.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism019_x264_18.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing078_x264_29.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents074_x264_16.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary007_x264_24.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing037_x264_7.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_25.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism036_x264_22.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing101_x264_29.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_8.mp4
#   inflating: Trimmed Dataset/Explosion/Explosion032_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary021_x264_1.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing114_x264_14.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing011_x264_25.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary037_x264_17.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest019_x264_10.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery080_x264_23.mp4
#   inflating: Trimmed Dataset/Normal/Robbery095_x264_31.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary037_x264_28.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_5.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_26.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing008_x264_20.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism035_x264_13.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing101_x264_28.mp4
#   inflating: Trimmed Dataset/Normal/Robbery004_x264_1.mp4
#   inflating: Trimmed Dataset/Normal/Robbery050_x264_10.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary011_x264_11.mp4
#   inflating: Trimmed Dataset/Normal/Robbery095_x264_23.mp4
#   inflating: Trimmed Dataset/Normal/Robbery063_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary087_x264_13.mp4
#   inflating: Trimmed Dataset/Normal/Robbery048_x264_13.mp4
#   inflating: Trimmed Dataset/Normal/Robbery004_x264_2.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest011_x264_23.mp4
#   inflating: Trimmed Dataset/Normal/Robbery063_x264_8.mp4
#   inflating: Trimmed Dataset/Normal/Robbery049_x264_9.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary074_x264_7.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism019_x264_19.mp4
#   inflating: Trimmed Dataset/Assault/Assault002_x264_4.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest025_x264_12.mp4
#   inflating: Trimmed Dataset/Normal/Robbery036_x264_16.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse023_x264_8.mp4
# ...
#   inflating: Trimmed Dataset/Robbery/Robbery009_x264_20.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery004_x264_12.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary051_x264_7.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest001_x264_21.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest038_x264_12.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery038_x264_31.mp4
#   inflating: Trimmed Dataset/Arson/Arson014_x264_18.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery015_x264_30.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery013_x264_8.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery146_x264_23.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery091_x264_26.mp4
#   inflating: Trimmed Dataset/Arson/Arson042_x264_23.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest041_x264_12.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism040_x264_6.mp4
#   inflating: Trimmed Dataset/Normal/Robbery078_x264_3.mp4
#   inflating: Trimmed Dataset/Assault/Assault022_x264_5.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery122_x264_23.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery041_x264_13.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery127_x264_20.mp4
#   inflating: Trimmed Dataset/Normal/Robbery045_x264_7.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest032_x264_14.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_5.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_5.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism034_x264_21.mp4
#   inflating: Trimmed Dataset/Normal/Robbery118_x264_30.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing070_x264_29.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery133_x264_16.mp4
#   inflating: Trimmed Dataset/Normal/Robbery038_x264_5.mp4
#   inflating: Trimmed Dataset/Arson/Arson027_x264_26.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing054_x264_30.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary041_x264_23.mp4
#   inflating: Trimmed Dataset/Normal/Robbery112_x264_4.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery078_x264_13.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing104_x264_12.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery007_x264_23.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse023_x264_5.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_19.mp4
#   inflating: Trimmed Dataset/Normal/Robbery110_x264_22.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary018_x264_23.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery065_x264_29.mp4
#   inflating: Trimmed Dataset/Normal/Robbery104_x264_7.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery103_x264_14.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery081_x264_6.mp4
#   inflating: Trimmed Dataset/Arson/Arson002_x264_12.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery025_x264_17.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_7.mp4
#   inflating: Trimmed Dataset/Normal/Robbery126_x264_7.mp4
#   inflating: Trimmed Dataset/Shoplifting/Shoplifting018_x264_23.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery129_x264_2.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse025_x264_12.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse037_x264_5.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary090_x264_7.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery007_x264_20.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery051_x264_10.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing052_x264_19.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery085_x264_18.mp4
#   inflating: Trimmed Dataset/Normal/Robbery110_x264_16.mp4
#   inflating: Trimmed Dataset/Assault/Assault037_x264_7.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing061_x264_13.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing106_x264_10.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery061_x264_11.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary012_x264_9.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse008_x264_6.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse021_x264_16.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery060_x264_2.mp4
#   inflating: Trimmed Dataset/Arson/Arson029_x264_23.mp4
#   inflating: Trimmed Dataset/Normal/Robbery038_x264_3.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery081_x264_17.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing087_x264_17.mp4
#   inflating: Trimmed Dataset/Assault/Assault004_x264_9.mp4
#   inflating: Trimmed Dataset/Normal/Robbery083_x264_3.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing044_x264_23.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse050_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_8.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery149_x264_10.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest004_x264_8.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery057_x264_30.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery058_x264_8.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest032_x264_6.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary046_x264_11.mp4
#   inflating: Trimmed Dataset/Assault/Assault033_x264_31.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery146_x264_28.mp4
#   inflating: Trimmed Dataset/Shoplifting/Shoplifting010_x264_12.mp4
#   inflating: Trimmed Dataset/Fighting/Fighting007_x264_28.mp4
#   inflating: Trimmed Dataset/Arson/Arson011_x264_7.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery041_x264_10.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery019_x264_25.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery060_x264_23.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents141_x264_7.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse024_x264_30.mp4
#   inflating: Trimmed Dataset/Normal/Robbery148_x264_30.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery020_x264_15.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery015_x264_17.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse048_x264_29.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery149_x264_13.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary004_x264_24.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery122_x264_20.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism028_x264_16.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing023_x264_15.mp4
#   inflating: Trimmed Dataset/Normal/Robbery130_x264_0.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery082_x264_20.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery066_x264_5.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery025_x264_9.mp4
#   inflating: Trimmed Dataset/Normal/Robbery048_x264_3.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest005_x264_10.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_10.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing094_x264_16.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse006_x264_26.mp4
#   inflating: Trimmed Dataset/Normal/Robbery105_x264_26.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting041_x264_18.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting031_x264_25.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery115_x264_8.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary012_x264_7.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery058_x264_13.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting030_x264_26.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents074_x264_15.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing042_x264_0.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery123_x264_9.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting030_x264_23.mp4
#   inflating: Trimmed Dataset/Arson/Arson023_x264_12.mp4
#   inflating: Trimmed Dataset/Assault/Assault011_x264_8.mp4
#   inflating: Trimmed Dataset/Arson/Arson029_x264_19.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse026_x264_12.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery038_x264_20.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse043_x264_6.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery145_x264_19.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting029_x264_30.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents031_x264_8.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery023_x264_6.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery077_x264_26.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents013_x264_25.mp4
#   inflating: Trimmed Dataset/Fighting/Fighting007_x264_27.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing074_x264_15.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery067_x264_10.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents107_x264_11.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents139_x264_16.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting026_x264_2.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism044_x264_14.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary021_x264_12.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery030_x264_11.mp4
#   inflating: Trimmed Dataset/Explosion/Explosion009_x264_30.mp4
#   inflating: Trimmed Dataset/Fighting/Fighting013_x264_27.mp4
#   inflating: Trimmed Dataset/Explosion/Explosion038_x264_1.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting036_x264_17.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery081_x264_23.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery057_x264_23.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism002_x264_1.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing107_x264_18.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery029_x264_21.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest048_x264_11.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery088_x264_7.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing002_x264_21.mp4
#   inflating: Trimmed Dataset/Explosion/Explosion038_x264_2.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse010_x264_4.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery004_x264_22.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting048_x264_23.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse044_x264_22.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery031_x264_19.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary077_x264_6.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary012_x264_13.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery146_x264_5.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse034_x264_8.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery043_x264_11.mp4
#   inflating: Trimmed Dataset/Arson/Arson047_x264_27.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing071_x264_14.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting018_x264_20.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary051_x264_0.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary074_x264_19.mp4
#   inflating: Trimmed Dataset/Normal/Robbery066_x264_13.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting028_x264_13.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing051_x264_12.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest009_x264_27.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest017_x264_11.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents138_x264_10.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary041_x264_21.mp4
#   inflating: Trimmed Dataset/Normal/Robbery066_x264_17.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism030_x264_22.mp4
#   inflating: Trimmed Dataset/Assault/Assault048_x264_8.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents130_x264_4.mp4
#   inflating: Trimmed Dataset/Normal/Robbery129_x264_8.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing023_x264_26.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing042_x264_16.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse043_x264_12.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism034_x264_25.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary069_x264_25.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse026_x264_21.mp4
#   inflating: Trimmed Dataset/Assault/Assault022_x264_6.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents067_x264_18.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing114_x264_9.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_23.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing021_x264_2.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse016_x264_25.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest038_x264_22.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery136_x264_28.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing042_x264_15.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary099_x264_1.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents048_x264_6.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse043_x264_21.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents016_x264_9.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse031_x264_24.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse048_x264_30.mp4
#   inflating: Trimmed Dataset/Assault/Assault013_x264_9.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing022_x264_23.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting029_x264_26.mp4
#   inflating: Trimmed Dataset/Normal/Robbery114_x264_20.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest005_x264_23.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing094_x264_9.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing037_x264_10.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting036_x264_10.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism034_x264_23.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing112_x264_28.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary048_x264_24.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest022_x264_24.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse026_x264_27.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing009_x264_30.mp4
#   inflating: Trimmed Dataset/Normal/Robbery099_x264_15.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents131_x264_7.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents031_x264_10.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing094_x264_18.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary013_x264_7.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting026_x264_11.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest017_x264_14.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting042_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_7.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents037_x264_16.mp4
#   inflating: Trimmed Dataset/Assault/Assault040_x264_16.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest017_x264_18.mp4
#   inflating: Trimmed Dataset/Normal/Robbery099_x264_21.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse041_x264_16.mp4
#   inflating: Trimmed Dataset/Normal/Robbery111_x264_3.mp4
#   inflating: Trimmed Dataset/Arson/Arson034_x264_28.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse044_x264_30.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse022_x264_16.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing003_x264_29.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery071_x264_15.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest002_x264_17.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest005_x264_13.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary090_x264_24.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest042_x264_24.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting007_x264_27.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest024_x264_17.mp4
#   inflating: Trimmed Dataset/Arson/Arson003_x264_28.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents057_x264_8.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse023_x264_11.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing026_x264_24.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism013_x264_25.mp4
#   inflating: Trimmed Dataset/Assault/Assault005_x264_20.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery051_x264_16.mp4
#   inflating: Trimmed Dataset/Arson/Arson028_x264_29.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents037_x264_13.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing075_x264_22.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest024_x264_29.mp4
#   inflating: Trimmed Dataset/Fighting/Fighting013_x264_9.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest004_x264_27.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse006_x264_28.mp4
#   inflating: Trimmed Dataset/Normal/Robbery094_x264_23.mp4

# %%
shutil.rmtree("/content/curated_dataset")

# %%
# !mkdir curated_dataset
# !cp -r "/content/Trimmed Dataset/Arson" "/content/curated_dataset"
# !cp -r "/content/Trimmed Dataset/Normal" "/content/curated_dataset"

# %%
import os
path="/content/curated_dataset/"
count=0
for i in os.listdir(path):
  count=0
  for j in os.listdir(path+str(i)):
    count=count+1
  print(i+":",count)
# Out:
# Arson: 314
# Normal: 1198

# %%
count=0
for i in os.listdir("/content/curated_dataset/Normal"):
  a=random.choice(os.listdir("/content/curated_dataset/Normal"))
  os.remove("/content/curated_dataset/Normal/"+str(a))
  count=count+1
  if count==884:
    break

# %%
raw_data=load_files(os.getcwd()+r'/curated_dataset/', shuffle=True)
files=raw_data['filenames']
targets=raw_data['target']

train_files, test_files, train_targets, test_targets=train_test_split(files, targets, test_size=1/3, random_state=191)

# %%
len(train_files)
# Out:
# 418

# %%
valid_files = train_files[318:]
valid_targets = train_targets[318:]

# Remaining data will be used for training the model
train_files = train_files[:318]
train_targets = train_targets[:318]

# Generic details about the data
print('Total number of videos:', len(files))
print('\nNumber of videos in training data:', train_files.shape[0])
print('Number of videos in validation data:', valid_files.shape[0])
print('Number of videos in test data:', test_files.shape[0])
# Out:
# Total number of videos: 628
#
# Number of videos in training data: 318
# Number of videos in validation data: 100
# Number of videos in test data: 210

# %%
print('The categorical labels are converted into integers.\nFollowing is the mapping - \n')
for label in zip(range(14), raw_data['target_names']):
    print(label)
# Out:
# The categorical labels are converted into integers.
# Following is the mapping -
#
# (0, 'Arson')
# (1, 'Normal')

# %%
for pair in zip(train_files[:5], train_targets[:5]):
    print(pair)
# Out:
# ('/content/curated_dataset/Normal/Robbery083_x264_2.mp4', 1)
# ('/content/curated_dataset/Normal/Robbery035_x264_20.mp4', 1)
# ('/content/curated_dataset/Arson/Arson002_x264_14.mp4', 0)
# ('/content/curated_dataset/Arson/Arson028_x264_31.mp4', 0)
# ('/content/curated_dataset/Normal/Robbery119_x264_20.mp4', 1)

# %%
class Videos(object):

    def __init__(self, target_size=None, to_gray=True, max_frames=None,
                 extract_frames='middle', required_fps=None,
                 normalize_pixels=None):
        """
        Initializing the config variables

        Parameters:
            target_size (tuple): (New_Width, New_Height), Default 'None'
                A tuple denoting the target width and height of each frame in each of the video

            to_gray (boolean): Default 'True'
                If True, then each frame will be converted to gray scale. Otherwise, not.

            max_frames (int): Default 'None'
                The maximum number of frames to return for each video.
                Extra frames are removed based on the value of 'extract_frames'.

            extract_frames (str): {'first', 'middle', 'last'}, Default 'middle'
                'first': Extract the first 'N' frames

                'last': Extract the last 'N' frames

                'middle': Extract 'N' frames from the middle
                    Remove ((total_frames - max_frames) // 2) frames from the beginning as well as the end

            required_fps (int): Default 'None'
                Capture 'N' frame(s) per second from the video.

                Only the first 'N' frame(s) for each second in the video are captured.

            normalize_pixels (tuple/str): Default 'None'
                If 'None', the pixels will not be normalized.

                If a tuple - (New_min, New_max) is passed, Min-max Normalization will be used.

                If the value is 'z-score', then Z-score Normalization will be used.
                For each pixel p, z_score = (p - mean) / std
        """

        self.target_size = target_size
        self.to_gray = to_gray
        self.max_frames = max_frames
        self.extract_frames = extract_frames
        self.required_fps = required_fps
        self.normalize_pixels = normalize_pixels
        self.fps = None

    def read_videos(self, paths):
        """
        Parameters:
            paths (list): Required
                 A list of paths of the videos to be read

        Returns:
            Numpy.ndarray
                A 5-d tensor with shape (<No. of Videos>, <No. of frames>, <height>, <width>, <channels>)
        """

        list_of_videos = [
            self._read_video(path) for path in tqdm(paths)
        ]

        tensor = np.vstack(list_of_videos)

        if self.normalize_pixels != None:
            # Pixels are normalized for each video individually
            if (type(self.normalize_pixels) == tuple) and (len(self.normalize_pixels) == 2):
                base = self.normalize_pixels[0]
                r = self.normalize_pixels[1] - base
                min_ = np.min(tensor, axis=(1, 2, 3), keepdims=True)
                max_ = np.max(tensor, axis=(1, 2, 3), keepdims=True)
                return ((tensor.astype('float32') - min_) / (max_ - min_)) * r + base

            elif self.normalize_pixels == 'z-score':
                mean = np.mean(tensor, axis=(1, 2, 3), keepdims=True)
                std = np.std(tensor, axis=(1, 2, 3), keepdims=True)
                return (tensor.astype('float32') - mean) / std
            
            else:
                raise ValueError('Invalid value of \'normalize_pixels\'')

        return tensor

    def get_frame_count(self, paths):
        """
        Can be used to determine the value of `max_frames`

        Parameters:
            paths (list): Required
                 A list of paths of the videos to be read

        Returns:
            dict (python dictionary)
                For each video, the total number of frames in that video is stored in the dictionary.
        """

        frame_count = {}
        for path in paths:
            cap = FFmpegReader(filename=path)
            frame_count[path] = cap.inputframenum
            cap.close()

        return frame_count

    def _read_video(self, path):
        """
        Parameters:
            path (str): Required
                Path of the video to be read

        Returns:
            Numpy.ndarray
                A 5-d tensor with shape (1, <No. of frames>, <height>, <width>, <channels>)
        """

        cap = FFmpegReader(filename=path)
        list_of_frames = []
        self.fps = int(cap.inputfps)                  # Frame Rate

        for index, frame in enumerate(cap.nextFrame()):

            capture_frame = True
            if self.required_fps != None:
                is_valid = range(self.required_fps)
                capture_frame = (index % self.fps) in is_valid

            if capture_frame:

                if self.target_size is not None:
                    temp_image = image.array_to_img(frame)
                    frame = image.img_to_array(
                        temp_image.resize(
                            self.target_size,
                            Image.ANTIALIAS)).astype('uint8')

                # Shape of each frame -> (<height>, <width>, 3)
                list_of_frames.append(frame)

        temp_video = np.stack(list_of_frames)
        cap.close()

        if self.to_gray:
            temp_video = rgb2gray(temp_video)
                
        if self.max_frames is not None:
            temp_video = self._process_video(video=temp_video)

        return np.expand_dims(temp_video, axis=0)

    def _process_video(self, video):
        """
        Parameters:
            video (Numpy.ndarray):
                Shape = (<No. of frames>, <height>, <width>, <channels>)

                Video whose frames are to be extracted

        Returns:
            Numpy.ndarray
                A tensor (processed video) with shape (<`max_frames`>, <height>, <width>, <channels>)
        """

        total_frames = video.shape[0]
        if self.max_frames <= total_frames:

            if self.extract_frames == 'first':
                video = video[:self.max_frames]
            elif self.extract_frames == 'last':
                video = video[(total_frames - self.max_frames):]
            elif self.extract_frames == 'middle':
                # No. of frames to remove from the front
                front = ((total_frames - self.max_frames) // 2) + 1
                video = video[front:(front + self.max_frames)]
            else:
                raise ValueError('Invalid value of \'extract_frames\'')

        else:
            raise IndexError(
                'Required number of frames is greater than the total number of frames in the video')

        return video

# %%
# The path of a sample video in the training data
sample_files = train_files[:1]

# An object of the class 'Videos'
reader = Videos(target_size=None, 
                to_gray=False)

# Loading the sample videos, in their original format
sample = reader.read_videos(sample_files)
print('\nShape of the sample data:', sample.shape)

# Displaying a frame from the sample video
plt.imshow(sample[0][29])
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  4.68it/s]
# Shape of the sample data: (1, 30, 240, 320, 3)

# %%
# An object of the class `Videos` to load the data in the required format
reader = Videos(target_size=(128, 128), 
                to_gray=True, 
                max_frames=29, 
                extract_frames='middle', 
                normalize_pixels=(0, 1))

# %%
# Reading training videos and one-hot encoding the training labels
X_train = reader.read_videos(train_files)
y_train = to_categorical(train_targets, num_classes=2)
print('Shape of training data:', X_train.shape)
print('Shape of training labels:', y_train.shape)
# Out:
# 100%|██████████| 318/318 [01:53<00:00,  2.80it/s]
# Shape of training data: (318, 29, 128, 128, 1)
# Shape of training labels: (318, 2)

# %%
# Reading validation videos and one-hot encoding the validation labels
X_valid = reader.read_videos(valid_files)
y_valid = to_categorical(valid_targets, num_classes=2)
print('Shape of validation data:', X_valid.shape)
print('Shape of validation labels:', y_valid.shape)
# Out:
# 100%|██████████| 100/100 [00:38<00:00,  2.59it/s]
# Shape of validation data: (100, 29, 128, 128, 1)
# Shape of validation labels: (100, 2)

# %%
X_test = reader.read_videos(test_files)
y_test = to_categorical(test_targets, num_classes=2)
print('Shape of testing data:', X_test.shape)
print('Shape of testing labels:', y_test.shape)
# Out:
# 100%|██████████| 210/210 [01:18<00:00,  2.69it/s]
# Shape of testing data: (210, 29, 128, 128, 1)
# Shape of testing labels: (210, 2)

# %%
# After pre-processing

# Displaying the first frame of the first processed video from the training data
plt.imshow(np.squeeze(X_train[0][0], axis=2), cmap='gray')

# %%
def depthwise_conv3d_args_preprocessor(args, kwargs):
    converted = []

    if 'init' in kwargs:
        init = kwargs.pop('init')
        kwargs['depthwise_initializer'] = init
        converted.append(('init', 'depthwise_initializer'))

    args, kwargs, _converted = conv3d_args_preprocessor(args, kwargs)
    return args, kwargs, converted + _converted

    legacy_depthwise_conv3d_support = generate_legacy_interface(
    allowed_positional_args=['filters', 'kernel_size'],
    conversions=[('nb_filter', 'filters'),
                 ('subsample', 'strides'),
                 ('border_mode', 'padding'),
                 ('dim_ordering', 'data_format'),
                 ('b_regularizer', 'bias_regularizer'),
                 ('b_constraint', 'bias_constraint'),
                 ('bias', 'use_bias')],
    value_conversions={'dim_ordering': {'tf': 'channels_last',
                                        'th': 'channels_first',
                                        'default': None}},
    preprocessor=depthwise_conv3d_args_preprocessor)


class DepthwiseConv3D(Conv3D):
    """Depthwise 3D convolution.
    Depth-wise part of separable convolutions consist in performing
    just the first step/operation
    (which acts on each input channel separately).
    It does not perform the pointwise convolution (second step).
    The `depth_multiplier` argument controls how many
    output channels are generated per input channel in the depthwise step.
    # Arguments
        kernel_size: An integer or tuple/list of 3 integers, specifying the
            depth, width and height of the 3D convolution window.
            Can be a single integer to specify the same value for
            all spatial dimensions.
        strides: An integer or tuple/list of 3 integers,
            specifying the strides of the convolution along the depth, width and height.
            Can be a single integer to specify the same value for
            all spatial dimensions.
        padding: one of `"valid"` or `"same"` (case-insensitive).
        depth_multiplier: The number of depthwise convolution output channels
            for each input channel.
            The total number of depthwise convolution output
            channels will be equal to `filterss_in * depth_multiplier`.
        groups: The depth size of the convolution (as a variant of the original Depthwise conv)
        data_format: A string,
            one of `channels_last` (default) or `channels_first`.
            The ordering of the dimensions in the inputs.
            `channels_last` corresponds to inputs with shape
            `(batch, height, width, channels)` while `channels_first`
            corresponds to inputs with shape
            `(batch, channels, height, width)`.
            It defaults to the `image_data_format` value found in your
            Keras config file at `~/.keras/keras.json`.
            If you never set it, then it will be "channels_last".
        activation: Activation function to use
            (see [activations](../activations.md)).
            If you don't specify anything, no activation is applied
            (ie. "linear" activation: `a(x) = x`).
        use_bias: Boolean, whether the layer uses a bias vector.
        depthwise_initializer: Initializer for the depthwise kernel matrix
            (see [initializers](../initializers.md)).
        bias_initializer: Initializer for the bias vector
            (see [initializers](../initializers.md)).
        depthwise_regularizer: Regularizer function applied to
            the depthwise kernel matrix
            (see [regularizer](../regularizers.md)).
        bias_regularizer: Regularizer function applied to the bias vector
            (see [regularizer](../regularizers.md)).
        dialation_rate: List of ints.
                        Defines the dilation factor for each dimension in the
                        input. Defaults to (1,1,1)
        activity_regularizer: Regularizer function applied to
            the output of the layer (its "activation").
            (see [regularizer](../regularizers.md)).
        depthwise_constraint: Constraint function applied to
            the depthwise kernel matrix
            (see [constraints](../constraints.md)).
        bias_constraint: Constraint function applied to the bias vector
            (see [constraints](../constraints.md)).
    # Input shape
        5D tensor with shape:
        `(batch, depth, channels, rows, cols)` if data_format='channels_first'
        or 5D tensor with shape:
        `(batch, depth, rows, cols, channels)` if data_format='channels_last'.
    # Output shape
        5D tensor with shape:
        `(batch, filters * depth, new_depth, new_rows, new_cols)` if data_format='channels_first'
        or 4D tensor with shape:
        `(batch, new_depth, new_rows, new_cols, filters * depth)` if data_format='channels_last'.
        `rows` and `cols` values might have changed due to padding.
    """

    #@legacy_depthwise_conv3d_support
    def __init__(self,
                 kernel_size,
                 strides=(1, 1, 1),
                 padding='valid',
                 depth_multiplier=1,
                 groups=None,
                 data_format=None,
                 activation=None,
                 use_bias=True,
                 depthwise_initializer='glorot_uniform',
                 bias_initializer='zeros',
                 dilation_rate = (1, 1, 1),
                 depthwise_regularizer=None,
                 bias_regularizer=None,
                 activity_regularizer=None,
                 depthwise_constraint=None,
                 bias_constraint=None,
                 **kwargs):
        super(DepthwiseConv3D, self).__init__(
            filters=None,
            kernel_size=kernel_size,
            strides=strides,
            padding=padding,
            data_format=data_format,
            activation=activation,
            use_bias=use_bias,
            bias_regularizer=bias_regularizer,
            dilation_rate=dilation_rate,
            activity_regularizer=activity_regularizer,
            bias_constraint=bias_constraint,
            **kwargs)
        self.depth_multiplier = depth_multiplier
        self.groups = groups
        self.depthwise_initializer = initializers.get(depthwise_initializer)
        self.depthwise_regularizer = regularizers.get(depthwise_regularizer)
        self.depthwise_constraint = constraints.get(depthwise_constraint)
        self.bias_initializer = initializers.get(bias_initializer)
        self.dilation_rate = dilation_rate
        self._padding = _preprocess_padding(self.padding)
        self._strides = (1,) + self.strides + (1,)
        self._data_format = "NDHWC"
        self.input_dim = None

    def build(self, input_shape):
        if len(input_shape) < 5:
            raise ValueError('Inputs to `DepthwiseConv3D` should have rank 5. '
                             'Received input shape:', str(input_shape))
        if self.data_format == 'channels_first':
            channel_axis = 1
        else:
            channel_axis = -1
        if input_shape[channel_axis] is None:
            raise ValueError('The channel dimension of the inputs to '
                             '`DepthwiseConv3D` '
                             'should be defined. Found `None`.')
        self.input_dim = int(input_shape[channel_axis])

        if self.groups is None:
            self.groups = self.input_dim

        if self.groups > self.input_dim:
            raise ValueError('The number of groups cannot exceed the number of channels')

        if self.input_dim % self.groups != 0:
            raise ValueError('Warning! The channels dimension is not divisible by the group size chosen')

        depthwise_kernel_shape = (self.kernel_size[0],
                                  self.kernel_size[1],
                                  self.kernel_size[2],
                                  self.input_dim,
                                  self.depth_multiplier)

        self.depthwise_kernel = self.add_weight(
            shape=depthwise_kernel_shape,
            initializer=self.depthwise_initializer,
            name='depthwise_kernel',
            regularizer=self.depthwise_regularizer,
            constraint=self.depthwise_constraint)

        if self.use_bias:
            self.bias = self.add_weight(shape=(self.groups * self.depth_multiplier,),
                                        initializer=self.bias_initializer,
                                        name='bias',
                                        regularizer=self.bias_regularizer,
                                        constraint=self.bias_constraint)
        else:
            self.bias = None
        # Set input spec.
        self.input_spec = InputSpec(ndim=5, axes={channel_axis: self.input_dim})
        self.built = True

    def call(self, inputs, training=None):
        inputs = _preprocess_conv3d_input(inputs, self.data_format)

        if self.data_format == 'channels_last':
            dilation = (1,) + self.dilation_rate + (1,)
        else:
            dilation = self.dilation_rate + (1,) + (1,)

        if self._data_format == 'NCDHW':
            outputs = tf.concat(
                [tf.nn.conv3d(inputs[0][:, i:i+self.input_dim//self.groups, :, :, :], self.depthwise_kernel[:, :, :, i:i+self.input_dim//self.groups, :],
                    strides=self._strides,
                    padding=self._padding,
                    dilations=dilation,
                    data_format=self._data_format) for i in range(0, self.input_dim, self.input_dim//self.groups)], axis=1)

        else:
            outputs = tf.concat(
                [tf.nn.conv3d(inputs[0][:, :, :, :, i:i+self.input_dim//self.groups], self.depthwise_kernel[:, :, :, i:i+self.input_dim//self.groups, :],
                    strides=self._strides,
                    padding=self._padding,
                    dilations=dilation,
                    data_format=self._data_format) for i in range(0, self.input_dim, self.input_dim//self.groups)], axis=-1)

        if self.bias is not None:
            outputs = K.bias_add(
                outputs,
                self.bias,
                data_format=self.data_format)

        if self.activation is not None:
            return self.activation(outputs)

        return outputs

    def compute_output_shape(self, input_shape):
        if self.data_format == 'channels_first':
            depth = input_shape[2]
            rows = input_shape[3]
            cols = input_shape[4]
            out_filters = self.groups * self.depth_multiplier
        elif self.data_format == 'channels_last':
            depth = input_shape[1]
            rows = input_shape[2]
            cols = input_shape[3]
            out_filters = self.groups * self.depth_multiplier

        depth = conv_utils.conv_output_length(depth, self.kernel_size[0],
                                             self.padding,
                                             self.strides[0])

        rows = conv_utils.conv_output_length(rows, self.kernel_size[1],
                                             self.padding,
                                             self.strides[1])

        cols = conv_utils.conv_output_length(cols, self.kernel_size[2],
                                             self.padding,
                                             self.strides[2])

        if self.data_format == 'channels_first':
            return (input_shape[0], out_filters, depth, rows, cols)

        elif self.data_format == 'channels_last':
            return (input_shape[0], depth, rows, cols, out_filters)

    def get_config(self):
        config = super(DepthwiseConv3D, self).get_config()
        config.pop('filters')
        config.pop('kernel_initializer')
        config.pop('kernel_regularizer')
        config.pop('kernel_constraint')
        config['depth_multiplier'] = self.depth_multiplier
        config['depthwise_initializer'] = initializers.serialize(self.depthwise_initializer)
        config['depthwise_regularizer'] = regularizers.serialize(self.depthwise_regularizer)
        config['depthwise_constraint'] = constraints.serialize(self.depthwise_constraint)
        return config

DepthwiseConvolution3D = DepthwiseConv3D

# %%
model = Sequential()

# Adding Alternate convolutional and pooling layers
model.add(Conv3D(filters=16, kernel_size=(10, 3, 3), strides=(1, 1, 1), padding='same', activation='relu', 
                 input_shape=X_train.shape[1:]))
model.add(MaxPooling3D(pool_size=2, strides=(1, 2, 2), padding='same'))

model.add(Conv3D(filters=64, kernel_size=(5, 3, 3), strides=(3, 1, 1), padding='valid', activation='relu'))
model.add(MaxPooling3D(pool_size=2, strides=(1, 2, 2), padding='same'))

model.add(Conv3D(filters=256, kernel_size=(5, 3, 3), strides=(3, 1, 1), padding='valid', activation='relu'))
model.add(MaxPooling3D(pool_size=2, strides=(1, 2, 2), padding='same'))

# A global average pooling layer to get a 1-d vector
# The vector will have a depth (same as number of elements in the vector) of 256
model.add(GlobalAveragePooling3D())

# The Global average pooling layer is followed by a fully-connected neural network, with one hidden and one output layer

# Hidden Layer
model.add(Dense(32, activation='relu'))

# Output layer
model.add(Dense(2, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_8 (Conv3D)            (None, 29, 128, 128, 16)  1456
# _________________________________________________________________
# max_pooling3d_26 (MaxPooling (None, 29, 64, 64, 16)    0
# _________________________________________________________________
# conv3d_9 (Conv3D)            (None, 9, 62, 62, 64)     46144
# _________________________________________________________________
# max_pooling3d_27 (MaxPooling (None, 9, 31, 31, 64)     0
# _________________________________________________________________
# conv3d_10 (Conv3D)           (None, 2, 29, 29, 256)    737536
# _________________________________________________________________
# max_pooling3d_28 (MaxPooling (None, 2, 15, 15, 256)    0
# _________________________________________________________________
# global_average_pooling3d_8 ( (None, 256)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 32)                8224
# _________________________________________________________________
# dense_16 (Dense)             (None, 2)                 66
# =================================================================
# Total params: 793,426
# Trainable params: 793,426
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint

# Compiling the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Saving the model that performed the best on the validation set
checkpoint = ModelCheckpoint(filepath='Model_arson_1.weights.best.hdf5', save_best_only=True, verbose=1)

# Training the model for 40 epochs
history = model.fit(X_train, y_train, batch_size=16, epochs=80, 
                    validation_data=(X_valid, y_valid), verbose=2, callbacks=[checkpoint])
# Out:
# Train on 318 samples, validate on 100 samples
# Epoch 1/80
#  - 6s - loss: 0.6980 - accuracy: 0.4937 - val_loss: 0.7028 - val_accuracy: 0.4800
#
# Epoch 00001: val_loss improved from inf to 0.70283, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 2/80
#  - 4s - loss: 0.6930 - accuracy: 0.5377 - val_loss: 0.6880 - val_accuracy: 0.4800
#
# Epoch 00002: val_loss improved from 0.70283 to 0.68801, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 3/80
#  - 4s - loss: 0.6749 - accuracy: 0.5283 - val_loss: 0.6736 - val_accuracy: 0.4900
#
# Epoch 00003: val_loss improved from 0.68801 to 0.67355, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 4/80
#  - 4s - loss: 0.6516 - accuracy: 0.5881 - val_loss: 0.6769 - val_accuracy: 0.6300
#
# Epoch 00004: val_loss did not improve from 0.67355
# Epoch 5/80
#  - 4s - loss: 0.6737 - accuracy: 0.5629 - val_loss: 0.6728 - val_accuracy: 0.6300
#
# Epoch 00005: val_loss improved from 0.67355 to 0.67276, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 6/80
#  - 4s - loss: 0.6601 - accuracy: 0.6164 - val_loss: 0.6324 - val_accuracy: 0.5600
#
# Epoch 00006: val_loss improved from 0.67276 to 0.63235, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 7/80
#  - 4s - loss: 0.6206 - accuracy: 0.5881 - val_loss: 0.6310 - val_accuracy: 0.7000
#
# Epoch 00007: val_loss improved from 0.63235 to 0.63104, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 8/80
#  - 4s - loss: 0.5848 - accuracy: 0.7107 - val_loss: 0.5664 - val_accuracy: 0.7200
#
# Epoch 00008: val_loss improved from 0.63104 to 0.56640, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 9/80
#  - 4s - loss: 0.6104 - accuracy: 0.6667 - val_loss: 0.5785 - val_accuracy: 0.7100
#
# Epoch 00009: val_loss did not improve from 0.56640
# Epoch 10/80
#  - 4s - loss: 0.5238 - accuracy: 0.7296 - val_loss: 0.5757 - val_accuracy: 0.7000
#
# Epoch 00010: val_loss did not improve from 0.56640
# Epoch 11/80
#  - 4s - loss: 0.5049 - accuracy: 0.7390 - val_loss: 0.5565 - val_accuracy: 0.7000
#
# Epoch 00011: val_loss improved from 0.56640 to 0.55653, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 12/80
#  - 4s - loss: 0.5068 - accuracy: 0.7484 - val_loss: 0.5197 - val_accuracy: 0.7500
#
# Epoch 00012: val_loss improved from 0.55653 to 0.51966, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 13/80
#  - 4s - loss: 0.4693 - accuracy: 0.7673 - val_loss: 0.5075 - val_accuracy: 0.7600
#
# Epoch 00013: val_loss improved from 0.51966 to 0.50745, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 14/80
#  - 4s - loss: 0.4565 - accuracy: 0.7956 - val_loss: 0.5090 - val_accuracy: 0.7300
#
# Epoch 00014: val_loss did not improve from 0.50745
# Epoch 15/80
#  - 4s - loss: 0.4817 - accuracy: 0.7862 - val_loss: 0.5775 - val_accuracy: 0.6900
#
# Epoch 00015: val_loss did not improve from 0.50745
# Epoch 16/80
#  - 4s - loss: 0.4534 - accuracy: 0.7673 - val_loss: 0.5006 - val_accuracy: 0.7500
#
# Epoch 00016: val_loss improved from 0.50745 to 0.50056, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 17/80
#  - 4s - loss: 0.4104 - accuracy: 0.8145 - val_loss: 0.4720 - val_accuracy: 0.7600
#
# Epoch 00017: val_loss improved from 0.50056 to 0.47201, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 18/80
#  - 4s - loss: 0.4229 - accuracy: 0.7799 - val_loss: 0.4503 - val_accuracy: 0.8300
#
# Epoch 00018: val_loss improved from 0.47201 to 0.45032, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 19/80
#  - 4s - loss: 0.3661 - accuracy: 0.8333 - val_loss: 0.4159 - val_accuracy: 0.7900
#
# Epoch 00019: val_loss improved from 0.45032 to 0.41589, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 20/80
#  - 4s - loss: 0.3796 - accuracy: 0.8176 - val_loss: 0.4019 - val_accuracy: 0.7800
#
# Epoch 00020: val_loss improved from 0.41589 to 0.40191, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 21/80
#  - 4s - loss: 0.3434 - accuracy: 0.8491 - val_loss: 0.3330 - val_accuracy: 0.8700
#
# Epoch 00021: val_loss improved from 0.40191 to 0.33301, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 22/80
#  - 4s - loss: 0.3296 - accuracy: 0.8553 - val_loss: 0.4191 - val_accuracy: 0.8100
#
# Epoch 00022: val_loss did not improve from 0.33301
# Epoch 23/80
#  - 4s - loss: 0.2662 - accuracy: 0.8962 - val_loss: 0.3097 - val_accuracy: 0.9000
#
# Epoch 00023: val_loss improved from 0.33301 to 0.30971, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 24/80
#  - 4s - loss: 0.2438 - accuracy: 0.9025 - val_loss: 0.2785 - val_accuracy: 0.9300
#
# Epoch 00024: val_loss improved from 0.30971 to 0.27852, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 25/80
#  - 4s - loss: 0.2255 - accuracy: 0.8931 - val_loss: 0.3361 - val_accuracy: 0.8300
#
# Epoch 00025: val_loss did not improve from 0.27852
# Epoch 26/80
#  - 4s - loss: 0.2533 - accuracy: 0.8931 - val_loss: 0.3213 - val_accuracy: 0.8400
#
# Epoch 00026: val_loss did not improve from 0.27852
# Epoch 27/80
#  - 4s - loss: 0.2168 - accuracy: 0.9025 - val_loss: 0.2115 - val_accuracy: 0.9100
#
# Epoch 00027: val_loss improved from 0.27852 to 0.21155, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 28/80
#  - 4s - loss: 0.2061 - accuracy: 0.9277 - val_loss: 0.2320 - val_accuracy: 0.9400
#
# Epoch 00028: val_loss did not improve from 0.21155
# Epoch 29/80
#  - 4s - loss: 0.1618 - accuracy: 0.9403 - val_loss: 0.2979 - val_accuracy: 0.9300
#
# Epoch 00029: val_loss did not improve from 0.21155
# Epoch 30/80
#  - 4s - loss: 0.1379 - accuracy: 0.9528 - val_loss: 0.2332 - val_accuracy: 0.9300
#
# Epoch 00030: val_loss did not improve from 0.21155
# Epoch 31/80
#  - 4s - loss: 0.1299 - accuracy: 0.9591 - val_loss: 0.3007 - val_accuracy: 0.9300
#
# Epoch 00031: val_loss did not improve from 0.21155
# Epoch 32/80
#  - 4s - loss: 0.1639 - accuracy: 0.9340 - val_loss: 0.1962 - val_accuracy: 0.9500
#
# Epoch 00032: val_loss improved from 0.21155 to 0.19625, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 33/80
#  - 4s - loss: 0.1459 - accuracy: 0.9560 - val_loss: 0.2258 - val_accuracy: 0.9300
#
# Epoch 00033: val_loss did not improve from 0.19625
# Epoch 34/80
#  - 4s - loss: 0.1541 - accuracy: 0.9434 - val_loss: 0.1778 - val_accuracy: 0.9600
#
# Epoch 00034: val_loss improved from 0.19625 to 0.17783, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 35/80
#  - 4s - loss: 0.1800 - accuracy: 0.9245 - val_loss: 0.2781 - val_accuracy: 0.8500
#
# Epoch 00035: val_loss did not improve from 0.17783
# Epoch 36/80
#  - 4s - loss: 0.1141 - accuracy: 0.9528 - val_loss: 0.1979 - val_accuracy: 0.9100
#
# Epoch 00036: val_loss did not improve from 0.17783
# Epoch 37/80
#  - 4s - loss: 0.0902 - accuracy: 0.9623 - val_loss: 0.2760 - val_accuracy: 0.9100
#
# Epoch 00037: val_loss did not improve from 0.17783
# Epoch 38/80
#  - 4s - loss: 0.0774 - accuracy: 0.9686 - val_loss: 0.2305 - val_accuracy: 0.9400
#
# Epoch 00038: val_loss did not improve from 0.17783
# Epoch 39/80
#  - 4s - loss: 0.0599 - accuracy: 0.9780 - val_loss: 0.2131 - val_accuracy: 0.9500
#
# Epoch 00039: val_loss did not improve from 0.17783
# Epoch 40/80
#  - 4s - loss: 0.0604 - accuracy: 0.9811 - val_loss: 0.1333 - val_accuracy: 0.9600
#
# Epoch 00040: val_loss improved from 0.17783 to 0.13332, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 41/80
#  - 4s - loss: 0.0436 - accuracy: 0.9811 - val_loss: 0.1384 - val_accuracy: 0.9500
#
# Epoch 00041: val_loss did not improve from 0.13332
# Epoch 42/80
#  - 4s - loss: 0.0441 - accuracy: 0.9874 - val_loss: 0.2216 - val_accuracy: 0.9400
#
# Epoch 00042: val_loss did not improve from 0.13332
# Epoch 43/80
#  - 4s - loss: 0.0978 - accuracy: 0.9654 - val_loss: 0.2295 - val_accuracy: 0.9300
#
# Epoch 00043: val_loss did not improve from 0.13332
# Epoch 44/80
#  - 4s - loss: 0.0630 - accuracy: 0.9748 - val_loss: 0.1441 - val_accuracy: 0.9400
#
# Epoch 00044: val_loss did not improve from 0.13332
# Epoch 45/80
#  - 4s - loss: 0.0319 - accuracy: 0.9874 - val_loss: 0.1339 - val_accuracy: 0.9500
#
# Epoch 00045: val_loss did not improve from 0.13332
# Epoch 46/80
#  - 4s - loss: 0.0308 - accuracy: 0.9906 - val_loss: 0.0996 - val_accuracy: 0.9800
#
# Epoch 00046: val_loss improved from 0.13332 to 0.09959, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 47/80
#  - 4s - loss: 0.0827 - accuracy: 0.9591 - val_loss: 0.3272 - val_accuracy: 0.8700
#
# Epoch 00047: val_loss did not improve from 0.09959
# Epoch 48/80
#  - 4s - loss: 0.2543 - accuracy: 0.9151 - val_loss: 0.3454 - val_accuracy: 0.8500
#
# Epoch 00048: val_loss did not improve from 0.09959
# Epoch 49/80
#  - 4s - loss: 0.1137 - accuracy: 0.9528 - val_loss: 0.2596 - val_accuracy: 0.8800
#
# Epoch 00049: val_loss did not improve from 0.09959
# Epoch 50/80
#  - 4s - loss: 0.0495 - accuracy: 0.9780 - val_loss: 0.1206 - val_accuracy: 0.9600
#
# Epoch 00050: val_loss did not improve from 0.09959
# Epoch 51/80
#  - 4s - loss: 0.0362 - accuracy: 0.9937 - val_loss: 0.1135 - val_accuracy: 0.9700
#
# Epoch 00051: val_loss did not improve from 0.09959
# Epoch 52/80
#  - 4s - loss: 0.0459 - accuracy: 0.9811 - val_loss: 0.1270 - val_accuracy: 0.9600
#
# Epoch 00052: val_loss did not improve from 0.09959
# Epoch 53/80
#  - 4s - loss: 0.0967 - accuracy: 0.9717 - val_loss: 0.2253 - val_accuracy: 0.9300
#
# Epoch 00053: val_loss did not improve from 0.09959
# Epoch 54/80
#  - 4s - loss: 0.1527 - accuracy: 0.9340 - val_loss: 0.1436 - val_accuracy: 0.9700
#
# Epoch 00054: val_loss did not improve from 0.09959
# Epoch 55/80
#  - 4s - loss: 0.0636 - accuracy: 0.9717 - val_loss: 0.1056 - val_accuracy: 0.9600
#
# Epoch 00055: val_loss did not improve from 0.09959
# Epoch 56/80
#  - 4s - loss: 0.0348 - accuracy: 0.9906 - val_loss: 0.0667 - val_accuracy: 0.9800
#
# Epoch 00056: val_loss improved from 0.09959 to 0.06672, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 57/80
#  - 4s - loss: 0.0247 - accuracy: 0.9969 - val_loss: 0.0909 - val_accuracy: 0.9800
#
# Epoch 00057: val_loss did not improve from 0.06672
# Epoch 58/80
#  - 4s - loss: 0.0270 - accuracy: 0.9906 - val_loss: 0.0948 - val_accuracy: 0.9700
#
# Epoch 00058: val_loss did not improve from 0.06672
# Epoch 59/80
#  - 4s - loss: 0.0183 - accuracy: 0.9969 - val_loss: 0.0838 - val_accuracy: 0.9700
#
# Epoch 00059: val_loss did not improve from 0.06672
# Epoch 60/80
#  - 4s - loss: 0.0140 - accuracy: 0.9937 - val_loss: 0.0886 - val_accuracy: 0.9600
#
# Epoch 00060: val_loss did not improve from 0.06672
# Epoch 61/80
#  - 4s - loss: 0.0346 - accuracy: 0.9874 - val_loss: 0.2272 - val_accuracy: 0.8700
#
# Epoch 00061: val_loss did not improve from 0.06672
# Epoch 62/80
#  - 4s - loss: 0.0639 - accuracy: 0.9874 - val_loss: 0.0756 - val_accuracy: 0.9700
#
# Epoch 00062: val_loss did not improve from 0.06672
# Epoch 63/80
#  - 4s - loss: 0.0159 - accuracy: 0.9969 - val_loss: 0.0760 - val_accuracy: 0.9600
#
# Epoch 00063: val_loss did not improve from 0.06672
# Epoch 64/80
#  - 4s - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.0612 - val_accuracy: 0.9900
#
# Epoch 00064: val_loss improved from 0.06672 to 0.06123, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 65/80
#  - 4s - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.0769 - val_accuracy: 0.9600
#
# Epoch 00065: val_loss did not improve from 0.06123
# Epoch 66/80
#  - 4s - loss: 0.0112 - accuracy: 0.9969 - val_loss: 0.0602 - val_accuracy: 0.9800
#
# Epoch 00066: val_loss improved from 0.06123 to 0.06021, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 67/80
#  - 4s - loss: 0.0182 - accuracy: 0.9969 - val_loss: 0.0541 - val_accuracy: 0.9800
#
# Epoch 00067: val_loss improved from 0.06021 to 0.05413, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 68/80
#  - 4s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0501 - val_accuracy: 0.9900
#
# Epoch 00068: val_loss improved from 0.05413 to 0.05011, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 69/80
#  - 4s - loss: 0.0137 - accuracy: 0.9969 - val_loss: 0.0549 - val_accuracy: 0.9900
#
# Epoch 00069: val_loss did not improve from 0.05011
# Epoch 70/80
#  - 4s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0708 - val_accuracy: 0.9700
#
# Epoch 00070: val_loss did not improve from 0.05011
# Epoch 71/80
#  - 4s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0709 - val_accuracy: 0.9700
#
# Epoch 00071: val_loss did not improve from 0.05011
# Epoch 72/80
#  - 4s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0657 - val_accuracy: 0.9600
#
# Epoch 00072: val_loss did not improve from 0.05011
# Epoch 73/80
#  - 4s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0549 - val_accuracy: 0.9800
#
# Epoch 00073: val_loss did not improve from 0.05011
# Epoch 74/80
#  - 4s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0523 - val_accuracy: 0.9800
#
# Epoch 00074: val_loss did not improve from 0.05011
# Epoch 75/80
#  - 4s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0550 - val_accuracy: 0.9800
#
# Epoch 00075: val_loss did not improve from 0.05011
# Epoch 76/80
#  - 4s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0623 - val_accuracy: 0.9700
#
# Epoch 00076: val_loss did not improve from 0.05011
# Epoch 77/80
#  - 4s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0598 - val_accuracy: 0.9800
#
# Epoch 00077: val_loss did not improve from 0.05011
# Epoch 78/80
#  - 4s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0584 - val_accuracy: 0.9800
#
# Epoch 00078: val_loss did not improve from 0.05011
# Epoch 79/80
#  - 4s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0566 - val_accuracy: 0.9800
#
# Epoch 00079: val_loss did not improve from 0.05011
# Epoch 80/80
#  - 4s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0586 - val_accuracy: 0.9800
#
# Epoch 00080: val_loss did not improve from 0.05011

# %%
# Loading the model that performed the best on the validation set
model.load_weights('/content/Model_arson_1.weights.best.hdf5')

# Testing the model on the Test data
(loss, accuracy) = model.evaluate(X_test, y_test, batch_size=16, verbose=0)

print('Accuracy on test data: {:.2f}%'.format(accuracy * 100))
# Out:
# Accuracy on test data: 98.10%

# %%
# Making the plot larger
plt.figure(figsize=(12, 8))

loss = history.history['loss']                          # Loss on the training data
val_loss = history.history['val_loss']                  # Loss on the validation data
epochs = range(1, 81)

plt.plot(epochs, loss, 'ro-', label='Training Loss')
plt.plot(epochs, val_loss, 'go-', label = 'Validation Loss')
plt.legend()

# %%
# Making the plot larger
plt.figure(figsize=(12, 8))

acc = history.history['accuracy']                          # Loss on the training data
val_acc = history.history['val_accuracy']                  # Loss on the validation data
epochs = range(1, 81)

plt.plot(epochs, acc, 'ro-', label='Training Accuracy')
plt.plot(epochs, val_acc, 'go-', label = 'Validation Accuracy')
plt.legend()

# %%
y_pred=model.predict(X_test)
y_pred=y_pred>0.90
target_names = ['class Normal', 'class arson']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
# class Normal       0.99      0.96      0.98       112
#  class arson       0.97      0.98      0.97        98
#
#    micro avg       0.98      0.97      0.98       210
#    macro avg       0.98      0.97      0.98       210
# weighted avg       0.98      0.97      0.98       210
#  samples avg       0.97      0.97      0.97       210
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Using the Sequential Model
model = Sequential()

# Adding Alternate convolutional and pooling layers
model.add(Conv3D(filters=16, kernel_size=(5, 3, 3), strides=(1, 1, 1), padding='same', activation='relu', 
                 input_shape=X_train.shape[1:]))
model.add(MaxPooling3D(pool_size=2, strides=(2, 2, 2), padding='same'))

model.add(Conv3D(filters=64, kernel_size=(2, 3, 3), strides=(1, 1, 1), padding='valid', activation='relu'))
model.add(MaxPooling3D(pool_size=2, strides=(2, 2, 2), padding='same'))

model.add(Conv3D(filters=256, kernel_size=(2, 3, 3), strides=(1, 1, 1), padding='valid', activation='relu'))
model.add(MaxPooling3D(pool_size=2, strides=(2, 2, 2), padding='same'))

model.add(Conv3D(filters=1024, kernel_size=(2, 3, 3), strides=(1, 1, 1), padding='valid', activation='relu'))
model.add(MaxPooling3D(pool_size=2, strides=(2, 2, 2), padding='same'))

# A global average pooling layer to get a 1-d vector
# The vector will have a depth (same as number of elements in the vector) of 1024
model.add(GlobalAveragePooling3D())

# Hidden layer
model.add(Dense(32, activation='relu'))

# Dropout Layer
model.add(Dropout(0.5))

# Output layer
model.add(Dense(2, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_11 (Conv3D)           (None, 29, 128, 128, 16)  736
# _________________________________________________________________
# max_pooling3d_29 (MaxPooling (None, 15, 64, 64, 16)    0
# _________________________________________________________________
# conv3d_12 (Conv3D)           (None, 14, 62, 62, 64)    18496
# _________________________________________________________________
# max_pooling3d_30 (MaxPooling (None, 7, 31, 31, 64)     0
# _________________________________________________________________
# conv3d_13 (Conv3D)           (None, 6, 29, 29, 256)    295168
# _________________________________________________________________
# max_pooling3d_31 (MaxPooling (None, 3, 15, 15, 256)    0
# _________________________________________________________________
# conv3d_14 (Conv3D)           (None, 2, 13, 13, 1024)   4719616
# _________________________________________________________________
# max_pooling3d_32 (MaxPooling (None, 1, 7, 7, 1024)     0
# _________________________________________________________________
# global_average_pooling3d_9 ( (None, 1024)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 32)                32800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 2)                 66
# =================================================================
# Total params: 5,066,882
# Trainable params: 5,066,882
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint

# Compiling the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Saving the model that performed the best on the validation set
checkpoint = ModelCheckpoint(filepath='Model_arson_2_larger_parameters.weights.best.hdf5', save_best_only=True, verbose=1)

# Training the model for 40 epochs
history = model.fit(X_train, y_train, batch_size=16, epochs=80, 
                    validation_data=(X_valid, y_valid), verbose=2, callbacks=[checkpoint])
# Out:
# Train on 318 samples, validate on 100 samples
# Epoch 1/80
#  - 5s - loss: 0.6807 - accuracy: 0.5409 - val_loss: 0.6841 - val_accuracy: 0.6900
#
# Epoch 00001: val_loss improved from inf to 0.68412, saving model to Model_arson_2_larger_parameters.weights.best.hdf5
# Epoch 2/80
#  - 5s - loss: 0.6488 - accuracy: 0.6635 - val_loss: 0.6106 - val_accuracy: 0.6900
#
# Epoch 00002: val_loss improved from 0.68412 to 0.61058, saving model to Model_arson_2_larger_parameters.weights.best.hdf5
# Epoch 3/80
#  - 5s - loss: 0.5807 - accuracy: 0.7107 - val_loss: 0.6884 - val_accuracy: 0.5700
#
# Epoch 00003: val_loss did not improve from 0.61058
# Epoch 4/80
#  - 5s - loss: 0.5712 - accuracy: 0.7201 - val_loss: 0.5541 - val_accuracy: 0.7200
#
# Epoch 00004: val_loss improved from 0.61058 to 0.55410, saving model to Model_arson_2_larger_parameters.weights.best.hdf5
# Epoch 5/80
#  - 5s - loss: 0.5512 - accuracy: 0.7264 - val_loss: 0.8144 - val_accuracy: 0.5800
#
# Epoch 00005: val_loss did not improve from 0.55410
# Epoch 6/80
#  - 5s - loss: 0.5801 - accuracy: 0.6572 - val_loss: 0.5261 - val_accuracy: 0.7900
#
# Epoch 00006: val_loss improved from 0.55410 to 0.52612, saving model to Model_arson_2_larger_parameters.weights.best.hdf5
# Epoch 7/80
#  - 5s - loss: 0.4524 - accuracy: 0.7767 - val_loss: 0.4506 - val_accuracy: 0.7800
#
# Epoch 00007: val_loss improved from 0.52612 to 0.45057, saving model to Model_arson_2_larger_parameters.weights.best.hdf5
# Epoch 8/80
#  - 5s - loss: 0.4512 - accuracy: 0.7925 - val_loss: 0.4403 - val_accuracy: 0.7800
#
# Epoch 00008: val_loss improved from 0.45057 to 0.44026, saving model to Model_arson_2_larger_parameters.weights.best.hdf5
# Epoch 9/80
#  - 5s - loss: 0.3608 - accuracy: 0.8365 - val_loss: 0.3449 - val_accuracy: 0.8800
#
# Epoch 00009: val_loss improved from 0.44026 to 0.34494, saving model to Model_arson_2_larger_parameters.weights.best.hdf5
# Epoch 10/80
#  - 5s - loss: 0.4215 - accuracy: 0.8050 - val_loss: 0.5678 - val_accuracy: 0.7200
#
# Epoch 00010: val_loss did not improve from 0.34494
# Epoch 11/80
#  - 5s - loss: 0.3657 - accuracy: 0.8522 - val_loss: 0.3470 - val_accuracy: 0.8300
#
# Epoch 00011: val_loss did not improve from 0.34494
# Epoch 12/80
#  - 5s - loss: 0.2980 - accuracy: 0.8899 - val_loss: 0.3154 - val_accuracy: 0.8700
#
# Epoch 00012: val_loss improved from 0.34494 to 0.31537, saving model to Model_arson_2_larger_parameters.weights.best.hdf5
# Epoch 13/80
#  - 5s - loss: 0.2692 - accuracy: 0.8931 - val_loss: 0.3044 - val_accuracy: 0.8900
#
# Epoch 00013: val_loss improved from 0.31537 to 0.30439, saving model to Model_arson_2_larger_parameters.weights.best.hdf5
# Epoch 14/80
#  - 5s - loss: 0.1773 - accuracy: 0.9434 - val_loss: 0.2475 - val_accuracy: 0.8800
#
# Epoch 00014: val_loss improved from 0.30439 to 0.24746, saving model to Model_arson_2_larger_parameters.weights.best.hdf5
# Epoch 15/80
#  - 5s - loss: 0.3581 - accuracy: 0.8616 - val_loss: 0.6962 - val_accuracy: 0.7100
#
# Epoch 00015: val_loss did not improve from 0.24746
# Epoch 16/80
#  - 5s - loss: 0.3379 - accuracy: 0.8553 - val_loss: 0.3272 - val_accuracy: 0.8600
#
# Epoch 00016: val_loss did not improve from 0.24746
# Epoch 17/80
#  - 5s - loss: 0.1990 - accuracy: 0.9465 - val_loss: 0.2279 - val_accuracy: 0.9300
#
# Epoch 00017: val_loss improved from 0.24746 to 0.22789, saving model to Model_arson_2_larger_parameters.weights.best.hdf5
# Epoch 18/80
#  - 5s - loss: 0.2251 - accuracy: 0.9465 - val_loss: 0.3638 - val_accuracy: 0.8200
#
# Epoch 00018: val_loss did not improve from 0.22789
# Epoch 19/80
#  - 5s - loss: 0.2003 - accuracy: 0.9340 - val_loss: 0.2960 - val_accuracy: 0.9000
#
# Epoch 00019: val_loss did not improve from 0.22789
# Epoch 20/80
#  - 5s - loss: 0.1220 - accuracy: 0.9686 - val_loss: 0.2717 - val_accuracy: 0.9100
#
# Epoch 00020: val_loss did not improve from 0.22789
# Epoch 21/80
#  - 5s - loss: 0.0893 - accuracy: 0.9780 - val_loss: 0.4214 - val_accuracy: 0.8900
#
# Epoch 00021: val_loss did not improve from 0.22789
# Epoch 22/80
#  - 5s - loss: 0.1466 - accuracy: 0.9591 - val_loss: 0.3757 - val_accuracy: 0.9200
#
# Epoch 00022: val_loss did not improve from 0.22789
# Epoch 23/80
#  - 5s - loss: 0.1909 - accuracy: 0.9403 - val_loss: 0.3214 - val_accuracy: 0.9000
#
# Epoch 00023: val_loss did not improve from 0.22789
# Epoch 24/80
#  - 5s - loss: 0.1152 - accuracy: 0.9717 - val_loss: 0.3458 - val_accuracy: 0.9100
#
# Epoch 00024: val_loss did not improve from 0.22789
# Epoch 25/80
#  - 5s - loss: 0.0767 - accuracy: 0.9748 - val_loss: 0.2556 - val_accuracy: 0.9400
#
# Epoch 00025: val_loss did not improve from 0.22789
# Epoch 26/80
#  - 5s - loss: 0.0905 - accuracy: 0.9748 - val_loss: 0.3733 - val_accuracy: 0.9400
#
# Epoch 00026: val_loss did not improve from 0.22789
# Epoch 27/80
#  - 5s - loss: 0.0938 - accuracy: 0.9591 - val_loss: 0.9564 - val_accuracy: 0.7500
#
# Epoch 00027: val_loss did not improve from 0.22789
# Epoch 28/80
#  - 5s - loss: 0.1435 - accuracy: 0.9591 - val_loss: 0.3541 - val_accuracy: 0.9000
#
# Epoch 00028: val_loss did not improve from 0.22789
# Epoch 29/80
#  - 5s - loss: 0.0900 - accuracy: 0.9843 - val_loss: 0.3199 - val_accuracy: 0.9200
#
# Epoch 00029: val_loss did not improve from 0.22789
# Epoch 30/80
#  - 5s - loss: 0.0652 - accuracy: 0.9843 - val_loss: 0.4124 - val_accuracy: 0.9300
#
# Epoch 00030: val_loss did not improve from 0.22789
# Epoch 31/80
#  - 5s - loss: 0.0553 - accuracy: 0.9748 - val_loss: 0.3734 - val_accuracy: 0.9400
#
# Epoch 00031: val_loss did not improve from 0.22789
# Epoch 32/80
#  - 5s - loss: 0.0924 - accuracy: 0.9717 - val_loss: 0.6594 - val_accuracy: 0.8400
#
# Epoch 00032: val_loss did not improve from 0.22789
# Epoch 33/80
#  - 5s - loss: 0.0706 - accuracy: 0.9780 - val_loss: 0.4868 - val_accuracy: 0.9000
#
# Epoch 00033: val_loss did not improve from 0.22789
# Epoch 34/80
#  - 5s - loss: 0.0457 - accuracy: 0.9843 - val_loss: 0.4495 - val_accuracy: 0.9100
#
# Epoch 00034: val_loss did not improve from 0.22789
# Epoch 35/80
#  - 5s - loss: 0.0508 - accuracy: 0.9811 - val_loss: 0.3726 - val_accuracy: 0.9400
#
# Epoch 00035: val_loss did not improve from 0.22789
# Epoch 36/80
#  - 5s - loss: 0.0362 - accuracy: 0.9843 - val_loss: 0.4358 - val_accuracy: 0.9400
#
# Epoch 00036: val_loss did not improve from 0.22789
# Epoch 37/80
#  - 5s - loss: 0.0246 - accuracy: 0.9937 - val_loss: 0.7057 - val_accuracy: 0.9100
#
# Epoch 00037: val_loss did not improve from 0.22789
# Epoch 38/80
#  - 5s - loss: 0.5072 - accuracy: 0.8899 - val_loss: 0.5828 - val_accuracy: 0.7700
#
# Epoch 00038: val_loss did not improve from 0.22789
# Epoch 39/80
#  - 5s - loss: 0.3707 - accuracy: 0.8459 - val_loss: 0.3732 - val_accuracy: 0.8000
#
# Epoch 00039: val_loss did not improve from 0.22789
# Epoch 40/80
#  - 5s - loss: 0.2621 - accuracy: 0.9245 - val_loss: 0.3474 - val_accuracy: 0.9000
#
# Epoch 00040: val_loss did not improve from 0.22789
# Epoch 41/80
#  - 5s - loss: 0.1190 - accuracy: 0.9654 - val_loss: 0.2092 - val_accuracy: 0.9500
#
# Epoch 00041: val_loss improved from 0.22789 to 0.20921, saving model to Model_arson_2_larger_parameters.weights.best.hdf5
# Epoch 42/80
#  - 5s - loss: 0.1344 - accuracy: 0.9623 - val_loss: 0.1288 - val_accuracy: 0.9800
#
# Epoch 00042: val_loss improved from 0.20921 to 0.12879, saving model to Model_arson_2_larger_parameters.weights.best.hdf5
# Epoch 43/80
#  - 5s - loss: 0.0715 - accuracy: 0.9843 - val_loss: 0.1262 - val_accuracy: 0.9900
#
# Epoch 00043: val_loss improved from 0.12879 to 0.12620, saving model to Model_arson_2_larger_parameters.weights.best.hdf5
# Epoch 44/80
#  - 5s - loss: 0.0863 - accuracy: 0.9780 - val_loss: 0.2203 - val_accuracy: 0.9500
#
# Epoch 00044: val_loss did not improve from 0.12620
# Epoch 45/80
#  - 5s - loss: 0.1340 - accuracy: 0.9434 - val_loss: 0.1684 - val_accuracy: 0.9500
#
# Epoch 00045: val_loss did not improve from 0.12620
# Epoch 46/80
#  - 5s - loss: 0.0910 - accuracy: 0.9748 - val_loss: 0.1915 - val_accuracy: 0.9300
#
# Epoch 00046: val_loss did not improve from 0.12620
# Epoch 47/80
#  - 5s - loss: 0.0322 - accuracy: 0.9969 - val_loss: 0.2743 - val_accuracy: 0.9200
#
# Epoch 00047: val_loss did not improve from 0.12620
# Epoch 48/80
#  - 5s - loss: 0.0470 - accuracy: 0.9811 - val_loss: 0.3291 - val_accuracy: 0.9100
#
# Epoch 00048: val_loss did not improve from 0.12620
# Epoch 49/80
#  - 5s - loss: 0.1011 - accuracy: 0.9654 - val_loss: 0.5318 - val_accuracy: 0.9300
#
# Epoch 00049: val_loss did not improve from 0.12620
# Epoch 50/80
#  - 5s - loss: 0.0687 - accuracy: 0.9843 - val_loss: 0.2890 - val_accuracy: 0.9400
#
# Epoch 00050: val_loss did not improve from 0.12620
# Epoch 51/80
#  - 5s - loss: 0.0388 - accuracy: 0.9843 - val_loss: 0.3060 - val_accuracy: 0.9300
#
# Epoch 00051: val_loss did not improve from 0.12620
# Epoch 52/80
#  - 5s - loss: 0.0240 - accuracy: 0.9906 - val_loss: 0.3467 - val_accuracy: 0.9500
#
# Epoch 00052: val_loss did not improve from 0.12620
# Epoch 53/80
#  - 5s - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.3905 - val_accuracy: 0.9500
#
# Epoch 00053: val_loss did not improve from 0.12620
# Epoch 54/80
#  - 5s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.4308 - val_accuracy: 0.9500
#
# Epoch 00054: val_loss did not improve from 0.12620
# Epoch 55/80
#  - 5s - loss: 0.0059 - accuracy: 0.9969 - val_loss: 0.4748 - val_accuracy: 0.9300
#
# Epoch 00055: val_loss did not improve from 0.12620
# Epoch 56/80
#  - 5s - loss: 0.0561 - accuracy: 0.9686 - val_loss: 0.6901 - val_accuracy: 0.9200
#
# Epoch 00056: val_loss did not improve from 0.12620
# Epoch 57/80
#  - 5s - loss: 0.1099 - accuracy: 0.9686 - val_loss: 0.5718 - val_accuracy: 0.9200
#
# Epoch 00057: val_loss did not improve from 0.12620
# Epoch 58/80
#  - 5s - loss: 0.0297 - accuracy: 0.9906 - val_loss: 0.5047 - val_accuracy: 0.9400
#
# Epoch 00058: val_loss did not improve from 0.12620
# Epoch 59/80
#  - 5s - loss: 0.0270 - accuracy: 0.9874 - val_loss: 0.4971 - val_accuracy: 0.9500
#
# Epoch 00059: val_loss did not improve from 0.12620
# Epoch 60/80
#  - 5s - loss: 0.0195 - accuracy: 0.9937 - val_loss: 0.5820 - val_accuracy: 0.9200
#
# Epoch 00060: val_loss did not improve from 0.12620
# Epoch 61/80
#  - 5s - loss: 0.0117 - accuracy: 0.9969 - val_loss: 0.5107 - val_accuracy: 0.9600
#
# Epoch 00061: val_loss did not improve from 0.12620
# Epoch 62/80
#  - 5s - loss: 0.0081 - accuracy: 0.9969 - val_loss: 0.5548 - val_accuracy: 0.9200
#
# Epoch 00062: val_loss did not improve from 0.12620
# Epoch 63/80
#  - 5s - loss: 0.0132 - accuracy: 0.9937 - val_loss: 0.5631 - val_accuracy: 0.9500
#
# Epoch 00063: val_loss did not improve from 0.12620
# Epoch 64/80
#  - 5s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.5806 - val_accuracy: 0.9500
#
# Epoch 00064: val_loss did not improve from 0.12620
# Epoch 65/80
#  - 5s - loss: 0.0070 - accuracy: 0.9969 - val_loss: 0.6229 - val_accuracy: 0.9500
#
# Epoch 00065: val_loss did not improve from 0.12620
# Epoch 66/80
#  - 5s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.7443 - val_accuracy: 0.9500
#
# Epoch 00066: val_loss did not improve from 0.12620
# Epoch 67/80
#  - 5s - loss: 8.5111e-04 - accuracy: 1.0000 - val_loss: 0.7639 - val_accuracy: 0.9500
#
# Epoch 00067: val_loss did not improve from 0.12620
# Epoch 68/80
#  - 5s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.7487 - val_accuracy: 0.9500
#
# Epoch 00068: val_loss did not improve from 0.12620
# Epoch 69/80
#  - 5s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.8032 - val_accuracy: 0.9500
#
# Epoch 00069: val_loss did not improve from 0.12620
# Epoch 70/80
#  - 5s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.7707 - val_accuracy: 0.9400
#
# Epoch 00070: val_loss did not improve from 0.12620
# Epoch 71/80
#  - 5s - loss: 0.0102 - accuracy: 1.0000 - val_loss: 1.2111 - val_accuracy: 0.9700
#
# Epoch 00071: val_loss did not improve from 0.12620
# Epoch 72/80
#  - 5s - loss: 0.2602 - accuracy: 0.9434 - val_loss: 0.2995 - val_accuracy: 0.9400
#
# Epoch 00072: val_loss did not improve from 0.12620
# Epoch 73/80
#  - 5s - loss: 0.0798 - accuracy: 0.9780 - val_loss: 0.2737 - val_accuracy: 0.9400
#
# Epoch 00073: val_loss did not improve from 0.12620
# Epoch 74/80
#  - 5s - loss: 0.0306 - accuracy: 0.9937 - val_loss: 0.2072 - val_accuracy: 0.9800
#
# Epoch 00074: val_loss did not improve from 0.12620
# Epoch 75/80
#  - 5s - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.1976 - val_accuracy: 0.9700
#
# Epoch 00075: val_loss did not improve from 0.12620
# Epoch 76/80
#  - 5s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.2045 - val_accuracy: 0.9800
#
# Epoch 00076: val_loss did not improve from 0.12620
# Epoch 77/80
#  - 5s - loss: 0.0056 - accuracy: 0.9969 - val_loss: 0.2063 - val_accuracy: 0.9800
#
# Epoch 00077: val_loss did not improve from 0.12620
# Epoch 78/80
#  - 5s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.2089 - val_accuracy: 0.9800
#
# Epoch 00078: val_loss did not improve from 0.12620
# Epoch 79/80
#  - 5s - loss: 0.0074 - accuracy: 0.9937 - val_loss: 0.1955 - val_accuracy: 0.9800
#
# Epoch 00079: val_loss did not improve from 0.12620
# Epoch 80/80
#  - 5s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2155 - val_accuracy: 0.9700
#
# Epoch 00080: val_loss did not improve from 0.12620

# %%
# Loading the model that performed the best on the validation set
model.load_weights('/content/Model_arson_2_larger_parameters.weights.best.hdf5')

# Testing the model on the Test data
(loss, accuracy) = model.evaluate(X_test, y_test, batch_size=16, verbose=0)

print('Accuracy on test data: {:.2f}%'.format(accuracy * 100))
# Out:
# Accuracy on test data: 99.05%

# %%
# Making the plot larger
plt.figure(figsize=(12, 8))

loss = history.history['loss']                          # Loss on the training data
val_loss = history.history['val_loss']                  # Loss on the validation data
epochs = range(1, 81)

plt.plot(epochs, loss, 'ro-', label='Training Loss')
plt.plot(epochs, val_loss, 'go-', label = 'Validation Loss')
plt.legend()


# Making the plot larger
plt.figure(figsize=(12, 8))

acc = history.history['accuracy']                          # Loss on the training data
val_acc = history.history['val_accuracy']                  # Loss on the validation data
epochs = range(1, 81)

plt.plot(epochs, acc, 'ro-', label='Training Accuracy')
plt.plot(epochs, val_acc, 'go-', label = 'Validation Accuracy')
plt.legend()


y_pred=model.predict(X_test)
y_pred=y_pred>0.80
target_names = ['class Normal', 'class arson']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
# class Normal       1.00      0.98      0.99       112
#  class arson       0.99      0.99      0.99        98
#
#    micro avg       1.00      0.99      0.99       210
#    macro avg       0.99      0.99      0.99       210
# weighted avg       1.00      0.99      0.99       210
#  samples avg       0.99      0.99      0.99       210

# %%
model_d = Sequential()

# Adding Alternate convolutional and pooling layers
model_d.add(DepthwiseConv3D( kernel_size=(10, 3, 3),depth_multiplier=2, strides=(1, 1, 1), padding='same', activation='relu', 
                 input_shape=X_train.shape[1:]))
model_d.add(MaxPooling3D(pool_size=2, strides=(1, 2, 2), padding='same'))

model_d.add(DepthwiseConv3D( depth_multiplier=4,kernel_size=(5, 3, 3), strides=(3, 1, 1), padding='valid', activation='relu'))
model_d.add(MaxPooling3D(pool_size=2, strides=(1, 2, 2), padding='same'))

model_d.add(DepthwiseConv3D(depth_multiplier=8, kernel_size=(5, 3, 3), strides=(3, 1, 1), padding='valid', activation='relu'))
model_d.add(MaxPooling3D(pool_size=2, strides=(1, 2, 2), padding='same'))

# A global average pooling layer to get a 1-d vector
# The vector will have a depth (same as number of elements in the vector) of 256
model_d.add(GlobalAveragePooling3D())

# The Global average pooling layer is followed by a fully-connected neural network, with one hidden and one output layer

# Hidden Layer
model_d.add(Dense(32, activation='relu'))

# Output layer
model_d.add(Dense(2, activation='softmax'))

model_d.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# depthwise_conv3d_20 (Depthwi (None, 29, 128, 128, 2)   182
# _________________________________________________________________
# max_pooling3d_33 (MaxPooling (None, 29, 64, 64, 2)     0
# _________________________________________________________________
# depthwise_conv3d_21 (Depthwi (None, 9, 62, 62, 8)      368
# _________________________________________________________________
# max_pooling3d_34 (MaxPooling (None, 9, 31, 31, 8)      0
# _________________________________________________________________
# depthwise_conv3d_22 (Depthwi (None, 2, 29, 29, 64)     2944
# _________________________________________________________________
# max_pooling3d_35 (MaxPooling (None, 2, 15, 15, 64)     0
# _________________________________________________________________
# global_average_pooling3d_10  (None, 64)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_20 (Dense)             (None, 2)                 66
# =================================================================
# Total params: 5,640
# Trainable params: 5,640
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint

# Compiling the model
model_d.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Saving the model that performed the best on the validation set
checkpoint = ModelCheckpoint(filepath='Model_depthwise_1_arson.weights.best.hdf5', save_best_only=True, verbose=1)

# Training the model for 40 epochs
history = model_d.fit(X_train, y_train, batch_size=16, epochs=200, 
                    validation_data=(X_valid, y_valid), verbose=2, callbacks=[checkpoint])
# Out:
# Train on 318 samples, validate on 100 samples
# Epoch 1/200
#  - 3s - loss: 0.6905 - accuracy: 0.4906 - val_loss: 0.6886 - val_accuracy: 0.4800
#
# Epoch 00001: val_loss improved from inf to 0.68864, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 2/200
#  - 3s - loss: 0.6767 - accuracy: 0.5283 - val_loss: 0.6804 - val_accuracy: 0.4800
#
# Epoch 00002: val_loss improved from 0.68864 to 0.68043, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 3/200
#  - 3s - loss: 0.6574 - accuracy: 0.5629 - val_loss: 0.6605 - val_accuracy: 0.6100
#
# Epoch 00003: val_loss improved from 0.68043 to 0.66046, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 4/200
#  - 3s - loss: 0.6325 - accuracy: 0.6541 - val_loss: 0.6473 - val_accuracy: 0.6000
#
# Epoch 00004: val_loss improved from 0.66046 to 0.64734, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 5/200
#  - 3s - loss: 0.6271 - accuracy: 0.6698 - val_loss: 0.6808 - val_accuracy: 0.5300
#
# Epoch 00005: val_loss did not improve from 0.64734
# Epoch 6/200
#  - 3s - loss: 0.5966 - accuracy: 0.7013 - val_loss: 0.6197 - val_accuracy: 0.6500
#
# Epoch 00006: val_loss improved from 0.64734 to 0.61975, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 7/200
#  - 3s - loss: 0.5859 - accuracy: 0.7107 - val_loss: 0.6372 - val_accuracy: 0.6400
#
# Epoch 00007: val_loss did not improve from 0.61975
# Epoch 8/200
#  - 3s - loss: 0.5513 - accuracy: 0.7264 - val_loss: 0.5721 - val_accuracy: 0.7200
#
# Epoch 00008: val_loss improved from 0.61975 to 0.57213, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 9/200
#  - 3s - loss: 0.5561 - accuracy: 0.7170 - val_loss: 0.6301 - val_accuracy: 0.6700
#
# Epoch 00009: val_loss did not improve from 0.57213
# Epoch 10/200
#  - 3s - loss: 0.5580 - accuracy: 0.7013 - val_loss: 0.5652 - val_accuracy: 0.6900
#
# Epoch 00010: val_loss improved from 0.57213 to 0.56517, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 11/200
#  - 3s - loss: 0.5319 - accuracy: 0.7579 - val_loss: 0.5463 - val_accuracy: 0.7400
#
# Epoch 00011: val_loss improved from 0.56517 to 0.54633, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 12/200
#  - 3s - loss: 0.5088 - accuracy: 0.7799 - val_loss: 0.5244 - val_accuracy: 0.7600
#
# Epoch 00012: val_loss improved from 0.54633 to 0.52441, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 13/200
#  - 3s - loss: 0.5009 - accuracy: 0.7704 - val_loss: 0.5347 - val_accuracy: 0.7200
#
# Epoch 00013: val_loss did not improve from 0.52441
# Epoch 14/200
#  - 3s - loss: 0.5149 - accuracy: 0.7421 - val_loss: 0.5091 - val_accuracy: 0.7900
#
# Epoch 00014: val_loss improved from 0.52441 to 0.50911, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 15/200
#  - 3s - loss: 0.4901 - accuracy: 0.7736 - val_loss: 0.5132 - val_accuracy: 0.7600
#
# Epoch 00015: val_loss did not improve from 0.50911
# Epoch 16/200
#  - 3s - loss: 0.4719 - accuracy: 0.7987 - val_loss: 0.4930 - val_accuracy: 0.7600
#
# Epoch 00016: val_loss improved from 0.50911 to 0.49303, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 17/200
#  - 3s - loss: 0.4646 - accuracy: 0.7799 - val_loss: 0.4897 - val_accuracy: 0.7900
#
# Epoch 00017: val_loss improved from 0.49303 to 0.48973, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 18/200
#  - 3s - loss: 0.4702 - accuracy: 0.7893 - val_loss: 0.4832 - val_accuracy: 0.7600
#
# Epoch 00018: val_loss improved from 0.48973 to 0.48323, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 19/200
#  - 3s - loss: 0.4689 - accuracy: 0.7799 - val_loss: 0.5128 - val_accuracy: 0.7700
#
# Epoch 00019: val_loss did not improve from 0.48323
# Epoch 20/200
#  - 3s - loss: 0.4505 - accuracy: 0.8082 - val_loss: 0.4745 - val_accuracy: 0.7800
#
# Epoch 00020: val_loss improved from 0.48323 to 0.47449, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 21/200
#  - 3s - loss: 0.4366 - accuracy: 0.8113 - val_loss: 0.4588 - val_accuracy: 0.7800
#
# Epoch 00021: val_loss improved from 0.47449 to 0.45878, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 22/200
#  - 3s - loss: 0.4468 - accuracy: 0.7925 - val_loss: 0.4679 - val_accuracy: 0.7700
#
# Epoch 00022: val_loss did not improve from 0.45878
# Epoch 23/200
#  - 3s - loss: 0.4771 - accuracy: 0.7925 - val_loss: 0.4976 - val_accuracy: 0.7300
#
# Epoch 00023: val_loss did not improve from 0.45878
# Epoch 24/200
#  - 3s - loss: 0.4517 - accuracy: 0.7862 - val_loss: 0.4730 - val_accuracy: 0.7800
#
# Epoch 00024: val_loss did not improve from 0.45878
# Epoch 25/200
#  - 3s - loss: 0.4379 - accuracy: 0.7925 - val_loss: 0.4782 - val_accuracy: 0.7800
#
# Epoch 00025: val_loss did not improve from 0.45878
# Epoch 26/200
#  - 3s - loss: 0.4287 - accuracy: 0.8176 - val_loss: 0.4470 - val_accuracy: 0.8100
#
# Epoch 00026: val_loss improved from 0.45878 to 0.44699, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 27/200
#  - 3s - loss: 0.4319 - accuracy: 0.8208 - val_loss: 0.4416 - val_accuracy: 0.8000
#
# Epoch 00027: val_loss improved from 0.44699 to 0.44160, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 28/200
#  - 3s - loss: 0.4595 - accuracy: 0.7830 - val_loss: 0.4363 - val_accuracy: 0.7800
#
# Epoch 00028: val_loss improved from 0.44160 to 0.43628, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 29/200
#  - 3s - loss: 0.4432 - accuracy: 0.8050 - val_loss: 0.4637 - val_accuracy: 0.7500
#
# Epoch 00029: val_loss did not improve from 0.43628
# Epoch 30/200
#  - 3s - loss: 0.4347 - accuracy: 0.8050 - val_loss: 0.4396 - val_accuracy: 0.7900
#
# Epoch 00030: val_loss did not improve from 0.43628
# Epoch 31/200
#  - 3s - loss: 0.4319 - accuracy: 0.7893 - val_loss: 0.4315 - val_accuracy: 0.8000
#
# Epoch 00031: val_loss improved from 0.43628 to 0.43150, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 32/200
#  - 3s - loss: 0.4178 - accuracy: 0.8176 - val_loss: 0.4282 - val_accuracy: 0.8000
#
# Epoch 00032: val_loss improved from 0.43150 to 0.42821, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 33/200
#  - 3s - loss: 0.4232 - accuracy: 0.8208 - val_loss: 0.4468 - val_accuracy: 0.7800
#
# Epoch 00033: val_loss did not improve from 0.42821
# Epoch 34/200
#  - 3s - loss: 0.4295 - accuracy: 0.8176 - val_loss: 0.4243 - val_accuracy: 0.8200
#
# Epoch 00034: val_loss improved from 0.42821 to 0.42427, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 35/200
#  - 3s - loss: 0.4206 - accuracy: 0.8113 - val_loss: 0.4333 - val_accuracy: 0.8000
#
# Epoch 00035: val_loss did not improve from 0.42427
# Epoch 36/200
#  - 3s - loss: 0.4134 - accuracy: 0.8176 - val_loss: 0.4744 - val_accuracy: 0.7400
#
# Epoch 00036: val_loss did not improve from 0.42427
# Epoch 37/200
#  - 3s - loss: 0.4157 - accuracy: 0.8050 - val_loss: 0.4170 - val_accuracy: 0.8000
#
# Epoch 00037: val_loss improved from 0.42427 to 0.41703, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 38/200
#  - 3s - loss: 0.4081 - accuracy: 0.8145 - val_loss: 0.4405 - val_accuracy: 0.7900
#
# Epoch 00038: val_loss did not improve from 0.41703
# Epoch 39/200
#  - 3s - loss: 0.4133 - accuracy: 0.8239 - val_loss: 0.4263 - val_accuracy: 0.7800
#
# Epoch 00039: val_loss did not improve from 0.41703
# Epoch 40/200
#  - 3s - loss: 0.4401 - accuracy: 0.7830 - val_loss: 0.4426 - val_accuracy: 0.7600
#
# Epoch 00040: val_loss did not improve from 0.41703
# Epoch 41/200
#  - 3s - loss: 0.4150 - accuracy: 0.8113 - val_loss: 0.4429 - val_accuracy: 0.7600
#
# Epoch 00041: val_loss did not improve from 0.41703
# Epoch 42/200
#  - 3s - loss: 0.4198 - accuracy: 0.8050 - val_loss: 0.4289 - val_accuracy: 0.7600
#
# Epoch 00042: val_loss did not improve from 0.41703
# Epoch 43/200
#  - 3s - loss: 0.4031 - accuracy: 0.8113 - val_loss: 0.4032 - val_accuracy: 0.8200
#
# Epoch 00043: val_loss improved from 0.41703 to 0.40317, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 44/200
#  - 3s - loss: 0.4021 - accuracy: 0.8176 - val_loss: 0.4040 - val_accuracy: 0.8000
#
# Epoch 00044: val_loss did not improve from 0.40317
# Epoch 45/200
#  - 3s - loss: 0.4009 - accuracy: 0.8176 - val_loss: 0.4270 - val_accuracy: 0.7900
#
# Epoch 00045: val_loss did not improve from 0.40317
# Epoch 46/200
#  - 3s - loss: 0.4101 - accuracy: 0.8302 - val_loss: 0.4097 - val_accuracy: 0.8000
#
# Epoch 00046: val_loss did not improve from 0.40317
# Epoch 47/200
#  - 3s - loss: 0.3932 - accuracy: 0.8302 - val_loss: 0.4017 - val_accuracy: 0.8100
#
# Epoch 00047: val_loss improved from 0.40317 to 0.40172, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 48/200
#  - 3s - loss: 0.3891 - accuracy: 0.8302 - val_loss: 0.3920 - val_accuracy: 0.8300
#
# Epoch 00048: val_loss improved from 0.40172 to 0.39199, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 49/200
#  - 3s - loss: 0.3856 - accuracy: 0.8333 - val_loss: 0.3843 - val_accuracy: 0.8400
#
# Epoch 00049: val_loss improved from 0.39199 to 0.38432, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 50/200
#  - 3s - loss: 0.3823 - accuracy: 0.8176 - val_loss: 0.3845 - val_accuracy: 0.8000
#
# Epoch 00050: val_loss did not improve from 0.38432
# Epoch 51/200
#  - 3s - loss: 0.3954 - accuracy: 0.8113 - val_loss: 0.3810 - val_accuracy: 0.8300
#
# Epoch 00051: val_loss improved from 0.38432 to 0.38097, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 52/200
#  - 3s - loss: 0.3830 - accuracy: 0.8333 - val_loss: 0.4159 - val_accuracy: 0.7900
#
# Epoch 00052: val_loss did not improve from 0.38097
# Epoch 53/200
#  - 3s - loss: 0.4081 - accuracy: 0.8113 - val_loss: 0.4354 - val_accuracy: 0.7900
#
# Epoch 00053: val_loss did not improve from 0.38097
# Epoch 54/200
#  - 3s - loss: 0.4061 - accuracy: 0.8208 - val_loss: 0.4061 - val_accuracy: 0.7900
#
# Epoch 00054: val_loss did not improve from 0.38097
# Epoch 55/200
#  - 3s - loss: 0.3933 - accuracy: 0.8176 - val_loss: 0.3778 - val_accuracy: 0.8300
#
# Epoch 00055: val_loss improved from 0.38097 to 0.37783, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 56/200
#  - 3s - loss: 0.3860 - accuracy: 0.8176 - val_loss: 0.3691 - val_accuracy: 0.8300
#
# Epoch 00056: val_loss improved from 0.37783 to 0.36915, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 57/200
#  - 3s - loss: 0.3798 - accuracy: 0.8522 - val_loss: 0.4384 - val_accuracy: 0.7700
#
# Epoch 00057: val_loss did not improve from 0.36915
# Epoch 58/200
#  - 3s - loss: 0.3736 - accuracy: 0.8428 - val_loss: 0.3689 - val_accuracy: 0.8300
#
# Epoch 00058: val_loss improved from 0.36915 to 0.36890, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 59/200
#  - 3s - loss: 0.3788 - accuracy: 0.8365 - val_loss: 0.3610 - val_accuracy: 0.8400
#
# Epoch 00059: val_loss improved from 0.36890 to 0.36103, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 60/200
#  - 3s - loss: 0.3897 - accuracy: 0.8145 - val_loss: 0.3571 - val_accuracy: 0.8500
#
# Epoch 00060: val_loss improved from 0.36103 to 0.35707, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 61/200
#  - 3s - loss: 0.3792 - accuracy: 0.8396 - val_loss: 0.3967 - val_accuracy: 0.8000
#
# Epoch 00061: val_loss did not improve from 0.35707
# Epoch 62/200
#  - 3s - loss: 0.3914 - accuracy: 0.8208 - val_loss: 0.3695 - val_accuracy: 0.8200
#
# Epoch 00062: val_loss did not improve from 0.35707
# Epoch 63/200
#  - 3s - loss: 0.3905 - accuracy: 0.8270 - val_loss: 0.3782 - val_accuracy: 0.8000
#
# Epoch 00063: val_loss did not improve from 0.35707
# Epoch 64/200
#  - 3s - loss: 0.3610 - accuracy: 0.8365 - val_loss: 0.5693 - val_accuracy: 0.7300
#
# Epoch 00064: val_loss did not improve from 0.35707
# Epoch 65/200
#  - 3s - loss: 0.4037 - accuracy: 0.8145 - val_loss: 0.3742 - val_accuracy: 0.8200
#
# Epoch 00065: val_loss did not improve from 0.35707
# Epoch 66/200
#  - 3s - loss: 0.3725 - accuracy: 0.8208 - val_loss: 0.3598 - val_accuracy: 0.8400
#
# Epoch 00066: val_loss did not improve from 0.35707
# Epoch 67/200
#  - 3s - loss: 0.3596 - accuracy: 0.8585 - val_loss: 0.3471 - val_accuracy: 0.8600
#
# Epoch 00067: val_loss improved from 0.35707 to 0.34707, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 68/200
#  - 3s - loss: 0.3521 - accuracy: 0.8459 - val_loss: 0.3637 - val_accuracy: 0.8300
#
# Epoch 00068: val_loss did not improve from 0.34707
# Epoch 69/200
#  - 3s - loss: 0.3512 - accuracy: 0.8396 - val_loss: 0.3469 - val_accuracy: 0.8300
#
# Epoch 00069: val_loss improved from 0.34707 to 0.34690, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 70/200
#  - 3s - loss: 0.3412 - accuracy: 0.8553 - val_loss: 0.3338 - val_accuracy: 0.8600
#
# Epoch 00070: val_loss improved from 0.34690 to 0.33384, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 71/200
#  - 3s - loss: 0.3354 - accuracy: 0.8648 - val_loss: 0.3318 - val_accuracy: 0.8500
#
# Epoch 00071: val_loss improved from 0.33384 to 0.33176, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 72/200
#  - 3s - loss: 0.3475 - accuracy: 0.8428 - val_loss: 0.3771 - val_accuracy: 0.8100
#
# Epoch 00072: val_loss did not improve from 0.33176
# Epoch 73/200
#  - 3s - loss: 0.3530 - accuracy: 0.8428 - val_loss: 0.3410 - val_accuracy: 0.8100
#
# Epoch 00073: val_loss did not improve from 0.33176
# Epoch 74/200
#  - 3s - loss: 0.3591 - accuracy: 0.8365 - val_loss: 0.3292 - val_accuracy: 0.8600
#
# Epoch 00074: val_loss improved from 0.33176 to 0.32924, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 75/200
#  - 3s - loss: 0.3279 - accuracy: 0.8616 - val_loss: 0.3133 - val_accuracy: 0.8500
#
# Epoch 00075: val_loss improved from 0.32924 to 0.31335, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 76/200
#  - 3s - loss: 0.3167 - accuracy: 0.8711 - val_loss: 0.3066 - val_accuracy: 0.8800
#
# Epoch 00076: val_loss improved from 0.31335 to 0.30657, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 77/200
#  - 3s - loss: 0.3171 - accuracy: 0.8742 - val_loss: 0.3046 - val_accuracy: 0.8700
#
# Epoch 00077: val_loss improved from 0.30657 to 0.30463, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 78/200
#  - 3s - loss: 0.3423 - accuracy: 0.8522 - val_loss: 0.3473 - val_accuracy: 0.8000
#
# Epoch 00078: val_loss did not improve from 0.30463
# Epoch 79/200
#  - 3s - loss: 0.3166 - accuracy: 0.8522 - val_loss: 0.3361 - val_accuracy: 0.7900
#
# Epoch 00079: val_loss did not improve from 0.30463
# Epoch 80/200
#  - 3s - loss: 0.3228 - accuracy: 0.8459 - val_loss: 0.4967 - val_accuracy: 0.8100
#
# Epoch 00080: val_loss did not improve from 0.30463
# Epoch 81/200
#  - 3s - loss: 0.3625 - accuracy: 0.8522 - val_loss: 0.3675 - val_accuracy: 0.8100
#
# Epoch 00081: val_loss did not improve from 0.30463
# Epoch 82/200
#  - 3s - loss: 0.3235 - accuracy: 0.8553 - val_loss: 0.3095 - val_accuracy: 0.8400
#
# Epoch 00082: val_loss did not improve from 0.30463
# Epoch 83/200
#  - 3s - loss: 0.3051 - accuracy: 0.8774 - val_loss: 0.2970 - val_accuracy: 0.9000
#
# Epoch 00083: val_loss improved from 0.30463 to 0.29699, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 84/200
#  - 3s - loss: 0.2940 - accuracy: 0.8805 - val_loss: 0.2889 - val_accuracy: 0.8800
#
# Epoch 00084: val_loss improved from 0.29699 to 0.28890, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 85/200
#  - 3s - loss: 0.2996 - accuracy: 0.8742 - val_loss: 0.2754 - val_accuracy: 0.8800
#
# Epoch 00085: val_loss improved from 0.28890 to 0.27537, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 86/200
#  - 3s - loss: 0.3175 - accuracy: 0.8491 - val_loss: 0.2811 - val_accuracy: 0.9000
#
# Epoch 00086: val_loss did not improve from 0.27537
# Epoch 87/200
#  - 3s - loss: 0.2863 - accuracy: 0.8742 - val_loss: 0.2916 - val_accuracy: 0.8400
#
# Epoch 00087: val_loss did not improve from 0.27537
# Epoch 88/200
#  - 3s - loss: 0.2837 - accuracy: 0.8711 - val_loss: 0.3148 - val_accuracy: 0.7800
#
# Epoch 00088: val_loss did not improve from 0.27537
# Epoch 89/200
#  - 3s - loss: 0.2819 - accuracy: 0.8868 - val_loss: 0.2867 - val_accuracy: 0.8900
#
# Epoch 00089: val_loss did not improve from 0.27537
# Epoch 90/200
#  - 3s - loss: 0.2704 - accuracy: 0.9057 - val_loss: 0.2607 - val_accuracy: 0.8900
#
# Epoch 00090: val_loss improved from 0.27537 to 0.26072, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 91/200
#  - 3s - loss: 0.2736 - accuracy: 0.8868 - val_loss: 0.2918 - val_accuracy: 0.8300
#
# Epoch 00091: val_loss did not improve from 0.26072
# Epoch 92/200
#  - 3s - loss: 0.2698 - accuracy: 0.8774 - val_loss: 0.3157 - val_accuracy: 0.8000
#
# Epoch 00092: val_loss did not improve from 0.26072
# Epoch 93/200
#  - 3s - loss: 0.2541 - accuracy: 0.8962 - val_loss: 0.2622 - val_accuracy: 0.8500
#
# Epoch 00093: val_loss did not improve from 0.26072
# Epoch 94/200
#  - 3s - loss: 0.2609 - accuracy: 0.8899 - val_loss: 0.2666 - val_accuracy: 0.8800
#
# Epoch 00094: val_loss did not improve from 0.26072
# Epoch 95/200
#  - 3s - loss: 0.2456 - accuracy: 0.9245 - val_loss: 0.2804 - val_accuracy: 0.9000
#
# Epoch 00095: val_loss did not improve from 0.26072
# Epoch 96/200
#  - 3s - loss: 0.2547 - accuracy: 0.8836 - val_loss: 0.2443 - val_accuracy: 0.9100
#
# Epoch 00096: val_loss improved from 0.26072 to 0.24434, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 97/200
#  - 3s - loss: 0.2458 - accuracy: 0.9057 - val_loss: 0.2635 - val_accuracy: 0.8600
#
# Epoch 00097: val_loss did not improve from 0.24434
# Epoch 98/200
#  - 3s - loss: 0.2284 - accuracy: 0.9214 - val_loss: 0.2384 - val_accuracy: 0.9200
#
# Epoch 00098: val_loss improved from 0.24434 to 0.23837, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 99/200
#  - 3s - loss: 0.2196 - accuracy: 0.9371 - val_loss: 0.2475 - val_accuracy: 0.9000
#
# Epoch 00099: val_loss did not improve from 0.23837
# Epoch 100/200
#  - 3s - loss: 0.2222 - accuracy: 0.9245 - val_loss: 0.3584 - val_accuracy: 0.8200
#
# Epoch 00100: val_loss did not improve from 0.23837
# Epoch 101/200
#  - 3s - loss: 0.2301 - accuracy: 0.9057 - val_loss: 0.2304 - val_accuracy: 0.9200
#
# Epoch 00101: val_loss improved from 0.23837 to 0.23038, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 102/200
#  - 3s - loss: 0.2775 - accuracy: 0.8679 - val_loss: 0.3309 - val_accuracy: 0.8200
#
# Epoch 00102: val_loss did not improve from 0.23038
# Epoch 103/200
#  - 3s - loss: 0.2921 - accuracy: 0.8679 - val_loss: 0.2323 - val_accuracy: 0.9200
#
# Epoch 00103: val_loss did not improve from 0.23038
# Epoch 104/200
#  - 3s - loss: 0.2167 - accuracy: 0.9277 - val_loss: 0.2331 - val_accuracy: 0.9000
#
# Epoch 00104: val_loss did not improve from 0.23038
# Epoch 105/200
#  - 3s - loss: 0.2089 - accuracy: 0.9403 - val_loss: 0.2185 - val_accuracy: 0.9100
#
# Epoch 00105: val_loss improved from 0.23038 to 0.21846, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 106/200
#  - 3s - loss: 0.1963 - accuracy: 0.9403 - val_loss: 0.2322 - val_accuracy: 0.8900
#
# Epoch 00106: val_loss did not improve from 0.21846
# Epoch 107/200
#  - 3s - loss: 0.2427 - accuracy: 0.9025 - val_loss: 0.3059 - val_accuracy: 0.8200
#
# Epoch 00107: val_loss did not improve from 0.21846
# Epoch 108/200
#  - 3s - loss: 0.2119 - accuracy: 0.9245 - val_loss: 0.2077 - val_accuracy: 0.9200
#
# Epoch 00108: val_loss improved from 0.21846 to 0.20774, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 109/200
#  - 3s - loss: 0.1938 - accuracy: 0.9371 - val_loss: 0.2626 - val_accuracy: 0.9000
#
# Epoch 00109: val_loss did not improve from 0.20774
# Epoch 110/200
#  - 3s - loss: 0.2507 - accuracy: 0.8836 - val_loss: 0.2140 - val_accuracy: 0.9200
#
# Epoch 00110: val_loss did not improve from 0.20774
# Epoch 111/200
#  - 3s - loss: 0.2009 - accuracy: 0.9277 - val_loss: 0.2799 - val_accuracy: 0.8900
#
# Epoch 00111: val_loss did not improve from 0.20774
# Epoch 112/200
#  - 3s - loss: 0.2206 - accuracy: 0.9277 - val_loss: 0.2288 - val_accuracy: 0.8700
#
# Epoch 00112: val_loss did not improve from 0.20774
# Epoch 113/200
#  - 3s - loss: 0.1820 - accuracy: 0.9465 - val_loss: 0.1979 - val_accuracy: 0.9100
#
# Epoch 00113: val_loss improved from 0.20774 to 0.19792, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 114/200
#  - 3s - loss: 0.2010 - accuracy: 0.9308 - val_loss: 0.2514 - val_accuracy: 0.9100
#
# Epoch 00114: val_loss did not improve from 0.19792
# Epoch 115/200
#  - 3s - loss: 0.1958 - accuracy: 0.9340 - val_loss: 0.2234 - val_accuracy: 0.9200
#
# Epoch 00115: val_loss did not improve from 0.19792
# Epoch 116/200
#  - 3s - loss: 0.2077 - accuracy: 0.9119 - val_loss: 0.2789 - val_accuracy: 0.8500
#
# Epoch 00116: val_loss did not improve from 0.19792
# Epoch 117/200
#  - 3s - loss: 0.2047 - accuracy: 0.9119 - val_loss: 0.3318 - val_accuracy: 0.8400
#
# Epoch 00117: val_loss did not improve from 0.19792
# Epoch 118/200
#  - 3s - loss: 0.1915 - accuracy: 0.9434 - val_loss: 0.2372 - val_accuracy: 0.9100
#
# Epoch 00118: val_loss did not improve from 0.19792
# Epoch 119/200
#  - 3s - loss: 0.1721 - accuracy: 0.9403 - val_loss: 0.2079 - val_accuracy: 0.9000
#
# Epoch 00119: val_loss did not improve from 0.19792
# Epoch 120/200
#  - 3s - loss: 0.1882 - accuracy: 0.9371 - val_loss: 0.1959 - val_accuracy: 0.9100
#
# Epoch 00120: val_loss improved from 0.19792 to 0.19586, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 121/200
#  - 3s - loss: 0.1664 - accuracy: 0.9497 - val_loss: 0.2217 - val_accuracy: 0.9200
#
# Epoch 00121: val_loss did not improve from 0.19586
# Epoch 122/200
#  - 3s - loss: 0.1596 - accuracy: 0.9465 - val_loss: 0.2020 - val_accuracy: 0.9000
#
# Epoch 00122: val_loss did not improve from 0.19586
# Epoch 123/200
#  - 3s - loss: 0.1511 - accuracy: 0.9623 - val_loss: 0.1800 - val_accuracy: 0.9300
#
# Epoch 00123: val_loss improved from 0.19586 to 0.18000, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 124/200
#  - 3s - loss: 0.1706 - accuracy: 0.9371 - val_loss: 0.1933 - val_accuracy: 0.9400
#
# Epoch 00124: val_loss did not improve from 0.18000
# Epoch 125/200
#  - 3s - loss: 0.1467 - accuracy: 0.9654 - val_loss: 0.1904 - val_accuracy: 0.9500
#
# Epoch 00125: val_loss did not improve from 0.18000
# Epoch 126/200
#  - 3s - loss: 0.1694 - accuracy: 0.9214 - val_loss: 0.1944 - val_accuracy: 0.9100
#
# Epoch 00126: val_loss did not improve from 0.18000
# Epoch 127/200
#  - 3s - loss: 0.1511 - accuracy: 0.9528 - val_loss: 0.4269 - val_accuracy: 0.8000
#
# Epoch 00127: val_loss did not improve from 0.18000
# Epoch 128/200
#  - 3s - loss: 0.1720 - accuracy: 0.9371 - val_loss: 0.1851 - val_accuracy: 0.9300
#
# Epoch 00128: val_loss did not improve from 0.18000
# Epoch 129/200
#  - 3s - loss: 0.1342 - accuracy: 0.9686 - val_loss: 0.1882 - val_accuracy: 0.9100
#
# Epoch 00129: val_loss did not improve from 0.18000
# Epoch 130/200
#  - 3s - loss: 0.1590 - accuracy: 0.9465 - val_loss: 0.2162 - val_accuracy: 0.8900
#
# Epoch 00130: val_loss did not improve from 0.18000
# Epoch 131/200
#  - 3s - loss: 0.1553 - accuracy: 0.9497 - val_loss: 0.1836 - val_accuracy: 0.9200
#
# Epoch 00131: val_loss did not improve from 0.18000
# Epoch 132/200
#  - 3s - loss: 0.1429 - accuracy: 0.9623 - val_loss: 0.1765 - val_accuracy: 0.9200
#
# Epoch 00132: val_loss improved from 0.18000 to 0.17649, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 133/200
#  - 3s - loss: 0.1296 - accuracy: 0.9623 - val_loss: 0.1857 - val_accuracy: 0.9500
#
# Epoch 00133: val_loss did not improve from 0.17649
# Epoch 134/200
#  - 3s - loss: 0.1256 - accuracy: 0.9623 - val_loss: 0.1661 - val_accuracy: 0.9300
#
# Epoch 00134: val_loss improved from 0.17649 to 0.16610, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 135/200
#  - 3s - loss: 0.1270 - accuracy: 0.9591 - val_loss: 0.1742 - val_accuracy: 0.9600
#
# Epoch 00135: val_loss did not improve from 0.16610
# Epoch 136/200
#  - 3s - loss: 0.1271 - accuracy: 0.9591 - val_loss: 0.1626 - val_accuracy: 0.9500
#
# Epoch 00136: val_loss improved from 0.16610 to 0.16263, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 137/200
#  - 3s - loss: 0.1215 - accuracy: 0.9654 - val_loss: 0.1912 - val_accuracy: 0.9200
#
# Epoch 00137: val_loss did not improve from 0.16263
# Epoch 138/200
#  - 3s - loss: 0.1299 - accuracy: 0.9591 - val_loss: 0.2037 - val_accuracy: 0.8900
#
# Epoch 00138: val_loss did not improve from 0.16263
# Epoch 139/200
#  - 3s - loss: 0.1206 - accuracy: 0.9591 - val_loss: 0.1689 - val_accuracy: 0.9500
#
# Epoch 00139: val_loss did not improve from 0.16263
# Epoch 140/200
#  - 3s - loss: 0.1125 - accuracy: 0.9686 - val_loss: 0.1674 - val_accuracy: 0.9200
#
# Epoch 00140: val_loss did not improve from 0.16263
# Epoch 141/200
#  - 3s - loss: 0.1391 - accuracy: 0.9497 - val_loss: 0.2164 - val_accuracy: 0.8700
#
# Epoch 00141: val_loss did not improve from 0.16263
# Epoch 142/200
#  - 3s - loss: 0.1392 - accuracy: 0.9528 - val_loss: 0.1798 - val_accuracy: 0.9500
#
# Epoch 00142: val_loss did not improve from 0.16263
# Epoch 143/200
#  - 3s - loss: 0.1428 - accuracy: 0.9277 - val_loss: 0.2153 - val_accuracy: 0.9300
#
# Epoch 00143: val_loss did not improve from 0.16263
# Epoch 144/200
#  - 3s - loss: 0.1751 - accuracy: 0.9277 - val_loss: 0.1839 - val_accuracy: 0.9100
#
# Epoch 00144: val_loss did not improve from 0.16263
# Epoch 145/200
#  - 3s - loss: 0.1223 - accuracy: 0.9591 - val_loss: 0.1672 - val_accuracy: 0.9500
#
# Epoch 00145: val_loss did not improve from 0.16263
# Epoch 146/200
#  - 3s - loss: 0.1143 - accuracy: 0.9560 - val_loss: 0.1625 - val_accuracy: 0.9300
#
# Epoch 00146: val_loss improved from 0.16263 to 0.16251, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 147/200
#  - 3s - loss: 0.1042 - accuracy: 0.9654 - val_loss: 0.1663 - val_accuracy: 0.9300
#
# Epoch 00147: val_loss did not improve from 0.16251
# Epoch 148/200
#  - 3s - loss: 0.0987 - accuracy: 0.9717 - val_loss: 0.1562 - val_accuracy: 0.9400
#
# Epoch 00148: val_loss improved from 0.16251 to 0.15621, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 149/200
#  - 3s - loss: 0.1011 - accuracy: 0.9654 - val_loss: 0.2099 - val_accuracy: 0.9000
#
# Epoch 00149: val_loss did not improve from 0.15621
# Epoch 150/200
#  - 3s - loss: 0.1083 - accuracy: 0.9591 - val_loss: 0.1561 - val_accuracy: 0.9300
#
# Epoch 00150: val_loss improved from 0.15621 to 0.15614, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 151/200
#  - 3s - loss: 0.1039 - accuracy: 0.9686 - val_loss: 0.1432 - val_accuracy: 0.9400
#
# Epoch 00151: val_loss improved from 0.15614 to 0.14315, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 152/200
#  - 3s - loss: 0.1080 - accuracy: 0.9528 - val_loss: 0.1748 - val_accuracy: 0.9000
#
# Epoch 00152: val_loss did not improve from 0.14315
# Epoch 153/200
#  - 3s - loss: 0.1091 - accuracy: 0.9591 - val_loss: 0.1426 - val_accuracy: 0.9600
#
# Epoch 00153: val_loss improved from 0.14315 to 0.14264, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 154/200
#  - 3s - loss: 0.0968 - accuracy: 0.9623 - val_loss: 0.1405 - val_accuracy: 0.9600
#
# Epoch 00154: val_loss improved from 0.14264 to 0.14052, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 155/200
#  - 3s - loss: 0.0992 - accuracy: 0.9623 - val_loss: 0.1860 - val_accuracy: 0.9300
#
# Epoch 00155: val_loss did not improve from 0.14052
# Epoch 156/200
#  - 3s - loss: 0.1163 - accuracy: 0.9560 - val_loss: 0.1634 - val_accuracy: 0.9600
#
# Epoch 00156: val_loss did not improve from 0.14052
# Epoch 157/200
#  - 3s - loss: 0.0974 - accuracy: 0.9654 - val_loss: 0.1505 - val_accuracy: 0.9600
#
# Epoch 00157: val_loss did not improve from 0.14052
# Epoch 158/200
#  - 3s - loss: 0.0931 - accuracy: 0.9654 - val_loss: 0.1311 - val_accuracy: 0.9700
#
# Epoch 00158: val_loss improved from 0.14052 to 0.13108, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 159/200
#  - 3s - loss: 0.0820 - accuracy: 0.9686 - val_loss: 0.1311 - val_accuracy: 0.9700
#
# Epoch 00159: val_loss did not improve from 0.13108
# Epoch 160/200
#  - 3s - loss: 0.0920 - accuracy: 0.9591 - val_loss: 0.1427 - val_accuracy: 0.9500
#
# Epoch 00160: val_loss did not improve from 0.13108
# Epoch 161/200
#  - 3s - loss: 0.0962 - accuracy: 0.9654 - val_loss: 0.1977 - val_accuracy: 0.9000
#
# Epoch 00161: val_loss did not improve from 0.13108
# Epoch 162/200
#  - 3s - loss: 0.1180 - accuracy: 0.9497 - val_loss: 0.1469 - val_accuracy: 0.9500
#
# Epoch 00162: val_loss did not improve from 0.13108
# Epoch 163/200
#  - 3s - loss: 0.0888 - accuracy: 0.9654 - val_loss: 0.1316 - val_accuracy: 0.9600
#
# Epoch 00163: val_loss did not improve from 0.13108
# Epoch 164/200
#  - 3s - loss: 0.0851 - accuracy: 0.9686 - val_loss: 0.1427 - val_accuracy: 0.9600
#
# Epoch 00164: val_loss did not improve from 0.13108
# Epoch 165/200
#  - 3s - loss: 0.0914 - accuracy: 0.9686 - val_loss: 0.1346 - val_accuracy: 0.9600
#
# Epoch 00165: val_loss did not improve from 0.13108
# Epoch 166/200
#  - 3s - loss: 0.0858 - accuracy: 0.9748 - val_loss: 0.1430 - val_accuracy: 0.9300
#
# Epoch 00166: val_loss did not improve from 0.13108
# Epoch 167/200
#  - 3s - loss: 0.0695 - accuracy: 0.9748 - val_loss: 0.1613 - val_accuracy: 0.9600
#
# Epoch 00167: val_loss did not improve from 0.13108
# Epoch 168/200
#  - 3s - loss: 0.0948 - accuracy: 0.9591 - val_loss: 0.1526 - val_accuracy: 0.9600
#
# Epoch 00168: val_loss did not improve from 0.13108
# Epoch 169/200
#  - 3s - loss: 0.0690 - accuracy: 0.9748 - val_loss: 0.1959 - val_accuracy: 0.9500
#
# Epoch 00169: val_loss did not improve from 0.13108
# Epoch 170/200
#  - 3s - loss: 0.1371 - accuracy: 0.9465 - val_loss: 0.1918 - val_accuracy: 0.9500
#
# Epoch 00170: val_loss did not improve from 0.13108
# Epoch 171/200
#  - 3s - loss: 0.1471 - accuracy: 0.9371 - val_loss: 0.1373 - val_accuracy: 0.9700
#
# Epoch 00171: val_loss did not improve from 0.13108
# Epoch 172/200
#  - 3s - loss: 0.1150 - accuracy: 0.9591 - val_loss: 0.1503 - val_accuracy: 0.9600
#
# Epoch 00172: val_loss did not improve from 0.13108
# Epoch 173/200
#  - 3s - loss: 0.0848 - accuracy: 0.9686 - val_loss: 0.1253 - val_accuracy: 0.9700
#
# Epoch 00173: val_loss improved from 0.13108 to 0.12534, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 174/200
#  - 3s - loss: 0.0884 - accuracy: 0.9654 - val_loss: 0.1431 - val_accuracy: 0.9400
#
# Epoch 00174: val_loss did not improve from 0.12534
# Epoch 175/200
#  - 3s - loss: 0.0881 - accuracy: 0.9748 - val_loss: 0.1621 - val_accuracy: 0.9500
#
# Epoch 00175: val_loss did not improve from 0.12534
# Epoch 176/200
#  - 3s - loss: 0.0755 - accuracy: 0.9717 - val_loss: 0.1269 - val_accuracy: 0.9700
#
# Epoch 00176: val_loss did not improve from 0.12534
# Epoch 177/200
#  - 3s - loss: 0.0876 - accuracy: 0.9623 - val_loss: 0.1436 - val_accuracy: 0.9400
#
# Epoch 00177: val_loss did not improve from 0.12534
# Epoch 178/200
#  - 3s - loss: 0.0669 - accuracy: 0.9811 - val_loss: 0.1343 - val_accuracy: 0.9600
#
# Epoch 00178: val_loss did not improve from 0.12534
# Epoch 179/200
#  - 3s - loss: 0.0971 - accuracy: 0.9654 - val_loss: 0.1656 - val_accuracy: 0.9500
#
# Epoch 00179: val_loss did not improve from 0.12534
# Epoch 180/200
#  - 3s - loss: 0.0661 - accuracy: 0.9717 - val_loss: 0.3753 - val_accuracy: 0.8500
#
# Epoch 00180: val_loss did not improve from 0.12534
# Epoch 181/200
#  - 3s - loss: 0.1041 - accuracy: 0.9591 - val_loss: 0.1693 - val_accuracy: 0.9200
#
# Epoch 00181: val_loss did not improve from 0.12534
# Epoch 182/200
#  - 3s - loss: 0.0782 - accuracy: 0.9780 - val_loss: 0.1449 - val_accuracy: 0.9500
#
# Epoch 00182: val_loss did not improve from 0.12534
# Epoch 183/200
#  - 3s - loss: 0.0669 - accuracy: 0.9686 - val_loss: 0.1165 - val_accuracy: 0.9800
#
# Epoch 00183: val_loss improved from 0.12534 to 0.11650, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 184/200
#  - 3s - loss: 0.0633 - accuracy: 0.9811 - val_loss: 0.1304 - val_accuracy: 0.9500
#
# Epoch 00184: val_loss did not improve from 0.11650
# Epoch 185/200
#  - 3s - loss: 0.0862 - accuracy: 0.9623 - val_loss: 0.2010 - val_accuracy: 0.9300
#
# Epoch 00185: val_loss did not improve from 0.11650
# Epoch 186/200
#  - 3s - loss: 0.0859 - accuracy: 0.9717 - val_loss: 0.1220 - val_accuracy: 0.9700
#
# Epoch 00186: val_loss did not improve from 0.11650
# Epoch 187/200
#  - 3s - loss: 0.0566 - accuracy: 0.9843 - val_loss: 0.1199 - val_accuracy: 0.9700
#
# Epoch 00187: val_loss did not improve from 0.11650
# Epoch 188/200
#  - 3s - loss: 0.0815 - accuracy: 0.9654 - val_loss: 0.1986 - val_accuracy: 0.9400
#
# Epoch 00188: val_loss did not improve from 0.11650
# Epoch 189/200
#  - 3s - loss: 0.0633 - accuracy: 0.9748 - val_loss: 0.1136 - val_accuracy: 0.9800
#
# Epoch 00189: val_loss improved from 0.11650 to 0.11364, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 190/200
#  - 3s - loss: 0.0862 - accuracy: 0.9623 - val_loss: 0.1373 - val_accuracy: 0.9500
#
# Epoch 00190: val_loss did not improve from 0.11364
# Epoch 191/200
#  - 3s - loss: 0.1008 - accuracy: 0.9560 - val_loss: 0.1040 - val_accuracy: 0.9700
#
# Epoch 00191: val_loss improved from 0.11364 to 0.10398, saving model to Model_depthwise_1_arson.weights.best.hdf5
# Epoch 192/200
#  - 3s - loss: 0.0738 - accuracy: 0.9686 - val_loss: 0.1216 - val_accuracy: 0.9500
#
# Epoch 00192: val_loss did not improve from 0.10398
# Epoch 193/200
#  - 3s - loss: 0.0519 - accuracy: 0.9811 - val_loss: 0.1347 - val_accuracy: 0.9500
#
# Epoch 00193: val_loss did not improve from 0.10398
# Epoch 194/200
#  - 3s - loss: 0.0560 - accuracy: 0.9811 - val_loss: 0.1155 - val_accuracy: 0.9700
#
# Epoch 00194: val_loss did not improve from 0.10398
# Epoch 195/200
#  - 3s - loss: 0.0819 - accuracy: 0.9686 - val_loss: 0.1188 - val_accuracy: 0.9700
#
# Epoch 00195: val_loss did not improve from 0.10398
# Epoch 196/200
#  - 3s - loss: 0.0971 - accuracy: 0.9654 - val_loss: 0.2714 - val_accuracy: 0.8600
#
# Epoch 00196: val_loss did not improve from 0.10398
# Epoch 197/200
#  - 3s - loss: 0.1478 - accuracy: 0.9277 - val_loss: 0.2374 - val_accuracy: 0.9200
#
# Epoch 00197: val_loss did not improve from 0.10398
# Epoch 198/200
#  - 3s - loss: 0.1387 - accuracy: 0.9340 - val_loss: 0.1406 - val_accuracy: 0.9600
#
# Epoch 00198: val_loss did not improve from 0.10398
# Epoch 199/200
#  - 3s - loss: 0.0664 - accuracy: 0.9717 - val_loss: 0.1064 - val_accuracy: 0.9700
#
# Epoch 00199: val_loss did not improve from 0.10398
# Epoch 200/200
#  - 3s - loss: 0.0918 - accuracy: 0.9686 - val_loss: 0.1510 - val_accuracy: 0.9400
#
# Epoch 00200: val_loss did not improve from 0.10398

# %%
# Loading the model that performed the best on the validation set
model_d.load_weights('/content/Model_depthwise_1_arson.weights.best.hdf5')

# Testing the model on the Test data
(loss, accuracy) = model_d.evaluate(X_test, y_test, batch_size=16, verbose=0)

print('Accuracy on test data: {:.2f}%'.format(accuracy * 100))

# Making the plot larger
plt.figure(figsize=(12, 8))

loss = history.history['loss']                          # Loss on the training data
val_loss = history.history['val_loss']                  # Loss on the validation data
epochs = range(1, 201)

plt.plot(epochs, loss, 'ro-', label='Training Loss')
plt.plot(epochs, val_loss, 'go-', label = 'Validation Loss')
plt.legend()


# Making the plot larger
plt.figure(figsize=(12, 8))

acc = history.history['accuracy']                          # Loss on the training data
val_acc = history.history['val_accuracy']                  # Loss on the validation data
epochs = range(1, 201)

plt.plot(epochs, acc, 'ro-', label='Training Accuracy')
plt.plot(epochs, val_acc, 'go-', label = 'Validation Accuracy')
plt.legend()


y_pred=model_d.predict(X_test)
y_pred=y_pred>0.80
target_names = ['class Normal', 'class arson']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
# Accuracy on test data: 95.24%
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
# class Normal       1.00      0.89      0.94       112
#  class arson       0.97      0.91      0.94        98
#
#    micro avg       0.98      0.90      0.94       210
#    macro avg       0.98      0.90      0.94       210
# weighted avg       0.98      0.90      0.94       210
#  samples avg       0.90      0.90      0.90       210

# %%
model_d = Sequential()

# Adding Alternate convolutional and pooling layers
model_d.add(DepthwiseConv3D( kernel_size=(10, 3, 3),depth_multiplier=2, strides=(1, 1, 1), padding='same', activation='relu', 
                 input_shape=X_train.shape[1:]))
model_d.add(MaxPooling3D(pool_size=2, strides=(1, 2, 2), padding='same'))

model_d.add(DepthwiseConv3D( depth_multiplier=2,kernel_size=(5, 3, 3), strides=(3, 1, 1), padding='valid', activation='relu'))
model_d.add(MaxPooling3D(pool_size=2, strides=(1, 2, 2), padding='same'))

model_d.add(DepthwiseConv3D(depth_multiplier=2, kernel_size=(5, 3, 3), strides=(3, 1, 1), padding='valid', activation='relu'))
model_d.add(MaxPooling3D(pool_size=2, strides=(1, 2, 2), padding='same'))

# A global average pooling layer to get a 1-d vector
# The vector will have a depth (same as number of elements in the vector) of 256
model_d.add(GlobalAveragePooling3D())

# The Global average pooling layer is followed by a fully-connected neural network, with one hidden and one output layer

# Hidden Layer
model_d.add(Dense(32, activation='relu'))

# Output layer
model_d.add(Dense(2, activation='softmax'))

model_d.summary()

from keras.callbacks import ModelCheckpoint

# Compiling the model
model_d.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Saving the model that performed the best on the validation set
checkpoint = ModelCheckpoint(filepath='Model_depthwise_2_arson.weights.best.hdf5', save_best_only=True, verbose=1)

# Training the model for 40 epochs
history = model_d.fit(X_train, y_train, batch_size=16, epochs=200, 
                    validation_data=(X_valid, y_valid), verbose=2, callbacks=[checkpoint])

# Loading the model that performed the best on the validation set
model_d.load_weights('/content/Model_depthwise_2_arson.weights.best.hdf5')

# Testing the model on the Test data
(loss, accuracy) = model_d.evaluate(X_test, y_test, batch_size=16, verbose=0)

print('Accuracy on test data: {:.2f}%'.format(accuracy * 100))

# Making the plot larger
plt.figure(figsize=(12, 8))

loss = history.history['loss']                          # Loss on the training data
val_loss = history.history['val_loss']                  # Loss on the validation data
epochs = range(1, 201)

plt.plot(epochs, loss, 'ro-', label='Training Loss')
plt.plot(epochs, val_loss, 'go-', label = 'Validation Loss')
plt.legend()


# Making the plot larger
plt.figure(figsize=(12, 8))

acc = history.history['accuracy']                          # Loss on the training data
val_acc = history.history['val_accuracy']                  # Loss on the validation data
epochs = range(1, 201)

plt.plot(epochs, acc, 'ro-', label='Training Accuracy')
plt.plot(epochs, val_acc, 'go-', label = 'Validation Accuracy')
plt.legend()


y_pred=model_d.predict(X_test)
y_pred=y_pred>0.80
target_names = ['class Normal', 'class arson']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# depthwise_conv3d_23 (Depthwi (None, 29, 128, 128, 2)   182
# _________________________________________________________________
# max_pooling3d_36 (MaxPooling (None, 29, 64, 64, 2)     0
# _________________________________________________________________
# depthwise_conv3d_24 (Depthwi (None, 9, 62, 62, 4)      184
# _________________________________________________________________
# max_pooling3d_37 (MaxPooling (None, 9, 31, 31, 4)      0
# _________________________________________________________________
# depthwise_conv3d_25 (Depthwi (None, 2, 29, 29, 8)      368
# _________________________________________________________________
# max_pooling3d_38 (MaxPooling (None, 2, 15, 15, 8)      0
# _________________________________________________________________
# global_average_pooling3d_11  (None, 8)                 0
# _________________________________________________________________
# dense_21 (Dense)             (None, 32)                288
# _________________________________________________________________
# dense_22 (Dense)             (None, 2)                 66
# =================================================================
# Total params: 1,088
# Trainable params: 1,088
# Non-trainable params: 0
# _________________________________________________________________
# Train on 318 samples, validate on 100 samples
# Epoch 1/200
#  - 3s - loss: 0.6843 - accuracy: 0.5472 - val_loss: 0.7021 - val_accuracy: 0.4800
#
# Epoch 00001: val_loss improved from inf to 0.70208, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 2/200
#  - 2s - loss: 0.6861 - accuracy: 0.5283 - val_loss: 0.6866 - val_accuracy: 0.4900
#
# Epoch 00002: val_loss improved from 0.70208 to 0.68663, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 3/200
#  - 2s - loss: 0.6757 - accuracy: 0.5535 - val_loss: 0.6764 - val_accuracy: 0.5100
#
# Epoch 00003: val_loss improved from 0.68663 to 0.67644, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 4/200
#  - 2s - loss: 0.6618 - accuracy: 0.6038 - val_loss: 0.6972 - val_accuracy: 0.5200
#
# Epoch 00004: val_loss did not improve from 0.67644
# Epoch 5/200
#  - 2s - loss: 0.6756 - accuracy: 0.5409 - val_loss: 0.6707 - val_accuracy: 0.5100
#
# Epoch 00005: val_loss improved from 0.67644 to 0.67066, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 6/200
#  - 3s - loss: 0.6383 - accuracy: 0.6321 - val_loss: 0.6596 - val_accuracy: 0.5700
#
# Epoch 00006: val_loss improved from 0.67066 to 0.65964, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 7/200
#  - 3s - loss: 0.6150 - accuracy: 0.6981 - val_loss: 0.6256 - val_accuracy: 0.5800
#
# Epoch 00007: val_loss improved from 0.65964 to 0.62557, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 8/200
#  - 3s - loss: 0.6274 - accuracy: 0.6038 - val_loss: 0.6436 - val_accuracy: 0.6200
#
# Epoch 00008: val_loss did not improve from 0.62557
# Epoch 9/200
#  - 2s - loss: 0.5902 - accuracy: 0.6918 - val_loss: 0.5885 - val_accuracy: 0.7400
#
# Epoch 00009: val_loss improved from 0.62557 to 0.58851, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 10/200
#  - 2s - loss: 0.5470 - accuracy: 0.7044 - val_loss: 0.5683 - val_accuracy: 0.6800
#
# Epoch 00010: val_loss improved from 0.58851 to 0.56835, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 11/200
#  - 2s - loss: 0.5142 - accuracy: 0.7736 - val_loss: 0.6231 - val_accuracy: 0.6000
#
# Epoch 00011: val_loss did not improve from 0.56835
# Epoch 12/200
#  - 2s - loss: 0.5251 - accuracy: 0.7296 - val_loss: 0.5364 - val_accuracy: 0.7800
#
# Epoch 00012: val_loss improved from 0.56835 to 0.53637, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 13/200
#  - 2s - loss: 0.4887 - accuracy: 0.7736 - val_loss: 0.5364 - val_accuracy: 0.7200
#
# Epoch 00013: val_loss did not improve from 0.53637
# Epoch 14/200
#  - 2s - loss: 0.5020 - accuracy: 0.7421 - val_loss: 0.5454 - val_accuracy: 0.7100
#
# Epoch 00014: val_loss did not improve from 0.53637
# Epoch 15/200
#  - 2s - loss: 0.5147 - accuracy: 0.7484 - val_loss: 0.5607 - val_accuracy: 0.6900
#
# Epoch 00015: val_loss did not improve from 0.53637
# Epoch 16/200
#  - 2s - loss: 0.4875 - accuracy: 0.8019 - val_loss: 0.5256 - val_accuracy: 0.7400
#
# Epoch 00016: val_loss improved from 0.53637 to 0.52560, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 17/200
#  - 2s - loss: 0.4743 - accuracy: 0.7925 - val_loss: 0.5121 - val_accuracy: 0.8000
#
# Epoch 00017: val_loss improved from 0.52560 to 0.51207, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 18/200
#  - 2s - loss: 0.4774 - accuracy: 0.8019 - val_loss: 0.5056 - val_accuracy: 0.7800
#
# Epoch 00018: val_loss improved from 0.51207 to 0.50560, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 19/200
#  - 2s - loss: 0.4516 - accuracy: 0.8333 - val_loss: 0.5653 - val_accuracy: 0.7100
#
# Epoch 00019: val_loss did not improve from 0.50560
# Epoch 20/200
#  - 2s - loss: 0.4586 - accuracy: 0.7925 - val_loss: 0.4997 - val_accuracy: 0.7900
#
# Epoch 00020: val_loss improved from 0.50560 to 0.49973, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 21/200
#  - 2s - loss: 0.4606 - accuracy: 0.8082 - val_loss: 0.5034 - val_accuracy: 0.7700
#
# Epoch 00021: val_loss did not improve from 0.49973
# Epoch 22/200
#  - 2s - loss: 0.4577 - accuracy: 0.7893 - val_loss: 0.4995 - val_accuracy: 0.8000
#
# Epoch 00022: val_loss improved from 0.49973 to 0.49946, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 23/200
#  - 2s - loss: 0.4473 - accuracy: 0.8019 - val_loss: 0.5227 - val_accuracy: 0.7400
#
# Epoch 00023: val_loss did not improve from 0.49946
# Epoch 24/200
#  - 2s - loss: 0.4426 - accuracy: 0.8050 - val_loss: 0.5032 - val_accuracy: 0.7600
#
# Epoch 00024: val_loss did not improve from 0.49946
# Epoch 25/200
#  - 2s - loss: 0.4478 - accuracy: 0.8082 - val_loss: 0.5160 - val_accuracy: 0.7400
#
# Epoch 00025: val_loss did not improve from 0.49946
# Epoch 26/200
#  - 2s - loss: 0.4593 - accuracy: 0.8113 - val_loss: 0.4972 - val_accuracy: 0.7900
#
# Epoch 00026: val_loss improved from 0.49946 to 0.49719, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 27/200
#  - 2s - loss: 0.4951 - accuracy: 0.7704 - val_loss: 0.5124 - val_accuracy: 0.7700
#
# Epoch 00027: val_loss did not improve from 0.49719
# Epoch 28/200
#  - 2s - loss: 0.4425 - accuracy: 0.8208 - val_loss: 0.4958 - val_accuracy: 0.7900
#
# Epoch 00028: val_loss improved from 0.49719 to 0.49584, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 29/200
#  - 2s - loss: 0.4589 - accuracy: 0.7830 - val_loss: 0.5124 - val_accuracy: 0.7400
#
# Epoch 00029: val_loss did not improve from 0.49584
# Epoch 30/200
#  - 2s - loss: 0.4398 - accuracy: 0.8333 - val_loss: 0.5000 - val_accuracy: 0.7500
#
# Epoch 00030: val_loss did not improve from 0.49584
# Epoch 31/200
#  - 2s - loss: 0.4434 - accuracy: 0.8208 - val_loss: 0.5223 - val_accuracy: 0.7200
#
# Epoch 00031: val_loss did not improve from 0.49584
# Epoch 32/200
#  - 2s - loss: 0.4395 - accuracy: 0.8208 - val_loss: 0.5087 - val_accuracy: 0.7800
#
# Epoch 00032: val_loss did not improve from 0.49584
# Epoch 33/200
#  - 2s - loss: 0.4396 - accuracy: 0.8208 - val_loss: 0.4873 - val_accuracy: 0.7900
#
# Epoch 00033: val_loss improved from 0.49584 to 0.48733, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 34/200
#  - 2s - loss: 0.4308 - accuracy: 0.7987 - val_loss: 0.5202 - val_accuracy: 0.7200
#
# Epoch 00034: val_loss did not improve from 0.48733
# Epoch 35/200
#  - 2s - loss: 0.4504 - accuracy: 0.7956 - val_loss: 0.4984 - val_accuracy: 0.7800
#
# Epoch 00035: val_loss did not improve from 0.48733
# Epoch 36/200
#  - 2s - loss: 0.4357 - accuracy: 0.8145 - val_loss: 0.4875 - val_accuracy: 0.8000
#
# Epoch 00036: val_loss did not improve from 0.48733
# Epoch 37/200
#  - 2s - loss: 0.4350 - accuracy: 0.8239 - val_loss: 0.4884 - val_accuracy: 0.7900
#
# Epoch 00037: val_loss did not improve from 0.48733
# Epoch 38/200
#  - 2s - loss: 0.4412 - accuracy: 0.8239 - val_loss: 0.4887 - val_accuracy: 0.7900
#
# Epoch 00038: val_loss did not improve from 0.48733
# Epoch 39/200
#  - 2s - loss: 0.4371 - accuracy: 0.8176 - val_loss: 0.4872 - val_accuracy: 0.7900
#
# Epoch 00039: val_loss improved from 0.48733 to 0.48725, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 40/200
#  - 3s - loss: 0.4390 - accuracy: 0.8176 - val_loss: 0.4845 - val_accuracy: 0.7900
#
# Epoch 00040: val_loss improved from 0.48725 to 0.48449, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 41/200
#  - 3s - loss: 0.4312 - accuracy: 0.8208 - val_loss: 0.5128 - val_accuracy: 0.7300
#
# Epoch 00041: val_loss did not improve from 0.48449
# Epoch 42/200
#  - 2s - loss: 0.4521 - accuracy: 0.8082 - val_loss: 0.4914 - val_accuracy: 0.7900
#
# Epoch 00042: val_loss did not improve from 0.48449
# Epoch 43/200
#  - 2s - loss: 0.4459 - accuracy: 0.7987 - val_loss: 0.4837 - val_accuracy: 0.7900
#
# Epoch 00043: val_loss improved from 0.48449 to 0.48367, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 44/200
#  - 2s - loss: 0.4342 - accuracy: 0.8082 - val_loss: 0.4972 - val_accuracy: 0.8000
#
# Epoch 00044: val_loss did not improve from 0.48367
# Epoch 45/200
#  - 3s - loss: 0.4400 - accuracy: 0.8050 - val_loss: 0.4987 - val_accuracy: 0.8000
#
# Epoch 00045: val_loss did not improve from 0.48367
# Epoch 46/200
#  - 3s - loss: 0.4256 - accuracy: 0.8333 - val_loss: 0.4969 - val_accuracy: 0.7700
#
# Epoch 00046: val_loss did not improve from 0.48367
# Epoch 47/200
#  - 2s - loss: 0.4401 - accuracy: 0.8113 - val_loss: 0.4902 - val_accuracy: 0.7900
#
# Epoch 00047: val_loss did not improve from 0.48367
# Epoch 48/200
#  - 2s - loss: 0.4358 - accuracy: 0.8333 - val_loss: 0.4915 - val_accuracy: 0.7900
#
# Epoch 00048: val_loss did not improve from 0.48367
# Epoch 49/200
#  - 2s - loss: 0.4304 - accuracy: 0.8239 - val_loss: 0.5128 - val_accuracy: 0.7500
#
# Epoch 00049: val_loss did not improve from 0.48367
# Epoch 50/200
#  - 2s - loss: 0.4437 - accuracy: 0.8208 - val_loss: 0.4816 - val_accuracy: 0.7900
#
# Epoch 00050: val_loss improved from 0.48367 to 0.48165, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 51/200
#  - 2s - loss: 0.4281 - accuracy: 0.8208 - val_loss: 0.4828 - val_accuracy: 0.7900
#
# Epoch 00051: val_loss did not improve from 0.48165
# Epoch 52/200
#  - 2s - loss: 0.4302 - accuracy: 0.8145 - val_loss: 0.5239 - val_accuracy: 0.7000
#
# Epoch 00052: val_loss did not improve from 0.48165
# Epoch 53/200
#  - 2s - loss: 0.4198 - accuracy: 0.8396 - val_loss: 0.5874 - val_accuracy: 0.7000
#
# Epoch 00053: val_loss did not improve from 0.48165
# Epoch 54/200
#  - 2s - loss: 0.4605 - accuracy: 0.8019 - val_loss: 0.4989 - val_accuracy: 0.7800
#
# Epoch 00054: val_loss did not improve from 0.48165
# Epoch 55/200
#  - 2s - loss: 0.4244 - accuracy: 0.8208 - val_loss: 0.4978 - val_accuracy: 0.7900
#
# Epoch 00055: val_loss did not improve from 0.48165
# Epoch 56/200
#  - 2s - loss: 0.4265 - accuracy: 0.8176 - val_loss: 0.4937 - val_accuracy: 0.7700
#
# Epoch 00056: val_loss did not improve from 0.48165
# Epoch 57/200
#  - 2s - loss: 0.4284 - accuracy: 0.8145 - val_loss: 0.4900 - val_accuracy: 0.7800
#
# Epoch 00057: val_loss did not improve from 0.48165
# Epoch 58/200
#  - 2s - loss: 0.4336 - accuracy: 0.8176 - val_loss: 0.4865 - val_accuracy: 0.7900
#
# Epoch 00058: val_loss did not improve from 0.48165
# Epoch 59/200
#  - 2s - loss: 0.4250 - accuracy: 0.8145 - val_loss: 0.4802 - val_accuracy: 0.7900
#
# Epoch 00059: val_loss improved from 0.48165 to 0.48025, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 60/200
#  - 2s - loss: 0.4292 - accuracy: 0.8208 - val_loss: 0.4879 - val_accuracy: 0.7900
#
# Epoch 00060: val_loss did not improve from 0.48025
# Epoch 61/200
#  - 2s - loss: 0.4196 - accuracy: 0.8302 - val_loss: 0.4961 - val_accuracy: 0.7700
#
# Epoch 00061: val_loss did not improve from 0.48025
# Epoch 62/200
#  - 2s - loss: 0.4347 - accuracy: 0.8145 - val_loss: 0.4929 - val_accuracy: 0.7800
#
# Epoch 00062: val_loss did not improve from 0.48025
# Epoch 63/200
#  - 2s - loss: 0.4200 - accuracy: 0.8302 - val_loss: 0.4876 - val_accuracy: 0.7900
#
# Epoch 00063: val_loss did not improve from 0.48025
# Epoch 64/200
#  - 2s - loss: 0.4238 - accuracy: 0.8176 - val_loss: 0.4923 - val_accuracy: 0.8300
#
# Epoch 00064: val_loss did not improve from 0.48025
# Epoch 65/200
#  - 2s - loss: 0.4507 - accuracy: 0.7956 - val_loss: 0.4993 - val_accuracy: 0.8100
#
# Epoch 00065: val_loss did not improve from 0.48025
# Epoch 66/200
#  - 2s - loss: 0.4188 - accuracy: 0.7956 - val_loss: 0.5092 - val_accuracy: 0.7900
#
# Epoch 00066: val_loss did not improve from 0.48025
# Epoch 67/200
#  - 3s - loss: 0.4418 - accuracy: 0.7987 - val_loss: 0.4859 - val_accuracy: 0.7700
#
# Epoch 00067: val_loss did not improve from 0.48025
# Epoch 68/200
#  - 3s - loss: 0.4277 - accuracy: 0.8113 - val_loss: 0.5144 - val_accuracy: 0.7400
#
# Epoch 00068: val_loss did not improve from 0.48025
# Epoch 69/200
#  - 3s - loss: 0.4332 - accuracy: 0.8302 - val_loss: 0.5079 - val_accuracy: 0.7600
#
# Epoch 00069: val_loss did not improve from 0.48025
# Epoch 70/200
#  - 3s - loss: 0.4227 - accuracy: 0.8270 - val_loss: 0.4918 - val_accuracy: 0.7900
#
# Epoch 00070: val_loss did not improve from 0.48025
# Epoch 71/200
#  - 3s - loss: 0.4205 - accuracy: 0.8270 - val_loss: 0.4835 - val_accuracy: 0.7700
#
# Epoch 00071: val_loss did not improve from 0.48025
# Epoch 72/200
#  - 2s - loss: 0.4200 - accuracy: 0.8176 - val_loss: 0.4790 - val_accuracy: 0.7900
#
# Epoch 00072: val_loss improved from 0.48025 to 0.47901, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 73/200
#  - 2s - loss: 0.4221 - accuracy: 0.8145 - val_loss: 0.4861 - val_accuracy: 0.7900
#
# Epoch 00073: val_loss did not improve from 0.47901
# Epoch 74/200
#  - 2s - loss: 0.4167 - accuracy: 0.8333 - val_loss: 0.4807 - val_accuracy: 0.7800
#
# Epoch 00074: val_loss did not improve from 0.47901
# Epoch 75/200
#  - 2s - loss: 0.4206 - accuracy: 0.8270 - val_loss: 0.4789 - val_accuracy: 0.7700
#
# Epoch 00075: val_loss improved from 0.47901 to 0.47889, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 76/200
#  - 2s - loss: 0.4089 - accuracy: 0.8208 - val_loss: 0.4900 - val_accuracy: 0.8300
#
# Epoch 00076: val_loss did not improve from 0.47889
# Epoch 77/200
#  - 3s - loss: 0.4626 - accuracy: 0.8050 - val_loss: 0.5157 - val_accuracy: 0.7700
#
# Epoch 00077: val_loss did not improve from 0.47889
# Epoch 78/200
#  - 2s - loss: 0.4155 - accuracy: 0.7925 - val_loss: 0.5094 - val_accuracy: 0.8100
#
# Epoch 00078: val_loss did not improve from 0.47889
# Epoch 79/200
#  - 2s - loss: 0.4279 - accuracy: 0.8270 - val_loss: 0.5474 - val_accuracy: 0.7000
#
# Epoch 00079: val_loss did not improve from 0.47889
# Epoch 80/200
#  - 2s - loss: 0.4373 - accuracy: 0.8176 - val_loss: 0.4865 - val_accuracy: 0.7900
#
# Epoch 00080: val_loss did not improve from 0.47889
# Epoch 81/200
#  - 2s - loss: 0.4170 - accuracy: 0.8239 - val_loss: 0.4840 - val_accuracy: 0.7800
#
# Epoch 00081: val_loss did not improve from 0.47889
# Epoch 82/200
#  - 2s - loss: 0.4140 - accuracy: 0.8176 - val_loss: 0.4981 - val_accuracy: 0.7800
#
# Epoch 00082: val_loss did not improve from 0.47889
# Epoch 83/200
#  - 2s - loss: 0.4134 - accuracy: 0.8239 - val_loss: 0.4954 - val_accuracy: 0.8300
#
# Epoch 00083: val_loss did not improve from 0.47889
# Epoch 84/200
#  - 2s - loss: 0.4164 - accuracy: 0.8302 - val_loss: 0.4818 - val_accuracy: 0.7900
#
# Epoch 00084: val_loss did not improve from 0.47889
# Epoch 85/200
#  - 3s - loss: 0.4164 - accuracy: 0.8302 - val_loss: 0.4883 - val_accuracy: 0.7800
#
# Epoch 00085: val_loss did not improve from 0.47889
# Epoch 86/200
#  - 2s - loss: 0.4212 - accuracy: 0.8270 - val_loss: 0.4909 - val_accuracy: 0.7800
#
# Epoch 00086: val_loss did not improve from 0.47889
# Epoch 87/200
#  - 2s - loss: 0.4185 - accuracy: 0.8302 - val_loss: 0.4905 - val_accuracy: 0.7800
#
# Epoch 00087: val_loss did not improve from 0.47889
# Epoch 88/200
#  - 2s - loss: 0.4211 - accuracy: 0.8145 - val_loss: 0.4903 - val_accuracy: 0.7800
#
# Epoch 00088: val_loss did not improve from 0.47889
# Epoch 89/200
#  - 2s - loss: 0.4115 - accuracy: 0.8333 - val_loss: 0.5032 - val_accuracy: 0.7600
#
# Epoch 00089: val_loss did not improve from 0.47889
# Epoch 90/200
#  - 2s - loss: 0.4195 - accuracy: 0.8145 - val_loss: 0.4788 - val_accuracy: 0.7900
#
# Epoch 00090: val_loss improved from 0.47889 to 0.47882, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 91/200
#  - 2s - loss: 0.4169 - accuracy: 0.8270 - val_loss: 0.4845 - val_accuracy: 0.8200
#
# Epoch 00091: val_loss did not improve from 0.47882
# Epoch 92/200
#  - 2s - loss: 0.4134 - accuracy: 0.8428 - val_loss: 0.4772 - val_accuracy: 0.7700
#
# Epoch 00092: val_loss improved from 0.47882 to 0.47717, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 93/200
#  - 2s - loss: 0.4246 - accuracy: 0.8270 - val_loss: 0.5124 - val_accuracy: 0.7500
#
# Epoch 00093: val_loss did not improve from 0.47717
# Epoch 94/200
#  - 2s - loss: 0.4184 - accuracy: 0.8239 - val_loss: 0.5595 - val_accuracy: 0.7300
#
# Epoch 00094: val_loss did not improve from 0.47717
# Epoch 95/200
#  - 2s - loss: 0.4356 - accuracy: 0.7987 - val_loss: 0.4880 - val_accuracy: 0.7900
#
# Epoch 00095: val_loss did not improve from 0.47717
# Epoch 96/200
#  - 2s - loss: 0.4367 - accuracy: 0.8208 - val_loss: 0.4944 - val_accuracy: 0.8000
#
# Epoch 00096: val_loss did not improve from 0.47717
# Epoch 97/200
#  - 2s - loss: 0.4224 - accuracy: 0.8365 - val_loss: 0.4854 - val_accuracy: 0.7900
#
# Epoch 00097: val_loss did not improve from 0.47717
# Epoch 98/200
#  - 2s - loss: 0.4208 - accuracy: 0.8270 - val_loss: 0.4877 - val_accuracy: 0.7800
#
# Epoch 00098: val_loss did not improve from 0.47717
# Epoch 99/200
#  - 2s - loss: 0.4175 - accuracy: 0.8082 - val_loss: 0.4814 - val_accuracy: 0.7800
#
# Epoch 00099: val_loss did not improve from 0.47717
# Epoch 100/200
#  - 2s - loss: 0.4532 - accuracy: 0.7642 - val_loss: 0.4990 - val_accuracy: 0.8100
#
# Epoch 00100: val_loss did not improve from 0.47717
# Epoch 101/200
#  - 2s - loss: 0.4058 - accuracy: 0.8270 - val_loss: 0.4897 - val_accuracy: 0.7800
#
# Epoch 00101: val_loss did not improve from 0.47717
# Epoch 102/200
#  - 2s - loss: 0.4079 - accuracy: 0.8365 - val_loss: 0.4919 - val_accuracy: 0.7800
#
# Epoch 00102: val_loss did not improve from 0.47717
# Epoch 103/200
#  - 3s - loss: 0.4019 - accuracy: 0.8365 - val_loss: 0.4783 - val_accuracy: 0.7900
#
# Epoch 00103: val_loss did not improve from 0.47717
# Epoch 104/200
#  - 2s - loss: 0.4084 - accuracy: 0.8302 - val_loss: 0.5011 - val_accuracy: 0.7700
#
# Epoch 00104: val_loss did not improve from 0.47717
# Epoch 105/200
#  - 2s - loss: 0.4303 - accuracy: 0.8050 - val_loss: 0.4890 - val_accuracy: 0.8300
#
# Epoch 00105: val_loss did not improve from 0.47717
# Epoch 106/200
#  - 2s - loss: 0.4206 - accuracy: 0.8145 - val_loss: 0.5300 - val_accuracy: 0.7300
#
# Epoch 00106: val_loss did not improve from 0.47717
# Epoch 107/200
#  - 2s - loss: 0.4289 - accuracy: 0.8302 - val_loss: 0.5139 - val_accuracy: 0.8100
#
# Epoch 00107: val_loss did not improve from 0.47717
# Epoch 108/200
#  - 2s - loss: 0.4234 - accuracy: 0.8270 - val_loss: 0.5339 - val_accuracy: 0.7400
#
# Epoch 00108: val_loss did not improve from 0.47717
# Epoch 109/200
#  - 2s - loss: 0.4163 - accuracy: 0.8270 - val_loss: 0.4896 - val_accuracy: 0.7800
#
# Epoch 00109: val_loss did not improve from 0.47717
# Epoch 110/200
#  - 2s - loss: 0.4081 - accuracy: 0.8365 - val_loss: 0.4921 - val_accuracy: 0.7800
#
# Epoch 00110: val_loss did not improve from 0.47717
# Epoch 111/200
#  - 2s - loss: 0.4137 - accuracy: 0.8239 - val_loss: 0.5271 - val_accuracy: 0.7400
#
# Epoch 00111: val_loss did not improve from 0.47717
# Epoch 112/200
#  - 2s - loss: 0.4122 - accuracy: 0.8208 - val_loss: 0.4818 - val_accuracy: 0.7900
#
# Epoch 00112: val_loss did not improve from 0.47717
# Epoch 113/200
#  - 2s - loss: 0.4149 - accuracy: 0.8113 - val_loss: 0.5056 - val_accuracy: 0.7500
#
# Epoch 00113: val_loss did not improve from 0.47717
# Epoch 114/200
#  - 2s - loss: 0.4159 - accuracy: 0.8208 - val_loss: 0.4905 - val_accuracy: 0.8300
#
# Epoch 00114: val_loss did not improve from 0.47717
# Epoch 115/200
#  - 2s - loss: 0.4082 - accuracy: 0.8302 - val_loss: 0.4919 - val_accuracy: 0.7700
#
# Epoch 00115: val_loss did not improve from 0.47717
# Epoch 116/200
#  - 2s - loss: 0.4009 - accuracy: 0.8270 - val_loss: 0.4856 - val_accuracy: 0.8200
#
# Epoch 00116: val_loss did not improve from 0.47717
# Epoch 117/200
#  - 2s - loss: 0.4026 - accuracy: 0.8333 - val_loss: 0.4928 - val_accuracy: 0.7600
#
# Epoch 00117: val_loss did not improve from 0.47717
# Epoch 118/200
#  - 2s - loss: 0.3988 - accuracy: 0.8459 - val_loss: 0.5530 - val_accuracy: 0.7000
#
# Epoch 00118: val_loss did not improve from 0.47717
# Epoch 119/200
#  - 2s - loss: 0.4221 - accuracy: 0.8082 - val_loss: 0.5109 - val_accuracy: 0.7500
#
# Epoch 00119: val_loss did not improve from 0.47717
# Epoch 120/200
#  - 2s - loss: 0.4078 - accuracy: 0.8302 - val_loss: 0.4973 - val_accuracy: 0.7700
#
# Epoch 00120: val_loss did not improve from 0.47717
# Epoch 121/200
#  - 2s - loss: 0.4064 - accuracy: 0.8396 - val_loss: 0.4779 - val_accuracy: 0.7800
#
# Epoch 00121: val_loss did not improve from 0.47717
# Epoch 122/200
#  - 2s - loss: 0.4006 - accuracy: 0.8270 - val_loss: 0.4744 - val_accuracy: 0.7900
#
# Epoch 00122: val_loss improved from 0.47717 to 0.47441, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 123/200
#  - 2s - loss: 0.4078 - accuracy: 0.8333 - val_loss: 0.4800 - val_accuracy: 0.7700
#
# Epoch 00123: val_loss did not improve from 0.47441
# Epoch 124/200
#  - 2s - loss: 0.3961 - accuracy: 0.8365 - val_loss: 0.5305 - val_accuracy: 0.7500
#
# Epoch 00124: val_loss did not improve from 0.47441
# Epoch 125/200
#  - 2s - loss: 0.4047 - accuracy: 0.8239 - val_loss: 0.4834 - val_accuracy: 0.7800
#
# Epoch 00125: val_loss did not improve from 0.47441
# Epoch 126/200
#  - 2s - loss: 0.4008 - accuracy: 0.8302 - val_loss: 0.4854 - val_accuracy: 0.7700
#
# Epoch 00126: val_loss did not improve from 0.47441
# Epoch 127/200
#  - 2s - loss: 0.3931 - accuracy: 0.8428 - val_loss: 0.4754 - val_accuracy: 0.7900
#
# Epoch 00127: val_loss did not improve from 0.47441
# Epoch 128/200
#  - 2s - loss: 0.3993 - accuracy: 0.8396 - val_loss: 0.4779 - val_accuracy: 0.8000
#
# Epoch 00128: val_loss did not improve from 0.47441
# Epoch 129/200
#  - 2s - loss: 0.4055 - accuracy: 0.8270 - val_loss: 0.5654 - val_accuracy: 0.7200
#
# Epoch 00129: val_loss did not improve from 0.47441
# Epoch 130/200
#  - 2s - loss: 0.4455 - accuracy: 0.8019 - val_loss: 0.5044 - val_accuracy: 0.7600
#
# Epoch 00130: val_loss did not improve from 0.47441
# Epoch 131/200
#  - 2s - loss: 0.4000 - accuracy: 0.8333 - val_loss: 0.4892 - val_accuracy: 0.7800
#
# Epoch 00131: val_loss did not improve from 0.47441
# Epoch 132/200
#  - 2s - loss: 0.4387 - accuracy: 0.7987 - val_loss: 0.4889 - val_accuracy: 0.8000
#
# Epoch 00132: val_loss did not improve from 0.47441
# Epoch 133/200
#  - 2s - loss: 0.4179 - accuracy: 0.8239 - val_loss: 0.4942 - val_accuracy: 0.7600
#
# Epoch 00133: val_loss did not improve from 0.47441
# Epoch 134/200
#  - 2s - loss: 0.4145 - accuracy: 0.8176 - val_loss: 0.4902 - val_accuracy: 0.8200
#
# Epoch 00134: val_loss did not improve from 0.47441
# Epoch 135/200
#  - 2s - loss: 0.4001 - accuracy: 0.8365 - val_loss: 0.4884 - val_accuracy: 0.7900
#
# Epoch 00135: val_loss did not improve from 0.47441
# Epoch 136/200
#  - 3s - loss: 0.3987 - accuracy: 0.8302 - val_loss: 0.4797 - val_accuracy: 0.8000
#
# Epoch 00136: val_loss did not improve from 0.47441
# Epoch 137/200
#  - 2s - loss: 0.4033 - accuracy: 0.8302 - val_loss: 0.5046 - val_accuracy: 0.8000
#
# Epoch 00137: val_loss did not improve from 0.47441
# Epoch 138/200
#  - 2s - loss: 0.3999 - accuracy: 0.8333 - val_loss: 0.4787 - val_accuracy: 0.8000
#
# Epoch 00138: val_loss did not improve from 0.47441
# Epoch 139/200
#  - 2s - loss: 0.4017 - accuracy: 0.8365 - val_loss: 0.4789 - val_accuracy: 0.7900
#
# Epoch 00139: val_loss did not improve from 0.47441
# Epoch 140/200
#  - 2s - loss: 0.3920 - accuracy: 0.8396 - val_loss: 0.4940 - val_accuracy: 0.7500
#
# Epoch 00140: val_loss did not improve from 0.47441
# Epoch 141/200
#  - 2s - loss: 0.4321 - accuracy: 0.8082 - val_loss: 0.4966 - val_accuracy: 0.7800
#
# Epoch 00141: val_loss did not improve from 0.47441
# Epoch 142/200
#  - 2s - loss: 0.4386 - accuracy: 0.7956 - val_loss: 0.5209 - val_accuracy: 0.7600
#
# Epoch 00142: val_loss did not improve from 0.47441
# Epoch 143/200
#  - 2s - loss: 0.4168 - accuracy: 0.8239 - val_loss: 0.5044 - val_accuracy: 0.8100
#
# Epoch 00143: val_loss did not improve from 0.47441
# Epoch 144/200
#  - 2s - loss: 0.4113 - accuracy: 0.8208 - val_loss: 0.5003 - val_accuracy: 0.7700
#
# Epoch 00144: val_loss did not improve from 0.47441
# Epoch 145/200
#  - 2s - loss: 0.4038 - accuracy: 0.8176 - val_loss: 0.4863 - val_accuracy: 0.8000
#
# Epoch 00145: val_loss did not improve from 0.47441
# Epoch 146/200
#  - 2s - loss: 0.4119 - accuracy: 0.8428 - val_loss: 0.4837 - val_accuracy: 0.8000
#
# Epoch 00146: val_loss did not improve from 0.47441
# Epoch 147/200
#  - 2s - loss: 0.3930 - accuracy: 0.8459 - val_loss: 0.4767 - val_accuracy: 0.8000
#
# Epoch 00147: val_loss did not improve from 0.47441
# Epoch 148/200
#  - 2s - loss: 0.3970 - accuracy: 0.8239 - val_loss: 0.4812 - val_accuracy: 0.7900
#
# Epoch 00148: val_loss did not improve from 0.47441
# Epoch 149/200
#  - 2s - loss: 0.3980 - accuracy: 0.8365 - val_loss: 0.4781 - val_accuracy: 0.7900
#
# Epoch 00149: val_loss did not improve from 0.47441
# Epoch 150/200
#  - 2s - loss: 0.4008 - accuracy: 0.8239 - val_loss: 0.4850 - val_accuracy: 0.7800
#
# Epoch 00150: val_loss did not improve from 0.47441
# Epoch 151/200
#  - 2s - loss: 0.3893 - accuracy: 0.8302 - val_loss: 0.5033 - val_accuracy: 0.7500
#
# Epoch 00151: val_loss did not improve from 0.47441
# Epoch 152/200
#  - 2s - loss: 0.3909 - accuracy: 0.8396 - val_loss: 0.4779 - val_accuracy: 0.7900
#
# Epoch 00152: val_loss did not improve from 0.47441
# Epoch 153/200
#  - 2s - loss: 0.3888 - accuracy: 0.8491 - val_loss: 0.4986 - val_accuracy: 0.7600
#
# Epoch 00153: val_loss did not improve from 0.47441
# Epoch 154/200
#  - 3s - loss: 0.4005 - accuracy: 0.8239 - val_loss: 0.5043 - val_accuracy: 0.7500
#
# Epoch 00154: val_loss did not improve from 0.47441
# Epoch 155/200
#  - 2s - loss: 0.3882 - accuracy: 0.8491 - val_loss: 0.4762 - val_accuracy: 0.8000
#
# Epoch 00155: val_loss did not improve from 0.47441
# Epoch 156/200
#  - 2s - loss: 0.3982 - accuracy: 0.8365 - val_loss: 0.4770 - val_accuracy: 0.7900
#
# Epoch 00156: val_loss did not improve from 0.47441
# Epoch 157/200
#  - 2s - loss: 0.3955 - accuracy: 0.8396 - val_loss: 0.4777 - val_accuracy: 0.8000
#
# Epoch 00157: val_loss did not improve from 0.47441
# Epoch 158/200
#  - 2s - loss: 0.3862 - accuracy: 0.8459 - val_loss: 0.4854 - val_accuracy: 0.7800
#
# Epoch 00158: val_loss did not improve from 0.47441
# Epoch 159/200
#  - 2s - loss: 0.3832 - accuracy: 0.8491 - val_loss: 0.4760 - val_accuracy: 0.8000
#
# Epoch 00159: val_loss did not improve from 0.47441
# Epoch 160/200
#  - 2s - loss: 0.3982 - accuracy: 0.8428 - val_loss: 0.4866 - val_accuracy: 0.7800
#
# Epoch 00160: val_loss did not improve from 0.47441
# Epoch 161/200
#  - 2s - loss: 0.3929 - accuracy: 0.8333 - val_loss: 0.4759 - val_accuracy: 0.7900
#
# Epoch 00161: val_loss did not improve from 0.47441
# Epoch 162/200
#  - 2s - loss: 0.4080 - accuracy: 0.8302 - val_loss: 0.4807 - val_accuracy: 0.8000
#
# Epoch 00162: val_loss did not improve from 0.47441
# Epoch 163/200
#  - 2s - loss: 0.4028 - accuracy: 0.8428 - val_loss: 0.4903 - val_accuracy: 0.8200
#
# Epoch 00163: val_loss did not improve from 0.47441
# Epoch 164/200
#  - 2s - loss: 0.4064 - accuracy: 0.8113 - val_loss: 0.4810 - val_accuracy: 0.8200
#
# Epoch 00164: val_loss did not improve from 0.47441
# Epoch 165/200
#  - 2s - loss: 0.3836 - accuracy: 0.8365 - val_loss: 0.4806 - val_accuracy: 0.8300
#
# Epoch 00165: val_loss did not improve from 0.47441
# Epoch 166/200
#  - 2s - loss: 0.3855 - accuracy: 0.8491 - val_loss: 0.4790 - val_accuracy: 0.7900
#
# Epoch 00166: val_loss did not improve from 0.47441
# Epoch 167/200
#  - 2s - loss: 0.4095 - accuracy: 0.8082 - val_loss: 0.4965 - val_accuracy: 0.7900
#
# Epoch 00167: val_loss did not improve from 0.47441
# Epoch 168/200
#  - 2s - loss: 0.3953 - accuracy: 0.8208 - val_loss: 0.4890 - val_accuracy: 0.7900
#
# Epoch 00168: val_loss did not improve from 0.47441
# Epoch 169/200
#  - 3s - loss: 0.3926 - accuracy: 0.8428 - val_loss: 0.4788 - val_accuracy: 0.8000
#
# Epoch 00169: val_loss did not improve from 0.47441
# Epoch 170/200
#  - 2s - loss: 0.3818 - accuracy: 0.8428 - val_loss: 0.4754 - val_accuracy: 0.8200
#
# Epoch 00170: val_loss did not improve from 0.47441
# Epoch 171/200
#  - 2s - loss: 0.3877 - accuracy: 0.8522 - val_loss: 0.4729 - val_accuracy: 0.8000
#
# Epoch 00171: val_loss improved from 0.47441 to 0.47287, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 172/200
#  - 2s - loss: 0.3824 - accuracy: 0.8428 - val_loss: 0.4748 - val_accuracy: 0.8000
#
# Epoch 00172: val_loss did not improve from 0.47287
# Epoch 173/200
#  - 2s - loss: 0.3807 - accuracy: 0.8428 - val_loss: 0.4706 - val_accuracy: 0.8000
#
# Epoch 00173: val_loss improved from 0.47287 to 0.47058, saving model to Model_depthwise_2_arson.weights.best.hdf5
# Epoch 174/200
#  - 2s - loss: 0.3921 - accuracy: 0.8333 - val_loss: 0.4764 - val_accuracy: 0.8200
#
# Epoch 00174: val_loss did not improve from 0.47058
# Epoch 175/200
#  - 2s - loss: 0.4000 - accuracy: 0.8459 - val_loss: 0.5770 - val_accuracy: 0.7300
#
# Epoch 00175: val_loss did not improve from 0.47058
# Epoch 176/200
#  - 2s - loss: 0.4016 - accuracy: 0.8208 - val_loss: 0.4993 - val_accuracy: 0.7700
#
# Epoch 00176: val_loss did not improve from 0.47058
# Epoch 177/200
#  - 2s - loss: 0.3861 - accuracy: 0.8239 - val_loss: 0.4779 - val_accuracy: 0.8000
#
# Epoch 00177: val_loss did not improve from 0.47058
# Epoch 178/200
#  - 2s - loss: 0.3840 - accuracy: 0.8396 - val_loss: 0.4925 - val_accuracy: 0.7700
#
# Epoch 00178: val_loss did not improve from 0.47058
# Epoch 179/200
#  - 2s - loss: 0.3791 - accuracy: 0.8396 - val_loss: 0.4937 - val_accuracy: 0.7600
#
# Epoch 00179: val_loss did not improve from 0.47058
# Epoch 180/200
#  - 2s - loss: 0.3810 - accuracy: 0.8270 - val_loss: 0.4840 - val_accuracy: 0.8200
#
# Epoch 00180: val_loss did not improve from 0.47058
# Epoch 181/200
#  - 2s - loss: 0.4073 - accuracy: 0.8176 - val_loss: 0.4950 - val_accuracy: 0.7700
#
# Epoch 00181: val_loss did not improve from 0.47058
# Epoch 182/200
#  - 2s - loss: 0.3813 - accuracy: 0.8365 - val_loss: 0.4835 - val_accuracy: 0.8300
#
# Epoch 00182: val_loss did not improve from 0.47058
# Epoch 183/200
#  - 2s - loss: 0.3780 - accuracy: 0.8491 - val_loss: 0.4781 - val_accuracy: 0.7900
#
# Epoch 00183: val_loss did not improve from 0.47058
# Epoch 184/200
#  - 2s - loss: 0.3783 - accuracy: 0.8396 - val_loss: 0.4787 - val_accuracy: 0.7900
#
# Epoch 00184: val_loss did not improve from 0.47058
# Epoch 185/200
#  - 2s - loss: 0.3716 - accuracy: 0.8459 - val_loss: 0.5329 - val_accuracy: 0.7300
#
# Epoch 00185: val_loss did not improve from 0.47058
# Epoch 186/200
#  - 2s - loss: 0.3776 - accuracy: 0.8522 - val_loss: 0.4795 - val_accuracy: 0.8000
#
# Epoch 00186: val_loss did not improve from 0.47058
# Epoch 187/200
#  - 2s - loss: 0.3791 - accuracy: 0.8302 - val_loss: 0.5062 - val_accuracy: 0.7900
#
# Epoch 00187: val_loss did not improve from 0.47058
# Epoch 188/200
#  - 2s - loss: 0.3930 - accuracy: 0.8333 - val_loss: 0.4963 - val_accuracy: 0.8000
#
# Epoch 00188: val_loss did not improve from 0.47058
# Epoch 189/200
#  - 2s - loss: 0.3764 - accuracy: 0.8616 - val_loss: 0.5904 - val_accuracy: 0.7400
#
# Epoch 00189: val_loss did not improve from 0.47058
# Epoch 190/200
#  - 2s - loss: 0.4058 - accuracy: 0.8050 - val_loss: 0.5048 - val_accuracy: 0.7600
#
# Epoch 00190: val_loss did not improve from 0.47058
# Epoch 191/200
#  - 2s - loss: 0.3905 - accuracy: 0.8333 - val_loss: 0.4885 - val_accuracy: 0.7800
#
# Epoch 00191: val_loss did not improve from 0.47058
# Epoch 192/200
#  - 3s - loss: 0.3864 - accuracy: 0.8491 - val_loss: 0.4910 - val_accuracy: 0.7600
#
# Epoch 00192: val_loss did not improve from 0.47058
# Epoch 193/200
#  - 3s - loss: 0.3803 - accuracy: 0.8522 - val_loss: 0.4885 - val_accuracy: 0.7600
#
# Epoch 00193: val_loss did not improve from 0.47058
# Epoch 194/200
#  - 3s - loss: 0.3865 - accuracy: 0.8333 - val_loss: 0.4799 - val_accuracy: 0.8200
#
# Epoch 00194: val_loss did not improve from 0.47058
# Epoch 195/200
#  - 3s - loss: 0.3912 - accuracy: 0.8365 - val_loss: 0.5105 - val_accuracy: 0.7800
#
# Epoch 00195: val_loss did not improve from 0.47058
# Epoch 196/200
#  - 2s - loss: 0.3718 - accuracy: 0.8616 - val_loss: 0.4949 - val_accuracy: 0.7700
#
# Epoch 00196: val_loss did not improve from 0.47058
# Epoch 197/200
#  - 2s - loss: 0.3855 - accuracy: 0.8302 - val_loss: 0.5237 - val_accuracy: 0.7300
#
# Epoch 00197: val_loss did not improve from 0.47058
# Epoch 198/200
#  - 2s - loss: 0.4288 - accuracy: 0.7799 - val_loss: 0.5108 - val_accuracy: 0.7600
#
# Epoch 00198: val_loss did not improve from 0.47058
# Epoch 199/200
#  - 2s - loss: 0.3936 - accuracy: 0.8459 - val_loss: 0.4963 - val_accuracy: 0.8100
#
# Epoch 00199: val_loss did not improve from 0.47058
# Epoch 200/200
#  - 2s - loss: 0.3932 - accuracy: 0.8302 - val_loss: 0.4809 - val_accuracy: 0.8200
#
# Epoch 00200: val_loss did not improve from 0.47058
# Accuracy on test data: 79.05%
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
# class Normal       0.84      0.46      0.60       112
#  class arson       0.85      0.54      0.66        98
#
#    micro avg       0.85      0.50      0.63       210
#    macro avg       0.85      0.50      0.63       210
# weighted avg       0.85      0.50      0.63       210
#  samples avg       0.50      0.50      0.50       210

# %%
model_d = Sequential()

# Adding Alternate convolutional and pooling layers
model_d.add(DepthwiseConv3D( kernel_size=(10, 3, 3),depth_multiplier=2, strides=(1, 1, 1), padding='same', activation='relu', 
                 input_shape=X_train.shape[1:]))
model_d.add(MaxPooling3D(pool_size=2, strides=(1, 2, 2), padding='same'))

model_d.add(DepthwiseConv3D( depth_multiplier=4,kernel_size=(5, 3, 3), strides=(3, 1, 1), padding='valid', activation='relu'))
model_d.add(MaxPooling3D(pool_size=2, strides=(1, 2, 2), padding='same'))

model_d.add(DepthwiseConv3D(depth_multiplier=16, kernel_size=(5, 3, 3), strides=(3, 1, 1), padding='valid', activation='relu'))
model_d.add(MaxPooling3D(pool_size=2, strides=(1, 2, 2), padding='same'))



# A global average pooling layer to get a 1-d vector
# The vector will have a depth (same as number of elements in the vector) of 256
model_d.add(GlobalAveragePooling3D())

# The Global average pooling layer is followed by a fully-connected neural network, with one hidden and one output layer

# Hidden Layer
model_d.add(Dense(32, activation='relu'))

# Output layer
model_d.add(Dense(2, activation='softmax'))

model_d.summary()

from keras.callbacks import ModelCheckpoint

# Compiling the model
model_d.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Saving the model that performed the best on the validation set
checkpoint = ModelCheckpoint(filepath='Model_depthwise_3_arson.weights.best.hdf5', save_best_only=True, verbose=1)

# Training the model for 40 epochs
history = model_d.fit(X_train, y_train, batch_size=16, epochs=200, 
                    validation_data=(X_valid, y_valid), verbose=2, callbacks=[checkpoint])

# Loading the model that performed the best on the validation set
model_d.load_weights('/content/Model_depthwise_3_arson.weights.best.hdf5')

# Testing the model on the Test data
(loss, accuracy) = model_d.evaluate(X_test, y_test, batch_size=16, verbose=0)

print('Accuracy on test data: {:.2f}%'.format(accuracy * 100))

# Making the plot larger
plt.figure(figsize=(12, 8))

loss = history.history['loss']                          # Loss on the training data
val_loss = history.history['val_loss']                  # Loss on the validation data
epochs = range(1, 201)

plt.plot(epochs, loss, 'ro-', label='Training Loss')
plt.plot(epochs, val_loss, 'go-', label = 'Validation Loss')
plt.legend()


# Making the plot larger
plt.figure(figsize=(12, 8))

acc = history.history['accuracy']                          # Loss on the training data
val_acc = history.history['val_accuracy']                  # Loss on the validation data
epochs = range(1, 201)

plt.plot(epochs, acc, 'ro-', label='Training Accuracy')
plt.plot(epochs, val_acc, 'go-', label = 'Validation Accuracy')
plt.legend()


y_pred=model_d.predict(X_test)
y_pred=y_pred>0.80
target_names = ['class Normal', 'class arson']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# depthwise_conv3d_26 (Depthwi (None, 29, 128, 128, 2)   182
# _________________________________________________________________
# max_pooling3d_39 (MaxPooling (None, 29, 64, 64, 2)     0
# _________________________________________________________________
# depthwise_conv3d_27 (Depthwi (None, 9, 62, 62, 8)      368
# _________________________________________________________________
# max_pooling3d_40 (MaxPooling (None, 9, 31, 31, 8)      0
# _________________________________________________________________
# depthwise_conv3d_28 (Depthwi (None, 2, 29, 29, 128)    5888
# _________________________________________________________________
# max_pooling3d_41 (MaxPooling (None, 2, 15, 15, 128)    0
# _________________________________________________________________
# global_average_pooling3d_12  (None, 128)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 32)                4128
# _________________________________________________________________
# dense_24 (Dense)             (None, 2)                 66
# =================================================================
# Total params: 10,632
# Trainable params: 10,632
# Non-trainable params: 0
# _________________________________________________________________
# Train on 318 samples, validate on 100 samples
# Epoch 1/200
#  - 3s - loss: 0.6848 - accuracy: 0.5283 - val_loss: 0.6851 - val_accuracy: 0.4800
#
# Epoch 00001: val_loss improved from inf to 0.68508, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 2/200
#  - 3s - loss: 0.6682 - accuracy: 0.5283 - val_loss: 0.6691 - val_accuracy: 0.4900
#
# Epoch 00002: val_loss improved from 0.68508 to 0.66907, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 3/200
#  - 3s - loss: 0.6415 - accuracy: 0.5629 - val_loss: 0.6369 - val_accuracy: 0.7500
#
# Epoch 00003: val_loss improved from 0.66907 to 0.63691, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 4/200
#  - 3s - loss: 0.5987 - accuracy: 0.7390 - val_loss: 0.6133 - val_accuracy: 0.6500
#
# Epoch 00004: val_loss improved from 0.63691 to 0.61334, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 5/200
#  - 3s - loss: 0.5918 - accuracy: 0.7170 - val_loss: 0.5910 - val_accuracy: 0.7200
#
# Epoch 00005: val_loss improved from 0.61334 to 0.59102, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 6/200
#  - 3s - loss: 0.5378 - accuracy: 0.7579 - val_loss: 0.5566 - val_accuracy: 0.7400
#
# Epoch 00006: val_loss improved from 0.59102 to 0.55662, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 7/200
#  - 3s - loss: 0.5090 - accuracy: 0.7799 - val_loss: 0.5299 - val_accuracy: 0.7900
#
# Epoch 00007: val_loss improved from 0.55662 to 0.52992, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 8/200
#  - 3s - loss: 0.4892 - accuracy: 0.7830 - val_loss: 0.5125 - val_accuracy: 0.7800
#
# Epoch 00008: val_loss improved from 0.52992 to 0.51252, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 9/200
#  - 3s - loss: 0.4837 - accuracy: 0.8145 - val_loss: 0.5166 - val_accuracy: 0.8100
#
# Epoch 00009: val_loss did not improve from 0.51252
# Epoch 10/200
#  - 3s - loss: 0.5110 - accuracy: 0.7579 - val_loss: 0.5127 - val_accuracy: 0.7700
#
# Epoch 00010: val_loss did not improve from 0.51252
# Epoch 11/200
#  - 3s - loss: 0.4760 - accuracy: 0.8019 - val_loss: 0.4998 - val_accuracy: 0.7800
#
# Epoch 00011: val_loss improved from 0.51252 to 0.49982, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 12/200
#  - 3s - loss: 0.4828 - accuracy: 0.7704 - val_loss: 0.5147 - val_accuracy: 0.7200
#
# Epoch 00012: val_loss did not improve from 0.49982
# Epoch 13/200
#  - 3s - loss: 0.4579 - accuracy: 0.8050 - val_loss: 0.5121 - val_accuracy: 0.7900
#
# Epoch 00013: val_loss did not improve from 0.49982
# Epoch 14/200
#  - 3s - loss: 0.4585 - accuracy: 0.8082 - val_loss: 0.4796 - val_accuracy: 0.7800
#
# Epoch 00014: val_loss improved from 0.49982 to 0.47960, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 15/200
#  - 3s - loss: 0.4637 - accuracy: 0.7862 - val_loss: 0.4852 - val_accuracy: 0.7700
#
# Epoch 00015: val_loss did not improve from 0.47960
# Epoch 16/200
#  - 3s - loss: 0.4384 - accuracy: 0.8145 - val_loss: 0.4715 - val_accuracy: 0.8100
#
# Epoch 00016: val_loss improved from 0.47960 to 0.47147, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 17/200
#  - 3s - loss: 0.4247 - accuracy: 0.8333 - val_loss: 0.4574 - val_accuracy: 0.8400
#
# Epoch 00017: val_loss improved from 0.47147 to 0.45738, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 18/200
#  - 3s - loss: 0.4363 - accuracy: 0.8145 - val_loss: 0.5102 - val_accuracy: 0.7000
#
# Epoch 00018: val_loss did not improve from 0.45738
# Epoch 19/200
#  - 3s - loss: 0.4391 - accuracy: 0.8396 - val_loss: 0.4507 - val_accuracy: 0.8500
#
# Epoch 00019: val_loss improved from 0.45738 to 0.45068, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 20/200
#  - 3s - loss: 0.4623 - accuracy: 0.7956 - val_loss: 0.4754 - val_accuracy: 0.7300
#
# Epoch 00020: val_loss did not improve from 0.45068
# Epoch 21/200
#  - 3s - loss: 0.4205 - accuracy: 0.8239 - val_loss: 0.4442 - val_accuracy: 0.8400
#
# Epoch 00021: val_loss improved from 0.45068 to 0.44424, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 22/200
#  - 3s - loss: 0.4025 - accuracy: 0.8365 - val_loss: 0.4649 - val_accuracy: 0.8200
#
# Epoch 00022: val_loss did not improve from 0.44424
# Epoch 23/200
#  - 3s - loss: 0.4163 - accuracy: 0.8333 - val_loss: 0.4309 - val_accuracy: 0.8500
#
# Epoch 00023: val_loss improved from 0.44424 to 0.43086, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 24/200
#  - 3s - loss: 0.4094 - accuracy: 0.8270 - val_loss: 0.4290 - val_accuracy: 0.8600
#
# Epoch 00024: val_loss improved from 0.43086 to 0.42903, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 25/200
#  - 3s - loss: 0.4018 - accuracy: 0.8365 - val_loss: 0.4219 - val_accuracy: 0.8500
#
# Epoch 00025: val_loss improved from 0.42903 to 0.42194, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 26/200
#  - 3s - loss: 0.4865 - accuracy: 0.7673 - val_loss: 0.4448 - val_accuracy: 0.8400
#
# Epoch 00026: val_loss did not improve from 0.42194
# Epoch 27/200
#  - 3s - loss: 0.4665 - accuracy: 0.7830 - val_loss: 0.4447 - val_accuracy: 0.8700
#
# Epoch 00027: val_loss did not improve from 0.42194
# Epoch 28/200
#  - 3s - loss: 0.4318 - accuracy: 0.7862 - val_loss: 0.4832 - val_accuracy: 0.7800
#
# Epoch 00028: val_loss did not improve from 0.42194
# Epoch 29/200
#  - 3s - loss: 0.4009 - accuracy: 0.8365 - val_loss: 0.4426 - val_accuracy: 0.8300
#
# Epoch 00029: val_loss did not improve from 0.42194
# Epoch 30/200
#  - 3s - loss: 0.3974 - accuracy: 0.8302 - val_loss: 0.4212 - val_accuracy: 0.8500
#
# Epoch 00030: val_loss improved from 0.42194 to 0.42116, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 31/200
#  - 3s - loss: 0.3994 - accuracy: 0.8491 - val_loss: 0.4179 - val_accuracy: 0.8600
#
# Epoch 00031: val_loss improved from 0.42116 to 0.41793, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 32/200
#  - 3s - loss: 0.3878 - accuracy: 0.8396 - val_loss: 0.4062 - val_accuracy: 0.8800
#
# Epoch 00032: val_loss improved from 0.41793 to 0.40619, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 33/200
#  - 3s - loss: 0.3824 - accuracy: 0.8553 - val_loss: 0.4683 - val_accuracy: 0.7300
#
# Epoch 00033: val_loss did not improve from 0.40619
# Epoch 34/200
#  - 3s - loss: 0.3729 - accuracy: 0.8428 - val_loss: 0.3986 - val_accuracy: 0.8600
#
# Epoch 00034: val_loss improved from 0.40619 to 0.39858, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 35/200
#  - 3s - loss: 0.3661 - accuracy: 0.8648 - val_loss: 0.4005 - val_accuracy: 0.8300
#
# Epoch 00035: val_loss did not improve from 0.39858
# Epoch 36/200
#  - 3s - loss: 0.4200 - accuracy: 0.8082 - val_loss: 0.4334 - val_accuracy: 0.7600
#
# Epoch 00036: val_loss did not improve from 0.39858
# Epoch 37/200
#  - 3s - loss: 0.3738 - accuracy: 0.8302 - val_loss: 0.4493 - val_accuracy: 0.7200
#
# Epoch 00037: val_loss did not improve from 0.39858
# Epoch 38/200
#  - 3s - loss: 0.3436 - accuracy: 0.8491 - val_loss: 0.4053 - val_accuracy: 0.8400
#
# Epoch 00038: val_loss did not improve from 0.39858
# Epoch 39/200
#  - 3s - loss: 0.3539 - accuracy: 0.8585 - val_loss: 0.3702 - val_accuracy: 0.8200
#
# Epoch 00039: val_loss improved from 0.39858 to 0.37018, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 40/200
#  - 3s - loss: 0.3447 - accuracy: 0.8679 - val_loss: 0.3655 - val_accuracy: 0.8400
#
# Epoch 00040: val_loss improved from 0.37018 to 0.36551, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 41/200
#  - 3s - loss: 0.3446 - accuracy: 0.8616 - val_loss: 0.3459 - val_accuracy: 0.8600
#
# Epoch 00041: val_loss improved from 0.36551 to 0.34593, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 42/200
#  - 3s - loss: 0.3369 - accuracy: 0.8553 - val_loss: 0.3404 - val_accuracy: 0.8700
#
# Epoch 00042: val_loss improved from 0.34593 to 0.34038, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 43/200
#  - 3s - loss: 0.3423 - accuracy: 0.8428 - val_loss: 0.3254 - val_accuracy: 0.8600
#
# Epoch 00043: val_loss improved from 0.34038 to 0.32541, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 44/200
#  - 3s - loss: 0.3127 - accuracy: 0.8648 - val_loss: 0.3427 - val_accuracy: 0.8600
#
# Epoch 00044: val_loss did not improve from 0.32541
# Epoch 45/200
#  - 3s - loss: 0.3192 - accuracy: 0.8836 - val_loss: 0.3404 - val_accuracy: 0.8400
#
# Epoch 00045: val_loss did not improve from 0.32541
# Epoch 46/200
#  - 3s - loss: 0.3163 - accuracy: 0.8742 - val_loss: 0.3364 - val_accuracy: 0.8600
#
# Epoch 00046: val_loss did not improve from 0.32541
# Epoch 47/200
#  - 3s - loss: 0.3017 - accuracy: 0.8899 - val_loss: 0.3026 - val_accuracy: 0.8600
#
# Epoch 00047: val_loss improved from 0.32541 to 0.30258, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 48/200
#  - 3s - loss: 0.2818 - accuracy: 0.8931 - val_loss: 0.2898 - val_accuracy: 0.8800
#
# Epoch 00048: val_loss improved from 0.30258 to 0.28978, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 49/200
#  - 3s - loss: 0.2889 - accuracy: 0.8836 - val_loss: 0.3075 - val_accuracy: 0.8500
#
# Epoch 00049: val_loss did not improve from 0.28978
# Epoch 50/200
#  - 3s - loss: 0.2744 - accuracy: 0.8899 - val_loss: 0.2620 - val_accuracy: 0.9200
#
# Epoch 00050: val_loss improved from 0.28978 to 0.26203, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 51/200
#  - 3s - loss: 0.2884 - accuracy: 0.8899 - val_loss: 0.3332 - val_accuracy: 0.8200
#
# Epoch 00051: val_loss did not improve from 0.26203
# Epoch 52/200
#  - 3s - loss: 0.2856 - accuracy: 0.8805 - val_loss: 0.3376 - val_accuracy: 0.8500
#
# Epoch 00052: val_loss did not improve from 0.26203
# Epoch 53/200
#  - 3s - loss: 0.2654 - accuracy: 0.8994 - val_loss: 0.2820 - val_accuracy: 0.9100
#
# Epoch 00053: val_loss did not improve from 0.26203
# Epoch 54/200
#  - 3s - loss: 0.3175 - accuracy: 0.8585 - val_loss: 0.2866 - val_accuracy: 0.8700
#
# Epoch 00054: val_loss did not improve from 0.26203
# Epoch 55/200
#  - 3s - loss: 0.2374 - accuracy: 0.9151 - val_loss: 0.3810 - val_accuracy: 0.8200
#
# Epoch 00055: val_loss did not improve from 0.26203
# Epoch 56/200
#  - 3s - loss: 0.2393 - accuracy: 0.8994 - val_loss: 0.2727 - val_accuracy: 0.9100
#
# Epoch 00056: val_loss did not improve from 0.26203
# Epoch 57/200
#  - 3s - loss: 0.2404 - accuracy: 0.9088 - val_loss: 0.2364 - val_accuracy: 0.9300
#
# Epoch 00057: val_loss improved from 0.26203 to 0.23643, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 58/200
#  - 3s - loss: 0.2383 - accuracy: 0.9057 - val_loss: 0.3098 - val_accuracy: 0.8800
#
# Epoch 00058: val_loss did not improve from 0.23643
# Epoch 59/200
#  - 3s - loss: 0.2256 - accuracy: 0.9088 - val_loss: 0.2518 - val_accuracy: 0.9100
#
# Epoch 00059: val_loss did not improve from 0.23643
# Epoch 60/200
#  - 3s - loss: 0.2130 - accuracy: 0.9182 - val_loss: 0.2606 - val_accuracy: 0.9200
#
# Epoch 00060: val_loss did not improve from 0.23643
# Epoch 61/200
#  - 3s - loss: 0.2088 - accuracy: 0.9088 - val_loss: 0.2322 - val_accuracy: 0.9600
#
# Epoch 00061: val_loss improved from 0.23643 to 0.23221, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 62/200
#  - 3s - loss: 0.2590 - accuracy: 0.9057 - val_loss: 0.3687 - val_accuracy: 0.8200
#
# Epoch 00062: val_loss did not improve from 0.23221
# Epoch 63/200
#  - 3s - loss: 0.1983 - accuracy: 0.9151 - val_loss: 0.2345 - val_accuracy: 0.9200
#
# Epoch 00063: val_loss did not improve from 0.23221
# Epoch 64/200
#  - 3s - loss: 0.1969 - accuracy: 0.9245 - val_loss: 0.2570 - val_accuracy: 0.8700
#
# Epoch 00064: val_loss did not improve from 0.23221
# Epoch 65/200
#  - 3s - loss: 0.1903 - accuracy: 0.9182 - val_loss: 0.2227 - val_accuracy: 0.9300
#
# Epoch 00065: val_loss improved from 0.23221 to 0.22268, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 66/200
#  - 3s - loss: 0.1889 - accuracy: 0.9277 - val_loss: 0.2195 - val_accuracy: 0.9300
#
# Epoch 00066: val_loss improved from 0.22268 to 0.21954, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 67/200
#  - 3s - loss: 0.1768 - accuracy: 0.9371 - val_loss: 0.2633 - val_accuracy: 0.9000
#
# Epoch 00067: val_loss did not improve from 0.21954
# Epoch 68/200
#  - 3s - loss: 0.1856 - accuracy: 0.9403 - val_loss: 0.2135 - val_accuracy: 0.9600
#
# Epoch 00068: val_loss improved from 0.21954 to 0.21354, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 69/200
#  - 3s - loss: 0.1724 - accuracy: 0.9403 - val_loss: 0.2644 - val_accuracy: 0.9200
#
# Epoch 00069: val_loss did not improve from 0.21354
# Epoch 70/200
#  - 3s - loss: 0.1709 - accuracy: 0.9214 - val_loss: 0.1958 - val_accuracy: 0.9600
#
# Epoch 00070: val_loss improved from 0.21354 to 0.19579, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 71/200
#  - 3s - loss: 0.2097 - accuracy: 0.9119 - val_loss: 0.3214 - val_accuracy: 0.8900
#
# Epoch 00071: val_loss did not improve from 0.19579
# Epoch 72/200
#  - 3s - loss: 0.1913 - accuracy: 0.9214 - val_loss: 0.2459 - val_accuracy: 0.9400
#
# Epoch 00072: val_loss did not improve from 0.19579
# Epoch 73/200
#  - 3s - loss: 0.1738 - accuracy: 0.9245 - val_loss: 0.2745 - val_accuracy: 0.9100
#
# Epoch 00073: val_loss did not improve from 0.19579
# Epoch 74/200
#  - 3s - loss: 0.1400 - accuracy: 0.9528 - val_loss: 0.1904 - val_accuracy: 0.9400
#
# Epoch 00074: val_loss improved from 0.19579 to 0.19038, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 75/200
#  - 3s - loss: 0.1226 - accuracy: 0.9654 - val_loss: 0.3700 - val_accuracy: 0.8400
#
# Epoch 00075: val_loss did not improve from 0.19038
# Epoch 76/200
#  - 3s - loss: 0.1414 - accuracy: 0.9371 - val_loss: 0.1879 - val_accuracy: 0.9600
#
# Epoch 00076: val_loss improved from 0.19038 to 0.18791, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 77/200
#  - 3s - loss: 0.1528 - accuracy: 0.9403 - val_loss: 0.3483 - val_accuracy: 0.8500
#
# Epoch 00077: val_loss did not improve from 0.18791
# Epoch 78/200
#  - 3s - loss: 0.1331 - accuracy: 0.9623 - val_loss: 0.2548 - val_accuracy: 0.9300
#
# Epoch 00078: val_loss did not improve from 0.18791
# Epoch 79/200
#  - 3s - loss: 0.1273 - accuracy: 0.9528 - val_loss: 0.2019 - val_accuracy: 0.9600
#
# Epoch 00079: val_loss did not improve from 0.18791
# Epoch 80/200
#  - 3s - loss: 0.1320 - accuracy: 0.9403 - val_loss: 0.1986 - val_accuracy: 0.9600
#
# Epoch 00080: val_loss did not improve from 0.18791
# Epoch 81/200
#  - 3s - loss: 0.1533 - accuracy: 0.9182 - val_loss: 0.1799 - val_accuracy: 0.9400
#
# Epoch 00081: val_loss improved from 0.18791 to 0.17986, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 82/200
#  - 3s - loss: 0.2265 - accuracy: 0.8899 - val_loss: 0.2403 - val_accuracy: 0.9600
#
# Epoch 00082: val_loss did not improve from 0.17986
# Epoch 83/200
#  - 3s - loss: 0.1498 - accuracy: 0.9497 - val_loss: 0.2075 - val_accuracy: 0.9400
#
# Epoch 00083: val_loss did not improve from 0.17986
# Epoch 84/200
#  - 3s - loss: 0.1082 - accuracy: 0.9654 - val_loss: 0.1805 - val_accuracy: 0.9700
#
# Epoch 00084: val_loss did not improve from 0.17986
# Epoch 85/200
#  - 3s - loss: 0.0934 - accuracy: 0.9748 - val_loss: 0.2172 - val_accuracy: 0.9600
#
# Epoch 00085: val_loss did not improve from 0.17986
# Epoch 86/200
#  - 3s - loss: 0.0905 - accuracy: 0.9748 - val_loss: 0.2332 - val_accuracy: 0.9200
#
# Epoch 00086: val_loss did not improve from 0.17986
# Epoch 87/200
#  - 3s - loss: 0.0971 - accuracy: 0.9717 - val_loss: 0.1944 - val_accuracy: 0.9700
#
# Epoch 00087: val_loss did not improve from 0.17986
# Epoch 88/200
#  - 3s - loss: 0.1026 - accuracy: 0.9591 - val_loss: 0.3814 - val_accuracy: 0.8400
#
# Epoch 00088: val_loss did not improve from 0.17986
# Epoch 89/200
#  - 3s - loss: 0.1428 - accuracy: 0.9434 - val_loss: 0.2447 - val_accuracy: 0.9300
#
# Epoch 00089: val_loss did not improve from 0.17986
# Epoch 90/200
#  - 3s - loss: 0.1015 - accuracy: 0.9654 - val_loss: 0.1919 - val_accuracy: 0.9700
#
# Epoch 00090: val_loss did not improve from 0.17986
# Epoch 91/200
#  - 3s - loss: 0.0729 - accuracy: 0.9811 - val_loss: 0.1851 - val_accuracy: 0.9600
#
# Epoch 00091: val_loss did not improve from 0.17986
# Epoch 92/200
#  - 3s - loss: 0.0620 - accuracy: 0.9843 - val_loss: 0.2001 - val_accuracy: 0.9600
#
# Epoch 00092: val_loss did not improve from 0.17986
# Epoch 93/200
#  - 3s - loss: 0.0605 - accuracy: 0.9874 - val_loss: 0.1803 - val_accuracy: 0.9600
#
# Epoch 00093: val_loss did not improve from 0.17986
# Epoch 94/200
#  - 3s - loss: 0.0610 - accuracy: 0.9780 - val_loss: 0.2153 - val_accuracy: 0.9700
#
# Epoch 00094: val_loss did not improve from 0.17986
# Epoch 95/200
#  - 3s - loss: 0.0700 - accuracy: 0.9717 - val_loss: 0.3772 - val_accuracy: 0.8900
#
# Epoch 00095: val_loss did not improve from 0.17986
# Epoch 96/200
#  - 3s - loss: 0.1443 - accuracy: 0.9434 - val_loss: 0.4978 - val_accuracy: 0.8300
#
# Epoch 00096: val_loss did not improve from 0.17986
# Epoch 97/200
#  - 3s - loss: 0.1824 - accuracy: 0.9245 - val_loss: 0.2331 - val_accuracy: 0.9600
#
# Epoch 00097: val_loss did not improve from 0.17986
# Epoch 98/200
#  - 3s - loss: 0.0709 - accuracy: 0.9811 - val_loss: 0.1616 - val_accuracy: 0.9500
#
# Epoch 00098: val_loss improved from 0.17986 to 0.16157, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 99/200
#  - 3s - loss: 0.0654 - accuracy: 0.9811 - val_loss: 0.1633 - val_accuracy: 0.9600
#
# Epoch 00099: val_loss did not improve from 0.16157
# Epoch 100/200
#  - 3s - loss: 0.0679 - accuracy: 0.9843 - val_loss: 0.1873 - val_accuracy: 0.9600
#
# Epoch 00100: val_loss did not improve from 0.16157
# Epoch 101/200
#  - 3s - loss: 0.0757 - accuracy: 0.9780 - val_loss: 0.1804 - val_accuracy: 0.9700
#
# Epoch 00101: val_loss did not improve from 0.16157
# Epoch 102/200
#  - 3s - loss: 0.0485 - accuracy: 0.9937 - val_loss: 0.1653 - val_accuracy: 0.9600
#
# Epoch 00102: val_loss did not improve from 0.16157
# Epoch 103/200
#  - 3s - loss: 0.0559 - accuracy: 0.9843 - val_loss: 0.1740 - val_accuracy: 0.9700
#
# Epoch 00103: val_loss did not improve from 0.16157
# Epoch 104/200
#  - 3s - loss: 0.0444 - accuracy: 0.9937 - val_loss: 0.1541 - val_accuracy: 0.9600
#
# Epoch 00104: val_loss improved from 0.16157 to 0.15409, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 105/200
#  - 3s - loss: 0.0431 - accuracy: 0.9969 - val_loss: 0.2027 - val_accuracy: 0.9600
#
# Epoch 00105: val_loss did not improve from 0.15409
# Epoch 106/200
#  - 3s - loss: 0.0517 - accuracy: 0.9843 - val_loss: 0.1858 - val_accuracy: 0.9700
#
# Epoch 00106: val_loss did not improve from 0.15409
# Epoch 107/200
#  - 3s - loss: 0.0489 - accuracy: 0.9811 - val_loss: 0.2333 - val_accuracy: 0.9500
#
# Epoch 00107: val_loss did not improve from 0.15409
# Epoch 108/200
#  - 3s - loss: 0.0454 - accuracy: 0.9906 - val_loss: 0.1871 - val_accuracy: 0.9600
#
# Epoch 00108: val_loss did not improve from 0.15409
# Epoch 109/200
#  - 3s - loss: 0.0318 - accuracy: 1.0000 - val_loss: 0.1679 - val_accuracy: 0.9600
#
# Epoch 00109: val_loss did not improve from 0.15409
# Epoch 110/200
#  - 3s - loss: 0.0320 - accuracy: 0.9969 - val_loss: 0.1681 - val_accuracy: 0.9600
#
# Epoch 00110: val_loss did not improve from 0.15409
# Epoch 111/200
#  - 3s - loss: 0.0463 - accuracy: 0.9811 - val_loss: 0.1605 - val_accuracy: 0.9700
#
# Epoch 00111: val_loss did not improve from 0.15409
# Epoch 112/200
#  - 3s - loss: 0.0977 - accuracy: 0.9623 - val_loss: 0.1661 - val_accuracy: 0.9700
#
# Epoch 00112: val_loss did not improve from 0.15409
# Epoch 113/200
#  - 3s - loss: 0.0808 - accuracy: 0.9686 - val_loss: 0.1669 - val_accuracy: 0.9700
#
# Epoch 00113: val_loss did not improve from 0.15409
# Epoch 114/200
#  - 3s - loss: 0.0356 - accuracy: 0.9906 - val_loss: 0.1622 - val_accuracy: 0.9700
#
# Epoch 00114: val_loss did not improve from 0.15409
# Epoch 115/200
#  - 3s - loss: 0.0277 - accuracy: 0.9969 - val_loss: 0.1612 - val_accuracy: 0.9600
#
# Epoch 00115: val_loss did not improve from 0.15409
# Epoch 116/200
#  - 3s - loss: 0.0296 - accuracy: 0.9906 - val_loss: 0.1708 - val_accuracy: 0.9800
#
# Epoch 00116: val_loss did not improve from 0.15409
# Epoch 117/200
#  - 3s - loss: 0.0479 - accuracy: 0.9811 - val_loss: 0.3913 - val_accuracy: 0.8700
#
# Epoch 00117: val_loss did not improve from 0.15409
# Epoch 118/200
#  - 3s - loss: 0.0455 - accuracy: 0.9906 - val_loss: 0.1834 - val_accuracy: 0.9700
#
# Epoch 00118: val_loss did not improve from 0.15409
# Epoch 119/200
#  - 3s - loss: 0.0330 - accuracy: 0.9937 - val_loss: 0.1708 - val_accuracy: 0.9700
#
# Epoch 00119: val_loss did not improve from 0.15409
# Epoch 120/200
#  - 3s - loss: 0.0273 - accuracy: 0.9937 - val_loss: 0.1907 - val_accuracy: 0.9600
#
# Epoch 00120: val_loss did not improve from 0.15409
# Epoch 121/200
#  - 3s - loss: 0.0320 - accuracy: 1.0000 - val_loss: 0.1595 - val_accuracy: 0.9800
#
# Epoch 00121: val_loss did not improve from 0.15409
# Epoch 122/200
#  - 3s - loss: 0.0474 - accuracy: 0.9811 - val_loss: 0.4910 - val_accuracy: 0.8400
#
# Epoch 00122: val_loss did not improve from 0.15409
# Epoch 123/200
#  - 3s - loss: 0.0970 - accuracy: 0.9623 - val_loss: 0.1643 - val_accuracy: 0.9700
#
# Epoch 00123: val_loss did not improve from 0.15409
# Epoch 124/200
#  - 3s - loss: 0.0223 - accuracy: 0.9969 - val_loss: 0.1688 - val_accuracy: 0.9800
#
# Epoch 00124: val_loss did not improve from 0.15409
# Epoch 125/200
#  - 3s - loss: 0.0280 - accuracy: 0.9969 - val_loss: 0.2328 - val_accuracy: 0.9600
#
# Epoch 00125: val_loss did not improve from 0.15409
# Epoch 126/200
#  - 3s - loss: 0.0363 - accuracy: 0.9874 - val_loss: 0.1713 - val_accuracy: 0.9800
#
# Epoch 00126: val_loss did not improve from 0.15409
# Epoch 127/200
#  - 3s - loss: 0.0324 - accuracy: 0.9937 - val_loss: 0.3176 - val_accuracy: 0.9200
#
# Epoch 00127: val_loss did not improve from 0.15409
# Epoch 128/200
#  - 3s - loss: 0.0572 - accuracy: 0.9811 - val_loss: 0.2223 - val_accuracy: 0.9600
#
# Epoch 00128: val_loss did not improve from 0.15409
# Epoch 129/200
#  - 3s - loss: 0.1002 - accuracy: 0.9528 - val_loss: 0.1509 - val_accuracy: 0.9700
#
# Epoch 00129: val_loss improved from 0.15409 to 0.15087, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 130/200
#  - 3s - loss: 0.0358 - accuracy: 0.9969 - val_loss: 0.6717 - val_accuracy: 0.8300
#
# Epoch 00130: val_loss did not improve from 0.15087
# Epoch 131/200
#  - 3s - loss: 0.1141 - accuracy: 0.9591 - val_loss: 0.1404 - val_accuracy: 0.9800
#
# Epoch 00131: val_loss improved from 0.15087 to 0.14040, saving model to Model_depthwise_3_arson.weights.best.hdf5
# Epoch 132/200
#  - 3s - loss: 0.0471 - accuracy: 0.9843 - val_loss: 0.2386 - val_accuracy: 0.9400
#
# Epoch 00132: val_loss did not improve from 0.14040
# Epoch 133/200
#  - 3s - loss: 0.0312 - accuracy: 0.9937 - val_loss: 0.1631 - val_accuracy: 0.9600
#
# Epoch 00133: val_loss did not improve from 0.14040
# Epoch 134/200
#  - 3s - loss: 0.0209 - accuracy: 0.9937 - val_loss: 0.1428 - val_accuracy: 0.9700
#
# Epoch 00134: val_loss did not improve from 0.14040
# Epoch 135/200
#  - 3s - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.1441 - val_accuracy: 0.9900
#
# Epoch 00135: val_loss did not improve from 0.14040
# Epoch 136/200
#  - 3s - loss: 0.0181 - accuracy: 0.9969 - val_loss: 0.1901 - val_accuracy: 0.9600
#
# Epoch 00136: val_loss did not improve from 0.14040
# Epoch 137/200
#  - 3s - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9900
#
# Epoch 00137: val_loss did not improve from 0.14040
# Epoch 138/200
#  - 3s - loss: 0.0226 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9900
#
# Epoch 00138: val_loss did not improve from 0.14040
# Epoch 139/200
#  - 3s - loss: 0.0232 - accuracy: 0.9937 - val_loss: 0.2488 - val_accuracy: 0.9400
#
# Epoch 00139: val_loss did not improve from 0.14040
# Epoch 140/200
#  - 3s - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.1733 - val_accuracy: 0.9700
#
# Epoch 00140: val_loss did not improve from 0.14040
# Epoch 141/200
#  - 3s - loss: 0.0158 - accuracy: 0.9969 - val_loss: 0.1545 - val_accuracy: 0.9800
#
# Epoch 00141: val_loss did not improve from 0.14040
# Epoch 142/200
#  - 3s - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.1545 - val_accuracy: 0.9800
#
# Epoch 00142: val_loss did not improve from 0.14040
# Epoch 143/200
#  - 3s - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.1572 - val_accuracy: 0.9900
#
# Epoch 00143: val_loss did not improve from 0.14040
# Epoch 144/200
#  - 3s - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.1577 - val_accuracy: 0.9900
#
# Epoch 00144: val_loss did not improve from 0.14040
# Epoch 145/200
#  - 3s - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.1614 - val_accuracy: 0.9700
#
# Epoch 00145: val_loss did not improve from 0.14040
# Epoch 146/200
#  - 3s - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.1934 - val_accuracy: 0.9600
#
# Epoch 00146: val_loss did not improve from 0.14040
# Epoch 147/200
#  - 3s - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.1619 - val_accuracy: 0.9900
#
# Epoch 00147: val_loss did not improve from 0.14040
# Epoch 148/200
#  - 3s - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.1672 - val_accuracy: 0.9900
#
# Epoch 00148: val_loss did not improve from 0.14040
# Epoch 149/200
#  - 3s - loss: 0.0108 - accuracy: 0.9969 - val_loss: 0.1809 - val_accuracy: 0.9700
#
# Epoch 00149: val_loss did not improve from 0.14040
# Epoch 150/200
#  - 3s - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.1784 - val_accuracy: 0.9900
#
# Epoch 00150: val_loss did not improve from 0.14040
# Epoch 151/200
#  - 3s - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.1853 - val_accuracy: 0.9700
#
# Epoch 00151: val_loss did not improve from 0.14040
# Epoch 152/200
#  - 3s - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.1712 - val_accuracy: 0.9800
#
# Epoch 00152: val_loss did not improve from 0.14040
# Epoch 153/200
#  - 3s - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.1917 - val_accuracy: 0.9700
#
# Epoch 00153: val_loss did not improve from 0.14040
# Epoch 154/200
#  - 3s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.1729 - val_accuracy: 0.9900
#
# Epoch 00154: val_loss did not improve from 0.14040
# Epoch 155/200
#  - 3s - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.2561 - val_accuracy: 0.9400
#
# Epoch 00155: val_loss did not improve from 0.14040
# Epoch 156/200
#  - 3s - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.1752 - val_accuracy: 0.9700
#
# Epoch 00156: val_loss did not improve from 0.14040
# Epoch 157/200
#  - 3s - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.1854 - val_accuracy: 0.9700
#
# Epoch 00157: val_loss did not improve from 0.14040
# Epoch 158/200
#  - 3s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.2097 - val_accuracy: 0.9700
#
# Epoch 00158: val_loss did not improve from 0.14040
# Epoch 159/200
#  - 3s - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.2186 - val_accuracy: 0.9600
#
# Epoch 00159: val_loss did not improve from 0.14040
# Epoch 160/200
#  - 3s - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.1770 - val_accuracy: 0.9900
#
# Epoch 00160: val_loss did not improve from 0.14040
# Epoch 161/200
#  - 3s - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.1778 - val_accuracy: 0.9800
#
# Epoch 00161: val_loss did not improve from 0.14040
# Epoch 162/200
#  - 3s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9900
#
# Epoch 00162: val_loss did not improve from 0.14040
# Epoch 163/200
#  - 3s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.1770 - val_accuracy: 0.9900
#
# Epoch 00163: val_loss did not improve from 0.14040
# Epoch 164/200
#  - 3s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.1789 - val_accuracy: 0.9900
#
# Epoch 00164: val_loss did not improve from 0.14040
# Epoch 165/200
#  - 3s - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.1904 - val_accuracy: 0.9700
#
# Epoch 00165: val_loss did not improve from 0.14040
# Epoch 166/200
#  - 3s - loss: 0.0091 - accuracy: 0.9969 - val_loss: 0.1778 - val_accuracy: 0.9900
#
# Epoch 00166: val_loss did not improve from 0.14040
# Epoch 167/200
#  - 3s - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9700
#
# Epoch 00167: val_loss did not improve from 0.14040
# Epoch 168/200
#  - 3s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.1791 - val_accuracy: 0.9900
#
# Epoch 00168: val_loss did not improve from 0.14040
# Epoch 169/200
#  - 3s - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.1869 - val_accuracy: 0.9800
#
# Epoch 00169: val_loss did not improve from 0.14040
# Epoch 170/200
#  - 3s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.2036 - val_accuracy: 0.9600
#
# Epoch 00170: val_loss did not improve from 0.14040
# Epoch 171/200
#  - 3s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.1796 - val_accuracy: 0.9900
#
# Epoch 00171: val_loss did not improve from 0.14040
# Epoch 172/200
#  - 3s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.1966 - val_accuracy: 0.9800
#
# Epoch 00172: val_loss did not improve from 0.14040
# Epoch 173/200
#  - 3s - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.2068 - val_accuracy: 0.9600
#
# Epoch 00173: val_loss did not improve from 0.14040
# Epoch 174/200
#  - 3s - loss: 0.0244 - accuracy: 0.9937 - val_loss: 0.2809 - val_accuracy: 0.9400
#
# Epoch 00174: val_loss did not improve from 0.14040
# Epoch 175/200
#  - 3s - loss: 0.0744 - accuracy: 0.9654 - val_loss: 0.3713 - val_accuracy: 0.9100
#
# Epoch 00175: val_loss did not improve from 0.14040
# Epoch 176/200
#  - 3s - loss: 0.1189 - accuracy: 0.9528 - val_loss: 0.2437 - val_accuracy: 0.9700
#
# Epoch 00176: val_loss did not improve from 0.14040
# Epoch 177/200
#  - 3s - loss: 0.0406 - accuracy: 0.9811 - val_loss: 0.1941 - val_accuracy: 0.9700
#
# Epoch 00177: val_loss did not improve from 0.14040
# Epoch 178/200
#  - 3s - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.1954 - val_accuracy: 0.9700
#
# Epoch 00178: val_loss did not improve from 0.14040
# Epoch 179/200
#  - 3s - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.1773 - val_accuracy: 0.9700
#
# Epoch 00179: val_loss did not improve from 0.14040
# Epoch 180/200
#  - 3s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.1843 - val_accuracy: 0.9700
#
# Epoch 00180: val_loss did not improve from 0.14040
# Epoch 181/200
#  - 3s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.2326 - val_accuracy: 0.9500
#
# Epoch 00181: val_loss did not improve from 0.14040
# Epoch 182/200
#  - 3s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.2188 - val_accuracy: 0.9500
#
# Epoch 00182: val_loss did not improve from 0.14040
# Epoch 183/200
#  - 3s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.1710 - val_accuracy: 0.9900
#
# Epoch 00183: val_loss did not improve from 0.14040
# Epoch 184/200
#  - 3s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.1846 - val_accuracy: 0.9700
#
# Epoch 00184: val_loss did not improve from 0.14040
# Epoch 185/200
#  - 3s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.1806 - val_accuracy: 0.9900
#
# Epoch 00185: val_loss did not improve from 0.14040
# Epoch 186/200
#  - 3s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1757 - val_accuracy: 0.9900
#
# Epoch 00186: val_loss did not improve from 0.14040
# Epoch 187/200
#  - 3s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1843 - val_accuracy: 0.9900
#
# Epoch 00187: val_loss did not improve from 0.14040
# Epoch 188/200
#  - 3s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1828 - val_accuracy: 0.9900
#
# Epoch 00188: val_loss did not improve from 0.14040
# Epoch 189/200
#  - 3s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1875 - val_accuracy: 0.9800
#
# Epoch 00189: val_loss did not improve from 0.14040
# Epoch 190/200
#  - 3s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1798 - val_accuracy: 0.9900
#
# Epoch 00190: val_loss did not improve from 0.14040
# Epoch 191/200
#  - 3s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1800 - val_accuracy: 0.9900
#
# Epoch 00191: val_loss did not improve from 0.14040
# Epoch 192/200
#  - 3s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1939 - val_accuracy: 0.9700
#
# Epoch 00192: val_loss did not improve from 0.14040
# Epoch 193/200
#  - 3s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9900
#
# Epoch 00193: val_loss did not improve from 0.14040
# Epoch 194/200
#  - 3s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1815 - val_accuracy: 0.9900
#
# Epoch 00194: val_loss did not improve from 0.14040
# Epoch 195/200
#  - 3s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1867 - val_accuracy: 0.9900
#
# Epoch 00195: val_loss did not improve from 0.14040
# Epoch 196/200
#  - 3s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1843 - val_accuracy: 0.9900
#
# Epoch 00196: val_loss did not improve from 0.14040
# Epoch 197/200
#  - 3s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1843 - val_accuracy: 0.9900
#
# Epoch 00197: val_loss did not improve from 0.14040
# Epoch 198/200
#  - 3s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1909 - val_accuracy: 0.9900
#
# Epoch 00198: val_loss did not improve from 0.14040
# Epoch 199/200
#  - 3s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9900
#
# Epoch 00199: val_loss did not improve from 0.14040
# Epoch 200/200
#  - 3s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9900
#
# Epoch 00200: val_loss did not improve from 0.14040
# Accuracy on test data: 96.67%
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
# class Normal       0.98      0.96      0.97       112
#  class arson       0.96      0.92      0.94        98
#
#    micro avg       0.97      0.94      0.96       210
#    macro avg       0.97      0.94      0.96       210
# weighted avg       0.97      0.94      0.96       210
#  samples avg       0.94      0.94      0.94       210

# %%
# !mkdir "/content/gdrive/My Drive/Security Dataset/arson"
# !cp -r "/content/curated_dataset" "/content/gdrive/My Drive/Security Dataset/arson"

# %%
#!mkdir "/content/gdrive/My Drive/Security Dataset/arson/weights"
# !cp -r "/content/Model_depthwise_1_arson.weights.best.hdf5" "/content/gdrive/My Drive/Security Dataset/arson/weights"
# !cp -r "/content/Model_depthwise_2_arson.weights.best.hdf5" "/content/gdrive/My Drive/Security Dataset/arson/weights"
#!cp -r "/content/Model_arson_1.weights.best.hdf5" "/content/gdrive/My Drive/Security Dataset/arson/weights"
# !cp -r "/content/Model_arson_2_larger_parameters.weights.best.hdf5" "/content/gdrive/My Drive/Security Dataset/arson/weights"
