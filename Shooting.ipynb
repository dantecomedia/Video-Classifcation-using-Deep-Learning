# %% [markdown]
# <a href="https://colab.research.google.com/github/dantecomedia/Video-Classifcation-using-Deep-Learning/blob/master/Shooting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount("/content/gdrive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import numpy as np 
import pandas as pd
import os
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_files
import random
import shutil
# !pip install scikit-video
import numpy as np
from skvideo.io import FFmpegReader, ffprobe
from skvideo.utils import rgb2gray
from PIL import Image
from keras.preprocessing import image
from tqdm import tqdm
import matplotlib.pyplot as plt
from keras.utils import to_categorical
import matplotlib.pyplot as plt
from __future__ import absolute_import

from keras import backend as K
from keras import initializers
from keras import regularizers
from keras import constraints
from keras import layers
from keras.engine import InputSpec
from keras.utils import conv_utils
from keras.legacy.interfaces import conv3d_args_preprocessor, generate_legacy_interface
from keras.layers import Conv3D
from keras.backend.tensorflow_backend import _preprocess_padding, _preprocess_conv3d_input

import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv3D, MaxPooling3D, GlobalAveragePooling3D
from keras.layers.core import Dense
import tensorflow.keras.backend as K
from keras.callbacks import ModelCheckpoint
from keras.layers.core import Dropout
from sklearn.metrics import classification_report
# Out:
# Collecting scikit-video
#   Downloading https://files.pythonhosted.org/packages/b1/a6/c69cad508139a342810ae46e946ebb3256aa6e42f690d901bb68f50582e3/scikit_video-1.1.11-py2.py3-none-any.whl (2.3MB)
#      |████████████████████████████████| 2.3MB 4.9MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from scikit-video) (1.18.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from scikit-video) (7.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from scikit-video) (1.4.1)
# Installing collected packages: scikit-video
# Successfully installed scikit-video-1.1.11
# Using TensorFlow backend.

# %%
# !cp "/content/gdrive/My Drive/Security Dataset/Trimmed Dataset-20200612T201236Z-001.zip" "/content/"
# !unzip "/content/Trimmed Dataset-20200612T201236Z-001.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Trimmed Dataset/Burglary/Burglary011_x264_29.mp4
#   inflating: Trimmed Dataset/Arson/Arson034_x264_19.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_14.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_22.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest036_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_13.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary037_x264_22.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest017_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary014_x264_29.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_30.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary069_x264_11.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing018_x264_18.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary069_x264_2.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism044_x264_9.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism040_x264_3.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism045_x264_14.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing105_x264_14.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting036_x264_15.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism045_x264_8.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary007_x264_23.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest025_x264_13.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_5.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism035_x264_17.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing097_x264_11.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary089_x264_5.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary037_x264_30.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism040_x264_4.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism015_x264_17.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest009_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_12.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism002_x264_3.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary007_x264_18.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary015_x264_26.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_13.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing066_x264_14.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing106_x264_11.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents138_x264_11.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing018_x264_5.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest025_x264_21.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_6.mp4
#   inflating: Trimmed Dataset/Assault/Assault007_x264_31.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery066_x264_3.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing093_x264_19.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary015_x264_15.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_22.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing066_x264_15.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_21.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_2.mp4
#   inflating: Trimmed Dataset/Fighting/Fighting013_x264_29.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing094_x264_5.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary035_x264_5.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest038_x264_7.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_19.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing010_x264_30.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting029_x264_25.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary085_x264_6.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents036_x264_20.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary090_x264_8.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary021_x264_29.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest038_x264_18.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism002_x264_10.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism045_x264_12.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism047_x264_27.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_10.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing078_x264_30.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing093_x264_21.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary099_x264_5.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest013_x264_11.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_13.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents138_x264_22.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing018_x264_16.mp4
#   inflating: Trimmed Dataset/Shoplifting/Shoplifting022_x264_5.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary099_x264_4.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_29.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest036_x264_19.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing105_x264_9.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing097_x264_6.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents050_x264_10.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_18.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing008_x264_28.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism034_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary099_x264_2.mp4
#   inflating: Trimmed Dataset/Assault/Assault011_x264_18.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing009_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary014_x264_2.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing022_x264_15.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting022_x264_27.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing113_x264_25.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest009_x264_31.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism034_x264_19.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_12.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary036_x264_4.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing066_x264_17.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary036_x264_18.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism025_x264_3.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_17.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary037_x264_13.mp4
#   inflating: Trimmed Dataset/Assault/Assault004_x264_8.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary048_x264_10.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_10.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism035_x264_14.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing017_x264_21.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing066_x264_11.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_19.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing114_x264_2.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary069_x264_10.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary014_x264_0.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting019_x264_22.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing075_x264_29.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_22.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary069_x264_13.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary069_x264_31.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_27.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary099_x264_9.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary069_x264_30.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary099_x264_16.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_16.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_23.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary014_x264_10.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_12.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery053_x264_27.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing008_x264_30.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary011_x264_16.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting008_x264_12.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing017_x264_19.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_27.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism036_x264_18.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism004_x264_19.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_21.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism003_x264_19.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism034_x264_26.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism004_x264_2.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary055_x264_21.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing060_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary046_x264_12.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing078_x264_31.mp4
#   inflating: Trimmed Dataset/Explosion/Explosion026_x264_2.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_19.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_5.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_4.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_10.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_24.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing014_x264_7.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_20.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_28.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing075_x264_14.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery007_x264_9.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary036_x264_12.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting025_x264_12.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest036_x264_20.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary087_x264_14.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing108_x264_20.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest036_x264_28.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing101_x264_30.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism035_x264_6.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents036_x264_17.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary007_x264_2.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_11.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing017_x264_25.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing113_x264_28.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_9.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest040_x264_30.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing016_x264_27.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary022_x264_17.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing108_x264_31.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_4.mp4
#   inflating: Trimmed Dataset/Assault/Assault033_x264_22.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism045_x264_22.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_3.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism045_x264_11.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing015_x264_24.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism002_x264_12.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary015_x264_12.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing097_x264_8.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing078_x264_25.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_6.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_10.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents066_x264_8.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_30.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism013_x264_28.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary048_x264_14.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_7.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary037_x264_18.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_17.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary080_x264_10.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism035_x264_7.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism005_x264_27.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_11.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing008_x264_19.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_22.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_5.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_11.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest040_x264_29.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_15.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_11.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting030_x264_25.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_25.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism040_x264_28.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing097_x264_12.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents032_x264_21.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary015_x264_4.mp4
#   inflating: Trimmed Dataset/Normal/Robbery114_x264_22.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting041_x264_21.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary036_x264_5.mp4
#   inflating: Trimmed Dataset/Arson/Arson020_x264_27.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_18.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing097_x264_10.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary036_x264_23.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism045_x264_24.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing098_x264_30.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary074_x264_6.mp4
#   inflating: Trimmed Dataset/Shoplifting/Shoplifting048_x264_3.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary017_x264_25.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing018_x264_9.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing113_x264_29.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_24.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_31.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_20.mp4
#   inflating: Trimmed Dataset/Assault/Assault007_x264_11.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_17.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary048_x264_9.mp4
#   inflating: Trimmed Dataset/Assault/Assault017_x264_11.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_16.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting010_x264_22.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism001_x264_16.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism005_x264_23.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing037_x264_31.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary014_x264_31.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest009_x264_28.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism044_x264_25.mp4
#   inflating: Trimmed Dataset/Explosion/Explosion028_x264_9.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary035_x264_2.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_25.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_21.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest005_x264_20.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary015_x264_5.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_3.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing018_x264_17.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary074_x264_20.mp4
#   inflating: Trimmed Dataset/Shoplifting/Shoplifting025_x264_24.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_22.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing037_x264_24.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary021_x264_28.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest003_x264_28.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_8.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting007_x264_17.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing060_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary037_x264_14.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary011_x264_14.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse050_x264_24.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary014_x264_9.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest019_x264_14.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary089_x264_28.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism025_x264_2.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary011_x264_18.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing008_x264_18.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_7.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary048_x264_27.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary021_x264_3.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing113_x264_27.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest025_x264_26.mp4
#   inflating: Trimmed Dataset/Normal/Robbery066_x264_15.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism019_x264_17.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_24.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing108_x264_26.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing105_x264_8.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing060_x264_22.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary069_x264_27.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_11.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary090_x264_11.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest040_x264_27.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary099_x264_10.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse004_x264_3.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing105_x264_5.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing078_x264_24.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary026_x264_2.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism040_x264_9.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_9.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_26.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest040_x264_26.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest040_x264_20.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism034_x264_22.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary041_x264_19.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary015_x264_31.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_10.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism035_x264_5.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism045_x264_29.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing022_x264_22.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_4.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing113_x264_22.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_12.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing114_x264_7.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery029_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary080_x264_31.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary011_x264_1.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_19.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest025_x264_27.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary021_x264_7.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents126_x264_15.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism045_x264_20.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing066_x264_28.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse022_x264_9.mp4
#   inflating: Trimmed Dataset/Fighting/Fighting013_x264_22.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing006_x264_26.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest040_x264_25.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents032_x264_22.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing105_x264_11.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing008_x264_23.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary011_x264_6.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing105_x264_12.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing078_x264_27.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery053_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary069_x264_28.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary036_x264_31.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing037_x264_17.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_18.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_23.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest036_x264_9.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism005_x264_25.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing105_x264_7.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary074_x264_25.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest025_x264_24.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary037_x264_23.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_3.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism035_x264_9.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism035_x264_16.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary014_x264_3.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism044_x264_11.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary015_x264_30.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary074_x264_22.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary035_x264_10.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism002_x264_27.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_28.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing037_x264_8.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary085_x264_8.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing015_x264_26.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing112_x264_30.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing008_x264_31.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting042_x264_9.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting029_x264_17.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing018_x264_1.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary055_x264_31.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism044_x264_27.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing094_x264_7.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents031_x264_12.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary069_x264_6.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary015_x264_8.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary035_x264_4.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing044_x264_24.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents019_x264_31.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting030_x264_24.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_9.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing066_x264_9.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing008_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary041_x264_15.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism037_x264_12.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse027_x264_21.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing114_x264_13.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing112_x264_27.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary007_x264_13.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing112_x264_16.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse045_x264_1.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing011_x264_27.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_24.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary099_x264_25.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary085_x264_13.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse006_x264_30.mp4
#   inflating: Trimmed Dataset/Arson/Arson024_x264_20.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest040_x264_24.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery080_x264_9.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest032_x264_25.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest025_x264_29.mp4
#   inflating: Trimmed Dataset/Explosion/Explosion004_x264_5.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_14.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary007_x264_31.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents099_x264_16.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary048_x264_18.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing060_x264_21.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing018_x264_10.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing108_x264_23.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting005_x264_9.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary085_x264_17.mp4
#   inflating: Trimmed Dataset/Arson/Arson034_x264_24.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery136_x264_19.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism040_x264_10.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_9.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing078_x264_9.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism045_x264_16.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest025_x264_16.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism034_x264_28.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse027_x264_28.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary015_x264_14.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_16.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_28.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism034_x264_30.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary074_x264_24.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_31.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest024_x264_16.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism044_x264_16.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing112_x264_21.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_21.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary021_x264_9.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing114_x264_5.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing114_x264_11.mp4
#   inflating: Trimmed Dataset/Normal/Robbery007_x264_1.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary015_x264_3.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest036_x264_18.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_9.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing017_x264_18.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents019_x264_25.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary015_x264_16.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary014_x264_20.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing060_x264_27.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_15.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting007_x264_30.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary074_x264_31.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery129_x264_18.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing037_x264_12.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism036_x264_17.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents032_x264_8.mp4
#   inflating: Trimmed Dataset/Arson/Arson020_x264_31.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism047_x264_1.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary037_x264_20.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary011_x264_15.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery129_x264_22.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary089_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_18.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism036_x264_21.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary021_x264_27.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing010_x264_31.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing022_x264_19.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting011_x264_17.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism040_x264_1.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest036_x264_30.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism040_x264_5.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing081_x264_22.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary080_x264_23.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_25.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary069_x264_5.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary085_x264_10.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing078_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary036_x264_20.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism036_x264_20.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_14.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary017_x264_13.mp4
#   inflating: Trimmed Dataset/Assault/Assault009_x264_17.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary048_x264_22.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_19.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary055_x264_20.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_31.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing014_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_21.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents032_x264_24.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary024_x264_3.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest003_x264_24.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents032_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary036_x264_21.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary022_x264_24.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest036_x264_24.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_8.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing017_x264_22.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing044_x264_9.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing022_x264_18.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest042_x264_21.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_13.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_27.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_6.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_16.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing017_x264_12.mp4
#   inflating: Trimmed Dataset/Arson/Arson047_x264_18.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing112_x264_23.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing006_x264_27.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary014_x264_6.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing112_x264_14.mp4
#   inflating: Trimmed Dataset/Arson/Arson020_x264_23.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary015_x264_18.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary080_x264_7.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary022_x264_4.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary074_x264_18.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing022_x264_21.mp4
#   inflating: Trimmed Dataset/Assault/Assault028_x264_12.mp4
#   inflating: Trimmed Dataset/Arson/Arson024_x264_24.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary085_x264_5.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary022_x264_13.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing017_x264_15.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting020_x264_20.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary014_x264_22.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_27.mp4
#   inflating: Trimmed Dataset/Fighting/Fighting013_x264_17.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing078_x264_19.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents015_x264_21.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_23.mp4
#   inflating: Trimmed Dataset/Explosion/Explosion004_x264_3.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_20.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism045_x264_13.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_2.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism015_x264_19.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism030_x264_3.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism036_x264_19.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary074_x264_12.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing044_x264_21.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_28.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing114_x264_3.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest038_x264_30.mp4
#   inflating: Trimmed Dataset/Normal/Robbery111_x264_4.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_28.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_27.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest025_x264_20.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing101_x264_25.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing108_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary026_x264_12.mp4
#   inflating: Trimmed Dataset/Normal/Robbery114_x264_29.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery082_x264_17.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism045_x264_23.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing037_x264_1.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism040_x264_31.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing112_x264_31.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism035_x264_4.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism044_x264_15.mp4
#   inflating: Trimmed Dataset/Arson/Arson042_x264_26.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing018_x264_8.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary048_x264_12.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents145_x264_16.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_17.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary090_x264_9.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest040_x264_21.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing015_x264_30.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary089_x264_17.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary037_x264_21.mp4
#   inflating: Trimmed Dataset/Explosion/Explosion009_x264_12.mp4
#   inflating: Trimmed Dataset/Shoplifting/Shoplifting006_x264_27.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing018_x264_2.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_6.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest036_x264_25.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing113_x264_24.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest036_x264_22.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse043_x264_4.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse022_x264_13.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_31.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest025_x264_17.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_10.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse050_x264_21.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing017_x264_20.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents113_x264_21.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary080_x264_16.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing017_x264_17.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery029_x264_23.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest036_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary099_x264_17.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest009_x264_30.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing044_x264_7.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary048_x264_20.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary035_x264_7.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse043_x264_23.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing018_x264_6.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing078_x264_23.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism003_x264_20.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery082_x264_4.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary085_x264_12.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism040_x264_29.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism035_x264_2.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism037_x264_4.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing066_x264_8.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing078_x264_22.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary037_x264_5.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery100_x264_18.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing044_x264_28.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting007_x264_10.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary013_x264_22.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_22.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary099_x264_13.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest032_x264_13.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing075_x264_6.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_23.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing018_x264_19.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_20.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing060_x264_25.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_13.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing060_x264_20.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_3.mp4
#   inflating: Trimmed Dataset/Shoplifting/Shoplifting001_x264_9.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_4.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing101_x264_27.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary022_x264_22.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting026_x264_1.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing037_x264_2.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary021_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_6.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest040_x264_22.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing015_x264_27.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest001_x264_24.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism025_x264_8.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism035_x264_3.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting041_x264_16.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_12.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary069_x264_21.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism005_x264_22.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing112_x264_6.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary048_x264_11.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest003_x264_16.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_8.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism030_x264_4.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_24.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary019_x264_10.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism033_x264_19.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest025_x264_18.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary099_x264_29.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents141_x264_11.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing114_x264_12.mp4
#   inflating: Trimmed Dataset/Normal/Robbery114_x264_14.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary080_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary046_x264_28.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents140_x264_7.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing006_x264_28.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism004_x264_22.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing018_x264_4.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_22.mp4
#   inflating: Trimmed Dataset/Normal/Robbery007_x264_3.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary041_x264_28.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents048_x264_31.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest002_x264_23.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing097_x264_9.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism044_x264_19.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest013_x264_10.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing112_x264_12.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents018_x264_14.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary007_x264_11.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting036_x264_14.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary046_x264_18.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary099_x264_7.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_31.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary014_x264_7.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary015_x264_17.mp4
#   inflating: Trimmed Dataset/Shoplifting/Shoplifting049_x264_17.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary074_x264_17.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing112_x264_13.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_24.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary048_x264_25.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_8.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing050_x264_7.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_24.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism045_x264_7.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_2.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_11.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_19.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary015_x264_10.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse031_x264_26.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse026_x264_15.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism040_x264_2.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism005_x264_28.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing015_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary007_x264_15.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents011_x264_6.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_8.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing014_x264_18.mp4
#   inflating: Trimmed Dataset/Assault/Assault014_x264_10.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_7.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents091_x264_14.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism040_x264_0.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_8.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_19.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_25.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse013_x264_7.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing112_x264_7.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_18.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing051_x264_13.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary069_x264_23.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary011_x264_7.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery146_x264_21.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_9.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing051_x264_21.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism003_x264_15.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism036_x264_23.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_30.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing008_x264_25.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing113_x264_30.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary011_x264_10.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_14.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing050_x264_19.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary011_x264_3.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_31.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_9.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_16.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary053_x264_29.mp4
#   inflating: Trimmed Dataset/Assault/Assault014_x264_9.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism021_x264_17.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents025_x264_29.mp4
#   inflating: Trimmed Dataset/Explosion/Explosion020_x264_4.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery136_x264_21.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing075_x264_9.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary037_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary021_x264_2.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing105_x264_13.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary055_x264_19.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary007_x264_12.mp4
#   inflating: Trimmed Dataset/Explosion/Explosion033_x264_27.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery100_x264_14.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing106_x264_12.mp4
#   inflating: Trimmed Dataset/Assault/Assault025_x264_13.mp4
#   inflating: Trimmed Dataset/Normal/Robbery094_x264_1.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary027_x264_17.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism005_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary090_x264_18.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting031_x264_11.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_24.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism019_x264_18.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing078_x264_29.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents074_x264_16.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary007_x264_24.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing037_x264_7.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_25.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism036_x264_22.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing101_x264_29.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism038_x264_8.mp4
#   inflating: Trimmed Dataset/Explosion/Explosion032_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary021_x264_1.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing114_x264_14.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing011_x264_25.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary037_x264_17.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest019_x264_10.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery080_x264_23.mp4
#   inflating: Trimmed Dataset/Normal/Robbery095_x264_31.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary037_x264_28.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_5.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_26.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing008_x264_20.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism035_x264_13.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing101_x264_28.mp4
#   inflating: Trimmed Dataset/Normal/Robbery004_x264_1.mp4
#   inflating: Trimmed Dataset/Normal/Robbery050_x264_10.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary011_x264_11.mp4
#   inflating: Trimmed Dataset/Normal/Robbery095_x264_23.mp4
#   inflating: Trimmed Dataset/Normal/Robbery063_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary087_x264_13.mp4
#   inflating: Trimmed Dataset/Normal/Robbery048_x264_13.mp4
#   inflating: Trimmed Dataset/Normal/Robbery004_x264_2.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest011_x264_23.mp4
#   inflating: Trimmed Dataset/Normal/Robbery063_x264_8.mp4
#   inflating: Trimmed Dataset/Normal/Robbery049_x264_9.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary074_x264_7.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism019_x264_19.mp4
#   inflating: Trimmed Dataset/Assault/Assault002_x264_4.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest025_x264_12.mp4
#   inflating: Trimmed Dataset/Normal/Robbery036_x264_16.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse023_x264_8.mp4
# ...
#   inflating: Trimmed Dataset/Robbery/Robbery009_x264_20.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery004_x264_12.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary051_x264_7.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest001_x264_21.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest038_x264_12.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery038_x264_31.mp4
#   inflating: Trimmed Dataset/Arson/Arson014_x264_18.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery015_x264_30.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery013_x264_8.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery146_x264_23.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery091_x264_26.mp4
#   inflating: Trimmed Dataset/Arson/Arson042_x264_23.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest041_x264_12.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism040_x264_6.mp4
#   inflating: Trimmed Dataset/Normal/Robbery078_x264_3.mp4
#   inflating: Trimmed Dataset/Assault/Assault022_x264_5.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery122_x264_23.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery041_x264_13.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery127_x264_20.mp4
#   inflating: Trimmed Dataset/Normal/Robbery045_x264_7.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest032_x264_14.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_5.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest023_x264_5.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism034_x264_21.mp4
#   inflating: Trimmed Dataset/Normal/Robbery118_x264_30.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing070_x264_29.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery133_x264_16.mp4
#   inflating: Trimmed Dataset/Normal/Robbery038_x264_5.mp4
#   inflating: Trimmed Dataset/Arson/Arson027_x264_26.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing054_x264_30.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary041_x264_23.mp4
#   inflating: Trimmed Dataset/Normal/Robbery112_x264_4.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery078_x264_13.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing104_x264_12.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery007_x264_23.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse023_x264_5.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary066_x264_19.mp4
#   inflating: Trimmed Dataset/Normal/Robbery110_x264_22.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary018_x264_23.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery065_x264_29.mp4
#   inflating: Trimmed Dataset/Normal/Robbery104_x264_7.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery103_x264_14.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery081_x264_6.mp4
#   inflating: Trimmed Dataset/Arson/Arson002_x264_12.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery025_x264_17.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary071_x264_7.mp4
#   inflating: Trimmed Dataset/Normal/Robbery126_x264_7.mp4
#   inflating: Trimmed Dataset/Shoplifting/Shoplifting018_x264_23.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery129_x264_2.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse025_x264_12.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse037_x264_5.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary090_x264_7.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery007_x264_20.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery051_x264_10.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing052_x264_19.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery085_x264_18.mp4
#   inflating: Trimmed Dataset/Normal/Robbery110_x264_16.mp4
#   inflating: Trimmed Dataset/Assault/Assault037_x264_7.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing061_x264_13.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing106_x264_10.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery061_x264_11.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary012_x264_9.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse008_x264_6.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse021_x264_16.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery060_x264_2.mp4
#   inflating: Trimmed Dataset/Arson/Arson029_x264_23.mp4
#   inflating: Trimmed Dataset/Normal/Robbery038_x264_3.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery081_x264_17.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing087_x264_17.mp4
#   inflating: Trimmed Dataset/Assault/Assault004_x264_9.mp4
#   inflating: Trimmed Dataset/Normal/Robbery083_x264_3.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing044_x264_23.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse050_x264_26.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary084_x264_8.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery149_x264_10.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest004_x264_8.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery057_x264_30.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery058_x264_8.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest032_x264_6.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary046_x264_11.mp4
#   inflating: Trimmed Dataset/Assault/Assault033_x264_31.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery146_x264_28.mp4
#   inflating: Trimmed Dataset/Shoplifting/Shoplifting010_x264_12.mp4
#   inflating: Trimmed Dataset/Fighting/Fighting007_x264_28.mp4
#   inflating: Trimmed Dataset/Arson/Arson011_x264_7.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery041_x264_10.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery019_x264_25.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery060_x264_23.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents141_x264_7.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse024_x264_30.mp4
#   inflating: Trimmed Dataset/Normal/Robbery148_x264_30.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery020_x264_15.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery015_x264_17.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse048_x264_29.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery149_x264_13.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary004_x264_24.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery122_x264_20.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism028_x264_16.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing023_x264_15.mp4
#   inflating: Trimmed Dataset/Normal/Robbery130_x264_0.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery082_x264_20.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery066_x264_5.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery025_x264_9.mp4
#   inflating: Trimmed Dataset/Normal/Robbery048_x264_3.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest005_x264_10.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary056_x264_10.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing094_x264_16.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse006_x264_26.mp4
#   inflating: Trimmed Dataset/Normal/Robbery105_x264_26.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting041_x264_18.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting031_x264_25.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery115_x264_8.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary012_x264_7.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery058_x264_13.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting030_x264_26.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents074_x264_15.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing042_x264_0.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery123_x264_9.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting030_x264_23.mp4
#   inflating: Trimmed Dataset/Arson/Arson023_x264_12.mp4
#   inflating: Trimmed Dataset/Assault/Assault011_x264_8.mp4
#   inflating: Trimmed Dataset/Arson/Arson029_x264_19.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse026_x264_12.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery038_x264_20.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse043_x264_6.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery145_x264_19.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting029_x264_30.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents031_x264_8.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery023_x264_6.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery077_x264_26.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents013_x264_25.mp4
#   inflating: Trimmed Dataset/Fighting/Fighting007_x264_27.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing074_x264_15.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery067_x264_10.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents107_x264_11.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents139_x264_16.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting026_x264_2.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism044_x264_14.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary021_x264_12.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery030_x264_11.mp4
#   inflating: Trimmed Dataset/Explosion/Explosion009_x264_30.mp4
#   inflating: Trimmed Dataset/Fighting/Fighting013_x264_27.mp4
#   inflating: Trimmed Dataset/Explosion/Explosion038_x264_1.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting036_x264_17.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery081_x264_23.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery057_x264_23.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism002_x264_1.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing107_x264_18.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery029_x264_21.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest048_x264_11.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery088_x264_7.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing002_x264_21.mp4
#   inflating: Trimmed Dataset/Explosion/Explosion038_x264_2.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse010_x264_4.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery004_x264_22.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting048_x264_23.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse044_x264_22.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery031_x264_19.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary077_x264_6.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary012_x264_13.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery146_x264_5.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse034_x264_8.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery043_x264_11.mp4
#   inflating: Trimmed Dataset/Arson/Arson047_x264_27.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing071_x264_14.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting018_x264_20.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary051_x264_0.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary074_x264_19.mp4
#   inflating: Trimmed Dataset/Normal/Robbery066_x264_13.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting028_x264_13.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing051_x264_12.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest009_x264_27.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest017_x264_11.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents138_x264_10.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary041_x264_21.mp4
#   inflating: Trimmed Dataset/Normal/Robbery066_x264_17.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism030_x264_22.mp4
#   inflating: Trimmed Dataset/Assault/Assault048_x264_8.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents130_x264_4.mp4
#   inflating: Trimmed Dataset/Normal/Robbery129_x264_8.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing023_x264_26.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing042_x264_16.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse043_x264_12.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism034_x264_25.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary069_x264_25.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse026_x264_21.mp4
#   inflating: Trimmed Dataset/Assault/Assault022_x264_6.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents067_x264_18.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing114_x264_9.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_23.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing021_x264_2.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse016_x264_25.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest038_x264_22.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery136_x264_28.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing042_x264_15.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary099_x264_1.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents048_x264_6.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse043_x264_21.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents016_x264_9.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse031_x264_24.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse048_x264_30.mp4
#   inflating: Trimmed Dataset/Assault/Assault013_x264_9.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing022_x264_23.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting029_x264_26.mp4
#   inflating: Trimmed Dataset/Normal/Robbery114_x264_20.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest005_x264_23.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing094_x264_9.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing037_x264_10.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting036_x264_10.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism034_x264_23.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing112_x264_28.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary048_x264_24.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest022_x264_24.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse026_x264_27.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing009_x264_30.mp4
#   inflating: Trimmed Dataset/Normal/Robbery099_x264_15.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents131_x264_7.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents031_x264_10.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing094_x264_18.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary013_x264_7.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting026_x264_11.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest017_x264_14.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting042_x264_29.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary091_x264_7.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents037_x264_16.mp4
#   inflating: Trimmed Dataset/Assault/Assault040_x264_16.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest017_x264_18.mp4
#   inflating: Trimmed Dataset/Normal/Robbery099_x264_21.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse041_x264_16.mp4
#   inflating: Trimmed Dataset/Normal/Robbery111_x264_3.mp4
#   inflating: Trimmed Dataset/Arson/Arson034_x264_28.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse044_x264_30.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse022_x264_16.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing003_x264_29.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery071_x264_15.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest002_x264_17.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest005_x264_13.mp4
#   inflating: Trimmed Dataset/Burglary/Burglary090_x264_24.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest042_x264_24.mp4
#   inflating: Trimmed Dataset/Shooting/Shooting007_x264_27.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest024_x264_17.mp4
#   inflating: Trimmed Dataset/Arson/Arson003_x264_28.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents057_x264_8.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse023_x264_11.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing026_x264_24.mp4
#   inflating: Trimmed Dataset/Vandalism/Vandalism013_x264_25.mp4
#   inflating: Trimmed Dataset/Assault/Assault005_x264_20.mp4
#   inflating: Trimmed Dataset/Robbery/Robbery051_x264_16.mp4
#   inflating: Trimmed Dataset/Arson/Arson028_x264_29.mp4
#   inflating: Trimmed Dataset/RoadAccidents/RoadAccidents037_x264_13.mp4
#   inflating: Trimmed Dataset/Stealing/Stealing075_x264_22.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest024_x264_29.mp4
#   inflating: Trimmed Dataset/Fighting/Fighting013_x264_9.mp4
#   inflating: Trimmed Dataset/Arrest/Arrest004_x264_27.mp4
#   inflating: Trimmed Dataset/Abuse/Abuse006_x264_28.mp4
#   inflating: Trimmed Dataset/Normal/Robbery094_x264_23.mp4

# %%
shutil.rmtree("/content/curated_dataset")

# %%
# !mkdir curated_dataset
# !cp -r "/content/Trimmed Dataset/Shooting" "/content/curated_dataset"
# !cp -r "/content/Trimmed Dataset/Normal" "/content/curated_dataset"

# %%
import os
path="/content/curated_dataset/"
count=0
for i in os.listdir(path):
  count=0
  for j in os.listdir(path+str(i)):
    count=count+1
  print(i+":",count)
# Out:
# Shooting: 304
# Normal: 1198

# %%
count=0
for i in os.listdir("/content/curated_dataset/Normal"):
  a=random.choice(os.listdir("/content/curated_dataset/Normal"))
  os.remove("/content/curated_dataset/Normal/"+str(a))
  count=count+1
  if count==894:
    break

# %%
raw_data=load_files(os.getcwd()+r'/curated_dataset/', shuffle=True)
files=raw_data['filenames']
targets=raw_data['target']

train_files, test_files, train_targets, test_targets=train_test_split(files, targets, test_size=1/3, random_state=191)

# %%
len(train_files)
# Out:
# 405

# %%
valid_files = train_files[300:]
valid_targets = train_targets[300:]

# Remaining data will be used for training the model
train_files = train_files[:300]
train_targets = train_targets[:300]

# Generic details about the data
print('Total number of videos:', len(files))
print('\nNumber of videos in training data:', train_files.shape[0])
print('Number of videos in validation data:', valid_files.shape[0])
print('Number of videos in test data:', test_files.shape[0])
# Out:
# Total number of videos: 608
#
# Number of videos in training data: 300
# Number of videos in validation data: 105
# Number of videos in test data: 203

# %%
print('The categorical labels are converted into integers.\nFollowing is the mapping - \n')
for label in zip(range(14), raw_data['target_names']):
    print(label)
# Out:
# The categorical labels are converted into integers.
# Following is the mapping -
#
# (0, 'Normal')
# (1, 'Shooting')

# %%
for pair in zip(train_files[:5], train_targets[:5]):
    print(pair)
# Out:
# ('/content/curated_dataset/Shooting/Shooting042_x264_15.mp4', 1)
# ('/content/curated_dataset/Shooting/Shooting018_x264_25.mp4', 1)
# ('/content/curated_dataset/Normal/Robbery053_x264_8.mp4', 0)
# ('/content/curated_dataset/Shooting/Shooting052_x264_25.mp4', 1)
# ('/content/curated_dataset/Normal/Robbery109_x264_30.mp4', 0)

# %%
class Videos(object):

    def __init__(self, target_size=None, to_gray=True, max_frames=None,
                 extract_frames='middle', required_fps=None,
                 normalize_pixels=None):
        """
        Initializing the config variables

        Parameters:
            target_size (tuple): (New_Width, New_Height), Default 'None'
                A tuple denoting the target width and height of each frame in each of the video

            to_gray (boolean): Default 'True'
                If True, then each frame will be converted to gray scale. Otherwise, not.

            max_frames (int): Default 'None'
                The maximum number of frames to return for each video.
                Extra frames are removed based on the value of 'extract_frames'.

            extract_frames (str): {'first', 'middle', 'last'}, Default 'middle'
                'first': Extract the first 'N' frames

                'last': Extract the last 'N' frames

                'middle': Extract 'N' frames from the middle
                    Remove ((total_frames - max_frames) // 2) frames from the beginning as well as the end

            required_fps (int): Default 'None'
                Capture 'N' frame(s) per second from the video.

                Only the first 'N' frame(s) for each second in the video are captured.

            normalize_pixels (tuple/str): Default 'None'
                If 'None', the pixels will not be normalized.

                If a tuple - (New_min, New_max) is passed, Min-max Normalization will be used.

                If the value is 'z-score', then Z-score Normalization will be used.
                For each pixel p, z_score = (p - mean) / std
        """

        self.target_size = target_size
        self.to_gray = to_gray
        self.max_frames = max_frames
        self.extract_frames = extract_frames
        self.required_fps = required_fps
        self.normalize_pixels = normalize_pixels
        self.fps = None

    def read_videos(self, paths):
        """
        Parameters:
            paths (list): Required
                 A list of paths of the videos to be read

        Returns:
            Numpy.ndarray
                A 5-d tensor with shape (<No. of Videos>, <No. of frames>, <height>, <width>, <channels>)
        """

        list_of_videos = [
            self._read_video(path) for path in tqdm(paths)
        ]

        tensor = np.vstack(list_of_videos)

        if self.normalize_pixels != None:
            # Pixels are normalized for each video individually
            if (type(self.normalize_pixels) == tuple) and (len(self.normalize_pixels) == 2):
                base = self.normalize_pixels[0]
                r = self.normalize_pixels[1] - base
                min_ = np.min(tensor, axis=(1, 2, 3), keepdims=True)
                max_ = np.max(tensor, axis=(1, 2, 3), keepdims=True)
                return ((tensor.astype('float32') - min_) / (max_ - min_)) * r + base

            elif self.normalize_pixels == 'z-score':
                mean = np.mean(tensor, axis=(1, 2, 3), keepdims=True)
                std = np.std(tensor, axis=(1, 2, 3), keepdims=True)
                return (tensor.astype('float32') - mean) / std
            
            else:
                raise ValueError('Invalid value of \'normalize_pixels\'')

        return tensor

    def get_frame_count(self, paths):
        """
        Can be used to determine the value of `max_frames`

        Parameters:
            paths (list): Required
                 A list of paths of the videos to be read

        Returns:
            dict (python dictionary)
                For each video, the total number of frames in that video is stored in the dictionary.
        """

        frame_count = {}
        for path in paths:
            cap = FFmpegReader(filename=path)
            frame_count[path] = cap.inputframenum
            cap.close()

        return frame_count

    def _read_video(self, path):
        """
        Parameters:
            path (str): Required
                Path of the video to be read

        Returns:
            Numpy.ndarray
                A 5-d tensor with shape (1, <No. of frames>, <height>, <width>, <channels>)
        """

        cap = FFmpegReader(filename=path)
        list_of_frames = []
        self.fps = int(cap.inputfps)                  # Frame Rate

        for index, frame in enumerate(cap.nextFrame()):

            capture_frame = True
            if self.required_fps != None:
                is_valid = range(self.required_fps)
                capture_frame = (index % self.fps) in is_valid

            if capture_frame:

                if self.target_size is not None:
                    temp_image = image.array_to_img(frame)
                    frame = image.img_to_array(
                        temp_image.resize(
                            self.target_size,
                            Image.ANTIALIAS)).astype('uint8')

                # Shape of each frame -> (<height>, <width>, 3)
                list_of_frames.append(frame)

        temp_video = np.stack(list_of_frames)
        cap.close()

        if self.to_gray:
            temp_video = rgb2gray(temp_video)
                
        if self.max_frames is not None:
            temp_video = self._process_video(video=temp_video)

        return np.expand_dims(temp_video, axis=0)

    def _process_video(self, video):
        """
        Parameters:
            video (Numpy.ndarray):
                Shape = (<No. of frames>, <height>, <width>, <channels>)

                Video whose frames are to be extracted

        Returns:
            Numpy.ndarray
                A tensor (processed video) with shape (<`max_frames`>, <height>, <width>, <channels>)
        """

        total_frames = video.shape[0]
        if self.max_frames <= total_frames:

            if self.extract_frames == 'first':
                video = video[:self.max_frames]
            elif self.extract_frames == 'last':
                video = video[(total_frames - self.max_frames):]
            elif self.extract_frames == 'middle':
                # No. of frames to remove from the front
                front = ((total_frames - self.max_frames) // 2) + 1
                video = video[front:(front + self.max_frames)]
            else:
                raise ValueError('Invalid value of \'extract_frames\'')

        else:
            raise IndexError(
                'Required number of frames is greater than the total number of frames in the video')

        return video

# %%
# The path of a sample video in the training data
sample_files = train_files[:1]

# An object of the class 'Videos'
reader = Videos(target_size=None, 
                to_gray=False)

# Loading the sample videos, in their original format
sample = reader.read_videos(sample_files)
print('\nShape of the sample data:', sample.shape)

# Displaying a frame from the sample video
plt.imshow(sample[0][29])
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  4.48it/s]
# Shape of the sample data: (1, 30, 240, 320, 3)

# %%
# An object of the class `Videos` to load the data in the required format
reader = Videos(target_size=(128, 128), 
                to_gray=True, 
                max_frames=29, 
                extract_frames='middle', 
                normalize_pixels=(0, 1))

# %%
# Reading training videos and one-hot encoding the training labels
X_train = reader.read_videos(train_files)
y_train = to_categorical(train_targets, num_classes=2)
print('Shape of training data:', X_train.shape)
print('Shape of training labels:', y_train.shape)
# Out:
# 100%|██████████| 300/300 [01:31<00:00,  3.26it/s]
# Shape of training data: (300, 29, 128, 128, 1)
# Shape of training labels: (300, 2)

# %%
# Reading validation videos and one-hot encoding the validation labels
X_valid = reader.read_videos(valid_files)
y_valid = to_categorical(valid_targets, num_classes=2)
print('Shape of validation data:', X_valid.shape)
print('Shape of validation labels:', y_valid.shape)
# Out:
# 100%|██████████| 105/105 [00:34<00:00,  3.06it/s]
# Shape of validation data: (105, 29, 128, 128, 1)
# Shape of validation labels: (105, 2)

# %%
X_test = reader.read_videos(test_files)
y_test = to_categorical(test_targets, num_classes=2)
print('Shape of testing data:', X_test.shape)
print('Shape of testing labels:', y_test.shape)
# Out:
# 100%|██████████| 203/203 [01:09<00:00,  2.91it/s]
# Shape of testing data: (203, 29, 128, 128, 1)
# Shape of testing labels: (203, 2)

# %%
# After pre-processing

# Displaying the first frame of the first processed video from the training data
plt.imshow(np.squeeze(X_train[0][0], axis=2), cmap='gray')

# %%
def depthwise_conv3d_args_preprocessor(args, kwargs):
    converted = []

    if 'init' in kwargs:
        init = kwargs.pop('init')
        kwargs['depthwise_initializer'] = init
        converted.append(('init', 'depthwise_initializer'))

    args, kwargs, _converted = conv3d_args_preprocessor(args, kwargs)
    return args, kwargs, converted + _converted

    legacy_depthwise_conv3d_support = generate_legacy_interface(
    allowed_positional_args=['filters', 'kernel_size'],
    conversions=[('nb_filter', 'filters'),
                 ('subsample', 'strides'),
                 ('border_mode', 'padding'),
                 ('dim_ordering', 'data_format'),
                 ('b_regularizer', 'bias_regularizer'),
                 ('b_constraint', 'bias_constraint'),
                 ('bias', 'use_bias')],
    value_conversions={'dim_ordering': {'tf': 'channels_last',
                                        'th': 'channels_first',
                                        'default': None}},
    preprocessor=depthwise_conv3d_args_preprocessor)


class DepthwiseConv3D(Conv3D):
    """Depthwise 3D convolution.
    Depth-wise part of separable convolutions consist in performing
    just the first step/operation
    (which acts on each input channel separately).
    It does not perform the pointwise convolution (second step).
    The `depth_multiplier` argument controls how many
    output channels are generated per input channel in the depthwise step.
    # Arguments
        kernel_size: An integer or tuple/list of 3 integers, specifying the
            depth, width and height of the 3D convolution window.
            Can be a single integer to specify the same value for
            all spatial dimensions.
        strides: An integer or tuple/list of 3 integers,
            specifying the strides of the convolution along the depth, width and height.
            Can be a single integer to specify the same value for
            all spatial dimensions.
        padding: one of `"valid"` or `"same"` (case-insensitive).
        depth_multiplier: The number of depthwise convolution output channels
            for each input channel.
            The total number of depthwise convolution output
            channels will be equal to `filterss_in * depth_multiplier`.
        groups: The depth size of the convolution (as a variant of the original Depthwise conv)
        data_format: A string,
            one of `channels_last` (default) or `channels_first`.
            The ordering of the dimensions in the inputs.
            `channels_last` corresponds to inputs with shape
            `(batch, height, width, channels)` while `channels_first`
            corresponds to inputs with shape
            `(batch, channels, height, width)`.
            It defaults to the `image_data_format` value found in your
            Keras config file at `~/.keras/keras.json`.
            If you never set it, then it will be "channels_last".
        activation: Activation function to use
            (see [activations](../activations.md)).
            If you don't specify anything, no activation is applied
            (ie. "linear" activation: `a(x) = x`).
        use_bias: Boolean, whether the layer uses a bias vector.
        depthwise_initializer: Initializer for the depthwise kernel matrix
            (see [initializers](../initializers.md)).
        bias_initializer: Initializer for the bias vector
            (see [initializers](../initializers.md)).
        depthwise_regularizer: Regularizer function applied to
            the depthwise kernel matrix
            (see [regularizer](../regularizers.md)).
        bias_regularizer: Regularizer function applied to the bias vector
            (see [regularizer](../regularizers.md)).
        dialation_rate: List of ints.
                        Defines the dilation factor for each dimension in the
                        input. Defaults to (1,1,1)
        activity_regularizer: Regularizer function applied to
            the output of the layer (its "activation").
            (see [regularizer](../regularizers.md)).
        depthwise_constraint: Constraint function applied to
            the depthwise kernel matrix
            (see [constraints](../constraints.md)).
        bias_constraint: Constraint function applied to the bias vector
            (see [constraints](../constraints.md)).
    # Input shape
        5D tensor with shape:
        `(batch, depth, channels, rows, cols)` if data_format='channels_first'
        or 5D tensor with shape:
        `(batch, depth, rows, cols, channels)` if data_format='channels_last'.
    # Output shape
        5D tensor with shape:
        `(batch, filters * depth, new_depth, new_rows, new_cols)` if data_format='channels_first'
        or 4D tensor with shape:
        `(batch, new_depth, new_rows, new_cols, filters * depth)` if data_format='channels_last'.
        `rows` and `cols` values might have changed due to padding.
    """

    #@legacy_depthwise_conv3d_support
    def __init__(self,
                 kernel_size,
                 strides=(1, 1, 1),
                 padding='valid',
                 depth_multiplier=1,
                 groups=None,
                 data_format=None,
                 activation=None,
                 use_bias=True,
                 depthwise_initializer='glorot_uniform',
                 bias_initializer='zeros',
                 dilation_rate = (1, 1, 1),
                 depthwise_regularizer=None,
                 bias_regularizer=None,
                 activity_regularizer=None,
                 depthwise_constraint=None,
                 bias_constraint=None,
                 **kwargs):
        super(DepthwiseConv3D, self).__init__(
            filters=None,
            kernel_size=kernel_size,
            strides=strides,
            padding=padding,
            data_format=data_format,
            activation=activation,
            use_bias=use_bias,
            bias_regularizer=bias_regularizer,
            dilation_rate=dilation_rate,
            activity_regularizer=activity_regularizer,
            bias_constraint=bias_constraint,
            **kwargs)
        self.depth_multiplier = depth_multiplier
        self.groups = groups
        self.depthwise_initializer = initializers.get(depthwise_initializer)
        self.depthwise_regularizer = regularizers.get(depthwise_regularizer)
        self.depthwise_constraint = constraints.get(depthwise_constraint)
        self.bias_initializer = initializers.get(bias_initializer)
        self.dilation_rate = dilation_rate
        self._padding = _preprocess_padding(self.padding)
        self._strides = (1,) + self.strides + (1,)
        self._data_format = "NDHWC"
        self.input_dim = None

    def build(self, input_shape):
        if len(input_shape) < 5:
            raise ValueError('Inputs to `DepthwiseConv3D` should have rank 5. '
                             'Received input shape:', str(input_shape))
        if self.data_format == 'channels_first':
            channel_axis = 1
        else:
            channel_axis = -1
        if input_shape[channel_axis] is None:
            raise ValueError('The channel dimension of the inputs to '
                             '`DepthwiseConv3D` '
                             'should be defined. Found `None`.')
        self.input_dim = int(input_shape[channel_axis])

        if self.groups is None:
            self.groups = self.input_dim

        if self.groups > self.input_dim:
            raise ValueError('The number of groups cannot exceed the number of channels')

        if self.input_dim % self.groups != 0:
            raise ValueError('Warning! The channels dimension is not divisible by the group size chosen')

        depthwise_kernel_shape = (self.kernel_size[0],
                                  self.kernel_size[1],
                                  self.kernel_size[2],
                                  self.input_dim,
                                  self.depth_multiplier)

        self.depthwise_kernel = self.add_weight(
            shape=depthwise_kernel_shape,
            initializer=self.depthwise_initializer,
            name='depthwise_kernel',
            regularizer=self.depthwise_regularizer,
            constraint=self.depthwise_constraint)

        if self.use_bias:
            self.bias = self.add_weight(shape=(self.groups * self.depth_multiplier,),
                                        initializer=self.bias_initializer,
                                        name='bias',
                                        regularizer=self.bias_regularizer,
                                        constraint=self.bias_constraint)
        else:
            self.bias = None
        # Set input spec.
        self.input_spec = InputSpec(ndim=5, axes={channel_axis: self.input_dim})
        self.built = True

    def call(self, inputs, training=None):
        inputs = _preprocess_conv3d_input(inputs, self.data_format)

        if self.data_format == 'channels_last':
            dilation = (1,) + self.dilation_rate + (1,)
        else:
            dilation = self.dilation_rate + (1,) + (1,)

        if self._data_format == 'NCDHW':
            outputs = tf.concat(
                [tf.nn.conv3d(inputs[0][:, i:i+self.input_dim//self.groups, :, :, :], self.depthwise_kernel[:, :, :, i:i+self.input_dim//self.groups, :],
                    strides=self._strides,
                    padding=self._padding,
                    dilations=dilation,
                    data_format=self._data_format) for i in range(0, self.input_dim, self.input_dim//self.groups)], axis=1)

        else:
            outputs = tf.concat(
                [tf.nn.conv3d(inputs[0][:, :, :, :, i:i+self.input_dim//self.groups], self.depthwise_kernel[:, :, :, i:i+self.input_dim//self.groups, :],
                    strides=self._strides,
                    padding=self._padding,
                    dilations=dilation,
                    data_format=self._data_format) for i in range(0, self.input_dim, self.input_dim//self.groups)], axis=-1)

        if self.bias is not None:
            outputs = K.bias_add(
                outputs,
                self.bias,
                data_format=self.data_format)

        if self.activation is not None:
            return self.activation(outputs)

        return outputs

    def compute_output_shape(self, input_shape):
        if self.data_format == 'channels_first':
            depth = input_shape[2]
            rows = input_shape[3]
            cols = input_shape[4]
            out_filters = self.groups * self.depth_multiplier
        elif self.data_format == 'channels_last':
            depth = input_shape[1]
            rows = input_shape[2]
            cols = input_shape[3]
            out_filters = self.groups * self.depth_multiplier

        depth = conv_utils.conv_output_length(depth, self.kernel_size[0],
                                             self.padding,
                                             self.strides[0])

        rows = conv_utils.conv_output_length(rows, self.kernel_size[1],
                                             self.padding,
                                             self.strides[1])

        cols = conv_utils.conv_output_length(cols, self.kernel_size[2],
                                             self.padding,
                                             self.strides[2])

        if self.data_format == 'channels_first':
            return (input_shape[0], out_filters, depth, rows, cols)

        elif self.data_format == 'channels_last':
            return (input_shape[0], depth, rows, cols, out_filters)

    def get_config(self):
        config = super(DepthwiseConv3D, self).get_config()
        config.pop('filters')
        config.pop('kernel_initializer')
        config.pop('kernel_regularizer')
        config.pop('kernel_constraint')
        config['depth_multiplier'] = self.depth_multiplier
        config['depthwise_initializer'] = initializers.serialize(self.depthwise_initializer)
        config['depthwise_regularizer'] = regularizers.serialize(self.depthwise_regularizer)
        config['depthwise_constraint'] = constraints.serialize(self.depthwise_constraint)
        return config

DepthwiseConvolution3D = DepthwiseConv3D

# %%
model = Sequential()

# Adding Alternate convolutional and pooling layers
model.add(Conv3D(filters=16, kernel_size=(10, 3, 3), strides=(1, 1, 1), padding='same', activation='relu', 
                 input_shape=X_train.shape[1:]))
model.add(MaxPooling3D(pool_size=2, strides=(1, 2, 2), padding='same'))

model.add(Conv3D(filters=64, kernel_size=(5, 3, 3), strides=(3, 1, 1), padding='valid', activation='relu'))
model.add(MaxPooling3D(pool_size=2, strides=(1, 2, 2), padding='same'))

model.add(Conv3D(filters=256, kernel_size=(5, 3, 3), strides=(3, 1, 1), padding='valid', activation='relu'))
model.add(MaxPooling3D(pool_size=2, strides=(1, 2, 2), padding='same'))

# A global average pooling layer to get a 1-d vector
# The vector will have a depth (same as number of elements in the vector) of 256
model.add(GlobalAveragePooling3D())

# The Global average pooling layer is followed by a fully-connected neural network, with one hidden and one output layer

# Hidden Layer
model.add(Dense(32, activation='relu'))

# Output layer
model.add(Dense(2, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_1 (Conv3D)            (None, 29, 128, 128, 16)  1456
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 29, 64, 64, 16)    0
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 9, 62, 62, 64)     46144
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 9, 31, 31, 64)     0
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 2, 29, 29, 256)    737536
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 2, 15, 15, 256)    0
# _________________________________________________________________
# global_average_pooling3d_1 ( (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                8224
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 793,426
# Trainable params: 793,426
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint

# Compiling the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Saving the model that performed the best on the validation set
checkpoint = ModelCheckpoint(filepath='Model_shooting_1.weights.best.hdf5', save_best_only=True, verbose=1)

# Training the model for 40 epochs
history = model.fit(X_train, y_train, batch_size=16, epochs=80, 
                    validation_data=(X_valid, y_valid), verbose=2, callbacks=[checkpoint])
# Out:
# Train on 300 samples, validate on 105 samples
# Epoch 1/80
#  - 12s - loss: 0.7031 - accuracy: 0.4833 - val_loss: 0.6929 - val_accuracy: 0.4667
#
# Epoch 00001: val_loss improved from inf to 0.69288, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 2/80
#  - 4s - loss: 0.6872 - accuracy: 0.5100 - val_loss: 0.6839 - val_accuracy: 0.5333
#
# Epoch 00002: val_loss improved from 0.69288 to 0.68390, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 3/80
#  - 4s - loss: 0.6547 - accuracy: 0.6267 - val_loss: 0.6621 - val_accuracy: 0.5810
#
# Epoch 00003: val_loss improved from 0.68390 to 0.66215, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 4/80
#  - 4s - loss: 0.6640 - accuracy: 0.5900 - val_loss: 0.6845 - val_accuracy: 0.6190
#
# Epoch 00004: val_loss did not improve from 0.66215
# Epoch 5/80
#  - 4s - loss: 0.6595 - accuracy: 0.6233 - val_loss: 0.6520 - val_accuracy: 0.5714
#
# Epoch 00005: val_loss improved from 0.66215 to 0.65199, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 6/80
#  - 4s - loss: 0.6448 - accuracy: 0.6167 - val_loss: 0.6489 - val_accuracy: 0.5619
#
# Epoch 00006: val_loss improved from 0.65199 to 0.64887, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 7/80
#  - 4s - loss: 0.6436 - accuracy: 0.5967 - val_loss: 0.6481 - val_accuracy: 0.5619
#
# Epoch 00007: val_loss improved from 0.64887 to 0.64815, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 8/80
#  - 4s - loss: 0.6202 - accuracy: 0.6500 - val_loss: 0.6380 - val_accuracy: 0.6190
#
# Epoch 00008: val_loss improved from 0.64815 to 0.63804, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 9/80
#  - 4s - loss: 0.6223 - accuracy: 0.6367 - val_loss: 0.6427 - val_accuracy: 0.6381
#
# Epoch 00009: val_loss did not improve from 0.63804
# Epoch 10/80
#  - 4s - loss: 0.6096 - accuracy: 0.6700 - val_loss: 0.6252 - val_accuracy: 0.6571
#
# Epoch 00010: val_loss improved from 0.63804 to 0.62517, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 11/80
#  - 4s - loss: 0.5909 - accuracy: 0.6867 - val_loss: 0.6206 - val_accuracy: 0.6286
#
# Epoch 00011: val_loss improved from 0.62517 to 0.62060, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 12/80
#  - 4s - loss: 0.5739 - accuracy: 0.6833 - val_loss: 0.6164 - val_accuracy: 0.6381
#
# Epoch 00012: val_loss improved from 0.62060 to 0.61639, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 13/80
#  - 4s - loss: 0.5647 - accuracy: 0.7000 - val_loss: 0.6320 - val_accuracy: 0.6571
#
# Epoch 00013: val_loss did not improve from 0.61639
# Epoch 14/80
#  - 4s - loss: 0.5433 - accuracy: 0.7433 - val_loss: 0.5980 - val_accuracy: 0.6571
#
# Epoch 00014: val_loss improved from 0.61639 to 0.59798, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 15/80
#  - 4s - loss: 0.5292 - accuracy: 0.7700 - val_loss: 0.5896 - val_accuracy: 0.6857
#
# Epoch 00015: val_loss improved from 0.59798 to 0.58962, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 16/80
#  - 4s - loss: 0.5249 - accuracy: 0.7533 - val_loss: 0.5648 - val_accuracy: 0.6857
#
# Epoch 00016: val_loss improved from 0.58962 to 0.56482, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 17/80
#  - 4s - loss: 0.4835 - accuracy: 0.7433 - val_loss: 0.5630 - val_accuracy: 0.7048
#
# Epoch 00017: val_loss improved from 0.56482 to 0.56300, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 18/80
#  - 4s - loss: 0.5188 - accuracy: 0.7233 - val_loss: 0.5856 - val_accuracy: 0.6857
#
# Epoch 00018: val_loss did not improve from 0.56300
# Epoch 19/80
#  - 4s - loss: 0.4783 - accuracy: 0.7733 - val_loss: 0.5732 - val_accuracy: 0.7048
#
# Epoch 00019: val_loss did not improve from 0.56300
# Epoch 20/80
#  - 4s - loss: 0.4426 - accuracy: 0.7900 - val_loss: 0.5327 - val_accuracy: 0.6667
#
# Epoch 00020: val_loss improved from 0.56300 to 0.53273, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 21/80
#  - 4s - loss: 0.4421 - accuracy: 0.7900 - val_loss: 0.6190 - val_accuracy: 0.7048
#
# Epoch 00021: val_loss did not improve from 0.53273
# Epoch 22/80
#  - 4s - loss: 0.5327 - accuracy: 0.7100 - val_loss: 0.6949 - val_accuracy: 0.6667
#
# Epoch 00022: val_loss did not improve from 0.53273
# Epoch 23/80
#  - 4s - loss: 0.4565 - accuracy: 0.8067 - val_loss: 0.5464 - val_accuracy: 0.7048
#
# Epoch 00023: val_loss did not improve from 0.53273
# Epoch 24/80
#  - 4s - loss: 0.4788 - accuracy: 0.7700 - val_loss: 0.5543 - val_accuracy: 0.6762
#
# Epoch 00024: val_loss did not improve from 0.53273
# Epoch 25/80
#  - 4s - loss: 0.4292 - accuracy: 0.7967 - val_loss: 0.5453 - val_accuracy: 0.7143
#
# Epoch 00025: val_loss did not improve from 0.53273
# Epoch 26/80
#  - 4s - loss: 0.4217 - accuracy: 0.7867 - val_loss: 0.5225 - val_accuracy: 0.7524
#
# Epoch 00026: val_loss improved from 0.53273 to 0.52250, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 27/80
#  - 4s - loss: 0.4012 - accuracy: 0.8067 - val_loss: 0.5156 - val_accuracy: 0.7238
#
# Epoch 00027: val_loss improved from 0.52250 to 0.51559, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 28/80
#  - 4s - loss: 0.4137 - accuracy: 0.8067 - val_loss: 0.5162 - val_accuracy: 0.6952
#
# Epoch 00028: val_loss did not improve from 0.51559
# Epoch 29/80
#  - 4s - loss: 0.3870 - accuracy: 0.8267 - val_loss: 0.5022 - val_accuracy: 0.7333
#
# Epoch 00029: val_loss improved from 0.51559 to 0.50220, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 30/80
#  - 4s - loss: 0.3710 - accuracy: 0.8100 - val_loss: 0.5201 - val_accuracy: 0.7429
#
# Epoch 00030: val_loss did not improve from 0.50220
# Epoch 31/80
#  - 4s - loss: 0.3506 - accuracy: 0.8467 - val_loss: 0.5129 - val_accuracy: 0.7524
#
# Epoch 00031: val_loss did not improve from 0.50220
# Epoch 32/80
#  - 4s - loss: 0.3709 - accuracy: 0.8167 - val_loss: 0.5568 - val_accuracy: 0.7333
#
# Epoch 00032: val_loss did not improve from 0.50220
# Epoch 33/80
#  - 4s - loss: 0.3805 - accuracy: 0.7967 - val_loss: 0.5925 - val_accuracy: 0.7238
#
# Epoch 00033: val_loss did not improve from 0.50220
# Epoch 34/80
#  - 4s - loss: 0.3477 - accuracy: 0.8433 - val_loss: 0.4598 - val_accuracy: 0.7810
#
# Epoch 00034: val_loss improved from 0.50220 to 0.45984, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 35/80
#  - 4s - loss: 0.3972 - accuracy: 0.8133 - val_loss: 0.4838 - val_accuracy: 0.7238
#
# Epoch 00035: val_loss did not improve from 0.45984
# Epoch 36/80
#  - 4s - loss: 0.3494 - accuracy: 0.8067 - val_loss: 0.4938 - val_accuracy: 0.7429
#
# Epoch 00036: val_loss did not improve from 0.45984
# Epoch 37/80
#  - 4s - loss: 0.3094 - accuracy: 0.8600 - val_loss: 0.4695 - val_accuracy: 0.7429
#
# Epoch 00037: val_loss did not improve from 0.45984
# Epoch 38/80
#  - 4s - loss: 0.2819 - accuracy: 0.8833 - val_loss: 0.4613 - val_accuracy: 0.7619
#
# Epoch 00038: val_loss did not improve from 0.45984
# Epoch 39/80
#  - 4s - loss: 0.2703 - accuracy: 0.8933 - val_loss: 0.4609 - val_accuracy: 0.8286
#
# Epoch 00039: val_loss did not improve from 0.45984
# Epoch 40/80
#  - 4s - loss: 0.2564 - accuracy: 0.8800 - val_loss: 0.4637 - val_accuracy: 0.7905
#
# Epoch 00040: val_loss did not improve from 0.45984
# Epoch 41/80
#  - 4s - loss: 0.2668 - accuracy: 0.9000 - val_loss: 0.4213 - val_accuracy: 0.8381
#
# Epoch 00041: val_loss improved from 0.45984 to 0.42125, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 42/80
#  - 4s - loss: 0.2351 - accuracy: 0.9233 - val_loss: 0.5348 - val_accuracy: 0.7524
#
# Epoch 00042: val_loss did not improve from 0.42125
# Epoch 43/80
#  - 4s - loss: 0.2458 - accuracy: 0.9167 - val_loss: 0.4312 - val_accuracy: 0.8190
#
# Epoch 00043: val_loss did not improve from 0.42125
# Epoch 44/80
#  - 4s - loss: 0.2235 - accuracy: 0.9100 - val_loss: 0.5057 - val_accuracy: 0.8667
#
# Epoch 00044: val_loss did not improve from 0.42125
# Epoch 45/80
#  - 4s - loss: 0.2304 - accuracy: 0.9033 - val_loss: 0.6932 - val_accuracy: 0.7333
#
# Epoch 00045: val_loss did not improve from 0.42125
# Epoch 46/80
#  - 4s - loss: 0.2946 - accuracy: 0.8667 - val_loss: 0.6350 - val_accuracy: 0.8095
#
# Epoch 00046: val_loss did not improve from 0.42125
# Epoch 47/80
#  - 4s - loss: 0.2079 - accuracy: 0.9433 - val_loss: 0.4103 - val_accuracy: 0.8857
#
# Epoch 00047: val_loss improved from 0.42125 to 0.41034, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 48/80
#  - 4s - loss: 0.1932 - accuracy: 0.9400 - val_loss: 0.5224 - val_accuracy: 0.8762
#
# Epoch 00048: val_loss did not improve from 0.41034
# Epoch 49/80
#  - 4s - loss: 0.1911 - accuracy: 0.9233 - val_loss: 0.5239 - val_accuracy: 0.8952
#
# Epoch 00049: val_loss did not improve from 0.41034
# Epoch 50/80
#  - 4s - loss: 0.1443 - accuracy: 0.9567 - val_loss: 0.4060 - val_accuracy: 0.8952
#
# Epoch 00050: val_loss improved from 0.41034 to 0.40598, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 51/80
#  - 4s - loss: 0.1524 - accuracy: 0.9433 - val_loss: 0.4304 - val_accuracy: 0.8952
#
# Epoch 00051: val_loss did not improve from 0.40598
# Epoch 52/80
#  - 4s - loss: 0.1427 - accuracy: 0.9600 - val_loss: 0.4741 - val_accuracy: 0.8952
#
# Epoch 00052: val_loss did not improve from 0.40598
# Epoch 53/80
#  - 4s - loss: 0.1296 - accuracy: 0.9600 - val_loss: 0.3976 - val_accuracy: 0.8952
#
# Epoch 00053: val_loss improved from 0.40598 to 0.39756, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 54/80
#  - 4s - loss: 0.1043 - accuracy: 0.9767 - val_loss: 0.4386 - val_accuracy: 0.9048
#
# Epoch 00054: val_loss did not improve from 0.39756
# Epoch 55/80
#  - 4s - loss: 0.1830 - accuracy: 0.9333 - val_loss: 0.5025 - val_accuracy: 0.8762
#
# Epoch 00055: val_loss did not improve from 0.39756
# Epoch 56/80
#  - 4s - loss: 0.1162 - accuracy: 0.9700 - val_loss: 0.4488 - val_accuracy: 0.8952
#
# Epoch 00056: val_loss did not improve from 0.39756
# Epoch 57/80
#  - 4s - loss: 0.0904 - accuracy: 0.9800 - val_loss: 0.4768 - val_accuracy: 0.8952
#
# Epoch 00057: val_loss did not improve from 0.39756
# Epoch 58/80
#  - 4s - loss: 0.0841 - accuracy: 0.9700 - val_loss: 0.4775 - val_accuracy: 0.8667
#
# Epoch 00058: val_loss did not improve from 0.39756
# Epoch 59/80
#  - 4s - loss: 0.0817 - accuracy: 0.9800 - val_loss: 0.3903 - val_accuracy: 0.9048
#
# Epoch 00059: val_loss improved from 0.39756 to 0.39030, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 60/80
#  - 4s - loss: 0.0771 - accuracy: 0.9767 - val_loss: 0.6745 - val_accuracy: 0.8190
#
# Epoch 00060: val_loss did not improve from 0.39030
# Epoch 61/80
#  - 4s - loss: 0.0917 - accuracy: 0.9667 - val_loss: 0.4232 - val_accuracy: 0.9048
#
# Epoch 00061: val_loss did not improve from 0.39030
# Epoch 62/80
#  - 4s - loss: 0.0971 - accuracy: 0.9733 - val_loss: 0.4435 - val_accuracy: 0.9048
#
# Epoch 00062: val_loss did not improve from 0.39030
# Epoch 63/80
#  - 4s - loss: 0.0919 - accuracy: 0.9700 - val_loss: 0.5017 - val_accuracy: 0.9333
#
# Epoch 00063: val_loss did not improve from 0.39030
# Epoch 64/80
#  - 4s - loss: 0.0788 - accuracy: 0.9800 - val_loss: 0.3910 - val_accuracy: 0.9143
#
# Epoch 00064: val_loss did not improve from 0.39030
# Epoch 65/80
#  - 4s - loss: 0.0557 - accuracy: 0.9767 - val_loss: 0.4525 - val_accuracy: 0.9238
#
# Epoch 00065: val_loss did not improve from 0.39030
# Epoch 66/80
#  - 4s - loss: 0.0466 - accuracy: 0.9900 - val_loss: 0.4015 - val_accuracy: 0.9143
#
# Epoch 00066: val_loss did not improve from 0.39030
# Epoch 67/80
#  - 4s - loss: 0.1082 - accuracy: 0.9633 - val_loss: 0.6337 - val_accuracy: 0.8952
#
# Epoch 00067: val_loss did not improve from 0.39030
# Epoch 68/80
#  - 4s - loss: 0.0595 - accuracy: 0.9833 - val_loss: 0.4594 - val_accuracy: 0.9143
#
# Epoch 00068: val_loss did not improve from 0.39030
# Epoch 69/80
#  - 4s - loss: 0.0661 - accuracy: 0.9833 - val_loss: 0.6325 - val_accuracy: 0.8571
#
# Epoch 00069: val_loss did not improve from 0.39030
# Epoch 70/80
#  - 4s - loss: 0.0550 - accuracy: 0.9767 - val_loss: 0.5017 - val_accuracy: 0.8857
#
# Epoch 00070: val_loss did not improve from 0.39030
# Epoch 71/80
#  - 4s - loss: 0.0621 - accuracy: 0.9867 - val_loss: 0.4044 - val_accuracy: 0.9238
#
# Epoch 00071: val_loss did not improve from 0.39030
# Epoch 72/80
#  - 4s - loss: 0.0273 - accuracy: 0.9967 - val_loss: 0.3819 - val_accuracy: 0.9143
#
# Epoch 00072: val_loss improved from 0.39030 to 0.38187, saving model to Model_shooting_1.weights.best.hdf5
# Epoch 73/80
#  - 4s - loss: 0.0173 - accuracy: 0.9967 - val_loss: 0.5392 - val_accuracy: 0.9048
#
# Epoch 00073: val_loss did not improve from 0.38187
# Epoch 74/80
#  - 4s - loss: 0.0361 - accuracy: 0.9900 - val_loss: 0.4394 - val_accuracy: 0.9143
#
# Epoch 00074: val_loss did not improve from 0.38187
# Epoch 75/80
#  - 4s - loss: 0.0177 - accuracy: 0.9933 - val_loss: 0.4171 - val_accuracy: 0.9238
#
# Epoch 00075: val_loss did not improve from 0.38187
# Epoch 76/80
#  - 4s - loss: 0.0147 - accuracy: 0.9967 - val_loss: 0.3984 - val_accuracy: 0.9143
#
# Epoch 00076: val_loss did not improve from 0.38187
# Epoch 77/80
#  - 4s - loss: 0.0157 - accuracy: 0.9967 - val_loss: 0.4984 - val_accuracy: 0.9429
#
# Epoch 00077: val_loss did not improve from 0.38187
# Epoch 78/80
#  - 4s - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.4275 - val_accuracy: 0.9143
#
# Epoch 00078: val_loss did not improve from 0.38187
# Epoch 79/80
#  - 4s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.4353 - val_accuracy: 0.9238
#
# Epoch 00079: val_loss did not improve from 0.38187
# Epoch 80/80
#  - 4s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.4568 - val_accuracy: 0.9333
#
# Epoch 00080: val_loss did not improve from 0.38187

# %%
# Loading the model that performed the best on the validation set
model.load_weights('/content/Model_shooting_1.weights.best.hdf5')

# Testing the model on the Test data
(loss, accuracy) = model.evaluate(X_test, y_test, batch_size=16, verbose=0)

print('Accuracy on test data: {:.2f}%'.format(accuracy * 100))
# Out:
# Accuracy on test data: 96.06%

# %%
# Making the plot larger
plt.figure(figsize=(12, 8))

loss = history.history['loss']                          # Loss on the training data
val_loss = history.history['val_loss']                  # Loss on the validation data
epochs = range(1, 81)

plt.plot(epochs, loss, 'ro-', label='Training Loss')
plt.plot(epochs, val_loss, 'go-', label = 'Validation Loss')
plt.legend()

# %%
# Making the plot larger
plt.figure(figsize=(12, 8))

acc = history.history['accuracy']                          # Loss on the training data
val_acc = history.history['val_accuracy']                  # Loss on the validation data
epochs = range(1, 81)

plt.plot(epochs, acc, 'ro-', label='Training Accuracy')
plt.plot(epochs, val_acc, 'go-', label = 'Validation Accuracy')
plt.legend()

# %%
y_pred=model.predict(X_test)
y_pred=y_pred>0.80
target_names = ['class Normal', 'class Shooting']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
#   class Normal       0.95      0.87      0.91        97
# class Shooting       0.96      0.90      0.93       106
#
#      micro avg       0.96      0.88      0.92       203
#      macro avg       0.96      0.88      0.92       203
#   weighted avg       0.96      0.88      0.92       203
#    samples avg       0.88      0.88      0.88       203
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Using the Sequential Model
model = Sequential()

# Adding Alternate convolutional and pooling layers
model.add(Conv3D(filters=16, kernel_size=(5, 3, 3), strides=(1, 1, 1), padding='same', activation='relu', 
                 input_shape=X_train.shape[1:]))
model.add(MaxPooling3D(pool_size=2, strides=(2, 2, 2), padding='same'))

model.add(Conv3D(filters=64, kernel_size=(2, 3, 3), strides=(1, 1, 1), padding='valid', activation='relu'))
model.add(MaxPooling3D(pool_size=2, strides=(2, 2, 2), padding='same'))

model.add(Conv3D(filters=256, kernel_size=(2, 3, 3), strides=(1, 1, 1), padding='valid', activation='relu'))
model.add(MaxPooling3D(pool_size=2, strides=(2, 2, 2), padding='same'))

model.add(Conv3D(filters=1024, kernel_size=(2, 3, 3), strides=(1, 1, 1), padding='valid', activation='relu'))
model.add(MaxPooling3D(pool_size=2, strides=(2, 2, 2), padding='same'))

# A global average pooling layer to get a 1-d vector
# The vector will have a depth (same as number of elements in the vector) of 1024
model.add(GlobalAveragePooling3D())

# Hidden layer
model.add(Dense(32, activation='relu'))

# Dropout Layer
model.add(Dropout(0.5))

# Output layer
model.add(Dense(2, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_4 (Conv3D)            (None, 29, 128, 128, 16)  736
# _________________________________________________________________
# max_pooling3d_4 (MaxPooling3 (None, 15, 64, 64, 16)    0
# _________________________________________________________________
# conv3d_5 (Conv3D)            (None, 14, 62, 62, 64)    18496
# _________________________________________________________________
# max_pooling3d_5 (MaxPooling3 (None, 7, 31, 31, 64)     0
# _________________________________________________________________
# conv3d_6 (Conv3D)            (None, 6, 29, 29, 256)    295168
# _________________________________________________________________
# max_pooling3d_6 (MaxPooling3 (None, 3, 15, 15, 256)    0
# _________________________________________________________________
# conv3d_7 (Conv3D)            (None, 2, 13, 13, 1024)   4719616
# _________________________________________________________________
# max_pooling3d_7 (MaxPooling3 (None, 1, 7, 7, 1024)     0
# _________________________________________________________________
# global_average_pooling3d_2 ( (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                32800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 5,066,882
# Trainable params: 5,066,882
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint

# Compiling the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Saving the model that performed the best on the validation set
checkpoint = ModelCheckpoint(filepath='Model_shooting_2_larger_parameters.weights.best.hdf5', save_best_only=True, verbose=1)

# Training the model for 40 epochs
history = model.fit(X_train, y_train, batch_size=16, epochs=80, 
                    validation_data=(X_valid, y_valid), verbose=2, callbacks=[checkpoint])
# Out:
# Train on 300 samples, validate on 105 samples
# Epoch 1/80
#  - 6s - loss: 0.7075 - accuracy: 0.4900 - val_loss: 0.6912 - val_accuracy: 0.5048
#
# Epoch 00001: val_loss improved from inf to 0.69123, saving model to Model_shooting_2_larger_parameters.weights.best.hdf5
# Epoch 2/80
#  - 4s - loss: 0.6901 - accuracy: 0.5633 - val_loss: 0.6874 - val_accuracy: 0.5524
#
# Epoch 00002: val_loss improved from 0.69123 to 0.68741, saving model to Model_shooting_2_larger_parameters.weights.best.hdf5
# Epoch 3/80
#  - 4s - loss: 0.6770 - accuracy: 0.5767 - val_loss: 0.6823 - val_accuracy: 0.6000
#
# Epoch 00003: val_loss improved from 0.68741 to 0.68232, saving model to Model_shooting_2_larger_parameters.weights.best.hdf5
# Epoch 4/80
#  - 4s - loss: 0.6635 - accuracy: 0.5900 - val_loss: 0.6750 - val_accuracy: 0.6190
#
# Epoch 00004: val_loss improved from 0.68232 to 0.67495, saving model to Model_shooting_2_larger_parameters.weights.best.hdf5
# Epoch 5/80
#  - 4s - loss: 0.6506 - accuracy: 0.6233 - val_loss: 0.6703 - val_accuracy: 0.6381
#
# Epoch 00005: val_loss improved from 0.67495 to 0.67032, saving model to Model_shooting_2_larger_parameters.weights.best.hdf5
# Epoch 6/80
#  - 4s - loss: 0.6322 - accuracy: 0.6367 - val_loss: 0.6369 - val_accuracy: 0.5619
#
# Epoch 00006: val_loss improved from 0.67032 to 0.63693, saving model to Model_shooting_2_larger_parameters.weights.best.hdf5
# Epoch 7/80
#  - 4s - loss: 0.6237 - accuracy: 0.6633 - val_loss: 0.6482 - val_accuracy: 0.6571
#
# Epoch 00007: val_loss did not improve from 0.63693
# Epoch 8/80
#  - 4s - loss: 0.6108 - accuracy: 0.6733 - val_loss: 0.6570 - val_accuracy: 0.6476
#
# Epoch 00008: val_loss did not improve from 0.63693
# Epoch 9/80
#  - 4s - loss: 0.5825 - accuracy: 0.6767 - val_loss: 0.6452 - val_accuracy: 0.6857
#
# Epoch 00009: val_loss did not improve from 0.63693
# Epoch 10/80
#  - 4s - loss: 0.5545 - accuracy: 0.7233 - val_loss: 0.6555 - val_accuracy: 0.6000
#
# Epoch 00010: val_loss did not improve from 0.63693
# Epoch 11/80
#  - 4s - loss: 0.5613 - accuracy: 0.7333 - val_loss: 0.5730 - val_accuracy: 0.7429
#
# Epoch 00011: val_loss improved from 0.63693 to 0.57297, saving model to Model_shooting_2_larger_parameters.weights.best.hdf5
# Epoch 12/80
#  - 4s - loss: 0.5585 - accuracy: 0.7600 - val_loss: 0.5821 - val_accuracy: 0.7143
#
# Epoch 00012: val_loss did not improve from 0.57297
# Epoch 13/80
#  - 4s - loss: 0.5038 - accuracy: 0.7567 - val_loss: 0.8052 - val_accuracy: 0.6667
#
# Epoch 00013: val_loss did not improve from 0.57297
# Epoch 14/80
#  - 4s - loss: 0.5418 - accuracy: 0.7833 - val_loss: 0.5875 - val_accuracy: 0.7048
#
# Epoch 00014: val_loss did not improve from 0.57297
# Epoch 15/80
#  - 4s - loss: 0.4534 - accuracy: 0.7867 - val_loss: 0.6361 - val_accuracy: 0.6857
#
# Epoch 00015: val_loss did not improve from 0.57297
# Epoch 16/80
#  - 4s - loss: 0.4400 - accuracy: 0.8033 - val_loss: 0.5354 - val_accuracy: 0.7714
#
# Epoch 00016: val_loss improved from 0.57297 to 0.53536, saving model to Model_shooting_2_larger_parameters.weights.best.hdf5
# Epoch 17/80
#  - 4s - loss: 0.4689 - accuracy: 0.7900 - val_loss: 0.5607 - val_accuracy: 0.7810
#
# Epoch 00017: val_loss did not improve from 0.53536
# Epoch 18/80
#  - 4s - loss: 0.4033 - accuracy: 0.8167 - val_loss: 0.5493 - val_accuracy: 0.7333
#
# Epoch 00018: val_loss did not improve from 0.53536
# Epoch 19/80
#  - 4s - loss: 0.3795 - accuracy: 0.8167 - val_loss: 0.4324 - val_accuracy: 0.7905
#
# Epoch 00019: val_loss improved from 0.53536 to 0.43237, saving model to Model_shooting_2_larger_parameters.weights.best.hdf5
# Epoch 20/80
#  - 4s - loss: 0.3468 - accuracy: 0.8633 - val_loss: 0.5213 - val_accuracy: 0.8381
#
# Epoch 00020: val_loss did not improve from 0.43237
# Epoch 21/80
#  - 4s - loss: 0.3162 - accuracy: 0.8767 - val_loss: 0.3590 - val_accuracy: 0.8667
#
# Epoch 00021: val_loss improved from 0.43237 to 0.35902, saving model to Model_shooting_2_larger_parameters.weights.best.hdf5
# Epoch 22/80
#  - 4s - loss: 0.3131 - accuracy: 0.8700 - val_loss: 0.5378 - val_accuracy: 0.7810
#
# Epoch 00022: val_loss did not improve from 0.35902
# Epoch 23/80
#  - 4s - loss: 0.3118 - accuracy: 0.8500 - val_loss: 0.4107 - val_accuracy: 0.8667
#
# Epoch 00023: val_loss did not improve from 0.35902
# Epoch 24/80
#  - 4s - loss: 0.2893 - accuracy: 0.8900 - val_loss: 0.4508 - val_accuracy: 0.8095
#
# Epoch 00024: val_loss did not improve from 0.35902
# Epoch 25/80
#  - 4s - loss: 0.2624 - accuracy: 0.9067 - val_loss: 0.5386 - val_accuracy: 0.8381
#
# Epoch 00025: val_loss did not improve from 0.35902
# Epoch 26/80
#  - 4s - loss: 0.3468 - accuracy: 0.8567 - val_loss: 0.4017 - val_accuracy: 0.8000
#
# Epoch 00026: val_loss did not improve from 0.35902
# Epoch 27/80
#  - 4s - loss: 0.2772 - accuracy: 0.9033 - val_loss: 0.5064 - val_accuracy: 0.8571
#
# Epoch 00027: val_loss did not improve from 0.35902
# Epoch 28/80
#  - 4s - loss: 0.2165 - accuracy: 0.9167 - val_loss: 0.5585 - val_accuracy: 0.8667
#
# Epoch 00028: val_loss did not improve from 0.35902
# Epoch 29/80
#  - 4s - loss: 0.2932 - accuracy: 0.8933 - val_loss: 0.4162 - val_accuracy: 0.8381
#
# Epoch 00029: val_loss did not improve from 0.35902
# Epoch 30/80
#  - 4s - loss: 0.2274 - accuracy: 0.9233 - val_loss: 0.3909 - val_accuracy: 0.8762
#
# Epoch 00030: val_loss did not improve from 0.35902
# Epoch 31/80
#  - 4s - loss: 0.1876 - accuracy: 0.9367 - val_loss: 0.3717 - val_accuracy: 0.8571
#
# Epoch 00031: val_loss did not improve from 0.35902
# Epoch 32/80
#  - 4s - loss: 0.2730 - accuracy: 0.9000 - val_loss: 0.5348 - val_accuracy: 0.7429
#
# Epoch 00032: val_loss did not improve from 0.35902
# Epoch 33/80
#  - 4s - loss: 0.2067 - accuracy: 0.9267 - val_loss: 0.4390 - val_accuracy: 0.8476
#
# Epoch 00033: val_loss did not improve from 0.35902
# Epoch 34/80
#  - 4s - loss: 0.1592 - accuracy: 0.9467 - val_loss: 0.2694 - val_accuracy: 0.9238
#
# Epoch 00034: val_loss improved from 0.35902 to 0.26936, saving model to Model_shooting_2_larger_parameters.weights.best.hdf5
# Epoch 35/80
#  - 4s - loss: 0.1830 - accuracy: 0.9367 - val_loss: 0.4847 - val_accuracy: 0.8381
#
# Epoch 00035: val_loss did not improve from 0.26936
# Epoch 36/80
#  - 4s - loss: 0.1728 - accuracy: 0.9433 - val_loss: 0.3334 - val_accuracy: 0.9048
#
# Epoch 00036: val_loss did not improve from 0.26936
# Epoch 37/80
#  - 4s - loss: 0.1263 - accuracy: 0.9567 - val_loss: 0.3006 - val_accuracy: 0.9238
#
# Epoch 00037: val_loss did not improve from 0.26936
# Epoch 38/80
#  - 4s - loss: 0.1044 - accuracy: 0.9667 - val_loss: 0.2218 - val_accuracy: 0.9333
#
# Epoch 00038: val_loss improved from 0.26936 to 0.22176, saving model to Model_shooting_2_larger_parameters.weights.best.hdf5
# Epoch 39/80
#  - 4s - loss: 0.1264 - accuracy: 0.9667 - val_loss: 0.2015 - val_accuracy: 0.9333
#
# Epoch 00039: val_loss improved from 0.22176 to 0.20151, saving model to Model_shooting_2_larger_parameters.weights.best.hdf5
# Epoch 40/80
#  - 4s - loss: 0.1634 - accuracy: 0.9400 - val_loss: 0.3183 - val_accuracy: 0.8762
#
# Epoch 00040: val_loss did not improve from 0.20151
# Epoch 41/80
#  - 4s - loss: 0.1559 - accuracy: 0.9567 - val_loss: 0.2316 - val_accuracy: 0.8952
#
# Epoch 00041: val_loss did not improve from 0.20151
# Epoch 42/80
#  - 4s - loss: 0.0874 - accuracy: 0.9600 - val_loss: 0.1939 - val_accuracy: 0.9429
#
# Epoch 00042: val_loss improved from 0.20151 to 0.19391, saving model to Model_shooting_2_larger_parameters.weights.best.hdf5
# Epoch 43/80
#  - 4s - loss: 0.0776 - accuracy: 0.9867 - val_loss: 0.2207 - val_accuracy: 0.9333
#
# Epoch 00043: val_loss did not improve from 0.19391
# Epoch 44/80
#  - 4s - loss: 0.0543 - accuracy: 0.9833 - val_loss: 0.3031 - val_accuracy: 0.9238
#
# Epoch 00044: val_loss did not improve from 0.19391
# Epoch 45/80
#  - 4s - loss: 0.1055 - accuracy: 0.9600 - val_loss: 0.2892 - val_accuracy: 0.9333
#
# Epoch 00045: val_loss did not improve from 0.19391
# Epoch 46/80
#  - 4s - loss: 0.3964 - accuracy: 0.8567 - val_loss: 0.6319 - val_accuracy: 0.8286
#
# Epoch 00046: val_loss did not improve from 0.19391
# Epoch 47/80
#  - 4s - loss: 0.2396 - accuracy: 0.9133 - val_loss: 0.3645 - val_accuracy: 0.8762
#
# Epoch 00047: val_loss did not improve from 0.19391
# Epoch 48/80
#  - 4s - loss: 0.1348 - accuracy: 0.9533 - val_loss: 0.3452 - val_accuracy: 0.9048
#
# Epoch 00048: val_loss did not improve from 0.19391
# Epoch 49/80
#  - 4s - loss: 0.0864 - accuracy: 0.9700 - val_loss: 0.4542 - val_accuracy: 0.8952
#
# Epoch 00049: val_loss did not improve from 0.19391
# Epoch 50/80
#  - 4s - loss: 0.0630 - accuracy: 0.9867 - val_loss: 0.4495 - val_accuracy: 0.9048
#
# Epoch 00050: val_loss did not improve from 0.19391
# Epoch 51/80
#  - 4s - loss: 0.0367 - accuracy: 0.9867 - val_loss: 0.4919 - val_accuracy: 0.9238
#
# Epoch 00051: val_loss did not improve from 0.19391
# Epoch 52/80
#  - 4s - loss: 0.0359 - accuracy: 0.9833 - val_loss: 0.4319 - val_accuracy: 0.9238
#
# Epoch 00052: val_loss did not improve from 0.19391
# Epoch 53/80
#  - 4s - loss: 0.0235 - accuracy: 0.9967 - val_loss: 0.4804 - val_accuracy: 0.9429
#
# Epoch 00053: val_loss did not improve from 0.19391
# Epoch 54/80
#  - 4s - loss: 0.0231 - accuracy: 1.0000 - val_loss: 0.5474 - val_accuracy: 0.9333
#
# Epoch 00054: val_loss did not improve from 0.19391
# Epoch 55/80
#  - 4s - loss: 0.0384 - accuracy: 0.9900 - val_loss: 0.7913 - val_accuracy: 0.8952
#
# Epoch 00055: val_loss did not improve from 0.19391
# Epoch 56/80
#  - 4s - loss: 0.1050 - accuracy: 0.9633 - val_loss: 0.4162 - val_accuracy: 0.8857
#
# Epoch 00056: val_loss did not improve from 0.19391
# Epoch 57/80
#  - 4s - loss: 0.0562 - accuracy: 0.9767 - val_loss: 0.6424 - val_accuracy: 0.9333
#
# Epoch 00057: val_loss did not improve from 0.19391
# Epoch 58/80
#  - 4s - loss: 0.0276 - accuracy: 0.9933 - val_loss: 0.3773 - val_accuracy: 0.9238
#
# Epoch 00058: val_loss did not improve from 0.19391
# Epoch 59/80
#  - 4s - loss: 0.0242 - accuracy: 0.9967 - val_loss: 0.4531 - val_accuracy: 0.9143
#
# Epoch 00059: val_loss did not improve from 0.19391
# Epoch 60/80
#  - 4s - loss: 0.0395 - accuracy: 0.9900 - val_loss: 0.4396 - val_accuracy: 0.9524
#
# Epoch 00060: val_loss did not improve from 0.19391
# Epoch 61/80
#  - 4s - loss: 0.0208 - accuracy: 0.9967 - val_loss: 0.4353 - val_accuracy: 0.9429
#
# Epoch 00061: val_loss did not improve from 0.19391
# Epoch 62/80
#  - 4s - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.5004 - val_accuracy: 0.9524
#
# Epoch 00062: val_loss did not improve from 0.19391
# Epoch 63/80
#  - 4s - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.5428 - val_accuracy: 0.9429
#
# Epoch 00063: val_loss did not improve from 0.19391
# Epoch 64/80
#  - 4s - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.5841 - val_accuracy: 0.9524
#
# Epoch 00064: val_loss did not improve from 0.19391
# Epoch 65/80
#  - 4s - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.6302 - val_accuracy: 0.9524
#
# Epoch 00065: val_loss did not improve from 0.19391
# Epoch 66/80
#  - 4s - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.6708 - val_accuracy: 0.9524
#
# Epoch 00066: val_loss did not improve from 0.19391
# Epoch 67/80
#  - 4s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.7265 - val_accuracy: 0.9524
#
# Epoch 00067: val_loss did not improve from 0.19391
# Epoch 68/80
#  - 4s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.7518 - val_accuracy: 0.9429
#
# Epoch 00068: val_loss did not improve from 0.19391
# Epoch 69/80
#  - 4s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.7674 - val_accuracy: 0.9429
#
# Epoch 00069: val_loss did not improve from 0.19391
# Epoch 70/80
#  - 4s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.7937 - val_accuracy: 0.9524
#
# Epoch 00070: val_loss did not improve from 0.19391
# Epoch 71/80
#  - 4s - loss: 0.0089 - accuracy: 0.9967 - val_loss: 0.8186 - val_accuracy: 0.9524
#
# Epoch 00071: val_loss did not improve from 0.19391
# Epoch 72/80
#  - 4s - loss: 0.0203 - accuracy: 0.9967 - val_loss: 0.6833 - val_accuracy: 0.9429
#
# Epoch 00072: val_loss did not improve from 0.19391
# Epoch 73/80
#  - 4s - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.7772 - val_accuracy: 0.9429
#
# Epoch 00073: val_loss did not improve from 0.19391
# Epoch 74/80
#  - 4s - loss: 0.0091 - accuracy: 0.9967 - val_loss: 0.8199 - val_accuracy: 0.9524
#
# Epoch 00074: val_loss did not improve from 0.19391
# Epoch 75/80
#  - 4s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.8524 - val_accuracy: 0.9333
#
# Epoch 00075: val_loss did not improve from 0.19391
# Epoch 76/80
#  - 4s - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.8618 - val_accuracy: 0.9524
#
# Epoch 00076: val_loss did not improve from 0.19391
# Epoch 77/80
#  - 4s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.7719 - val_accuracy: 0.9524
#
# Epoch 00077: val_loss did not improve from 0.19391
# Epoch 78/80
#  - 4s - loss: 0.0340 - accuracy: 0.9833 - val_loss: 0.8582 - val_accuracy: 0.8571
#
# Epoch 00078: val_loss did not improve from 0.19391
# Epoch 79/80
#  - 4s - loss: 0.1636 - accuracy: 0.9467 - val_loss: 0.4718 - val_accuracy: 0.9238
#
# Epoch 00079: val_loss did not improve from 0.19391
# Epoch 80/80
#  - 4s - loss: 0.0942 - accuracy: 0.9700 - val_loss: 0.4981 - val_accuracy: 0.9524
#
# Epoch 00080: val_loss did not improve from 0.19391

# %%
# Loading the model that performed the best on the validation set
model.load_weights('/content/Model_shooting_2_larger_parameters.weights.best.hdf5')

# Testing the model on the Test data
(loss, accuracy) = model.evaluate(X_test, y_test, batch_size=16, verbose=0)

print('Accuracy on test data: {:.2f}%'.format(accuracy * 100))
# Out:
# Accuracy on test data: 91.63%

# %%
# Making the plot larger
plt.figure(figsize=(12, 8))

loss = history.history['loss']                          # Loss on the training data
val_loss = history.history['val_loss']                  # Loss on the validation data
epochs = range(1, 81)

plt.plot(epochs, loss, 'ro-', label='Training Loss')
plt.plot(epochs, val_loss, 'go-', label = 'Validation Loss')
plt.legend()


# Making the plot larger
plt.figure(figsize=(12, 8))

acc = history.history['accuracy']                          # Loss on the training data
val_acc = history.history['val_accuracy']                  # Loss on the validation data
epochs = range(1, 81)

plt.plot(epochs, acc, 'ro-', label='Training Accuracy')
plt.plot(epochs, val_acc, 'go-', label = 'Validation Accuracy')
plt.legend()


y_pred=model.predict(X_test)
y_pred=y_pred>0.80
target_names = ['class Normal', 'class Shooting']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                 precision    recall  f1-score   support
#
#   class Normal       0.92      0.94      0.93        97
# class Shooting       0.98      0.76      0.86       106
#
#      micro avg       0.95      0.85      0.89       203
#      macro avg       0.95      0.85      0.89       203
#   weighted avg       0.95      0.85      0.89       203
#    samples avg       0.85      0.85      0.85       203

# %%
model_d = Sequential()

# Adding Alternate convolutional and pooling layers
model_d.add(DepthwiseConv3D( kernel_size=(10, 3, 3),depth_multiplier=2, strides=(1, 1, 1), padding='same', activation='relu', 
                 input_shape=X_train.shape[1:]))
model_d.add(MaxPooling3D(pool_size=2, strides=(1, 2, 2), padding='same'))

model_d.add(DepthwiseConv3D( depth_multiplier=4,kernel_size=(5, 3, 3), strides=(3, 1, 1), padding='valid', activation='relu'))
model_d.add(MaxPooling3D(pool_size=2, strides=(1, 2, 2), padding='same'))

model_d.add(DepthwiseConv3D(depth_multiplier=8, kernel_size=(5, 3, 3), strides=(3, 1, 1), padding='valid', activation='relu'))
model_d.add(MaxPooling3D(pool_size=2, strides=(1, 2, 2), padding='same'))

# A global average pooling layer to get a 1-d vector
# The vector will have a depth (same as number of elements in the vector) of 256
model_d.add(GlobalAveragePooling3D())

# The Global average pooling layer is followed by a fully-connected neural network, with one hidden and one output layer

# Hidden Layer
model_d.add(Dense(32, activation='relu'))

# Output layer
model_d.add(Dense(2, activation='softmax'))

model_d.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# depthwise_conv3d_4 (Depthwis (None, 29, 128, 128, 2)   182
# _________________________________________________________________
# max_pooling3d_11 (MaxPooling (None, 29, 64, 64, 2)     0
# _________________________________________________________________
# depthwise_conv3d_5 (Depthwis (None, 9, 62, 62, 8)      368
# _________________________________________________________________
# max_pooling3d_12 (MaxPooling (None, 9, 31, 31, 8)      0
# _________________________________________________________________
# depthwise_conv3d_6 (Depthwis (None, 2, 29, 29, 64)     2944
# _________________________________________________________________
# max_pooling3d_13 (MaxPooling (None, 2, 15, 15, 64)     0
# _________________________________________________________________
# global_average_pooling3d_4 ( (None, 64)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 5,640
# Trainable params: 5,640
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint

# Compiling the model
model_d.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Saving the model that performed the best on the validation set
checkpoint = ModelCheckpoint(filepath='Model_depthwise_1_shooting.weights.best.hdf5', save_best_only=True, verbose=1)

# Training the model for 40 epochs
history = model_d.fit(X_train, y_train, batch_size=16, epochs=200, 
                    validation_data=(X_valid, y_valid), verbose=2, callbacks=[checkpoint])
# Out:
# Train on 300 samples, validate on 105 samples
# Epoch 1/200
#  - 4s - loss: 0.6911 - accuracy: 0.5033 - val_loss: 0.6837 - val_accuracy: 0.5333
#
# Epoch 00001: val_loss improved from inf to 0.68374, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 2/200
#  - 2s - loss: 0.6907 - accuracy: 0.5133 - val_loss: 0.6797 - val_accuracy: 0.5333
#
# Epoch 00002: val_loss improved from 0.68374 to 0.67971, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 3/200
#  - 2s - loss: 0.6834 - accuracy: 0.5500 - val_loss: 0.6781 - val_accuracy: 0.6095
#
# Epoch 00003: val_loss improved from 0.67971 to 0.67810, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 4/200
#  - 2s - loss: 0.6727 - accuracy: 0.6300 - val_loss: 0.6651 - val_accuracy: 0.5524
#
# Epoch 00004: val_loss improved from 0.67810 to 0.66507, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 5/200
#  - 2s - loss: 0.6567 - accuracy: 0.6500 - val_loss: 0.6574 - val_accuracy: 0.5714
#
# Epoch 00005: val_loss improved from 0.66507 to 0.65735, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 6/200
#  - 2s - loss: 0.6388 - accuracy: 0.6533 - val_loss: 0.6437 - val_accuracy: 0.6286
#
# Epoch 00006: val_loss improved from 0.65735 to 0.64367, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 7/200
#  - 2s - loss: 0.6225 - accuracy: 0.6633 - val_loss: 0.6362 - val_accuracy: 0.6286
#
# Epoch 00007: val_loss improved from 0.64367 to 0.63623, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 8/200
#  - 2s - loss: 0.6187 - accuracy: 0.6733 - val_loss: 0.6682 - val_accuracy: 0.5524
#
# Epoch 00008: val_loss did not improve from 0.63623
# Epoch 9/200
#  - 2s - loss: 0.6166 - accuracy: 0.6633 - val_loss: 0.6360 - val_accuracy: 0.6286
#
# Epoch 00009: val_loss improved from 0.63623 to 0.63600, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 10/200
#  - 2s - loss: 0.6013 - accuracy: 0.6900 - val_loss: 0.6107 - val_accuracy: 0.6571
#
# Epoch 00010: val_loss improved from 0.63600 to 0.61066, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 11/200
#  - 2s - loss: 0.5812 - accuracy: 0.6933 - val_loss: 0.6107 - val_accuracy: 0.6857
#
# Epoch 00011: val_loss did not improve from 0.61066
# Epoch 12/200
#  - 2s - loss: 0.5714 - accuracy: 0.6933 - val_loss: 0.6131 - val_accuracy: 0.6095
#
# Epoch 00012: val_loss did not improve from 0.61066
# Epoch 13/200
#  - 2s - loss: 0.5663 - accuracy: 0.7033 - val_loss: 0.5914 - val_accuracy: 0.6476
#
# Epoch 00013: val_loss improved from 0.61066 to 0.59143, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 14/200
#  - 2s - loss: 0.5582 - accuracy: 0.7000 - val_loss: 0.6015 - val_accuracy: 0.6381
#
# Epoch 00014: val_loss did not improve from 0.59143
# Epoch 15/200
#  - 2s - loss: 0.5484 - accuracy: 0.7233 - val_loss: 0.6142 - val_accuracy: 0.6762
#
# Epoch 00015: val_loss did not improve from 0.59143
# Epoch 16/200
#  - 2s - loss: 0.5616 - accuracy: 0.7133 - val_loss: 0.6257 - val_accuracy: 0.6857
#
# Epoch 00016: val_loss did not improve from 0.59143
# Epoch 17/200
#  - 2s - loss: 0.5385 - accuracy: 0.7500 - val_loss: 0.5752 - val_accuracy: 0.6476
#
# Epoch 00017: val_loss improved from 0.59143 to 0.57523, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 18/200
#  - 2s - loss: 0.5378 - accuracy: 0.7167 - val_loss: 0.5759 - val_accuracy: 0.6857
#
# Epoch 00018: val_loss did not improve from 0.57523
# Epoch 19/200
#  - 2s - loss: 0.5261 - accuracy: 0.7500 - val_loss: 0.5477 - val_accuracy: 0.6762
#
# Epoch 00019: val_loss improved from 0.57523 to 0.54773, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 20/200
#  - 2s - loss: 0.5443 - accuracy: 0.7433 - val_loss: 0.6397 - val_accuracy: 0.6000
#
# Epoch 00020: val_loss did not improve from 0.54773
# Epoch 21/200
#  - 2s - loss: 0.5254 - accuracy: 0.7333 - val_loss: 0.5871 - val_accuracy: 0.6381
#
# Epoch 00021: val_loss did not improve from 0.54773
# Epoch 22/200
#  - 2s - loss: 0.5118 - accuracy: 0.7400 - val_loss: 0.5679 - val_accuracy: 0.6667
#
# Epoch 00022: val_loss did not improve from 0.54773
# Epoch 23/200
#  - 2s - loss: 0.5096 - accuracy: 0.7433 - val_loss: 0.5599 - val_accuracy: 0.6857
#
# Epoch 00023: val_loss did not improve from 0.54773
# Epoch 24/200
#  - 2s - loss: 0.5047 - accuracy: 0.7567 - val_loss: 0.5767 - val_accuracy: 0.6857
#
# Epoch 00024: val_loss did not improve from 0.54773
# Epoch 25/200
#  - 2s - loss: 0.5043 - accuracy: 0.7633 - val_loss: 0.5523 - val_accuracy: 0.6952
#
# Epoch 00025: val_loss did not improve from 0.54773
# Epoch 26/200
#  - 2s - loss: 0.5025 - accuracy: 0.7600 - val_loss: 0.5552 - val_accuracy: 0.7143
#
# Epoch 00026: val_loss did not improve from 0.54773
# Epoch 27/200
#  - 2s - loss: 0.5001 - accuracy: 0.7533 - val_loss: 0.5478 - val_accuracy: 0.6762
#
# Epoch 00027: val_loss did not improve from 0.54773
# Epoch 28/200
#  - 2s - loss: 0.4999 - accuracy: 0.7500 - val_loss: 0.6771 - val_accuracy: 0.6190
#
# Epoch 00028: val_loss did not improve from 0.54773
# Epoch 29/200
#  - 2s - loss: 0.4996 - accuracy: 0.7400 - val_loss: 0.5392 - val_accuracy: 0.7143
#
# Epoch 00029: val_loss improved from 0.54773 to 0.53921, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 30/200
#  - 2s - loss: 0.4796 - accuracy: 0.7500 - val_loss: 0.5434 - val_accuracy: 0.6762
#
# Epoch 00030: val_loss did not improve from 0.53921
# Epoch 31/200
#  - 2s - loss: 0.5368 - accuracy: 0.7067 - val_loss: 0.6999 - val_accuracy: 0.6190
#
# Epoch 00031: val_loss did not improve from 0.53921
# Epoch 32/200
#  - 2s - loss: 0.5012 - accuracy: 0.7333 - val_loss: 0.5547 - val_accuracy: 0.6667
#
# Epoch 00032: val_loss did not improve from 0.53921
# Epoch 33/200
#  - 2s - loss: 0.4792 - accuracy: 0.7567 - val_loss: 0.5321 - val_accuracy: 0.6667
#
# Epoch 00033: val_loss improved from 0.53921 to 0.53215, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 34/200
#  - 2s - loss: 0.4676 - accuracy: 0.7467 - val_loss: 0.5147 - val_accuracy: 0.6857
#
# Epoch 00034: val_loss improved from 0.53215 to 0.51469, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 35/200
#  - 2s - loss: 0.4552 - accuracy: 0.7733 - val_loss: 0.5043 - val_accuracy: 0.6952
#
# Epoch 00035: val_loss improved from 0.51469 to 0.50427, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 36/200
#  - 2s - loss: 0.4447 - accuracy: 0.7600 - val_loss: 0.4964 - val_accuracy: 0.7238
#
# Epoch 00036: val_loss improved from 0.50427 to 0.49639, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 37/200
#  - 2s - loss: 0.4556 - accuracy: 0.7567 - val_loss: 0.5163 - val_accuracy: 0.7238
#
# Epoch 00037: val_loss did not improve from 0.49639
# Epoch 38/200
#  - 2s - loss: 0.4410 - accuracy: 0.7567 - val_loss: 0.4944 - val_accuracy: 0.7619
#
# Epoch 00038: val_loss improved from 0.49639 to 0.49441, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 39/200
#  - 2s - loss: 0.4452 - accuracy: 0.7667 - val_loss: 0.5257 - val_accuracy: 0.6857
#
# Epoch 00039: val_loss did not improve from 0.49441
# Epoch 40/200
#  - 2s - loss: 0.4303 - accuracy: 0.7533 - val_loss: 0.5052 - val_accuracy: 0.7143
#
# Epoch 00040: val_loss did not improve from 0.49441
# Epoch 41/200
#  - 2s - loss: 0.4285 - accuracy: 0.7500 - val_loss: 0.4889 - val_accuracy: 0.7619
#
# Epoch 00041: val_loss improved from 0.49441 to 0.48886, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 42/200
#  - 2s - loss: 0.4217 - accuracy: 0.7800 - val_loss: 0.4792 - val_accuracy: 0.7714
#
# Epoch 00042: val_loss improved from 0.48886 to 0.47923, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 43/200
#  - 2s - loss: 0.4081 - accuracy: 0.7867 - val_loss: 0.4772 - val_accuracy: 0.7905
#
# Epoch 00043: val_loss improved from 0.47923 to 0.47719, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 44/200
#  - 2s - loss: 0.4401 - accuracy: 0.7633 - val_loss: 0.5432 - val_accuracy: 0.6952
#
# Epoch 00044: val_loss did not improve from 0.47719
# Epoch 45/200
#  - 2s - loss: 0.4144 - accuracy: 0.7867 - val_loss: 0.4644 - val_accuracy: 0.8095
#
# Epoch 00045: val_loss improved from 0.47719 to 0.46441, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 46/200
#  - 2s - loss: 0.4060 - accuracy: 0.8033 - val_loss: 0.4829 - val_accuracy: 0.7619
#
# Epoch 00046: val_loss did not improve from 0.46441
# Epoch 47/200
#  - 2s - loss: 0.3995 - accuracy: 0.7867 - val_loss: 0.4779 - val_accuracy: 0.7429
#
# Epoch 00047: val_loss did not improve from 0.46441
# Epoch 48/200
#  - 2s - loss: 0.4185 - accuracy: 0.7767 - val_loss: 0.4812 - val_accuracy: 0.7333
#
# Epoch 00048: val_loss did not improve from 0.46441
# Epoch 49/200
#  - 2s - loss: 0.4217 - accuracy: 0.7800 - val_loss: 0.5288 - val_accuracy: 0.7048
#
# Epoch 00049: val_loss did not improve from 0.46441
# Epoch 50/200
#  - 2s - loss: 0.4034 - accuracy: 0.7933 - val_loss: 0.5015 - val_accuracy: 0.7048
#
# Epoch 00050: val_loss did not improve from 0.46441
# Epoch 51/200
#  - 2s - loss: 0.4070 - accuracy: 0.7867 - val_loss: 0.5091 - val_accuracy: 0.7429
#
# Epoch 00051: val_loss did not improve from 0.46441
# Epoch 52/200
#  - 2s - loss: 0.4112 - accuracy: 0.8067 - val_loss: 0.4936 - val_accuracy: 0.7333
#
# Epoch 00052: val_loss did not improve from 0.46441
# Epoch 53/200
#  - 2s - loss: 0.4216 - accuracy: 0.7867 - val_loss: 0.5544 - val_accuracy: 0.6952
#
# Epoch 00053: val_loss did not improve from 0.46441
# Epoch 54/200
#  - 2s - loss: 0.4042 - accuracy: 0.8100 - val_loss: 0.4605 - val_accuracy: 0.8000
#
# Epoch 00054: val_loss improved from 0.46441 to 0.46048, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 55/200
#  - 2s - loss: 0.3802 - accuracy: 0.8233 - val_loss: 0.4665 - val_accuracy: 0.7905
#
# Epoch 00055: val_loss did not improve from 0.46048
# Epoch 56/200
#  - 2s - loss: 0.4239 - accuracy: 0.7733 - val_loss: 0.5335 - val_accuracy: 0.7143
#
# Epoch 00056: val_loss did not improve from 0.46048
# Epoch 57/200
#  - 2s - loss: 0.4295 - accuracy: 0.7633 - val_loss: 0.4812 - val_accuracy: 0.7810
#
# Epoch 00057: val_loss did not improve from 0.46048
# Epoch 58/200
#  - 2s - loss: 0.3851 - accuracy: 0.7933 - val_loss: 0.4688 - val_accuracy: 0.7333
#
# Epoch 00058: val_loss did not improve from 0.46048
# Epoch 59/200
#  - 2s - loss: 0.3826 - accuracy: 0.7900 - val_loss: 0.4611 - val_accuracy: 0.8476
#
# Epoch 00059: val_loss did not improve from 0.46048
# Epoch 60/200
#  - 2s - loss: 0.3718 - accuracy: 0.8300 - val_loss: 0.5072 - val_accuracy: 0.7429
#
# Epoch 00060: val_loss did not improve from 0.46048
# Epoch 61/200
#  - 2s - loss: 0.3853 - accuracy: 0.8000 - val_loss: 0.4661 - val_accuracy: 0.7714
#
# Epoch 00061: val_loss did not improve from 0.46048
# Epoch 62/200
#  - 2s - loss: 0.3715 - accuracy: 0.8067 - val_loss: 0.4610 - val_accuracy: 0.7905
#
# Epoch 00062: val_loss did not improve from 0.46048
# Epoch 63/200
#  - 2s - loss: 0.3783 - accuracy: 0.8400 - val_loss: 0.4795 - val_accuracy: 0.7714
#
# Epoch 00063: val_loss did not improve from 0.46048
# Epoch 64/200
#  - 2s - loss: 0.3654 - accuracy: 0.8100 - val_loss: 0.4683 - val_accuracy: 0.7905
#
# Epoch 00064: val_loss did not improve from 0.46048
# Epoch 65/200
#  - 2s - loss: 0.3755 - accuracy: 0.8067 - val_loss: 0.4662 - val_accuracy: 0.7619
#
# Epoch 00065: val_loss did not improve from 0.46048
# Epoch 66/200
#  - 2s - loss: 0.3908 - accuracy: 0.8167 - val_loss: 0.4548 - val_accuracy: 0.8381
#
# Epoch 00066: val_loss improved from 0.46048 to 0.45483, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 67/200
#  - 2s - loss: 0.3524 - accuracy: 0.8467 - val_loss: 0.4668 - val_accuracy: 0.7524
#
# Epoch 00067: val_loss did not improve from 0.45483
# Epoch 68/200
#  - 2s - loss: 0.3340 - accuracy: 0.8600 - val_loss: 0.4552 - val_accuracy: 0.7619
#
# Epoch 00068: val_loss did not improve from 0.45483
# Epoch 69/200
#  - 2s - loss: 0.3292 - accuracy: 0.8767 - val_loss: 0.4481 - val_accuracy: 0.7905
#
# Epoch 00069: val_loss improved from 0.45483 to 0.44807, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 70/200
#  - 2s - loss: 0.3285 - accuracy: 0.8667 - val_loss: 0.4621 - val_accuracy: 0.7714
#
# Epoch 00070: val_loss did not improve from 0.44807
# Epoch 71/200
#  - 2s - loss: 0.3339 - accuracy: 0.8533 - val_loss: 0.4511 - val_accuracy: 0.7714
#
# Epoch 00071: val_loss did not improve from 0.44807
# Epoch 72/200
#  - 3s - loss: 0.3227 - accuracy: 0.8733 - val_loss: 0.4801 - val_accuracy: 0.7810
#
# Epoch 00072: val_loss did not improve from 0.44807
# Epoch 73/200
#  - 3s - loss: 0.3623 - accuracy: 0.8200 - val_loss: 0.5311 - val_accuracy: 0.7333
#
# Epoch 00073: val_loss did not improve from 0.44807
# Epoch 74/200
#  - 3s - loss: 0.3521 - accuracy: 0.8300 - val_loss: 0.5022 - val_accuracy: 0.7333
#
# Epoch 00074: val_loss did not improve from 0.44807
# Epoch 75/200
#  - 2s - loss: 0.3303 - accuracy: 0.8567 - val_loss: 0.4557 - val_accuracy: 0.8286
#
# Epoch 00075: val_loss did not improve from 0.44807
# Epoch 76/200
#  - 2s - loss: 0.3743 - accuracy: 0.8200 - val_loss: 0.5363 - val_accuracy: 0.7048
#
# Epoch 00076: val_loss did not improve from 0.44807
# Epoch 77/200
#  - 2s - loss: 0.3810 - accuracy: 0.8267 - val_loss: 0.5502 - val_accuracy: 0.7905
#
# Epoch 00077: val_loss did not improve from 0.44807
# Epoch 78/200
#  - 2s - loss: 0.3767 - accuracy: 0.8333 - val_loss: 0.4970 - val_accuracy: 0.7238
#
# Epoch 00078: val_loss did not improve from 0.44807
# Epoch 79/200
#  - 2s - loss: 0.3609 - accuracy: 0.8400 - val_loss: 0.4846 - val_accuracy: 0.7238
#
# Epoch 00079: val_loss did not improve from 0.44807
# Epoch 80/200
#  - 2s - loss: 0.3872 - accuracy: 0.8267 - val_loss: 0.5065 - val_accuracy: 0.7429
#
# Epoch 00080: val_loss did not improve from 0.44807
# Epoch 81/200
#  - 2s - loss: 0.3664 - accuracy: 0.8300 - val_loss: 0.5076 - val_accuracy: 0.7619
#
# Epoch 00081: val_loss did not improve from 0.44807
# Epoch 82/200
#  - 2s - loss: 0.3399 - accuracy: 0.8367 - val_loss: 0.4807 - val_accuracy: 0.7619
#
# Epoch 00082: val_loss did not improve from 0.44807
# Epoch 83/200
#  - 2s - loss: 0.3508 - accuracy: 0.8533 - val_loss: 0.4696 - val_accuracy: 0.7619
#
# Epoch 00083: val_loss did not improve from 0.44807
# Epoch 84/200
#  - 2s - loss: 0.3283 - accuracy: 0.8433 - val_loss: 0.4656 - val_accuracy: 0.7619
#
# Epoch 00084: val_loss did not improve from 0.44807
# Epoch 85/200
#  - 2s - loss: 0.3734 - accuracy: 0.8400 - val_loss: 0.5130 - val_accuracy: 0.7524
#
# Epoch 00085: val_loss did not improve from 0.44807
# Epoch 86/200
#  - 2s - loss: 0.3310 - accuracy: 0.8633 - val_loss: 0.4441 - val_accuracy: 0.7905
#
# Epoch 00086: val_loss improved from 0.44807 to 0.44406, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 87/200
#  - 2s - loss: 0.3476 - accuracy: 0.8500 - val_loss: 0.4817 - val_accuracy: 0.7714
#
# Epoch 00087: val_loss did not improve from 0.44406
# Epoch 88/200
#  - 2s - loss: 0.2926 - accuracy: 0.8767 - val_loss: 0.4418 - val_accuracy: 0.8381
#
# Epoch 00088: val_loss improved from 0.44406 to 0.44181, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 89/200
#  - 2s - loss: 0.2832 - accuracy: 0.9033 - val_loss: 0.4393 - val_accuracy: 0.7810
#
# Epoch 00089: val_loss improved from 0.44181 to 0.43925, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 90/200
#  - 2s - loss: 0.2723 - accuracy: 0.8833 - val_loss: 0.6096 - val_accuracy: 0.7333
#
# Epoch 00090: val_loss did not improve from 0.43925
# Epoch 91/200
#  - 2s - loss: 0.3184 - accuracy: 0.8500 - val_loss: 0.4598 - val_accuracy: 0.8286
#
# Epoch 00091: val_loss did not improve from 0.43925
# Epoch 92/200
#  - 2s - loss: 0.2816 - accuracy: 0.8767 - val_loss: 0.4475 - val_accuracy: 0.7905
#
# Epoch 00092: val_loss did not improve from 0.43925
# Epoch 93/200
#  - 2s - loss: 0.2671 - accuracy: 0.8833 - val_loss: 0.4530 - val_accuracy: 0.8190
#
# Epoch 00093: val_loss did not improve from 0.43925
# Epoch 94/200
#  - 2s - loss: 0.2751 - accuracy: 0.8700 - val_loss: 0.4401 - val_accuracy: 0.7810
#
# Epoch 00094: val_loss did not improve from 0.43925
# Epoch 95/200
#  - 2s - loss: 0.2612 - accuracy: 0.8933 - val_loss: 0.5096 - val_accuracy: 0.8000
#
# Epoch 00095: val_loss did not improve from 0.43925
# Epoch 96/200
#  - 2s - loss: 0.2522 - accuracy: 0.9067 - val_loss: 0.4715 - val_accuracy: 0.7619
#
# Epoch 00096: val_loss did not improve from 0.43925
# Epoch 97/200
#  - 2s - loss: 0.2733 - accuracy: 0.8900 - val_loss: 0.4906 - val_accuracy: 0.8476
#
# Epoch 00097: val_loss did not improve from 0.43925
# Epoch 98/200
#  - 2s - loss: 0.2540 - accuracy: 0.8900 - val_loss: 0.4982 - val_accuracy: 0.7429
#
# Epoch 00098: val_loss did not improve from 0.43925
# Epoch 99/200
#  - 2s - loss: 0.2472 - accuracy: 0.9033 - val_loss: 0.4368 - val_accuracy: 0.8286
#
# Epoch 00099: val_loss improved from 0.43925 to 0.43682, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 100/200
#  - 2s - loss: 0.2347 - accuracy: 0.9067 - val_loss: 0.4614 - val_accuracy: 0.7619
#
# Epoch 00100: val_loss did not improve from 0.43682
# Epoch 101/200
#  - 2s - loss: 0.2528 - accuracy: 0.9033 - val_loss: 0.4475 - val_accuracy: 0.8095
#
# Epoch 00101: val_loss did not improve from 0.43682
# Epoch 102/200
#  - 2s - loss: 0.2313 - accuracy: 0.9000 - val_loss: 0.4377 - val_accuracy: 0.8286
#
# Epoch 00102: val_loss did not improve from 0.43682
# Epoch 103/200
#  - 2s - loss: 0.2252 - accuracy: 0.9233 - val_loss: 0.4734 - val_accuracy: 0.7810
#
# Epoch 00103: val_loss did not improve from 0.43682
# Epoch 104/200
#  - 2s - loss: 0.2467 - accuracy: 0.9133 - val_loss: 0.4538 - val_accuracy: 0.7905
#
# Epoch 00104: val_loss did not improve from 0.43682
# Epoch 105/200
#  - 2s - loss: 0.2369 - accuracy: 0.9167 - val_loss: 0.4497 - val_accuracy: 0.7810
#
# Epoch 00105: val_loss did not improve from 0.43682
# Epoch 106/200
#  - 2s - loss: 0.2398 - accuracy: 0.8967 - val_loss: 0.4585 - val_accuracy: 0.7619
#
# Epoch 00106: val_loss did not improve from 0.43682
# Epoch 107/200
#  - 2s - loss: 0.2478 - accuracy: 0.9000 - val_loss: 0.4866 - val_accuracy: 0.8000
#
# Epoch 00107: val_loss did not improve from 0.43682
# Epoch 108/200
#  - 2s - loss: 0.2348 - accuracy: 0.9100 - val_loss: 0.4538 - val_accuracy: 0.8476
#
# Epoch 00108: val_loss did not improve from 0.43682
# Epoch 109/200
#  - 2s - loss: 0.2300 - accuracy: 0.9167 - val_loss: 0.4413 - val_accuracy: 0.7905
#
# Epoch 00109: val_loss did not improve from 0.43682
# Epoch 110/200
#  - 2s - loss: 0.2198 - accuracy: 0.9167 - val_loss: 0.4321 - val_accuracy: 0.8286
#
# Epoch 00110: val_loss improved from 0.43682 to 0.43209, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 111/200
#  - 2s - loss: 0.2364 - accuracy: 0.9000 - val_loss: 0.4686 - val_accuracy: 0.8476
#
# Epoch 00111: val_loss did not improve from 0.43209
# Epoch 112/200
#  - 2s - loss: 0.2026 - accuracy: 0.9167 - val_loss: 0.4211 - val_accuracy: 0.8381
#
# Epoch 00112: val_loss improved from 0.43209 to 0.42113, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 113/200
#  - 2s - loss: 0.1993 - accuracy: 0.9367 - val_loss: 0.4330 - val_accuracy: 0.7714
#
# Epoch 00113: val_loss did not improve from 0.42113
# Epoch 114/200
#  - 2s - loss: 0.1909 - accuracy: 0.9267 - val_loss: 0.5847 - val_accuracy: 0.7810
#
# Epoch 00114: val_loss did not improve from 0.42113
# Epoch 115/200
#  - 2s - loss: 0.2609 - accuracy: 0.8933 - val_loss: 0.4892 - val_accuracy: 0.8000
#
# Epoch 00115: val_loss did not improve from 0.42113
# Epoch 116/200
#  - 2s - loss: 0.2186 - accuracy: 0.9200 - val_loss: 0.5027 - val_accuracy: 0.7905
#
# Epoch 00116: val_loss did not improve from 0.42113
# Epoch 117/200
#  - 2s - loss: 0.2097 - accuracy: 0.9267 - val_loss: 0.4434 - val_accuracy: 0.8286
#
# Epoch 00117: val_loss did not improve from 0.42113
# Epoch 118/200
#  - 2s - loss: 0.2085 - accuracy: 0.9267 - val_loss: 0.4451 - val_accuracy: 0.8000
#
# Epoch 00118: val_loss did not improve from 0.42113
# Epoch 119/200
#  - 2s - loss: 0.2068 - accuracy: 0.9400 - val_loss: 0.4503 - val_accuracy: 0.8286
#
# Epoch 00119: val_loss did not improve from 0.42113
# Epoch 120/200
#  - 2s - loss: 0.1957 - accuracy: 0.9467 - val_loss: 0.4820 - val_accuracy: 0.7810
#
# Epoch 00120: val_loss did not improve from 0.42113
# Epoch 121/200
#  - 2s - loss: 0.2431 - accuracy: 0.9133 - val_loss: 0.4746 - val_accuracy: 0.8381
#
# Epoch 00121: val_loss did not improve from 0.42113
# Epoch 122/200
#  - 2s - loss: 0.2377 - accuracy: 0.9133 - val_loss: 0.4276 - val_accuracy: 0.7619
#
# Epoch 00122: val_loss did not improve from 0.42113
# Epoch 123/200
#  - 2s - loss: 0.2496 - accuracy: 0.9067 - val_loss: 0.4743 - val_accuracy: 0.8381
#
# Epoch 00123: val_loss did not improve from 0.42113
# Epoch 124/200
#  - 2s - loss: 0.1976 - accuracy: 0.9233 - val_loss: 0.4484 - val_accuracy: 0.7810
#
# Epoch 00124: val_loss did not improve from 0.42113
# Epoch 125/200
#  - 2s - loss: 0.1960 - accuracy: 0.9333 - val_loss: 0.4169 - val_accuracy: 0.7810
#
# Epoch 00125: val_loss improved from 0.42113 to 0.41692, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 126/200
#  - 2s - loss: 0.1701 - accuracy: 0.9400 - val_loss: 0.4436 - val_accuracy: 0.8571
#
# Epoch 00126: val_loss did not improve from 0.41692
# Epoch 127/200
#  - 2s - loss: 0.1959 - accuracy: 0.9333 - val_loss: 0.4740 - val_accuracy: 0.7810
#
# Epoch 00127: val_loss did not improve from 0.41692
# Epoch 128/200
#  - 2s - loss: 0.1731 - accuracy: 0.9400 - val_loss: 0.4351 - val_accuracy: 0.8667
#
# Epoch 00128: val_loss did not improve from 0.41692
# Epoch 129/200
#  - 2s - loss: 0.1760 - accuracy: 0.9367 - val_loss: 0.4266 - val_accuracy: 0.7905
#
# Epoch 00129: val_loss did not improve from 0.41692
# Epoch 130/200
#  - 2s - loss: 0.1688 - accuracy: 0.9533 - val_loss: 0.4255 - val_accuracy: 0.8381
#
# Epoch 00130: val_loss did not improve from 0.41692
# Epoch 131/200
#  - 2s - loss: 0.1842 - accuracy: 0.9367 - val_loss: 0.4595 - val_accuracy: 0.7905
#
# Epoch 00131: val_loss did not improve from 0.41692
# Epoch 132/200
#  - 2s - loss: 0.1815 - accuracy: 0.9267 - val_loss: 0.4559 - val_accuracy: 0.8190
#
# Epoch 00132: val_loss did not improve from 0.41692
# Epoch 133/200
#  - 2s - loss: 0.1729 - accuracy: 0.9367 - val_loss: 0.4447 - val_accuracy: 0.8762
#
# Epoch 00133: val_loss did not improve from 0.41692
# Epoch 134/200
#  - 2s - loss: 0.2040 - accuracy: 0.9433 - val_loss: 0.4388 - val_accuracy: 0.7905
#
# Epoch 00134: val_loss did not improve from 0.41692
# Epoch 135/200
#  - 2s - loss: 0.1634 - accuracy: 0.9433 - val_loss: 0.4507 - val_accuracy: 0.8476
#
# Epoch 00135: val_loss did not improve from 0.41692
# Epoch 136/200
#  - 2s - loss: 0.1665 - accuracy: 0.9533 - val_loss: 0.3991 - val_accuracy: 0.8762
#
# Epoch 00136: val_loss improved from 0.41692 to 0.39915, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 137/200
#  - 2s - loss: 0.1627 - accuracy: 0.9400 - val_loss: 0.4340 - val_accuracy: 0.8667
#
# Epoch 00137: val_loss did not improve from 0.39915
# Epoch 138/200
#  - 2s - loss: 0.1803 - accuracy: 0.9500 - val_loss: 0.4885 - val_accuracy: 0.8286
#
# Epoch 00138: val_loss did not improve from 0.39915
# Epoch 139/200
#  - 2s - loss: 0.2054 - accuracy: 0.9200 - val_loss: 0.4190 - val_accuracy: 0.8762
#
# Epoch 00139: val_loss did not improve from 0.39915
# Epoch 140/200
#  - 2s - loss: 0.1657 - accuracy: 0.9533 - val_loss: 0.4546 - val_accuracy: 0.8000
#
# Epoch 00140: val_loss did not improve from 0.39915
# Epoch 141/200
#  - 2s - loss: 0.1627 - accuracy: 0.9533 - val_loss: 0.5276 - val_accuracy: 0.8286
#
# Epoch 00141: val_loss did not improve from 0.39915
# Epoch 142/200
#  - 2s - loss: 0.1605 - accuracy: 0.9500 - val_loss: 0.4520 - val_accuracy: 0.8000
#
# Epoch 00142: val_loss did not improve from 0.39915
# Epoch 143/200
#  - 2s - loss: 0.1806 - accuracy: 0.9333 - val_loss: 0.4036 - val_accuracy: 0.8571
#
# Epoch 00143: val_loss did not improve from 0.39915
# Epoch 144/200
#  - 2s - loss: 0.2608 - accuracy: 0.8967 - val_loss: 0.4896 - val_accuracy: 0.8381
#
# Epoch 00144: val_loss did not improve from 0.39915
# Epoch 145/200
#  - 2s - loss: 0.2087 - accuracy: 0.9100 - val_loss: 0.5114 - val_accuracy: 0.7810
#
# Epoch 00145: val_loss did not improve from 0.39915
# Epoch 146/200
#  - 2s - loss: 0.1967 - accuracy: 0.9400 - val_loss: 0.4956 - val_accuracy: 0.8095
#
# Epoch 00146: val_loss did not improve from 0.39915
# Epoch 147/200
#  - 2s - loss: 0.1542 - accuracy: 0.9500 - val_loss: 0.3982 - val_accuracy: 0.8667
#
# Epoch 00147: val_loss improved from 0.39915 to 0.39822, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 148/200
#  - 2s - loss: 0.1601 - accuracy: 0.9567 - val_loss: 0.4123 - val_accuracy: 0.8857
#
# Epoch 00148: val_loss did not improve from 0.39822
# Epoch 149/200
#  - 2s - loss: 0.1321 - accuracy: 0.9733 - val_loss: 0.4512 - val_accuracy: 0.8476
#
# Epoch 00149: val_loss did not improve from 0.39822
# Epoch 150/200
#  - 2s - loss: 0.1404 - accuracy: 0.9700 - val_loss: 0.3915 - val_accuracy: 0.8667
#
# Epoch 00150: val_loss improved from 0.39822 to 0.39153, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 151/200
#  - 2s - loss: 0.1365 - accuracy: 0.9567 - val_loss: 0.4004 - val_accuracy: 0.8952
#
# Epoch 00151: val_loss did not improve from 0.39153
# Epoch 152/200
#  - 2s - loss: 0.1365 - accuracy: 0.9667 - val_loss: 0.4017 - val_accuracy: 0.8667
#
# Epoch 00152: val_loss did not improve from 0.39153
# Epoch 153/200
#  - 2s - loss: 0.1409 - accuracy: 0.9467 - val_loss: 0.4460 - val_accuracy: 0.8762
#
# Epoch 00153: val_loss did not improve from 0.39153
# Epoch 154/200
#  - 2s - loss: 0.1314 - accuracy: 0.9633 - val_loss: 0.3906 - val_accuracy: 0.8667
#
# Epoch 00154: val_loss improved from 0.39153 to 0.39060, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 155/200
#  - 2s - loss: 0.1511 - accuracy: 0.9600 - val_loss: 0.4119 - val_accuracy: 0.8571
#
# Epoch 00155: val_loss did not improve from 0.39060
# Epoch 156/200
#  - 2s - loss: 0.1298 - accuracy: 0.9667 - val_loss: 0.4091 - val_accuracy: 0.8762
#
# Epoch 00156: val_loss did not improve from 0.39060
# Epoch 157/200
#  - 2s - loss: 0.1197 - accuracy: 0.9700 - val_loss: 0.3974 - val_accuracy: 0.8476
#
# Epoch 00157: val_loss did not improve from 0.39060
# Epoch 158/200
#  - 2s - loss: 0.1294 - accuracy: 0.9567 - val_loss: 0.4932 - val_accuracy: 0.8381
#
# Epoch 00158: val_loss did not improve from 0.39060
# Epoch 159/200
#  - 2s - loss: 0.1692 - accuracy: 0.9433 - val_loss: 0.5731 - val_accuracy: 0.8190
#
# Epoch 00159: val_loss did not improve from 0.39060
# Epoch 160/200
#  - 2s - loss: 0.1544 - accuracy: 0.9533 - val_loss: 0.4942 - val_accuracy: 0.8190
#
# Epoch 00160: val_loss did not improve from 0.39060
# Epoch 161/200
#  - 2s - loss: 0.2048 - accuracy: 0.9300 - val_loss: 0.4257 - val_accuracy: 0.8667
#
# Epoch 00161: val_loss did not improve from 0.39060
# Epoch 162/200
#  - 2s - loss: 0.1649 - accuracy: 0.9500 - val_loss: 0.4142 - val_accuracy: 0.8762
#
# Epoch 00162: val_loss did not improve from 0.39060
# Epoch 163/200
#  - 2s - loss: 0.1439 - accuracy: 0.9567 - val_loss: 0.4166 - val_accuracy: 0.8000
#
# Epoch 00163: val_loss did not improve from 0.39060
# Epoch 164/200
#  - 2s - loss: 0.1318 - accuracy: 0.9567 - val_loss: 0.3877 - val_accuracy: 0.8762
#
# Epoch 00164: val_loss improved from 0.39060 to 0.38770, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 165/200
#  - 2s - loss: 0.1480 - accuracy: 0.9500 - val_loss: 0.4286 - val_accuracy: 0.8667
#
# Epoch 00165: val_loss did not improve from 0.38770
# Epoch 166/200
#  - 2s - loss: 0.1691 - accuracy: 0.9367 - val_loss: 0.4528 - val_accuracy: 0.8000
#
# Epoch 00166: val_loss did not improve from 0.38770
# Epoch 167/200
#  - 2s - loss: 0.1732 - accuracy: 0.9300 - val_loss: 0.3950 - val_accuracy: 0.8667
#
# Epoch 00167: val_loss did not improve from 0.38770
# Epoch 168/200
#  - 2s - loss: 0.1835 - accuracy: 0.9367 - val_loss: 0.4643 - val_accuracy: 0.8571
#
# Epoch 00168: val_loss did not improve from 0.38770
# Epoch 169/200
#  - 2s - loss: 0.1535 - accuracy: 0.9500 - val_loss: 0.4056 - val_accuracy: 0.8667
#
# Epoch 00169: val_loss did not improve from 0.38770
# Epoch 170/200
#  - 2s - loss: 0.1234 - accuracy: 0.9667 - val_loss: 0.3679 - val_accuracy: 0.9048
#
# Epoch 00170: val_loss improved from 0.38770 to 0.36794, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 171/200
#  - 2s - loss: 0.1213 - accuracy: 0.9633 - val_loss: 0.3713 - val_accuracy: 0.8857
#
# Epoch 00171: val_loss did not improve from 0.36794
# Epoch 172/200
#  - 2s - loss: 0.1011 - accuracy: 0.9800 - val_loss: 0.3806 - val_accuracy: 0.8952
#
# Epoch 00172: val_loss did not improve from 0.36794
# Epoch 173/200
#  - 2s - loss: 0.0991 - accuracy: 0.9833 - val_loss: 0.3623 - val_accuracy: 0.8952
#
# Epoch 00173: val_loss improved from 0.36794 to 0.36229, saving model to Model_depthwise_1_shooting.weights.best.hdf5
# Epoch 174/200
#  - 2s - loss: 0.0933 - accuracy: 0.9833 - val_loss: 0.3752 - val_accuracy: 0.8857
#
# Epoch 00174: val_loss did not improve from 0.36229
# Epoch 175/200
#  - 2s - loss: 0.1035 - accuracy: 0.9767 - val_loss: 0.3876 - val_accuracy: 0.8667
#
# Epoch 00175: val_loss did not improve from 0.36229
# Epoch 176/200
#  - 2s - loss: 0.0933 - accuracy: 0.9800 - val_loss: 0.3912 - val_accuracy: 0.8286
#
# Epoch 00176: val_loss did not improve from 0.36229
# Epoch 177/200
#  - 2s - loss: 0.0962 - accuracy: 0.9833 - val_loss: 0.3787 - val_accuracy: 0.9048
#
# Epoch 00177: val_loss did not improve from 0.36229
# Epoch 178/200
#  - 2s - loss: 0.1014 - accuracy: 0.9733 - val_loss: 0.3662 - val_accuracy: 0.8952
#
# Epoch 00178: val_loss did not improve from 0.36229
# Epoch 179/200
#  - 2s - loss: 0.1056 - accuracy: 0.9633 - val_loss: 0.3975 - val_accuracy: 0.8857
#
# Epoch 00179: val_loss did not improve from 0.36229
# Epoch 180/200
#  - 2s - loss: 0.0915 - accuracy: 0.9833 - val_loss: 0.3625 - val_accuracy: 0.8857
#
# Epoch 00180: val_loss did not improve from 0.36229
# Epoch 181/200
#  - 2s - loss: 0.0999 - accuracy: 0.9800 - val_loss: 0.3906 - val_accuracy: 0.8667
#
# Epoch 00181: val_loss did not improve from 0.36229
# Epoch 182/200
#  - 2s - loss: 0.1028 - accuracy: 0.9633 - val_loss: 0.3810 - val_accuracy: 0.8476
#
# Epoch 00182: val_loss did not improve from 0.36229
# Epoch 183/200
#  - 2s - loss: 0.0983 - accuracy: 0.9767 - val_loss: 0.3786 - val_accuracy: 0.8667
#
# Epoch 00183: val_loss did not improve from 0.36229
# Epoch 184/200
#  - 2s - loss: 0.0950 - accuracy: 0.9867 - val_loss: 0.4131 - val_accuracy: 0.9048
#
# Epoch 00184: val_loss did not improve from 0.36229
# Epoch 185/200
#  - 2s - loss: 0.1044 - accuracy: 0.9733 - val_loss: 0.3747 - val_accuracy: 0.8476
#
# Epoch 00185: val_loss did not improve from 0.36229
# Epoch 186/200
#  - 2s - loss: 0.0855 - accuracy: 0.9933 - val_loss: 0.3750 - val_accuracy: 0.8952
#
# Epoch 00186: val_loss did not improve from 0.36229
# Epoch 187/200
#  - 2s - loss: 0.0987 - accuracy: 0.9733 - val_loss: 0.3746 - val_accuracy: 0.8762
#
# Epoch 00187: val_loss did not improve from 0.36229
# Epoch 188/200
#  - 2s - loss: 0.0865 - accuracy: 0.9833 - val_loss: 0.4976 - val_accuracy: 0.8571
#
# Epoch 00188: val_loss did not improve from 0.36229
# Epoch 189/200
#  - 2s - loss: 0.0941 - accuracy: 0.9733 - val_loss: 0.4078 - val_accuracy: 0.8095
#
# Epoch 00189: val_loss did not improve from 0.36229
# Epoch 190/200
#  - 2s - loss: 0.1045 - accuracy: 0.9667 - val_loss: 0.3659 - val_accuracy: 0.8952
#
# Epoch 00190: val_loss did not improve from 0.36229
# Epoch 191/200
#  - 2s - loss: 0.0939 - accuracy: 0.9733 - val_loss: 0.3673 - val_accuracy: 0.8857
#
# Epoch 00191: val_loss did not improve from 0.36229
# Epoch 192/200
#  - 2s - loss: 0.0855 - accuracy: 0.9867 - val_loss: 0.4417 - val_accuracy: 0.8381
#
# Epoch 00192: val_loss did not improve from 0.36229
# Epoch 193/200
#  - 2s - loss: 0.0803 - accuracy: 0.9800 - val_loss: 0.3743 - val_accuracy: 0.8857
#
# Epoch 00193: val_loss did not improve from 0.36229
# Epoch 194/200
#  - 2s - loss: 0.0904 - accuracy: 0.9833 - val_loss: 0.3682 - val_accuracy: 0.9048
#
# Epoch 00194: val_loss did not improve from 0.36229
# Epoch 195/200
#  - 2s - loss: 0.0908 - accuracy: 0.9867 - val_loss: 0.3853 - val_accuracy: 0.9048
#
# Epoch 00195: val_loss did not improve from 0.36229
# Epoch 196/200
#  - 2s - loss: 0.0897 - accuracy: 0.9733 - val_loss: 0.4626 - val_accuracy: 0.8667
#
# Epoch 00196: val_loss did not improve from 0.36229
# Epoch 197/200
#  - 3s - loss: 0.0804 - accuracy: 0.9833 - val_loss: 0.3740 - val_accuracy: 0.8762
#
# Epoch 00197: val_loss did not improve from 0.36229
# Epoch 198/200
#  - 2s - loss: 0.0734 - accuracy: 0.9867 - val_loss: 0.4843 - val_accuracy: 0.8190
#
# Epoch 00198: val_loss did not improve from 0.36229
# Epoch 199/200
#  - 2s - loss: 0.2007 - accuracy: 0.9200 - val_loss: 0.5036 - val_accuracy: 0.8762
#
# Epoch 00199: val_loss did not improve from 0.36229
# Epoch 200/200
#  - 3s - loss: 0.1905 - accuracy: 0.9367 - val_loss: 0.5084 - val_accuracy: 0.7714
#
# Epoch 00200: val_loss did not improve from 0.36229

# %%
# Loading the model that performed the best on the validation set
model_d.load_weights('/content/Model_depthwise_1_shooting.weights.best.hdf5')

# Testing the model on the Test data
(loss, accuracy) = model_d.evaluate(X_test, y_test, batch_size=16, verbose=0)

print('Accuracy on test data: {:.2f}%'.format(accuracy * 100))

# Making the plot larger
plt.figure(figsize=(12, 8))

loss = history.history['loss']                          # Loss on the training data
val_loss = history.history['val_loss']                  # Loss on the validation data
epochs = range(1, 201)

plt.plot(epochs, loss, 'ro-', label='Training Loss')
plt.plot(epochs, val_loss, 'go-', label = 'Validation Loss')
plt.legend()


# Making the plot larger
plt.figure(figsize=(12, 8))

acc = history.history['accuracy']                          # Loss on the training data
val_acc = history.history['val_accuracy']                  # Loss on the validation data
epochs = range(1, 201)

plt.plot(epochs, acc, 'ro-', label='Training Accuracy')
plt.plot(epochs, val_acc, 'go-', label = 'Validation Accuracy')
plt.legend()


y_pred=model_d.predict(X_test)
y_pred=y_pred>0.80
target_names = ['class Normal', 'class Shooting']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
# Accuracy on test data: 92.12%
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                 precision    recall  f1-score   support
#
#   class Normal       0.95      0.85      0.90        97
# class Shooting       0.95      0.73      0.82       106
#
#      micro avg       0.95      0.78      0.86       203
#      macro avg       0.95      0.79      0.86       203
#   weighted avg       0.95      0.78      0.86       203
#    samples avg       0.78      0.78      0.78       203

# %%
model_d = Sequential()

# Adding Alternate convolutional and pooling layers
model_d.add(DepthwiseConv3D( kernel_size=(10, 3, 3),depth_multiplier=2, strides=(1, 1, 1), padding='same', activation='relu', 
                 input_shape=X_train.shape[1:]))
model_d.add(MaxPooling3D(pool_size=2, strides=(1, 2, 2), padding='same'))

model_d.add(DepthwiseConv3D( depth_multiplier=2,kernel_size=(5, 3, 3), strides=(3, 1, 1), padding='valid', activation='relu'))
model_d.add(MaxPooling3D(pool_size=2, strides=(1, 2, 2), padding='same'))

model_d.add(DepthwiseConv3D(depth_multiplier=2, kernel_size=(5, 3, 3), strides=(3, 1, 1), padding='valid', activation='relu'))
model_d.add(MaxPooling3D(pool_size=2, strides=(1, 2, 2), padding='same'))

# A global average pooling layer to get a 1-d vector
# The vector will have a depth (same as number of elements in the vector) of 256
model_d.add(GlobalAveragePooling3D())

# The Global average pooling layer is followed by a fully-connected neural network, with one hidden and one output layer

# Hidden Layer
model_d.add(Dense(32, activation='relu'))

# Output layer
model_d.add(Dense(2, activation='softmax'))

model_d.summary()

from keras.callbacks import ModelCheckpoint

# Compiling the model
model_d.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Saving the model that performed the best on the validation set
checkpoint = ModelCheckpoint(filepath='Model_depthwise_2_shooting.weights.best.hdf5', save_best_only=True, verbose=1)

# Training the model for 40 epochs
history = model_d.fit(X_train, y_train, batch_size=16, epochs=200, 
                    validation_data=(X_valid, y_valid), verbose=2, callbacks=[checkpoint])

# Loading the model that performed the best on the validation set
model_d.load_weights('/content/Model_depthwise_2_shooting.weights.best.hdf5')

# Testing the model on the Test data
(loss, accuracy) = model_d.evaluate(X_test, y_test, batch_size=16, verbose=0)

print('Accuracy on test data: {:.2f}%'.format(accuracy * 100))

# Making the plot larger
plt.figure(figsize=(12, 8))

loss = history.history['loss']                          # Loss on the training data
val_loss = history.history['val_loss']                  # Loss on the validation data
epochs = range(1, 201)

plt.plot(epochs, loss, 'ro-', label='Training Loss')
plt.plot(epochs, val_loss, 'go-', label = 'Validation Loss')
plt.legend()


# Making the plot larger
plt.figure(figsize=(12, 8))

acc = history.history['accuracy']                          # Loss on the training data
val_acc = history.history['val_accuracy']                  # Loss on the validation data
epochs = range(1, 201)

plt.plot(epochs, acc, 'ro-', label='Training Accuracy')
plt.plot(epochs, val_acc, 'go-', label = 'Validation Accuracy')
plt.legend()


y_pred=model_d.predict(X_test)
y_pred=y_pred>0.80
target_names = ['class Normal', 'class Shooting']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# depthwise_conv3d_10 (Depthwi (None, 29, 128, 128, 2)   182
# _________________________________________________________________
# max_pooling3d_17 (MaxPooling (None, 29, 64, 64, 2)     0
# _________________________________________________________________
# depthwise_conv3d_11 (Depthwi (None, 9, 62, 62, 4)      184
# _________________________________________________________________
# max_pooling3d_18 (MaxPooling (None, 9, 31, 31, 4)      0
# _________________________________________________________________
# depthwise_conv3d_12 (Depthwi (None, 2, 29, 29, 8)      368
# _________________________________________________________________
# max_pooling3d_19 (MaxPooling (None, 2, 15, 15, 8)      0
# _________________________________________________________________
# global_average_pooling3d_6 ( (None, 8)                 0
# _________________________________________________________________
# dense_11 (Dense)             (None, 32)                288
# _________________________________________________________________
# dense_12 (Dense)             (None, 2)                 66
# =================================================================
# Total params: 1,088
# Trainable params: 1,088
# Non-trainable params: 0
# _________________________________________________________________
# Train on 300 samples, validate on 105 samples
# Epoch 1/200
#  - 3s - loss: 0.6932 - accuracy: 0.4733 - val_loss: 0.6918 - val_accuracy: 0.5905
#
# Epoch 00001: val_loss improved from inf to 0.69184, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 2/200
#  - 2s - loss: 0.6922 - accuracy: 0.5067 - val_loss: 0.6872 - val_accuracy: 0.5333
#
# Epoch 00002: val_loss improved from 0.69184 to 0.68723, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 3/200
#  - 2s - loss: 0.6897 - accuracy: 0.5033 - val_loss: 0.6837 - val_accuracy: 0.5333
#
# Epoch 00003: val_loss improved from 0.68723 to 0.68372, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 4/200
#  - 2s - loss: 0.6894 - accuracy: 0.5033 - val_loss: 0.6800 - val_accuracy: 0.5333
#
# Epoch 00004: val_loss improved from 0.68372 to 0.68004, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 5/200
#  - 2s - loss: 0.6894 - accuracy: 0.5933 - val_loss: 0.6841 - val_accuracy: 0.6095
#
# Epoch 00005: val_loss did not improve from 0.68004
# Epoch 6/200
#  - 2s - loss: 0.6816 - accuracy: 0.5300 - val_loss: 0.6745 - val_accuracy: 0.5143
#
# Epoch 00006: val_loss improved from 0.68004 to 0.67455, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 7/200
#  - 2s - loss: 0.6726 - accuracy: 0.6400 - val_loss: 0.6717 - val_accuracy: 0.5905
#
# Epoch 00007: val_loss improved from 0.67455 to 0.67174, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 8/200
#  - 2s - loss: 0.6614 - accuracy: 0.5967 - val_loss: 0.6704 - val_accuracy: 0.5238
#
# Epoch 00008: val_loss improved from 0.67174 to 0.67044, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 9/200
#  - 2s - loss: 0.6425 - accuracy: 0.6467 - val_loss: 0.6606 - val_accuracy: 0.6000
#
# Epoch 00009: val_loss improved from 0.67044 to 0.66058, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 10/200
#  - 2s - loss: 0.6346 - accuracy: 0.6900 - val_loss: 0.6664 - val_accuracy: 0.5524
#
# Epoch 00010: val_loss did not improve from 0.66058
# Epoch 11/200
#  - 2s - loss: 0.6233 - accuracy: 0.6400 - val_loss: 0.6565 - val_accuracy: 0.5810
#
# Epoch 00011: val_loss improved from 0.66058 to 0.65647, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 12/200
#  - 2s - loss: 0.6172 - accuracy: 0.6700 - val_loss: 0.6537 - val_accuracy: 0.6000
#
# Epoch 00012: val_loss improved from 0.65647 to 0.65374, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 13/200
#  - 2s - loss: 0.6169 - accuracy: 0.6433 - val_loss: 0.6573 - val_accuracy: 0.6476
#
# Epoch 00013: val_loss did not improve from 0.65374
# Epoch 14/200
#  - 2s - loss: 0.6216 - accuracy: 0.6567 - val_loss: 0.6512 - val_accuracy: 0.6190
#
# Epoch 00014: val_loss improved from 0.65374 to 0.65119, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 15/200
#  - 2s - loss: 0.6116 - accuracy: 0.6600 - val_loss: 0.6499 - val_accuracy: 0.6190
#
# Epoch 00015: val_loss improved from 0.65119 to 0.64988, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 16/200
#  - 2s - loss: 0.6029 - accuracy: 0.7000 - val_loss: 0.6778 - val_accuracy: 0.6190
#
# Epoch 00016: val_loss did not improve from 0.64988
# Epoch 17/200
#  - 2s - loss: 0.6081 - accuracy: 0.6500 - val_loss: 0.6511 - val_accuracy: 0.6190
#
# Epoch 00017: val_loss did not improve from 0.64988
# Epoch 18/200
#  - 2s - loss: 0.6042 - accuracy: 0.6833 - val_loss: 0.6502 - val_accuracy: 0.6095
#
# Epoch 00018: val_loss did not improve from 0.64988
# Epoch 19/200
#  - 2s - loss: 0.6099 - accuracy: 0.6867 - val_loss: 0.6484 - val_accuracy: 0.6190
#
# Epoch 00019: val_loss improved from 0.64988 to 0.64840, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 20/200
#  - 2s - loss: 0.5999 - accuracy: 0.6800 - val_loss: 0.6569 - val_accuracy: 0.6000
#
# Epoch 00020: val_loss did not improve from 0.64840
# Epoch 21/200
#  - 2s - loss: 0.6012 - accuracy: 0.6700 - val_loss: 0.6505 - val_accuracy: 0.6000
#
# Epoch 00021: val_loss did not improve from 0.64840
# Epoch 22/200
#  - 2s - loss: 0.5984 - accuracy: 0.7067 - val_loss: 0.6790 - val_accuracy: 0.5810
#
# Epoch 00022: val_loss did not improve from 0.64840
# Epoch 23/200
#  - 2s - loss: 0.6038 - accuracy: 0.6600 - val_loss: 0.6481 - val_accuracy: 0.6095
#
# Epoch 00023: val_loss improved from 0.64840 to 0.64807, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 24/200
#  - 2s - loss: 0.5950 - accuracy: 0.6833 - val_loss: 0.6467 - val_accuracy: 0.6286
#
# Epoch 00024: val_loss improved from 0.64807 to 0.64669, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 25/200
#  - 2s - loss: 0.6009 - accuracy: 0.7033 - val_loss: 0.6653 - val_accuracy: 0.6095
#
# Epoch 00025: val_loss did not improve from 0.64669
# Epoch 26/200
#  - 2s - loss: 0.5949 - accuracy: 0.6867 - val_loss: 0.6462 - val_accuracy: 0.6286
#
# Epoch 00026: val_loss improved from 0.64669 to 0.64624, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 27/200
#  - 2s - loss: 0.5969 - accuracy: 0.7000 - val_loss: 0.6441 - val_accuracy: 0.6286
#
# Epoch 00027: val_loss improved from 0.64624 to 0.64409, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 28/200
#  - 2s - loss: 0.5969 - accuracy: 0.7133 - val_loss: 0.7124 - val_accuracy: 0.5714
#
# Epoch 00028: val_loss did not improve from 0.64409
# Epoch 29/200
#  - 2s - loss: 0.6001 - accuracy: 0.6633 - val_loss: 0.6422 - val_accuracy: 0.6286
#
# Epoch 00029: val_loss improved from 0.64409 to 0.64222, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 30/200
#  - 2s - loss: 0.5887 - accuracy: 0.7033 - val_loss: 0.6711 - val_accuracy: 0.5905
#
# Epoch 00030: val_loss did not improve from 0.64222
# Epoch 31/200
#  - 2s - loss: 0.5942 - accuracy: 0.6767 - val_loss: 0.6418 - val_accuracy: 0.6286
#
# Epoch 00031: val_loss improved from 0.64222 to 0.64184, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 32/200
#  - 2s - loss: 0.5921 - accuracy: 0.6700 - val_loss: 0.6414 - val_accuracy: 0.6095
#
# Epoch 00032: val_loss improved from 0.64184 to 0.64141, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 33/200
#  - 2s - loss: 0.5914 - accuracy: 0.7133 - val_loss: 0.6457 - val_accuracy: 0.6286
#
# Epoch 00033: val_loss did not improve from 0.64141
# Epoch 34/200
#  - 2s - loss: 0.5933 - accuracy: 0.6833 - val_loss: 0.6712 - val_accuracy: 0.5905
#
# Epoch 00034: val_loss did not improve from 0.64141
# Epoch 35/200
#  - 2s - loss: 0.5903 - accuracy: 0.6833 - val_loss: 0.6406 - val_accuracy: 0.6381
#
# Epoch 00035: val_loss improved from 0.64141 to 0.64058, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 36/200
#  - 2s - loss: 0.5888 - accuracy: 0.6733 - val_loss: 0.6381 - val_accuracy: 0.6381
#
# Epoch 00036: val_loss improved from 0.64058 to 0.63814, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 37/200
#  - 2s - loss: 0.5943 - accuracy: 0.7133 - val_loss: 0.6600 - val_accuracy: 0.6000
#
# Epoch 00037: val_loss did not improve from 0.63814
# Epoch 38/200
#  - 2s - loss: 0.5849 - accuracy: 0.7033 - val_loss: 0.6397 - val_accuracy: 0.6095
#
# Epoch 00038: val_loss did not improve from 0.63814
# Epoch 39/200
#  - 2s - loss: 0.5853 - accuracy: 0.7067 - val_loss: 0.6558 - val_accuracy: 0.5905
#
# Epoch 00039: val_loss did not improve from 0.63814
# Epoch 40/200
#  - 2s - loss: 0.5943 - accuracy: 0.6733 - val_loss: 0.6488 - val_accuracy: 0.6286
#
# Epoch 00040: val_loss did not improve from 0.63814
# Epoch 41/200
#  - 2s - loss: 0.5983 - accuracy: 0.6800 - val_loss: 0.6749 - val_accuracy: 0.5905
#
# Epoch 00041: val_loss did not improve from 0.63814
# Epoch 42/200
#  - 2s - loss: 0.5869 - accuracy: 0.6867 - val_loss: 0.6396 - val_accuracy: 0.6381
#
# Epoch 00042: val_loss did not improve from 0.63814
# Epoch 43/200
#  - 2s - loss: 0.5810 - accuracy: 0.7200 - val_loss: 0.6370 - val_accuracy: 0.6476
#
# Epoch 00043: val_loss improved from 0.63814 to 0.63699, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 44/200
#  - 2s - loss: 0.5827 - accuracy: 0.6933 - val_loss: 0.6388 - val_accuracy: 0.6476
#
# Epoch 00044: val_loss did not improve from 0.63699
# Epoch 45/200
#  - 2s - loss: 0.5809 - accuracy: 0.6833 - val_loss: 0.6367 - val_accuracy: 0.6381
#
# Epoch 00045: val_loss improved from 0.63699 to 0.63665, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 46/200
#  - 2s - loss: 0.5856 - accuracy: 0.6900 - val_loss: 0.6394 - val_accuracy: 0.6000
#
# Epoch 00046: val_loss did not improve from 0.63665
# Epoch 47/200
#  - 2s - loss: 0.5962 - accuracy: 0.6800 - val_loss: 0.6369 - val_accuracy: 0.6381
#
# Epoch 00047: val_loss did not improve from 0.63665
# Epoch 48/200
#  - 2s - loss: 0.5919 - accuracy: 0.6900 - val_loss: 0.6816 - val_accuracy: 0.5714
#
# Epoch 00048: val_loss did not improve from 0.63665
# Epoch 49/200
#  - 2s - loss: 0.6098 - accuracy: 0.6900 - val_loss: 0.6420 - val_accuracy: 0.6286
#
# Epoch 00049: val_loss did not improve from 0.63665
# Epoch 50/200
#  - 2s - loss: 0.5840 - accuracy: 0.6900 - val_loss: 0.6324 - val_accuracy: 0.6381
#
# Epoch 00050: val_loss improved from 0.63665 to 0.63240, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 51/200
#  - 2s - loss: 0.5762 - accuracy: 0.7033 - val_loss: 0.6349 - val_accuracy: 0.6381
#
# Epoch 00051: val_loss did not improve from 0.63240
# Epoch 52/200
#  - 2s - loss: 0.5751 - accuracy: 0.7067 - val_loss: 0.6495 - val_accuracy: 0.6095
#
# Epoch 00052: val_loss did not improve from 0.63240
# Epoch 53/200
#  - 2s - loss: 0.5823 - accuracy: 0.6833 - val_loss: 0.6419 - val_accuracy: 0.6190
#
# Epoch 00053: val_loss did not improve from 0.63240
# Epoch 54/200
#  - 2s - loss: 0.5816 - accuracy: 0.6667 - val_loss: 0.6758 - val_accuracy: 0.6476
#
# Epoch 00054: val_loss did not improve from 0.63240
# Epoch 55/200
#  - 2s - loss: 0.5929 - accuracy: 0.6767 - val_loss: 0.6378 - val_accuracy: 0.6286
#
# Epoch 00055: val_loss did not improve from 0.63240
# Epoch 56/200
#  - 2s - loss: 0.5745 - accuracy: 0.7200 - val_loss: 0.6273 - val_accuracy: 0.6476
#
# Epoch 00056: val_loss improved from 0.63240 to 0.62727, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 57/200
#  - 2s - loss: 0.5689 - accuracy: 0.6967 - val_loss: 0.6272 - val_accuracy: 0.6381
#
# Epoch 00057: val_loss improved from 0.62727 to 0.62723, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 58/200
#  - 2s - loss: 0.5611 - accuracy: 0.7000 - val_loss: 0.5966 - val_accuracy: 0.6381
#
# Epoch 00058: val_loss improved from 0.62723 to 0.59661, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 59/200
#  - 2s - loss: 0.5594 - accuracy: 0.7133 - val_loss: 0.6052 - val_accuracy: 0.6095
#
# Epoch 00059: val_loss did not improve from 0.59661
# Epoch 60/200
#  - 2s - loss: 0.5523 - accuracy: 0.7167 - val_loss: 0.6119 - val_accuracy: 0.6381
#
# Epoch 00060: val_loss did not improve from 0.59661
# Epoch 61/200
#  - 2s - loss: 0.5571 - accuracy: 0.7133 - val_loss: 0.5967 - val_accuracy: 0.6000
#
# Epoch 00061: val_loss did not improve from 0.59661
# Epoch 62/200
#  - 2s - loss: 0.5544 - accuracy: 0.7133 - val_loss: 0.6417 - val_accuracy: 0.6095
#
# Epoch 00062: val_loss did not improve from 0.59661
# Epoch 63/200
#  - 2s - loss: 0.5512 - accuracy: 0.7300 - val_loss: 0.6135 - val_accuracy: 0.6476
#
# Epoch 00063: val_loss did not improve from 0.59661
# Epoch 64/200
#  - 2s - loss: 0.5552 - accuracy: 0.7200 - val_loss: 0.5896 - val_accuracy: 0.6095
#
# Epoch 00064: val_loss improved from 0.59661 to 0.58963, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 65/200
#  - 2s - loss: 0.5525 - accuracy: 0.7367 - val_loss: 0.5779 - val_accuracy: 0.6381
#
# Epoch 00065: val_loss improved from 0.58963 to 0.57793, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 66/200
#  - 2s - loss: 0.5455 - accuracy: 0.7233 - val_loss: 0.5944 - val_accuracy: 0.6095
#
# Epoch 00066: val_loss did not improve from 0.57793
# Epoch 67/200
#  - 2s - loss: 0.5376 - accuracy: 0.7267 - val_loss: 0.5920 - val_accuracy: 0.6571
#
# Epoch 00067: val_loss did not improve from 0.57793
# Epoch 68/200
#  - 2s - loss: 0.5393 - accuracy: 0.7633 - val_loss: 0.6137 - val_accuracy: 0.6381
#
# Epoch 00068: val_loss did not improve from 0.57793
# Epoch 69/200
#  - 2s - loss: 0.5426 - accuracy: 0.7267 - val_loss: 0.5994 - val_accuracy: 0.6667
#
# Epoch 00069: val_loss did not improve from 0.57793
# Epoch 70/200
#  - 2s - loss: 0.5335 - accuracy: 0.7467 - val_loss: 0.5687 - val_accuracy: 0.6952
#
# Epoch 00070: val_loss improved from 0.57793 to 0.56867, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 71/200
#  - 2s - loss: 0.5475 - accuracy: 0.7367 - val_loss: 0.6266 - val_accuracy: 0.6667
#
# Epoch 00071: val_loss did not improve from 0.56867
# Epoch 72/200
#  - 2s - loss: 0.5547 - accuracy: 0.7200 - val_loss: 0.6239 - val_accuracy: 0.6190
#
# Epoch 00072: val_loss did not improve from 0.56867
# Epoch 73/200
#  - 2s - loss: 0.5618 - accuracy: 0.6933 - val_loss: 0.6112 - val_accuracy: 0.6476
#
# Epoch 00073: val_loss did not improve from 0.56867
# Epoch 74/200
#  - 2s - loss: 0.5607 - accuracy: 0.6900 - val_loss: 0.6133 - val_accuracy: 0.6381
#
# Epoch 00074: val_loss did not improve from 0.56867
# Epoch 75/200
#  - 2s - loss: 0.5411 - accuracy: 0.7433 - val_loss: 0.6058 - val_accuracy: 0.6381
#
# Epoch 00075: val_loss did not improve from 0.56867
# Epoch 76/200
#  - 2s - loss: 0.5541 - accuracy: 0.7167 - val_loss: 0.6217 - val_accuracy: 0.6571
#
# Epoch 00076: val_loss did not improve from 0.56867
# Epoch 77/200
#  - 2s - loss: 0.5326 - accuracy: 0.7400 - val_loss: 0.6510 - val_accuracy: 0.6095
#
# Epoch 00077: val_loss did not improve from 0.56867
# Epoch 78/200
#  - 2s - loss: 0.5396 - accuracy: 0.7033 - val_loss: 0.5925 - val_accuracy: 0.6190
#
# Epoch 00078: val_loss did not improve from 0.56867
# Epoch 79/200
#  - 2s - loss: 0.5290 - accuracy: 0.7333 - val_loss: 0.6033 - val_accuracy: 0.6571
#
# Epoch 00079: val_loss did not improve from 0.56867
# Epoch 80/200
#  - 2s - loss: 0.5411 - accuracy: 0.7033 - val_loss: 0.6388 - val_accuracy: 0.6286
#
# Epoch 00080: val_loss did not improve from 0.56867
# Epoch 81/200
#  - 2s - loss: 0.5448 - accuracy: 0.7333 - val_loss: 0.6046 - val_accuracy: 0.6381
#
# Epoch 00081: val_loss did not improve from 0.56867
# Epoch 82/200
#  - 2s - loss: 0.5295 - accuracy: 0.7233 - val_loss: 0.5861 - val_accuracy: 0.6571
#
# Epoch 00082: val_loss did not improve from 0.56867
# Epoch 83/200
#  - 2s - loss: 0.5455 - accuracy: 0.7500 - val_loss: 0.5864 - val_accuracy: 0.6476
#
# Epoch 00083: val_loss did not improve from 0.56867
# Epoch 84/200
#  - 2s - loss: 0.5335 - accuracy: 0.7333 - val_loss: 0.6251 - val_accuracy: 0.6571
#
# Epoch 00084: val_loss did not improve from 0.56867
# Epoch 85/200
#  - 2s - loss: 0.5351 - accuracy: 0.7233 - val_loss: 0.5859 - val_accuracy: 0.6381
#
# Epoch 00085: val_loss did not improve from 0.56867
# Epoch 86/200
#  - 2s - loss: 0.5204 - accuracy: 0.7433 - val_loss: 0.5852 - val_accuracy: 0.6095
#
# Epoch 00086: val_loss did not improve from 0.56867
# Epoch 87/200
#  - 2s - loss: 0.5260 - accuracy: 0.7433 - val_loss: 0.5853 - val_accuracy: 0.6571
#
# Epoch 00087: val_loss did not improve from 0.56867
# Epoch 88/200
#  - 2s - loss: 0.5218 - accuracy: 0.7433 - val_loss: 0.5848 - val_accuracy: 0.6286
#
# Epoch 00088: val_loss did not improve from 0.56867
# Epoch 89/200
#  - 2s - loss: 0.5243 - accuracy: 0.7533 - val_loss: 0.5921 - val_accuracy: 0.6667
#
# Epoch 00089: val_loss did not improve from 0.56867
# Epoch 90/200
#  - 2s - loss: 0.5203 - accuracy: 0.7267 - val_loss: 0.5855 - val_accuracy: 0.6571
#
# Epoch 00090: val_loss did not improve from 0.56867
# Epoch 91/200
#  - 2s - loss: 0.5240 - accuracy: 0.7567 - val_loss: 0.5998 - val_accuracy: 0.6190
#
# Epoch 00091: val_loss did not improve from 0.56867
# Epoch 92/200
#  - 2s - loss: 0.5142 - accuracy: 0.7433 - val_loss: 0.5822 - val_accuracy: 0.6571
#
# Epoch 00092: val_loss did not improve from 0.56867
# Epoch 93/200
#  - 2s - loss: 0.5098 - accuracy: 0.7633 - val_loss: 0.5871 - val_accuracy: 0.6286
#
# Epoch 00093: val_loss did not improve from 0.56867
# Epoch 94/200
#  - 2s - loss: 0.5071 - accuracy: 0.7600 - val_loss: 0.5812 - val_accuracy: 0.5905
#
# Epoch 00094: val_loss did not improve from 0.56867
# Epoch 95/200
#  - 2s - loss: 0.5086 - accuracy: 0.7500 - val_loss: 0.5873 - val_accuracy: 0.6286
#
# Epoch 00095: val_loss did not improve from 0.56867
# Epoch 96/200
#  - 2s - loss: 0.5285 - accuracy: 0.7233 - val_loss: 0.6115 - val_accuracy: 0.6571
#
# Epoch 00096: val_loss did not improve from 0.56867
# Epoch 97/200
#  - 2s - loss: 0.5090 - accuracy: 0.7367 - val_loss: 0.5812 - val_accuracy: 0.6286
#
# Epoch 00097: val_loss did not improve from 0.56867
# Epoch 98/200
#  - 2s - loss: 0.5034 - accuracy: 0.7600 - val_loss: 0.6099 - val_accuracy: 0.6571
#
# Epoch 00098: val_loss did not improve from 0.56867
# Epoch 99/200
#  - 2s - loss: 0.5039 - accuracy: 0.7600 - val_loss: 0.6043 - val_accuracy: 0.6667
#
# Epoch 00099: val_loss did not improve from 0.56867
# Epoch 100/200
#  - 2s - loss: 0.5051 - accuracy: 0.7667 - val_loss: 0.5785 - val_accuracy: 0.6286
#
# Epoch 00100: val_loss did not improve from 0.56867
# Epoch 101/200
#  - 2s - loss: 0.5081 - accuracy: 0.7467 - val_loss: 0.5781 - val_accuracy: 0.6190
#
# Epoch 00101: val_loss did not improve from 0.56867
# Epoch 102/200
#  - 2s - loss: 0.4970 - accuracy: 0.7700 - val_loss: 0.6017 - val_accuracy: 0.6381
#
# Epoch 00102: val_loss did not improve from 0.56867
# Epoch 103/200
#  - 2s - loss: 0.5021 - accuracy: 0.7333 - val_loss: 0.5851 - val_accuracy: 0.6476
#
# Epoch 00103: val_loss did not improve from 0.56867
# Epoch 104/200
#  - 2s - loss: 0.4943 - accuracy: 0.7700 - val_loss: 0.5756 - val_accuracy: 0.6286
#
# Epoch 00104: val_loss did not improve from 0.56867
# Epoch 105/200
#  - 2s - loss: 0.5282 - accuracy: 0.7033 - val_loss: 0.5742 - val_accuracy: 0.6286
#
# Epoch 00105: val_loss did not improve from 0.56867
# Epoch 106/200
#  - 2s - loss: 0.5284 - accuracy: 0.7000 - val_loss: 0.6204 - val_accuracy: 0.6381
#
# Epoch 00106: val_loss did not improve from 0.56867
# Epoch 107/200
#  - 2s - loss: 0.5076 - accuracy: 0.7333 - val_loss: 0.6067 - val_accuracy: 0.6571
#
# Epoch 00107: val_loss did not improve from 0.56867
# Epoch 108/200
#  - 2s - loss: 0.4882 - accuracy: 0.7633 - val_loss: 0.5699 - val_accuracy: 0.6095
#
# Epoch 00108: val_loss did not improve from 0.56867
# Epoch 109/200
#  - 2s - loss: 0.4900 - accuracy: 0.7567 - val_loss: 0.6416 - val_accuracy: 0.6381
#
# Epoch 00109: val_loss did not improve from 0.56867
# Epoch 110/200
#  - 2s - loss: 0.5067 - accuracy: 0.7333 - val_loss: 0.6096 - val_accuracy: 0.6476
#
# Epoch 00110: val_loss did not improve from 0.56867
# Epoch 111/200
#  - 2s - loss: 0.4993 - accuracy: 0.7500 - val_loss: 0.5776 - val_accuracy: 0.6381
#
# Epoch 00111: val_loss did not improve from 0.56867
# Epoch 112/200
#  - 2s - loss: 0.4944 - accuracy: 0.7633 - val_loss: 0.5753 - val_accuracy: 0.6190
#
# Epoch 00112: val_loss did not improve from 0.56867
# Epoch 113/200
#  - 2s - loss: 0.4783 - accuracy: 0.7700 - val_loss: 0.5901 - val_accuracy: 0.6571
#
# Epoch 00113: val_loss did not improve from 0.56867
# Epoch 114/200
#  - 2s - loss: 0.4783 - accuracy: 0.7667 - val_loss: 0.5902 - val_accuracy: 0.6476
#
# Epoch 00114: val_loss did not improve from 0.56867
# Epoch 115/200
#  - 2s - loss: 0.4860 - accuracy: 0.7500 - val_loss: 0.5814 - val_accuracy: 0.6095
#
# Epoch 00115: val_loss did not improve from 0.56867
# Epoch 116/200
#  - 2s - loss: 0.4885 - accuracy: 0.7367 - val_loss: 0.5775 - val_accuracy: 0.6286
#
# Epoch 00116: val_loss did not improve from 0.56867
# Epoch 117/200
#  - 2s - loss: 0.4833 - accuracy: 0.7367 - val_loss: 0.5621 - val_accuracy: 0.6381
#
# Epoch 00117: val_loss improved from 0.56867 to 0.56210, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 118/200
#  - 2s - loss: 0.4780 - accuracy: 0.7500 - val_loss: 0.6044 - val_accuracy: 0.6381
#
# Epoch 00118: val_loss did not improve from 0.56210
# Epoch 119/200
#  - 2s - loss: 0.4853 - accuracy: 0.7467 - val_loss: 0.5582 - val_accuracy: 0.6476
#
# Epoch 00119: val_loss improved from 0.56210 to 0.55823, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 120/200
#  - 2s - loss: 0.4785 - accuracy: 0.7500 - val_loss: 0.5634 - val_accuracy: 0.6286
#
# Epoch 00120: val_loss did not improve from 0.55823
# Epoch 121/200
#  - 2s - loss: 0.4848 - accuracy: 0.7900 - val_loss: 0.5808 - val_accuracy: 0.6571
#
# Epoch 00121: val_loss did not improve from 0.55823
# Epoch 122/200
#  - 2s - loss: 0.4664 - accuracy: 0.7667 - val_loss: 0.5722 - val_accuracy: 0.6476
#
# Epoch 00122: val_loss did not improve from 0.55823
# Epoch 123/200
#  - 2s - loss: 0.5149 - accuracy: 0.7267 - val_loss: 0.5605 - val_accuracy: 0.6286
#
# Epoch 00123: val_loss did not improve from 0.55823
# Epoch 124/200
#  - 2s - loss: 0.4946 - accuracy: 0.7733 - val_loss: 0.5599 - val_accuracy: 0.6762
#
# Epoch 00124: val_loss did not improve from 0.55823
# Epoch 125/200
#  - 2s - loss: 0.4679 - accuracy: 0.7600 - val_loss: 0.5476 - val_accuracy: 0.6476
#
# Epoch 00125: val_loss improved from 0.55823 to 0.54765, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 126/200
#  - 2s - loss: 0.4587 - accuracy: 0.7700 - val_loss: 0.5463 - val_accuracy: 0.6286
#
# Epoch 00126: val_loss improved from 0.54765 to 0.54628, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 127/200
#  - 2s - loss: 0.4848 - accuracy: 0.7533 - val_loss: 0.5570 - val_accuracy: 0.6667
#
# Epoch 00127: val_loss did not improve from 0.54628
# Epoch 128/200
#  - 2s - loss: 0.4524 - accuracy: 0.7900 - val_loss: 0.5460 - val_accuracy: 0.6286
#
# Epoch 00128: val_loss improved from 0.54628 to 0.54602, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 129/200
#  - 2s - loss: 0.4583 - accuracy: 0.7733 - val_loss: 0.5473 - val_accuracy: 0.6571
#
# Epoch 00129: val_loss did not improve from 0.54602
# Epoch 130/200
#  - 2s - loss: 0.4423 - accuracy: 0.7900 - val_loss: 0.5369 - val_accuracy: 0.7238
#
# Epoch 00130: val_loss improved from 0.54602 to 0.53693, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 131/200
#  - 2s - loss: 0.4589 - accuracy: 0.7633 - val_loss: 0.6187 - val_accuracy: 0.6762
#
# Epoch 00131: val_loss did not improve from 0.53693
# Epoch 132/200
#  - 2s - loss: 0.5363 - accuracy: 0.7067 - val_loss: 0.7665 - val_accuracy: 0.6190
#
# Epoch 00132: val_loss did not improve from 0.53693
# Epoch 133/200
#  - 2s - loss: 0.5308 - accuracy: 0.7267 - val_loss: 0.5424 - val_accuracy: 0.7048
#
# Epoch 00133: val_loss did not improve from 0.53693
# Epoch 134/200
#  - 2s - loss: 0.4495 - accuracy: 0.7867 - val_loss: 0.5412 - val_accuracy: 0.7143
#
# Epoch 00134: val_loss did not improve from 0.53693
# Epoch 135/200
#  - 2s - loss: 0.4497 - accuracy: 0.7733 - val_loss: 0.5736 - val_accuracy: 0.6857
#
# Epoch 00135: val_loss did not improve from 0.53693
# Epoch 136/200
#  - 2s - loss: 0.4414 - accuracy: 0.7633 - val_loss: 0.5337 - val_accuracy: 0.7333
#
# Epoch 00136: val_loss improved from 0.53693 to 0.53365, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 137/200
#  - 2s - loss: 0.4331 - accuracy: 0.7933 - val_loss: 0.5527 - val_accuracy: 0.6762
#
# Epoch 00137: val_loss did not improve from 0.53365
# Epoch 138/200
#  - 2s - loss: 0.4447 - accuracy: 0.7800 - val_loss: 0.5492 - val_accuracy: 0.6571
#
# Epoch 00138: val_loss did not improve from 0.53365
# Epoch 139/200
#  - 2s - loss: 0.4273 - accuracy: 0.7733 - val_loss: 0.5720 - val_accuracy: 0.7048
#
# Epoch 00139: val_loss did not improve from 0.53365
# Epoch 140/200
#  - 2s - loss: 0.4423 - accuracy: 0.7700 - val_loss: 0.5516 - val_accuracy: 0.6571
#
# Epoch 00140: val_loss did not improve from 0.53365
# Epoch 141/200
#  - 2s - loss: 0.4272 - accuracy: 0.8067 - val_loss: 0.5576 - val_accuracy: 0.6762
#
# Epoch 00141: val_loss did not improve from 0.53365
# Epoch 142/200
#  - 2s - loss: 0.4203 - accuracy: 0.7867 - val_loss: 0.5186 - val_accuracy: 0.7333
#
# Epoch 00142: val_loss improved from 0.53365 to 0.51864, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 143/200
#  - 2s - loss: 0.4290 - accuracy: 0.8000 - val_loss: 0.5438 - val_accuracy: 0.6571
#
# Epoch 00143: val_loss did not improve from 0.51864
# Epoch 144/200
#  - 2s - loss: 0.4170 - accuracy: 0.8033 - val_loss: 0.5199 - val_accuracy: 0.6952
#
# Epoch 00144: val_loss did not improve from 0.51864
# Epoch 145/200
#  - 2s - loss: 0.4134 - accuracy: 0.8200 - val_loss: 0.5232 - val_accuracy: 0.6762
#
# Epoch 00145: val_loss did not improve from 0.51864
# Epoch 146/200
#  - 2s - loss: 0.4207 - accuracy: 0.7900 - val_loss: 0.5063 - val_accuracy: 0.7048
#
# Epoch 00146: val_loss improved from 0.51864 to 0.50632, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 147/200
#  - 2s - loss: 0.4227 - accuracy: 0.8000 - val_loss: 0.5484 - val_accuracy: 0.6952
#
# Epoch 00147: val_loss did not improve from 0.50632
# Epoch 148/200
#  - 2s - loss: 0.4348 - accuracy: 0.7700 - val_loss: 0.5661 - val_accuracy: 0.6857
#
# Epoch 00148: val_loss did not improve from 0.50632
# Epoch 149/200
#  - 2s - loss: 0.4222 - accuracy: 0.8033 - val_loss: 0.5268 - val_accuracy: 0.7048
#
# Epoch 00149: val_loss did not improve from 0.50632
# Epoch 150/200
#  - 2s - loss: 0.4116 - accuracy: 0.8033 - val_loss: 0.5326 - val_accuracy: 0.7238
#
# Epoch 00150: val_loss did not improve from 0.50632
# Epoch 151/200
#  - 2s - loss: 0.4144 - accuracy: 0.8033 - val_loss: 0.5251 - val_accuracy: 0.6857
#
# Epoch 00151: val_loss did not improve from 0.50632
# Epoch 152/200
#  - 2s - loss: 0.4214 - accuracy: 0.7967 - val_loss: 0.5253 - val_accuracy: 0.6857
#
# Epoch 00152: val_loss did not improve from 0.50632
# Epoch 153/200
#  - 2s - loss: 0.4221 - accuracy: 0.7900 - val_loss: 0.5425 - val_accuracy: 0.7143
#
# Epoch 00153: val_loss did not improve from 0.50632
# Epoch 154/200
#  - 2s - loss: 0.4187 - accuracy: 0.8000 - val_loss: 0.5234 - val_accuracy: 0.7143
#
# Epoch 00154: val_loss did not improve from 0.50632
# Epoch 155/200
#  - 2s - loss: 0.4164 - accuracy: 0.8100 - val_loss: 0.5865 - val_accuracy: 0.6952
#
# Epoch 00155: val_loss did not improve from 0.50632
# Epoch 156/200
#  - 2s - loss: 0.4403 - accuracy: 0.7733 - val_loss: 0.5236 - val_accuracy: 0.7143
#
# Epoch 00156: val_loss did not improve from 0.50632
# Epoch 157/200
#  - 2s - loss: 0.3997 - accuracy: 0.8000 - val_loss: 0.5356 - val_accuracy: 0.7333
#
# Epoch 00157: val_loss did not improve from 0.50632
# Epoch 158/200
#  - 2s - loss: 0.4169 - accuracy: 0.8000 - val_loss: 0.5518 - val_accuracy: 0.6571
#
# Epoch 00158: val_loss did not improve from 0.50632
# Epoch 159/200
#  - 2s - loss: 0.4388 - accuracy: 0.7867 - val_loss: 0.5885 - val_accuracy: 0.6857
#
# Epoch 00159: val_loss did not improve from 0.50632
# Epoch 160/200
#  - 2s - loss: 0.4295 - accuracy: 0.7833 - val_loss: 0.6215 - val_accuracy: 0.6857
#
# Epoch 00160: val_loss did not improve from 0.50632
# Epoch 161/200
#  - 2s - loss: 0.4224 - accuracy: 0.8000 - val_loss: 0.5286 - val_accuracy: 0.7143
#
# Epoch 00161: val_loss did not improve from 0.50632
# Epoch 162/200
#  - 2s - loss: 0.3989 - accuracy: 0.8067 - val_loss: 0.5299 - val_accuracy: 0.7048
#
# Epoch 00162: val_loss did not improve from 0.50632
# Epoch 163/200
#  - 2s - loss: 0.4050 - accuracy: 0.8100 - val_loss: 0.5072 - val_accuracy: 0.6857
#
# Epoch 00163: val_loss did not improve from 0.50632
# Epoch 164/200
#  - 2s - loss: 0.4126 - accuracy: 0.7933 - val_loss: 0.5268 - val_accuracy: 0.7143
#
# Epoch 00164: val_loss did not improve from 0.50632
# Epoch 165/200
#  - 2s - loss: 0.4299 - accuracy: 0.7867 - val_loss: 0.5588 - val_accuracy: 0.7048
#
# Epoch 00165: val_loss did not improve from 0.50632
# Epoch 166/200
#  - 2s - loss: 0.4177 - accuracy: 0.7967 - val_loss: 0.5638 - val_accuracy: 0.7048
#
# Epoch 00166: val_loss did not improve from 0.50632
# Epoch 167/200
#  - 2s - loss: 0.4198 - accuracy: 0.8000 - val_loss: 0.5449 - val_accuracy: 0.7143
#
# Epoch 00167: val_loss did not improve from 0.50632
# Epoch 168/200
#  - 2s - loss: 0.4050 - accuracy: 0.8167 - val_loss: 0.5171 - val_accuracy: 0.7048
#
# Epoch 00168: val_loss did not improve from 0.50632
# Epoch 169/200
#  - 2s - loss: 0.3968 - accuracy: 0.8067 - val_loss: 0.5245 - val_accuracy: 0.6952
#
# Epoch 00169: val_loss did not improve from 0.50632
# Epoch 170/200
#  - 2s - loss: 0.4000 - accuracy: 0.8167 - val_loss: 0.5235 - val_accuracy: 0.6857
#
# Epoch 00170: val_loss did not improve from 0.50632
# Epoch 171/200
#  - 2s - loss: 0.3965 - accuracy: 0.7867 - val_loss: 0.5197 - val_accuracy: 0.7048
#
# Epoch 00171: val_loss did not improve from 0.50632
# Epoch 172/200
#  - 2s - loss: 0.3919 - accuracy: 0.8167 - val_loss: 0.4970 - val_accuracy: 0.7333
#
# Epoch 00172: val_loss improved from 0.50632 to 0.49701, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 173/200
#  - 2s - loss: 0.3886 - accuracy: 0.8100 - val_loss: 0.5110 - val_accuracy: 0.7619
#
# Epoch 00173: val_loss did not improve from 0.49701
# Epoch 174/200
#  - 2s - loss: 0.3955 - accuracy: 0.8233 - val_loss: 0.5140 - val_accuracy: 0.6952
#
# Epoch 00174: val_loss did not improve from 0.49701
# Epoch 175/200
#  - 2s - loss: 0.3897 - accuracy: 0.8200 - val_loss: 0.4980 - val_accuracy: 0.6952
#
# Epoch 00175: val_loss did not improve from 0.49701
# Epoch 176/200
#  - 2s - loss: 0.3973 - accuracy: 0.8100 - val_loss: 0.6787 - val_accuracy: 0.6667
#
# Epoch 00176: val_loss did not improve from 0.49701
# Epoch 177/200
#  - 2s - loss: 0.4131 - accuracy: 0.8033 - val_loss: 0.5165 - val_accuracy: 0.7048
#
# Epoch 00177: val_loss did not improve from 0.49701
# Epoch 178/200
#  - 2s - loss: 0.3820 - accuracy: 0.8133 - val_loss: 0.7420 - val_accuracy: 0.6857
#
# Epoch 00178: val_loss did not improve from 0.49701
# Epoch 179/200
#  - 2s - loss: 0.4213 - accuracy: 0.8067 - val_loss: 0.5632 - val_accuracy: 0.6952
#
# Epoch 00179: val_loss did not improve from 0.49701
# Epoch 180/200
#  - 2s - loss: 0.4153 - accuracy: 0.7933 - val_loss: 0.5152 - val_accuracy: 0.7333
#
# Epoch 00180: val_loss did not improve from 0.49701
# Epoch 181/200
#  - 2s - loss: 0.3935 - accuracy: 0.8033 - val_loss: 0.5203 - val_accuracy: 0.7048
#
# Epoch 00181: val_loss did not improve from 0.49701
# Epoch 182/200
#  - 2s - loss: 0.3762 - accuracy: 0.8100 - val_loss: 0.4952 - val_accuracy: 0.7333
#
# Epoch 00182: val_loss improved from 0.49701 to 0.49521, saving model to Model_depthwise_2_shooting.weights.best.hdf5
# Epoch 183/200
#  - 2s - loss: 0.3979 - accuracy: 0.8033 - val_loss: 0.5059 - val_accuracy: 0.7619
#
# Epoch 00183: val_loss did not improve from 0.49521
# Epoch 184/200
#  - 2s - loss: 0.3943 - accuracy: 0.8200 - val_loss: 0.5481 - val_accuracy: 0.7333
#
# Epoch 00184: val_loss did not improve from 0.49521
# Epoch 185/200
#  - 2s - loss: 0.3824 - accuracy: 0.8067 - val_loss: 0.5161 - val_accuracy: 0.6762
#
# Epoch 00185: val_loss did not improve from 0.49521
# Epoch 186/200
#  - 2s - loss: 0.4038 - accuracy: 0.8133 - val_loss: 0.5124 - val_accuracy: 0.7619
#
# Epoch 00186: val_loss did not improve from 0.49521
# Epoch 187/200
#  - 2s - loss: 0.4045 - accuracy: 0.8067 - val_loss: 0.5483 - val_accuracy: 0.7238
#
# Epoch 00187: val_loss did not improve from 0.49521
# Epoch 188/200
#  - 2s - loss: 0.4006 - accuracy: 0.8067 - val_loss: 0.5073 - val_accuracy: 0.7524
#
# Epoch 00188: val_loss did not improve from 0.49521
# Epoch 189/200
#  - 2s - loss: 0.3770 - accuracy: 0.8233 - val_loss: 0.5235 - val_accuracy: 0.6857
#
# Epoch 00189: val_loss did not improve from 0.49521
# Epoch 190/200
#  - 2s - loss: 0.3813 - accuracy: 0.8267 - val_loss: 0.5192 - val_accuracy: 0.7714
#
# Epoch 00190: val_loss did not improve from 0.49521
# Epoch 191/200
#  - 2s - loss: 0.3641 - accuracy: 0.8367 - val_loss: 0.5652 - val_accuracy: 0.6762
#
# Epoch 00191: val_loss did not improve from 0.49521
# Epoch 192/200
#  - 2s - loss: 0.4050 - accuracy: 0.7933 - val_loss: 0.5253 - val_accuracy: 0.7429
#
# Epoch 00192: val_loss did not improve from 0.49521
# Epoch 193/200
#  - 2s - loss: 0.4090 - accuracy: 0.8067 - val_loss: 0.5423 - val_accuracy: 0.7238
#
# Epoch 00193: val_loss did not improve from 0.49521
# Epoch 194/200
#  - 2s - loss: 0.3810 - accuracy: 0.8167 - val_loss: 0.5108 - val_accuracy: 0.7524
#
# Epoch 00194: val_loss did not improve from 0.49521
# Epoch 195/200
#  - 2s - loss: 0.3656 - accuracy: 0.8233 - val_loss: 0.5356 - val_accuracy: 0.6571
#
# Epoch 00195: val_loss did not improve from 0.49521
# Epoch 196/200
#  - 2s - loss: 0.3835 - accuracy: 0.8133 - val_loss: 0.5327 - val_accuracy: 0.7619
#
# Epoch 00196: val_loss did not improve from 0.49521
# Epoch 197/200
#  - 2s - loss: 0.3874 - accuracy: 0.8200 - val_loss: 0.5270 - val_accuracy: 0.6857
#
# Epoch 00197: val_loss did not improve from 0.49521
# Epoch 198/200
#  - 2s - loss: 0.3651 - accuracy: 0.8167 - val_loss: 0.5156 - val_accuracy: 0.7429
#
# Epoch 00198: val_loss did not improve from 0.49521
# Epoch 199/200
#  - 2s - loss: 0.3746 - accuracy: 0.8500 - val_loss: 0.4979 - val_accuracy: 0.7619
#
# Epoch 00199: val_loss did not improve from 0.49521
# Epoch 200/200
#  - 2s - loss: 0.3781 - accuracy: 0.8300 - val_loss: 0.5128 - val_accuracy: 0.6952
#
# Epoch 00200: val_loss did not improve from 0.49521
# Accuracy on test data: 76.35%
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                 precision    recall  f1-score   support
#
#   class Normal       0.82      0.58      0.68        97
# class Shooting       0.91      0.37      0.52       106
#
#      micro avg       0.86      0.47      0.61       203
#      macro avg       0.87      0.47      0.60       203
#   weighted avg       0.87      0.47      0.60       203
#    samples avg       0.47      0.47      0.47       203

# %%
model_d = Sequential()

# Adding Alternate convolutional and pooling layers
model_d.add(DepthwiseConv3D( kernel_size=(10, 3, 3),depth_multiplier=2, strides=(1, 1, 1), padding='same', activation='relu', 
                 input_shape=X_train.shape[1:]))
model_d.add(MaxPooling3D(pool_size=2, strides=(1, 2, 2), padding='same'))

model_d.add(DepthwiseConv3D( depth_multiplier=4,kernel_size=(5, 3, 3), strides=(3, 1, 1), padding='valid', activation='relu'))
model_d.add(MaxPooling3D(pool_size=2, strides=(1, 2, 2), padding='same'))

model_d.add(DepthwiseConv3D(depth_multiplier=16, kernel_size=(5, 3, 3), strides=(3, 1, 1), padding='valid', activation='relu'))
model_d.add(MaxPooling3D(pool_size=2, strides=(1, 2, 2), padding='same'))



# A global average pooling layer to get a 1-d vector
# The vector will have a depth (same as number of elements in the vector) of 256
model_d.add(GlobalAveragePooling3D())

# The Global average pooling layer is followed by a fully-connected neural network, with one hidden and one output layer

# Hidden Layer
model_d.add(Dense(32, activation='relu'))

# Output layer
model_d.add(Dense(2, activation='softmax'))

model_d.summary()

from keras.callbacks import ModelCheckpoint

# Compiling the model
model_d.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Saving the model that performed the best on the validation set
checkpoint = ModelCheckpoint(filepath='Model_depthwise_3_shooting.weights.best.hdf5', save_best_only=True, verbose=1)

# Training the model for 40 epochs
history = model_d.fit(X_train, y_train, batch_size=16, epochs=200, 
                    validation_data=(X_valid, y_valid), verbose=2, callbacks=[checkpoint])

# Loading the model that performed the best on the validation set
model_d.load_weights('/content/Model_depthwise_3_shooting.weights.best.hdf5')

# Testing the model on the Test data
(loss, accuracy) = model_d.evaluate(X_test, y_test, batch_size=16, verbose=0)

print('Accuracy on test data: {:.2f}%'.format(accuracy * 100))

# Making the plot larger
plt.figure(figsize=(12, 8))

loss = history.history['loss']                          # Loss on the training data
val_loss = history.history['val_loss']                  # Loss on the validation data
epochs = range(1, 201)

plt.plot(epochs, loss, 'ro-', label='Training Loss')
plt.plot(epochs, val_loss, 'go-', label = 'Validation Loss')
plt.legend()


# Making the plot larger
plt.figure(figsize=(12, 8))

acc = history.history['accuracy']                          # Loss on the training data
val_acc = history.history['val_accuracy']                  # Loss on the validation data
epochs = range(1, 201)

plt.plot(epochs, acc, 'ro-', label='Training Accuracy')
plt.plot(epochs, val_acc, 'go-', label = 'Validation Accuracy')
plt.legend()


y_pred=model_d.predict(X_test)
y_pred=y_pred>0.80
target_names = ['class Normal', 'class Shooting']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# depthwise_conv3d_17 (Depthwi (None, 29, 128, 128, 2)   182
# _________________________________________________________________
# max_pooling3d_23 (MaxPooling (None, 29, 64, 64, 2)     0
# _________________________________________________________________
# depthwise_conv3d_18 (Depthwi (None, 9, 62, 62, 8)      368
# _________________________________________________________________
# max_pooling3d_24 (MaxPooling (None, 9, 31, 31, 8)      0
# _________________________________________________________________
# depthwise_conv3d_19 (Depthwi (None, 2, 29, 29, 128)    5888
# _________________________________________________________________
# max_pooling3d_25 (MaxPooling (None, 2, 15, 15, 128)    0
# _________________________________________________________________
# global_average_pooling3d_7 ( (None, 128)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 32)                4128
# _________________________________________________________________
# dense_14 (Dense)             (None, 2)                 66
# =================================================================
# Total params: 10,632
# Trainable params: 10,632
# Non-trainable params: 0
# _________________________________________________________________
# Train on 300 samples, validate on 105 samples
# Epoch 1/200
#  - 3s - loss: 0.6925 - accuracy: 0.5000 - val_loss: 0.6879 - val_accuracy: 0.5333
#
# Epoch 00001: val_loss improved from inf to 0.68790, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 2/200
#  - 3s - loss: 0.6885 - accuracy: 0.5200 - val_loss: 0.6800 - val_accuracy: 0.5429
#
# Epoch 00002: val_loss improved from 0.68790 to 0.68003, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 3/200
#  - 3s - loss: 0.6810 - accuracy: 0.5367 - val_loss: 0.6693 - val_accuracy: 0.5619
#
# Epoch 00003: val_loss improved from 0.68003 to 0.66930, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 4/200
#  - 2s - loss: 0.6824 - accuracy: 0.5500 - val_loss: 0.6648 - val_accuracy: 0.5619
#
# Epoch 00004: val_loss improved from 0.66930 to 0.66476, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 5/200
#  - 2s - loss: 0.6534 - accuracy: 0.6067 - val_loss: 0.6619 - val_accuracy: 0.6095
#
# Epoch 00005: val_loss improved from 0.66476 to 0.66191, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 6/200
#  - 3s - loss: 0.6394 - accuracy: 0.6367 - val_loss: 0.6364 - val_accuracy: 0.6762
#
# Epoch 00006: val_loss improved from 0.66191 to 0.63637, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 7/200
#  - 2s - loss: 0.6542 - accuracy: 0.6000 - val_loss: 0.6603 - val_accuracy: 0.6095
#
# Epoch 00007: val_loss did not improve from 0.63637
# Epoch 8/200
#  - 2s - loss: 0.6372 - accuracy: 0.6400 - val_loss: 0.6382 - val_accuracy: 0.5714
#
# Epoch 00008: val_loss did not improve from 0.63637
# Epoch 9/200
#  - 2s - loss: 0.6193 - accuracy: 0.6467 - val_loss: 0.6432 - val_accuracy: 0.6571
#
# Epoch 00009: val_loss did not improve from 0.63637
# Epoch 10/200
#  - 2s - loss: 0.6137 - accuracy: 0.6767 - val_loss: 0.6185 - val_accuracy: 0.6571
#
# Epoch 00010: val_loss improved from 0.63637 to 0.61855, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 11/200
#  - 2s - loss: 0.6133 - accuracy: 0.6300 - val_loss: 0.6332 - val_accuracy: 0.6476
#
# Epoch 00011: val_loss did not improve from 0.61855
# Epoch 12/200
#  - 2s - loss: 0.6112 - accuracy: 0.6833 - val_loss: 0.6208 - val_accuracy: 0.6286
#
# Epoch 00012: val_loss did not improve from 0.61855
# Epoch 13/200
#  - 3s - loss: 0.6191 - accuracy: 0.6400 - val_loss: 0.6388 - val_accuracy: 0.5619
#
# Epoch 00013: val_loss did not improve from 0.61855
# Epoch 14/200
#  - 3s - loss: 0.6586 - accuracy: 0.5833 - val_loss: 0.6867 - val_accuracy: 0.6000
#
# Epoch 00014: val_loss did not improve from 0.61855
# Epoch 15/200
#  - 3s - loss: 0.6230 - accuracy: 0.6533 - val_loss: 0.6224 - val_accuracy: 0.6571
#
# Epoch 00015: val_loss did not improve from 0.61855
# Epoch 16/200
#  - 2s - loss: 0.6009 - accuracy: 0.6933 - val_loss: 0.6123 - val_accuracy: 0.6762
#
# Epoch 00016: val_loss improved from 0.61855 to 0.61233, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 17/200
#  - 2s - loss: 0.5939 - accuracy: 0.6867 - val_loss: 0.6080 - val_accuracy: 0.6571
#
# Epoch 00017: val_loss improved from 0.61233 to 0.60795, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 18/200
#  - 2s - loss: 0.6043 - accuracy: 0.6567 - val_loss: 0.6095 - val_accuracy: 0.6571
#
# Epoch 00018: val_loss did not improve from 0.60795
# Epoch 19/200
#  - 2s - loss: 0.5866 - accuracy: 0.7067 - val_loss: 0.6181 - val_accuracy: 0.6381
#
# Epoch 00019: val_loss did not improve from 0.60795
# Epoch 20/200
#  - 2s - loss: 0.5759 - accuracy: 0.6833 - val_loss: 0.6162 - val_accuracy: 0.6190
#
# Epoch 00020: val_loss did not improve from 0.60795
# Epoch 21/200
#  - 2s - loss: 0.5778 - accuracy: 0.6967 - val_loss: 0.6707 - val_accuracy: 0.6095
#
# Epoch 00021: val_loss did not improve from 0.60795
# Epoch 22/200
#  - 3s - loss: 0.5650 - accuracy: 0.6967 - val_loss: 0.6173 - val_accuracy: 0.5714
#
# Epoch 00022: val_loss did not improve from 0.60795
# Epoch 23/200
#  - 2s - loss: 0.5578 - accuracy: 0.7100 - val_loss: 0.6021 - val_accuracy: 0.6286
#
# Epoch 00023: val_loss improved from 0.60795 to 0.60208, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 24/200
#  - 2s - loss: 0.5436 - accuracy: 0.7233 - val_loss: 0.5908 - val_accuracy: 0.6667
#
# Epoch 00024: val_loss improved from 0.60208 to 0.59079, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 25/200
#  - 3s - loss: 0.5404 - accuracy: 0.7233 - val_loss: 0.6039 - val_accuracy: 0.6381
#
# Epoch 00025: val_loss did not improve from 0.59079
# Epoch 26/200
#  - 2s - loss: 0.5338 - accuracy: 0.7433 - val_loss: 0.5837 - val_accuracy: 0.6286
#
# Epoch 00026: val_loss improved from 0.59079 to 0.58369, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 27/200
#  - 2s - loss: 0.5193 - accuracy: 0.7400 - val_loss: 0.5770 - val_accuracy: 0.6381
#
# Epoch 00027: val_loss improved from 0.58369 to 0.57699, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 28/200
#  - 3s - loss: 0.5097 - accuracy: 0.7600 - val_loss: 0.5848 - val_accuracy: 0.6952
#
# Epoch 00028: val_loss did not improve from 0.57699
# Epoch 29/200
#  - 3s - loss: 0.5456 - accuracy: 0.7067 - val_loss: 0.6255 - val_accuracy: 0.6381
#
# Epoch 00029: val_loss did not improve from 0.57699
# Epoch 30/200
#  - 3s - loss: 0.5292 - accuracy: 0.7300 - val_loss: 0.6198 - val_accuracy: 0.6286
#
# Epoch 00030: val_loss did not improve from 0.57699
# Epoch 31/200
#  - 3s - loss: 0.5335 - accuracy: 0.7267 - val_loss: 0.5874 - val_accuracy: 0.6667
#
# Epoch 00031: val_loss did not improve from 0.57699
# Epoch 32/200
#  - 3s - loss: 0.4899 - accuracy: 0.7600 - val_loss: 0.5620 - val_accuracy: 0.6667
#
# Epoch 00032: val_loss improved from 0.57699 to 0.56204, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 33/200
#  - 2s - loss: 0.4708 - accuracy: 0.7700 - val_loss: 0.5474 - val_accuracy: 0.6857
#
# Epoch 00033: val_loss improved from 0.56204 to 0.54737, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 34/200
#  - 3s - loss: 0.4706 - accuracy: 0.7867 - val_loss: 0.5496 - val_accuracy: 0.6857
#
# Epoch 00034: val_loss did not improve from 0.54737
# Epoch 35/200
#  - 2s - loss: 0.4692 - accuracy: 0.7633 - val_loss: 0.5630 - val_accuracy: 0.6952
#
# Epoch 00035: val_loss did not improve from 0.54737
# Epoch 36/200
#  - 2s - loss: 0.4807 - accuracy: 0.7333 - val_loss: 0.5626 - val_accuracy: 0.6571
#
# Epoch 00036: val_loss did not improve from 0.54737
# Epoch 37/200
#  - 3s - loss: 0.4819 - accuracy: 0.7600 - val_loss: 0.5722 - val_accuracy: 0.6667
#
# Epoch 00037: val_loss did not improve from 0.54737
# Epoch 38/200
#  - 2s - loss: 0.4534 - accuracy: 0.7633 - val_loss: 0.5924 - val_accuracy: 0.6571
#
# Epoch 00038: val_loss did not improve from 0.54737
# Epoch 39/200
#  - 2s - loss: 0.4641 - accuracy: 0.7500 - val_loss: 0.5706 - val_accuracy: 0.6952
#
# Epoch 00039: val_loss did not improve from 0.54737
# Epoch 40/200
#  - 3s - loss: 0.4623 - accuracy: 0.7967 - val_loss: 0.5392 - val_accuracy: 0.7238
#
# Epoch 00040: val_loss improved from 0.54737 to 0.53923, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 41/200
#  - 2s - loss: 0.4480 - accuracy: 0.7767 - val_loss: 0.5495 - val_accuracy: 0.6857
#
# Epoch 00041: val_loss did not improve from 0.53923
# Epoch 42/200
#  - 3s - loss: 0.4432 - accuracy: 0.7967 - val_loss: 0.5256 - val_accuracy: 0.7238
#
# Epoch 00042: val_loss improved from 0.53923 to 0.52562, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 43/200
#  - 2s - loss: 0.4380 - accuracy: 0.7867 - val_loss: 0.5343 - val_accuracy: 0.7048
#
# Epoch 00043: val_loss did not improve from 0.52562
# Epoch 44/200
#  - 2s - loss: 0.4323 - accuracy: 0.8000 - val_loss: 0.5099 - val_accuracy: 0.7619
#
# Epoch 00044: val_loss improved from 0.52562 to 0.50993, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 45/200
#  - 3s - loss: 0.4259 - accuracy: 0.7867 - val_loss: 0.5117 - val_accuracy: 0.7238
#
# Epoch 00045: val_loss did not improve from 0.50993
# Epoch 46/200
#  - 2s - loss: 0.4111 - accuracy: 0.8033 - val_loss: 0.5552 - val_accuracy: 0.6952
#
# Epoch 00046: val_loss did not improve from 0.50993
# Epoch 47/200
#  - 2s - loss: 0.4280 - accuracy: 0.7900 - val_loss: 0.5139 - val_accuracy: 0.6952
#
# Epoch 00047: val_loss did not improve from 0.50993
# Epoch 48/200
#  - 2s - loss: 0.4081 - accuracy: 0.8033 - val_loss: 0.4922 - val_accuracy: 0.7333
#
# Epoch 00048: val_loss improved from 0.50993 to 0.49216, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 49/200
#  - 3s - loss: 0.4272 - accuracy: 0.7733 - val_loss: 0.5002 - val_accuracy: 0.7238
#
# Epoch 00049: val_loss did not improve from 0.49216
# Epoch 50/200
#  - 3s - loss: 0.4069 - accuracy: 0.7967 - val_loss: 0.4812 - val_accuracy: 0.7524
#
# Epoch 00050: val_loss improved from 0.49216 to 0.48118, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 51/200
#  - 3s - loss: 0.4043 - accuracy: 0.7900 - val_loss: 0.5211 - val_accuracy: 0.7048
#
# Epoch 00051: val_loss did not improve from 0.48118
# Epoch 52/200
#  - 3s - loss: 0.3814 - accuracy: 0.8133 - val_loss: 0.4849 - val_accuracy: 0.7333
#
# Epoch 00052: val_loss did not improve from 0.48118
# Epoch 53/200
#  - 3s - loss: 0.3932 - accuracy: 0.8133 - val_loss: 0.4650 - val_accuracy: 0.7524
#
# Epoch 00053: val_loss improved from 0.48118 to 0.46496, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 54/200
#  - 2s - loss: 0.3996 - accuracy: 0.8167 - val_loss: 0.4841 - val_accuracy: 0.7333
#
# Epoch 00054: val_loss did not improve from 0.46496
# Epoch 55/200
#  - 2s - loss: 0.3838 - accuracy: 0.8100 - val_loss: 0.4671 - val_accuracy: 0.7333
#
# Epoch 00055: val_loss did not improve from 0.46496
# Epoch 56/200
#  - 3s - loss: 0.3844 - accuracy: 0.8133 - val_loss: 0.4947 - val_accuracy: 0.7333
#
# Epoch 00056: val_loss did not improve from 0.46496
# Epoch 57/200
#  - 2s - loss: 0.3764 - accuracy: 0.8233 - val_loss: 0.4750 - val_accuracy: 0.7524
#
# Epoch 00057: val_loss did not improve from 0.46496
# Epoch 58/200
#  - 2s - loss: 0.3664 - accuracy: 0.8333 - val_loss: 0.4538 - val_accuracy: 0.7810
#
# Epoch 00058: val_loss improved from 0.46496 to 0.45377, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 59/200
#  - 3s - loss: 0.3755 - accuracy: 0.8333 - val_loss: 0.4674 - val_accuracy: 0.7619
#
# Epoch 00059: val_loss did not improve from 0.45377
# Epoch 60/200
#  - 2s - loss: 0.3624 - accuracy: 0.8133 - val_loss: 0.4484 - val_accuracy: 0.7524
#
# Epoch 00060: val_loss improved from 0.45377 to 0.44844, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 61/200
#  - 3s - loss: 0.3536 - accuracy: 0.8233 - val_loss: 0.4703 - val_accuracy: 0.7524
#
# Epoch 00061: val_loss did not improve from 0.44844
# Epoch 62/200
#  - 3s - loss: 0.3539 - accuracy: 0.8300 - val_loss: 0.5213 - val_accuracy: 0.7238
#
# Epoch 00062: val_loss did not improve from 0.44844
# Epoch 63/200
#  - 3s - loss: 0.3701 - accuracy: 0.8267 - val_loss: 0.4652 - val_accuracy: 0.7524
#
# Epoch 00063: val_loss did not improve from 0.44844
# Epoch 64/200
#  - 2s - loss: 0.3823 - accuracy: 0.8133 - val_loss: 0.4508 - val_accuracy: 0.7429
#
# Epoch 00064: val_loss did not improve from 0.44844
# Epoch 65/200
#  - 3s - loss: 0.3484 - accuracy: 0.8367 - val_loss: 0.4453 - val_accuracy: 0.7524
#
# Epoch 00065: val_loss improved from 0.44844 to 0.44530, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 66/200
#  - 2s - loss: 0.3587 - accuracy: 0.8300 - val_loss: 0.4482 - val_accuracy: 0.7810
#
# Epoch 00066: val_loss did not improve from 0.44530
# Epoch 67/200
#  - 2s - loss: 0.3697 - accuracy: 0.8367 - val_loss: 0.4669 - val_accuracy: 0.7333
#
# Epoch 00067: val_loss did not improve from 0.44530
# Epoch 68/200
#  - 2s - loss: 0.3427 - accuracy: 0.8300 - val_loss: 0.4613 - val_accuracy: 0.7333
#
# Epoch 00068: val_loss did not improve from 0.44530
# Epoch 69/200
#  - 2s - loss: 0.3403 - accuracy: 0.8333 - val_loss: 0.4481 - val_accuracy: 0.7619
#
# Epoch 00069: val_loss did not improve from 0.44530
# Epoch 70/200
#  - 3s - loss: 0.3450 - accuracy: 0.8367 - val_loss: 0.5280 - val_accuracy: 0.7429
#
# Epoch 00070: val_loss did not improve from 0.44530
# Epoch 71/200
#  - 2s - loss: 0.4010 - accuracy: 0.7967 - val_loss: 0.4614 - val_accuracy: 0.7524
#
# Epoch 00071: val_loss did not improve from 0.44530
# Epoch 72/200
#  - 2s - loss: 0.3339 - accuracy: 0.8333 - val_loss: 0.4669 - val_accuracy: 0.7714
#
# Epoch 00072: val_loss did not improve from 0.44530
# Epoch 73/200
#  - 3s - loss: 0.3352 - accuracy: 0.8400 - val_loss: 0.4937 - val_accuracy: 0.7619
#
# Epoch 00073: val_loss did not improve from 0.44530
# Epoch 74/200
#  - 2s - loss: 0.3834 - accuracy: 0.8100 - val_loss: 0.5970 - val_accuracy: 0.7048
#
# Epoch 00074: val_loss did not improve from 0.44530
# Epoch 75/200
#  - 2s - loss: 0.3757 - accuracy: 0.8133 - val_loss: 0.4720 - val_accuracy: 0.7333
#
# Epoch 00075: val_loss did not improve from 0.44530
# Epoch 76/200
#  - 2s - loss: 0.3923 - accuracy: 0.8133 - val_loss: 0.5678 - val_accuracy: 0.7238
#
# Epoch 00076: val_loss did not improve from 0.44530
# Epoch 77/200
#  - 3s - loss: 0.3458 - accuracy: 0.8200 - val_loss: 0.4498 - val_accuracy: 0.7429
#
# Epoch 00077: val_loss did not improve from 0.44530
# Epoch 78/200
#  - 3s - loss: 0.3130 - accuracy: 0.8500 - val_loss: 0.4448 - val_accuracy: 0.7524
#
# Epoch 00078: val_loss improved from 0.44530 to 0.44483, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 79/200
#  - 3s - loss: 0.3138 - accuracy: 0.8533 - val_loss: 0.4520 - val_accuracy: 0.7714
#
# Epoch 00079: val_loss did not improve from 0.44483
# Epoch 80/200
#  - 3s - loss: 0.3229 - accuracy: 0.8633 - val_loss: 0.4631 - val_accuracy: 0.7810
#
# Epoch 00080: val_loss did not improve from 0.44483
# Epoch 81/200
#  - 3s - loss: 0.3404 - accuracy: 0.8333 - val_loss: 0.4267 - val_accuracy: 0.8476
#
# Epoch 00081: val_loss improved from 0.44483 to 0.42669, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 82/200
#  - 3s - loss: 0.3109 - accuracy: 0.8667 - val_loss: 0.4724 - val_accuracy: 0.7429
#
# Epoch 00082: val_loss did not improve from 0.42669
# Epoch 83/200
#  - 3s - loss: 0.3207 - accuracy: 0.8333 - val_loss: 0.5125 - val_accuracy: 0.7619
#
# Epoch 00083: val_loss did not improve from 0.42669
# Epoch 84/200
#  - 2s - loss: 0.3186 - accuracy: 0.8467 - val_loss: 0.4847 - val_accuracy: 0.7619
#
# Epoch 00084: val_loss did not improve from 0.42669
# Epoch 85/200
#  - 2s - loss: 0.3039 - accuracy: 0.8700 - val_loss: 0.4399 - val_accuracy: 0.7619
#
# Epoch 00085: val_loss did not improve from 0.42669
# Epoch 86/200
#  - 2s - loss: 0.3011 - accuracy: 0.8800 - val_loss: 0.4432 - val_accuracy: 0.7905
#
# Epoch 00086: val_loss did not improve from 0.42669
# Epoch 87/200
#  - 2s - loss: 0.3282 - accuracy: 0.8300 - val_loss: 0.5105 - val_accuracy: 0.7905
#
# Epoch 00087: val_loss did not improve from 0.42669
# Epoch 88/200
#  - 2s - loss: 0.3035 - accuracy: 0.8700 - val_loss: 0.4644 - val_accuracy: 0.7905
#
# Epoch 00088: val_loss did not improve from 0.42669
# Epoch 89/200
#  - 3s - loss: 0.2970 - accuracy: 0.8733 - val_loss: 0.4389 - val_accuracy: 0.7524
#
# Epoch 00089: val_loss did not improve from 0.42669
# Epoch 90/200
#  - 2s - loss: 0.2916 - accuracy: 0.8633 - val_loss: 0.4471 - val_accuracy: 0.8286
#
# Epoch 00090: val_loss did not improve from 0.42669
# Epoch 91/200
#  - 3s - loss: 0.2822 - accuracy: 0.8733 - val_loss: 0.4885 - val_accuracy: 0.7905
#
# Epoch 00091: val_loss did not improve from 0.42669
# Epoch 92/200
#  - 3s - loss: 0.3131 - accuracy: 0.8700 - val_loss: 0.4860 - val_accuracy: 0.8000
#
# Epoch 00092: val_loss did not improve from 0.42669
# Epoch 93/200
#  - 3s - loss: 0.3068 - accuracy: 0.8633 - val_loss: 0.4599 - val_accuracy: 0.7714
#
# Epoch 00093: val_loss did not improve from 0.42669
# Epoch 94/200
#  - 3s - loss: 0.3002 - accuracy: 0.8567 - val_loss: 0.4428 - val_accuracy: 0.8381
#
# Epoch 00094: val_loss did not improve from 0.42669
# Epoch 95/200
#  - 2s - loss: 0.2888 - accuracy: 0.8667 - val_loss: 0.4575 - val_accuracy: 0.7524
#
# Epoch 00095: val_loss did not improve from 0.42669
# Epoch 96/200
#  - 2s - loss: 0.2951 - accuracy: 0.8700 - val_loss: 0.4415 - val_accuracy: 0.8095
#
# Epoch 00096: val_loss did not improve from 0.42669
# Epoch 97/200
#  - 2s - loss: 0.2759 - accuracy: 0.9000 - val_loss: 0.4825 - val_accuracy: 0.7619
#
# Epoch 00097: val_loss did not improve from 0.42669
# Epoch 98/200
#  - 2s - loss: 0.2734 - accuracy: 0.8833 - val_loss: 0.4431 - val_accuracy: 0.7810
#
# Epoch 00098: val_loss did not improve from 0.42669
# Epoch 99/200
#  - 2s - loss: 0.2897 - accuracy: 0.8633 - val_loss: 0.4537 - val_accuracy: 0.7714
#
# Epoch 00099: val_loss did not improve from 0.42669
# Epoch 100/200
#  - 2s - loss: 0.2758 - accuracy: 0.8900 - val_loss: 0.4471 - val_accuracy: 0.8381
#
# Epoch 00100: val_loss did not improve from 0.42669
# Epoch 101/200
#  - 3s - loss: 0.2610 - accuracy: 0.8767 - val_loss: 0.4545 - val_accuracy: 0.8095
#
# Epoch 00101: val_loss did not improve from 0.42669
# Epoch 102/200
#  - 2s - loss: 0.3006 - accuracy: 0.8700 - val_loss: 0.4540 - val_accuracy: 0.8190
#
# Epoch 00102: val_loss did not improve from 0.42669
# Epoch 103/200
#  - 2s - loss: 0.2692 - accuracy: 0.8800 - val_loss: 0.4708 - val_accuracy: 0.7714
#
# Epoch 00103: val_loss did not improve from 0.42669
# Epoch 104/200
#  - 2s - loss: 0.2687 - accuracy: 0.8967 - val_loss: 0.4237 - val_accuracy: 0.8476
#
# Epoch 00104: val_loss improved from 0.42669 to 0.42368, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 105/200
#  - 2s - loss: 0.2618 - accuracy: 0.9000 - val_loss: 0.4284 - val_accuracy: 0.8095
#
# Epoch 00105: val_loss did not improve from 0.42368
# Epoch 106/200
#  - 2s - loss: 0.2541 - accuracy: 0.9033 - val_loss: 0.4615 - val_accuracy: 0.8190
#
# Epoch 00106: val_loss did not improve from 0.42368
# Epoch 107/200
#  - 2s - loss: 0.2559 - accuracy: 0.8933 - val_loss: 0.4323 - val_accuracy: 0.8095
#
# Epoch 00107: val_loss did not improve from 0.42368
# Epoch 108/200
#  - 2s - loss: 0.2560 - accuracy: 0.9100 - val_loss: 0.4413 - val_accuracy: 0.8571
#
# Epoch 00108: val_loss did not improve from 0.42368
# Epoch 109/200
#  - 2s - loss: 0.2391 - accuracy: 0.9200 - val_loss: 0.4466 - val_accuracy: 0.8381
#
# Epoch 00109: val_loss did not improve from 0.42368
# Epoch 110/200
#  - 2s - loss: 0.2395 - accuracy: 0.9100 - val_loss: 0.4423 - val_accuracy: 0.8286
#
# Epoch 00110: val_loss did not improve from 0.42368
# Epoch 111/200
#  - 2s - loss: 0.2442 - accuracy: 0.9033 - val_loss: 0.4412 - val_accuracy: 0.8190
#
# Epoch 00111: val_loss did not improve from 0.42368
# Epoch 112/200
#  - 2s - loss: 0.2525 - accuracy: 0.8967 - val_loss: 0.4909 - val_accuracy: 0.7524
#
# Epoch 00112: val_loss did not improve from 0.42368
# Epoch 113/200
#  - 2s - loss: 0.2709 - accuracy: 0.8700 - val_loss: 0.4484 - val_accuracy: 0.8381
#
# Epoch 00113: val_loss did not improve from 0.42368
# Epoch 114/200
#  - 2s - loss: 0.2333 - accuracy: 0.9167 - val_loss: 0.4345 - val_accuracy: 0.8381
#
# Epoch 00114: val_loss did not improve from 0.42368
# Epoch 115/200
#  - 2s - loss: 0.2365 - accuracy: 0.9200 - val_loss: 0.4291 - val_accuracy: 0.8476
#
# Epoch 00115: val_loss did not improve from 0.42368
# Epoch 116/200
#  - 2s - loss: 0.2397 - accuracy: 0.9167 - val_loss: 0.4318 - val_accuracy: 0.8476
#
# Epoch 00116: val_loss did not improve from 0.42368
# Epoch 117/200
#  - 2s - loss: 0.2248 - accuracy: 0.9167 - val_loss: 0.4493 - val_accuracy: 0.8286
#
# Epoch 00117: val_loss did not improve from 0.42368
# Epoch 118/200
#  - 2s - loss: 0.2392 - accuracy: 0.9200 - val_loss: 0.4493 - val_accuracy: 0.8381
#
# Epoch 00118: val_loss did not improve from 0.42368
# Epoch 119/200
#  - 2s - loss: 0.2171 - accuracy: 0.9233 - val_loss: 0.4167 - val_accuracy: 0.8571
#
# Epoch 00119: val_loss improved from 0.42368 to 0.41674, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 120/200
#  - 2s - loss: 0.2719 - accuracy: 0.8733 - val_loss: 0.5152 - val_accuracy: 0.8190
#
# Epoch 00120: val_loss did not improve from 0.41674
# Epoch 121/200
#  - 2s - loss: 0.2305 - accuracy: 0.9033 - val_loss: 0.4165 - val_accuracy: 0.8381
#
# Epoch 00121: val_loss improved from 0.41674 to 0.41651, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 122/200
#  - 2s - loss: 0.2164 - accuracy: 0.9333 - val_loss: 0.4805 - val_accuracy: 0.8095
#
# Epoch 00122: val_loss did not improve from 0.41651
# Epoch 123/200
#  - 2s - loss: 0.2428 - accuracy: 0.9067 - val_loss: 0.4263 - val_accuracy: 0.8476
#
# Epoch 00123: val_loss did not improve from 0.41651
# Epoch 124/200
#  - 2s - loss: 0.2212 - accuracy: 0.9133 - val_loss: 0.4088 - val_accuracy: 0.8476
#
# Epoch 00124: val_loss improved from 0.41651 to 0.40878, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 125/200
#  - 2s - loss: 0.2088 - accuracy: 0.9367 - val_loss: 0.4262 - val_accuracy: 0.8571
#
# Epoch 00125: val_loss did not improve from 0.40878
# Epoch 126/200
#  - 2s - loss: 0.2288 - accuracy: 0.9200 - val_loss: 0.4271 - val_accuracy: 0.8571
#
# Epoch 00126: val_loss did not improve from 0.40878
# Epoch 127/200
#  - 2s - loss: 0.2328 - accuracy: 0.9067 - val_loss: 0.4349 - val_accuracy: 0.8571
#
# Epoch 00127: val_loss did not improve from 0.40878
# Epoch 128/200
#  - 2s - loss: 0.2800 - accuracy: 0.8833 - val_loss: 0.4307 - val_accuracy: 0.8286
#
# Epoch 00128: val_loss did not improve from 0.40878
# Epoch 129/200
#  - 2s - loss: 0.2478 - accuracy: 0.8900 - val_loss: 0.6159 - val_accuracy: 0.7429
#
# Epoch 00129: val_loss did not improve from 0.40878
# Epoch 130/200
#  - 2s - loss: 0.2735 - accuracy: 0.8833 - val_loss: 0.4186 - val_accuracy: 0.8762
#
# Epoch 00130: val_loss did not improve from 0.40878
# Epoch 131/200
#  - 2s - loss: 0.2455 - accuracy: 0.9100 - val_loss: 0.4625 - val_accuracy: 0.8000
#
# Epoch 00131: val_loss did not improve from 0.40878
# Epoch 132/200
#  - 2s - loss: 0.2808 - accuracy: 0.8700 - val_loss: 0.5434 - val_accuracy: 0.7524
#
# Epoch 00132: val_loss did not improve from 0.40878
# Epoch 133/200
#  - 2s - loss: 0.2507 - accuracy: 0.9133 - val_loss: 0.4232 - val_accuracy: 0.8190
#
# Epoch 00133: val_loss did not improve from 0.40878
# Epoch 134/200
#  - 2s - loss: 0.2193 - accuracy: 0.9167 - val_loss: 0.4858 - val_accuracy: 0.8190
#
# Epoch 00134: val_loss did not improve from 0.40878
# Epoch 135/200
#  - 2s - loss: 0.2130 - accuracy: 0.9333 - val_loss: 0.4311 - val_accuracy: 0.8571
#
# Epoch 00135: val_loss did not improve from 0.40878
# Epoch 136/200
#  - 2s - loss: 0.1886 - accuracy: 0.9467 - val_loss: 0.4132 - val_accuracy: 0.8762
#
# Epoch 00136: val_loss did not improve from 0.40878
# Epoch 137/200
#  - 2s - loss: 0.2063 - accuracy: 0.9333 - val_loss: 0.4105 - val_accuracy: 0.8857
#
# Epoch 00137: val_loss did not improve from 0.40878
# Epoch 138/200
#  - 2s - loss: 0.1938 - accuracy: 0.9300 - val_loss: 0.4598 - val_accuracy: 0.8571
#
# Epoch 00138: val_loss did not improve from 0.40878
# Epoch 139/200
#  - 2s - loss: 0.1886 - accuracy: 0.9367 - val_loss: 0.4244 - val_accuracy: 0.8476
#
# Epoch 00139: val_loss did not improve from 0.40878
# Epoch 140/200
#  - 2s - loss: 0.2114 - accuracy: 0.9267 - val_loss: 0.4270 - val_accuracy: 0.8476
#
# Epoch 00140: val_loss did not improve from 0.40878
# Epoch 141/200
#  - 2s - loss: 0.1839 - accuracy: 0.9333 - val_loss: 0.4203 - val_accuracy: 0.8762
#
# Epoch 00141: val_loss did not improve from 0.40878
# Epoch 142/200
#  - 2s - loss: 0.1951 - accuracy: 0.9300 - val_loss: 0.4856 - val_accuracy: 0.8571
#
# Epoch 00142: val_loss did not improve from 0.40878
# Epoch 143/200
#  - 2s - loss: 0.2333 - accuracy: 0.8900 - val_loss: 0.4524 - val_accuracy: 0.8762
#
# Epoch 00143: val_loss did not improve from 0.40878
# Epoch 144/200
#  - 2s - loss: 0.2223 - accuracy: 0.9167 - val_loss: 0.4221 - val_accuracy: 0.8667
#
# Epoch 00144: val_loss did not improve from 0.40878
# Epoch 145/200
#  - 2s - loss: 0.2032 - accuracy: 0.9400 - val_loss: 0.4303 - val_accuracy: 0.8762
#
# Epoch 00145: val_loss did not improve from 0.40878
# Epoch 146/200
#  - 2s - loss: 0.1877 - accuracy: 0.9367 - val_loss: 0.4156 - val_accuracy: 0.8762
#
# Epoch 00146: val_loss did not improve from 0.40878
# Epoch 147/200
#  - 2s - loss: 0.1781 - accuracy: 0.9533 - val_loss: 0.3949 - val_accuracy: 0.8952
#
# Epoch 00147: val_loss improved from 0.40878 to 0.39491, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 148/200
#  - 2s - loss: 0.1797 - accuracy: 0.9467 - val_loss: 0.4198 - val_accuracy: 0.8762
#
# Epoch 00148: val_loss did not improve from 0.39491
# Epoch 149/200
#  - 2s - loss: 0.1911 - accuracy: 0.9367 - val_loss: 0.4370 - val_accuracy: 0.8381
#
# Epoch 00149: val_loss did not improve from 0.39491
# Epoch 150/200
#  - 2s - loss: 0.1966 - accuracy: 0.9200 - val_loss: 0.4121 - val_accuracy: 0.8952
#
# Epoch 00150: val_loss did not improve from 0.39491
# Epoch 151/200
#  - 2s - loss: 0.1752 - accuracy: 0.9533 - val_loss: 0.4122 - val_accuracy: 0.8667
#
# Epoch 00151: val_loss did not improve from 0.39491
# Epoch 152/200
#  - 2s - loss: 0.1680 - accuracy: 0.9467 - val_loss: 0.4153 - val_accuracy: 0.8762
#
# Epoch 00152: val_loss did not improve from 0.39491
# Epoch 153/200
#  - 2s - loss: 0.1749 - accuracy: 0.9600 - val_loss: 0.4049 - val_accuracy: 0.8762
#
# Epoch 00153: val_loss did not improve from 0.39491
# Epoch 154/200
#  - 2s - loss: 0.2111 - accuracy: 0.9167 - val_loss: 0.4309 - val_accuracy: 0.8952
#
# Epoch 00154: val_loss did not improve from 0.39491
# Epoch 155/200
#  - 2s - loss: 0.2079 - accuracy: 0.9233 - val_loss: 0.4267 - val_accuracy: 0.8762
#
# Epoch 00155: val_loss did not improve from 0.39491
# Epoch 156/200
#  - 2s - loss: 0.1790 - accuracy: 0.9433 - val_loss: 0.4553 - val_accuracy: 0.8857
#
# Epoch 00156: val_loss did not improve from 0.39491
# Epoch 157/200
#  - 2s - loss: 0.1752 - accuracy: 0.9433 - val_loss: 0.4942 - val_accuracy: 0.8381
#
# Epoch 00157: val_loss did not improve from 0.39491
# Epoch 158/200
#  - 2s - loss: 0.1580 - accuracy: 0.9500 - val_loss: 0.4129 - val_accuracy: 0.8857
#
# Epoch 00158: val_loss did not improve from 0.39491
# Epoch 159/200
#  - 2s - loss: 0.1456 - accuracy: 0.9567 - val_loss: 0.4230 - val_accuracy: 0.8857
#
# Epoch 00159: val_loss did not improve from 0.39491
# Epoch 160/200
#  - 2s - loss: 0.1479 - accuracy: 0.9467 - val_loss: 0.4172 - val_accuracy: 0.8857
#
# Epoch 00160: val_loss did not improve from 0.39491
# Epoch 161/200
#  - 2s - loss: 0.1539 - accuracy: 0.9567 - val_loss: 0.4319 - val_accuracy: 0.8952
#
# Epoch 00161: val_loss did not improve from 0.39491
# Epoch 162/200
#  - 2s - loss: 0.1637 - accuracy: 0.9500 - val_loss: 0.4316 - val_accuracy: 0.8857
#
# Epoch 00162: val_loss did not improve from 0.39491
# Epoch 163/200
#  - 2s - loss: 0.1521 - accuracy: 0.9533 - val_loss: 0.4135 - val_accuracy: 0.8857
#
# Epoch 00163: val_loss did not improve from 0.39491
# Epoch 164/200
#  - 2s - loss: 0.1521 - accuracy: 0.9500 - val_loss: 0.4547 - val_accuracy: 0.8952
#
# Epoch 00164: val_loss did not improve from 0.39491
# Epoch 165/200
#  - 2s - loss: 0.1418 - accuracy: 0.9567 - val_loss: 0.4324 - val_accuracy: 0.8952
#
# Epoch 00165: val_loss did not improve from 0.39491
# Epoch 166/200
#  - 2s - loss: 0.1466 - accuracy: 0.9600 - val_loss: 0.4221 - val_accuracy: 0.8857
#
# Epoch 00166: val_loss did not improve from 0.39491
# Epoch 167/200
#  - 2s - loss: 0.1462 - accuracy: 0.9467 - val_loss: 0.4638 - val_accuracy: 0.8667
#
# Epoch 00167: val_loss did not improve from 0.39491
# Epoch 168/200
#  - 2s - loss: 0.1328 - accuracy: 0.9600 - val_loss: 0.4196 - val_accuracy: 0.8762
#
# Epoch 00168: val_loss did not improve from 0.39491
# Epoch 169/200
#  - 2s - loss: 0.1401 - accuracy: 0.9500 - val_loss: 0.4869 - val_accuracy: 0.8762
#
# Epoch 00169: val_loss did not improve from 0.39491
# Epoch 170/200
#  - 2s - loss: 0.1527 - accuracy: 0.9533 - val_loss: 0.4044 - val_accuracy: 0.8952
#
# Epoch 00170: val_loss did not improve from 0.39491
# Epoch 171/200
#  - 2s - loss: 0.1403 - accuracy: 0.9567 - val_loss: 0.4289 - val_accuracy: 0.9048
#
# Epoch 00171: val_loss did not improve from 0.39491
# Epoch 172/200
#  - 2s - loss: 0.1410 - accuracy: 0.9600 - val_loss: 0.3935 - val_accuracy: 0.8857
#
# Epoch 00172: val_loss improved from 0.39491 to 0.39353, saving model to Model_depthwise_3_shooting.weights.best.hdf5
# Epoch 173/200
#  - 2s - loss: 0.1863 - accuracy: 0.9200 - val_loss: 0.4803 - val_accuracy: 0.8762
#
# Epoch 00173: val_loss did not improve from 0.39353
# Epoch 174/200
#  - 2s - loss: 0.2055 - accuracy: 0.9267 - val_loss: 0.4229 - val_accuracy: 0.8952
#
# Epoch 00174: val_loss did not improve from 0.39353
# Epoch 175/200
#  - 2s - loss: 0.1447 - accuracy: 0.9467 - val_loss: 0.4781 - val_accuracy: 0.8667
#
# Epoch 00175: val_loss did not improve from 0.39353
# Epoch 176/200
#  - 2s - loss: 0.1395 - accuracy: 0.9500 - val_loss: 0.4201 - val_accuracy: 0.8952
#
# Epoch 00176: val_loss did not improve from 0.39353
# Epoch 177/200
#  - 2s - loss: 0.1325 - accuracy: 0.9600 - val_loss: 0.4677 - val_accuracy: 0.8286
#
# Epoch 00177: val_loss did not improve from 0.39353
# Epoch 178/200
#  - 2s - loss: 0.1383 - accuracy: 0.9533 - val_loss: 0.4850 - val_accuracy: 0.8857
#
# Epoch 00178: val_loss did not improve from 0.39353
# Epoch 179/200
#  - 2s - loss: 0.1493 - accuracy: 0.9233 - val_loss: 0.4761 - val_accuracy: 0.8476
#
# Epoch 00179: val_loss did not improve from 0.39353
# Epoch 180/200
#  - 2s - loss: 0.1550 - accuracy: 0.9433 - val_loss: 0.4456 - val_accuracy: 0.8667
#
# Epoch 00180: val_loss did not improve from 0.39353
# Epoch 181/200
#  - 2s - loss: 0.1361 - accuracy: 0.9500 - val_loss: 0.3993 - val_accuracy: 0.9143
#
# Epoch 00181: val_loss did not improve from 0.39353
# Epoch 182/200
#  - 2s - loss: 0.1215 - accuracy: 0.9733 - val_loss: 0.4694 - val_accuracy: 0.8762
#
# Epoch 00182: val_loss did not improve from 0.39353
# Epoch 183/200
#  - 2s - loss: 0.1206 - accuracy: 0.9733 - val_loss: 0.4152 - val_accuracy: 0.8857
#
# Epoch 00183: val_loss did not improve from 0.39353
# Epoch 184/200
#  - 2s - loss: 0.1269 - accuracy: 0.9533 - val_loss: 0.4466 - val_accuracy: 0.8857
#
# Epoch 00184: val_loss did not improve from 0.39353
# Epoch 185/200
#  - 2s - loss: 0.1277 - accuracy: 0.9600 - val_loss: 0.4285 - val_accuracy: 0.8857
#
# Epoch 00185: val_loss did not improve from 0.39353
# Epoch 186/200
#  - 2s - loss: 0.1262 - accuracy: 0.9633 - val_loss: 0.4139 - val_accuracy: 0.8762
#
# Epoch 00186: val_loss did not improve from 0.39353
# Epoch 187/200
#  - 2s - loss: 0.1190 - accuracy: 0.9767 - val_loss: 0.4237 - val_accuracy: 0.8857
#
# Epoch 00187: val_loss did not improve from 0.39353
# Epoch 188/200
#  - 2s - loss: 0.1176 - accuracy: 0.9600 - val_loss: 0.4524 - val_accuracy: 0.8762
#
# Epoch 00188: val_loss did not improve from 0.39353
# Epoch 189/200
#  - 2s - loss: 0.1055 - accuracy: 0.9733 - val_loss: 0.4375 - val_accuracy: 0.8762
#
# Epoch 00189: val_loss did not improve from 0.39353
# Epoch 190/200
#  - 2s - loss: 0.1087 - accuracy: 0.9700 - val_loss: 0.4550 - val_accuracy: 0.8667
#
# Epoch 00190: val_loss did not improve from 0.39353
# Epoch 191/200
#  - 2s - loss: 0.1249 - accuracy: 0.9567 - val_loss: 0.4071 - val_accuracy: 0.9143
#
# Epoch 00191: val_loss did not improve from 0.39353
# Epoch 192/200
#  - 2s - loss: 0.1146 - accuracy: 0.9800 - val_loss: 0.4325 - val_accuracy: 0.8857
#
# Epoch 00192: val_loss did not improve from 0.39353
# Epoch 193/200
#  - 2s - loss: 0.1033 - accuracy: 0.9733 - val_loss: 0.4072 - val_accuracy: 0.8952
#
# Epoch 00193: val_loss did not improve from 0.39353
# Epoch 194/200
#  - 2s - loss: 0.1032 - accuracy: 0.9767 - val_loss: 0.4695 - val_accuracy: 0.8476
#
# Epoch 00194: val_loss did not improve from 0.39353
# Epoch 195/200
#  - 2s - loss: 0.1122 - accuracy: 0.9700 - val_loss: 0.4069 - val_accuracy: 0.9238
#
# Epoch 00195: val_loss did not improve from 0.39353
# Epoch 196/200
#  - 2s - loss: 0.1378 - accuracy: 0.9467 - val_loss: 0.4914 - val_accuracy: 0.8476
#
# Epoch 00196: val_loss did not improve from 0.39353
# Epoch 197/200
#  - 2s - loss: 0.1290 - accuracy: 0.9433 - val_loss: 0.4154 - val_accuracy: 0.8857
#
# Epoch 00197: val_loss did not improve from 0.39353
# Epoch 198/200
#  - 2s - loss: 0.1135 - accuracy: 0.9667 - val_loss: 0.4610 - val_accuracy: 0.8952
#
# Epoch 00198: val_loss did not improve from 0.39353
# Epoch 199/200
#  - 2s - loss: 0.1102 - accuracy: 0.9667 - val_loss: 0.4285 - val_accuracy: 0.9048
#
# Epoch 00199: val_loss did not improve from 0.39353
# Epoch 200/200
#  - 2s - loss: 0.1085 - accuracy: 0.9667 - val_loss: 0.4601 - val_accuracy: 0.8476
#
# Epoch 00200: val_loss did not improve from 0.39353
# Accuracy on test data: 90.64%
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                 precision    recall  f1-score   support
#
#   class Normal       0.92      0.71      0.80        97
# class Shooting       0.94      0.73      0.82       106
#
#      micro avg       0.93      0.72      0.81       203
#      macro avg       0.93      0.72      0.81       203
#   weighted avg       0.93      0.72      0.81       203
#    samples avg       0.72      0.72      0.72       203

# %%
# !mkdir "/content/gdrive/My Drive/Security Dataset/Shooting"
# !cp -r "/content/curated_dataset" "/content/gdrive/My Drive/Security Dataset/Shooting"

# %%
# !mkdir "/content/gdrive/My Drive/Security Dataset/Shooting/weights"
# !cp -r "/content/Model_depthwise_1_shooting.weights.best.hdf5" "/content/gdrive/My Drive/Security Dataset/Shooting/weights"
# !cp -r "/content/Model_depthwise_2_shooting.weights.best.hdf5" "/content/gdrive/My Drive/Security Dataset/Shooting/weights"
# !cp -r "/content/Model_shooting_1.weights.best.hdf5" "/content/gdrive/My Drive/Security Dataset/Shooting/weights"
# !cp -r "/content/Model_shooting_2_larger_parameters.weights.best.hdf5" "/content/gdrive/My Drive/Security Dataset/Shooting/weights"
